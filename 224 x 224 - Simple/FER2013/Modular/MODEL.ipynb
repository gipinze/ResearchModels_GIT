# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D, concatenate, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
import cv2
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 224
IMG_WIDTH = 224
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
with strategy.scope():

   # Define the input shape of the images
   input_shape = (224, 224, 3)

   # Define the convolutional module
   def conv_module(inputs, filters, kernel_size, activation='relu'):
      x = Conv2D(filters, kernel_size, padding='same', activation=activation)(inputs)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      return x

   # Define the fully connected module
   def fc_module(inputs, units, dropout_rate=0.5, activation='relu'):
      x = Dense(units, activation=activation)(inputs)
      x = Dropout(dropout_rate)(x)
      return x

   # Define the input layer
   inputs = Input(shape=input_shape)

   # Define the local feature sub-network
   conv1_local = conv_module(inputs, 32, (3, 3))
   conv2_local = conv_module(conv1_local, 64, (3, 3))
   conv3_local = conv_module(conv2_local, 128, (3, 3))
   flatten_local = Flatten()(conv3_local)
   fc1_local = fc_module(flatten_local, 512)
   fc2_local = fc_module(fc1_local, 256)

   # Define the global feature sub-network
   conv1_global = conv_module(inputs, 32, (5, 5))
   conv2_global = conv_module(conv1_global, 64, (5, 5))
   conv3_global = conv_module(conv2_global, 128, (5, 5))
   flatten_global = Flatten()(conv3_global)
   fc1_global = fc_module(flatten_global, 512)
   fc2_global = fc_module(fc1_global, 256)

   # Concatenate the outputs of the two sub-networks
   merged = concatenate([fc2_local, fc2_global])

   # Define the output layer
   outputs = Dense(7, activation='softmax')(merged)

   # Define the model
   model = Model(inputs=inputs, outputs=outputs)


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 32  2432        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 32  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 64  51264       ['max_pooling2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 128)  204928      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0          ['conv2d_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 128)  0          ['conv2d_5[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['max_pooling2d_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 100352)       0           ['max_pooling2d_5[0][0]']
#
#  dense (Dense)                  (None, 512)          51380736    ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 512)          51380736    ['flatten_1[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['dropout_1[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_4 (Dense)                (None, 7)            3591        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 103,379,591
# Trainable params: 103,379,591
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# from collections import Counter

# counter = Counter(train_generator.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     



# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 1.8060075093867334, 1: 16.54816513761468, 2: 1.7610446668293875, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 448/448 [==============================] - ETA: 0s - loss: 3.4253 - accuracy: 0.1431
# Epoch 1: val_accuracy improved from -inf to 0.15778, saving model to best_model.h5
# 448/448 [==============================] - 526s 1s/step - loss: 3.4253 - accuracy: 0.1431 - val_loss: 1.9353 - val_accuracy: 0.1578 - lr: 1.0000e-04
# Epoch 2/200
# 448/448 [==============================] - ETA: 0s - loss: 3.3802 - accuracy: 0.1806
# Epoch 2: val_accuracy improved from 0.15778 to 0.20452, saving model to best_model.h5
# 448/448 [==============================] - 281s 625ms/step - loss: 3.3802 - accuracy: 0.1806 - val_loss: 1.8956 - val_accuracy: 0.2045 - lr: 1.0000e-04
# Epoch 3/200
# 448/448 [==============================] - ETA: 0s - loss: 3.3498 - accuracy: 0.1940
# Epoch 3: val_accuracy did not improve from 0.20452
# 448/448 [==============================] - 269s 598ms/step - loss: 3.3498 - accuracy: 0.1940 - val_loss: 1.8823 - val_accuracy: 0.1989 - lr: 1.0000e-04
# Epoch 4/200
# 448/448 [==============================] - ETA: 0s - loss: 3.3055 - accuracy: 0.1994
# Epoch 4: val_accuracy did not improve from 0.20452
# 448/448 [==============================] - 270s 603ms/step - loss: 3.3055 - accuracy: 0.1994 - val_loss: 1.8665 - val_accuracy: 0.2009 - lr: 1.0000e-04
# Epoch 5/200
# 448/448 [==============================] - ETA: 0s - loss: 3.2750 - accuracy: 0.2067
# Epoch 5: val_accuracy improved from 0.20452 to 0.22335, saving model to best_model.h5
# 448/448 [==============================] - 271s 604ms/step - loss: 3.2750 - accuracy: 0.2067 - val_loss: 1.8248 - val_accuracy: 0.2234 - lr: 1.0000e-04
# Epoch 6/200
# 448/448 [==============================] - ETA: 0s - loss: 3.2222 - accuracy: 0.2331
# Epoch 6: val_accuracy improved from 0.22335 to 0.23451, saving model to best_model.h5
# 448/448 [==============================] - 274s 610ms/step - loss: 3.2222 - accuracy: 0.2331 - val_loss: 1.7882 - val_accuracy: 0.2345 - lr: 1.0000e-04
# Epoch 7/200
# 448/448 [==============================] - ETA: 0s - loss: 3.1632 - accuracy: 0.2465
# Epoch 7: val_accuracy improved from 0.23451 to 0.24079, saving model to best_model.h5
# 448/448 [==============================] - 271s 605ms/step - loss: 3.1632 - accuracy: 0.2465 - val_loss: 1.7851 - val_accuracy: 0.2408 - lr: 1.0000e-04
# Epoch 8/200
# 448/448 [==============================] - ETA: 0s - loss: 3.1172 - accuracy: 0.2603
# Epoch 8: val_accuracy improved from 0.24079 to 0.33301, saving model to best_model.h5
# 448/448 [==============================] - 270s 601ms/step - loss: 3.1172 - accuracy: 0.2603 - val_loss: 1.6962 - val_accuracy: 0.3330 - lr: 1.0000e-04
# Epoch 9/200
# 448/448 [==============================] - ETA: 0s - loss: 3.0791 - accuracy: 0.2765
# Epoch 9: val_accuracy did not improve from 0.33301
# 448/448 [==============================] - 269s 599ms/step - loss: 3.0791 - accuracy: 0.2765 - val_loss: 1.6929 - val_accuracy: 0.3237 - lr: 1.0000e-04
# Epoch 10/200
# 448/448 [==============================] - ETA: 0s - loss: 3.0414 - accuracy: 0.2962
# Epoch 10: val_accuracy did not improve from 0.33301
# 448/448 [==============================] - 268s 598ms/step - loss: 3.0414 - accuracy: 0.2962 - val_loss: 1.6983 - val_accuracy: 0.3175 - lr: 1.0000e-04
# Epoch 11/200
# 448/448 [==============================] - ETA: 0s - loss: 3.0164 - accuracy: 0.3050
# Epoch 11: val_accuracy improved from 0.33301 to 0.37737, saving model to best_model.h5
# 448/448 [==============================] - 270s 603ms/step - loss: 3.0164 - accuracy: 0.3050 - val_loss: 1.6453 - val_accuracy: 0.3774 - lr: 1.0000e-04
# Epoch 12/200
# 448/448 [==============================] - ETA: 0s - loss: 2.9800 - accuracy: 0.3204
# Epoch 12: val_accuracy improved from 0.37737 to 0.39355, saving model to best_model.h5
# 448/448 [==============================] - 269s 600ms/step - loss: 2.9800 - accuracy: 0.3204 - val_loss: 1.5819 - val_accuracy: 0.3936 - lr: 1.0000e-04
# Epoch 13/200
# 448/448 [==============================] - ETA: 0s - loss: 2.9406 - accuracy: 0.3246
# Epoch 13: val_accuracy improved from 0.39355 to 0.39690, saving model to best_model.h5
# 448/448 [==============================] - 270s 602ms/step - loss: 2.9406 - accuracy: 0.3246 - val_loss: 1.5859 - val_accuracy: 0.3969 - lr: 1.0000e-04
# Epoch 14/200
# 448/448 [==============================] - ETA: 0s - loss: 2.9162 - accuracy: 0.3440
# Epoch 14: val_accuracy improved from 0.39690 to 0.44252, saving model to best_model.h5
# 448/448 [==============================] - 270s 602ms/step - loss: 2.9162 - accuracy: 0.3440 - val_loss: 1.4812 - val_accuracy: 0.4425 - lr: 1.0000e-04
ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 448/448 [==============================] - 264s 590ms/step - loss: 2.1022 - accuracy: 0.5255 - val_loss: 1.1369 - val_accuracy: 0.5624 - lr: 5.0000e-05
# Epoch 82/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0885 - accuracy: 0.5290
# Epoch 82: val_accuracy did not improve from 0.57603
# 448/448 [==============================] - 266s 593ms/step - loss: 2.0885 - accuracy: 0.5290 - val_loss: 1.1159 - val_accuracy: 0.5735 - lr: 2.5000e-05
# Epoch 83/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0807 - accuracy: 0.5314
# Epoch 83: val_accuracy improved from 0.57603 to 0.57729, saving model to best_model.h5
# 448/448 [==============================] - 267s 595ms/step - loss: 2.0807 - accuracy: 0.5314 - val_loss: 1.1120 - val_accuracy: 0.5773 - lr: 2.5000e-05
# Epoch 84/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0619 - accuracy: 0.5316
# Epoch 84: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 264s 590ms/step - loss: 2.0619 - accuracy: 0.5316 - val_loss: 1.1138 - val_accuracy: 0.5753 - lr: 2.5000e-05
# Epoch 85/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0672 - accuracy: 0.5303
# Epoch 85: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 264s 590ms/step - loss: 2.0672 - accuracy: 0.5303 - val_loss: 1.1155 - val_accuracy: 0.5696 - lr: 2.5000e-05
# Epoch 86/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0782 - accuracy: 0.5309
# Epoch 86: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 263s 586ms/step - loss: 2.0782 - accuracy: 0.5309 - val_loss: 1.1066 - val_accuracy: 0.5767 - lr: 2.5000e-05
# Epoch 87/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0785 - accuracy: 0.5297
# Epoch 87: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 259s 578ms/step - loss: 2.0785 - accuracy: 0.5297 - val_loss: 1.1224 - val_accuracy: 0.5713 - lr: 2.5000e-05
# Epoch 88/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0612 - accuracy: 0.5302
# Epoch 88: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 259s 577ms/step - loss: 2.0612 - accuracy: 0.5302 - val_loss: 1.1152 - val_accuracy: 0.5755 - lr: 2.5000e-05
# Epoch 89/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0613 - accuracy: 0.5360
# Epoch 89: val_accuracy did not improve from 0.57729
# 448/448 [==============================] - 259s 577ms/step - loss: 2.0613 - accuracy: 0.5360 - val_loss: 1.1020 - val_accuracy: 0.5763 - lr: 2.5000e-05
# Epoch 90/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0495 - accuracy: 0.5375
# Epoch 90: val_accuracy improved from 0.57729 to 0.58231, saving model to best_model.h5
# 448/448 [==============================] - 260s 579ms/step - loss: 2.0495 - accuracy: 0.5375 - val_loss: 1.0956 - val_accuracy: 0.5823 - lr: 2.5000e-05
# Epoch 91/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0563 - accuracy: 0.5347
# Epoch 91: val_accuracy did not improve from 0.58231
# 448/448 [==============================] - 259s 578ms/step - loss: 2.0563 - accuracy: 0.5347 - val_loss: 1.1124 - val_accuracy: 0.5735 - lr: 2.5000e-05
# Epoch 92/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0570 - accuracy: 0.5365
# Epoch 92: val_accuracy did not improve from 0.58231
# 448/448 [==============================] - 258s 575ms/step - loss: 2.0570 - accuracy: 0.5365 - val_loss: 1.0976 - val_accuracy: 0.5819 - lr: 2.5000e-05
# Epoch 93/200
# 448/448 [==============================] - ETA: 0s - loss: 2.
200
# 448/448 [==============================] - ETA: 0s - loss: 2.0230 - accuracy: 0.5418
# Epoch 105: val_accuracy did not improve from 0.58315
# 448/448 [==============================] - 263s 587ms/step - loss: 2.0230 - accuracy: 0.5418 - val_loss: 1.0973 - val_accuracy: 0.5811 - lr: 1.2500e-05
# Epoch 106/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0176 - accuracy: 0.5431
# Epoch 106: val_accuracy improved from 0.58315 to 0.58454, saving model to best_model.h5
# 448/448 [==============================] - 266s 594ms/step - loss: 2.0176 - accuracy: 0.5431 - val_loss: 1.0953 - val_accuracy: 0.5845 - lr: 1.2500e-05
# Epoch 107/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0271 - accuracy: 0.5401
# Epoch 107: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 263s 585ms/step - loss: 2.0271 - accuracy: 0.5401 - val_loss: 1.0994 - val_accuracy: 0.5811 - lr: 1.2500e-05
# Epoch 108/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0179 - accuracy: 0.5443
# Epoch 108: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 262s 585ms/step - loss: 2.0179 - accuracy: 0.5443 - val_loss: 1.1091 - val_accuracy: 0.5804 - lr: 1.2500e-05
# Epoch 109/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0172 - accuracy: 0.5386
# Epoch 109: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 263s 588ms/step - loss: 2.0172 - accuracy: 0.5386 - val_loss: 1.0892 - val_accuracy: 0.5836 - lr: 1.2500e-05
# Epoch 110/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0020 - accuracy: 0.5407
# Epoch 110: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 264s 588ms/step - loss: 2.0020 - accuracy: 0.5407 - val_loss: 1.0925 - val_accuracy: 0.5819 - lr: 1.2500e-05
# Epoch 111/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0110 - accuracy: 0.5433
# Epoch 111: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 262s 584ms/step - loss: 2.0110 - accuracy: 0.5433 - val_loss: 1.0952 - val_accuracy: 0.5827 - lr: 1.2500e-05
# Epoch 112/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0053 - accuracy: 0.5430
# Epoch 112: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 264s 590ms/step - loss: 2.0053 - accuracy: 0.5430 - val_loss: 1.0996 - val_accuracy: 0.5778 - lr: 1.2500e-05
# Epoch 113/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0245 - accuracy: 0.5440
# Epoch 113: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 264s 589ms/step - loss: 2.0245 - accuracy: 0.5440 - val_loss: 1.0872 - val_accuracy: 0.5834 - lr: 1.2500e-05
# Epoch 114/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0120 - accuracy: 0.5440
# Epoch 114: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 263s 588ms/step - loss: 2.0120 - accuracy: 0.5440 - val_loss: 1.1005 - val_accuracy: 0.5811 - lr: 1.2500e-05
# Epoch 115/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9944 - accuracy: 0.5423
# Epoch 115: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 265s 590ms/step - loss: 1.9944 - accuracy: 0.5423 - val_loss: 1.0987 - val_accuracy: 0.5836 - lr: 1.2500e-05
# Epoch 116/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0174 - accuracy: 0.5425
# Epoch 116: val_accuracy did not improve from 0.58454
# 448/448 [==============================] - 262s 585ms/step - loss: 2.0174 - accuracy: 0.5425 - val_loss: 1.0998 - val_accuracy: 0.5819 - lr: 1.2500e-05
# Epoch 117/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9884 - accuracy: 0.5419
# Epoch 117: val_accuracy improved from 0.58454 to 0.58677, saving model to best_model.h5
# 448/448 [==============================] - 262s 584ms/step - loss: 1.9884 - accuracy: 0.5419 - val_loss: 1.0878 - val_accuracy: 0.5868 - lr: 1.2500e-05
# Epoch 118/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0118 - accuracy: 0.5383
# Epoch 118: val_accuracy did not improve from 0.58677
# 448/448 [==============================] - 259s 576ms/step - loss: 2.0118 - accuracy: 0.5383 - val_loss: 1.0895 - val_accuracy: 0.5844 - lr: 1.2500e-05
# Epoch 119/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0100 - accuracy: 0.5428
# Epoch 119: val_accuracy did not improve from 0.58677
# 448/448 [==============================] - 257s 574ms/step - loss: 2.0100 - accuracy: 0.5428 - val_loss: 1.1006 - val_accuracy: 0.5809 - lr: 1.2500e-05
# Epoch 120/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9882 - accuracy: 0.5468
# Epoch 120: val_accuracy did not improve from 0.58677
# 448/448 [==============================] - 257s 573ms/step - loss: 1.9882 - accuracy: 0.5468 - val_loss: 1.0948 - val_accuracy: 0.5854 - lr: 1.2500e-05
# Epoch 121/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9940 - accuracy: 0.5478
# Epoch 121: val_accuracy did not improve from 0.58677
# 448/448 [==============================] - 258s 575ms/step - loss: 1.9940 - accuracy: 0.5478 - val_loss: 1.0995 - val_accuracy: 0.5818 - lr: 1.2500e-05
# Epoch 122/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0160 - accuracy: 0.5410
# Epoch 122: val_accuracy did not improve from 0.58677
# 448/448 [==============================] - 257s 573ms/step - loss: 2.0160 - accuracy: 0.5410 - val_loss: 1.0950 - val_accuracy: 0.5836 - lr: 1.2500e-05
# Epoch 123/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9987 - accuracy: 0.5440
# Epoch 123: val_accuracy did not improve from 0.58677
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 448/448 [==============================] - 258s 575ms/step - loss: 1.9987 - accuracy: 0.5440 - val_loss: 1.1014 - val_accuracy: 0.5811 - lr: 1.2500e-05
# Epoch 124/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9755 - accuracy: 0.5460
# Epoch 124: val_accuracy improved from 0.58677 to 0.58747, saving model to best_model.h5
# 448/448 [==============================] - 261s 582ms/step - loss: 1.9755 - accuracy: 0.5460 - val_loss: 1.0866 - val_accuracy: 0.5875 - lr: 6.2500e-06
# Epoch 125/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9973 - accuracy: 0.5409
# Epoch 125: val_accuracy did not improve from 0.58747
# 448/448 [==============================] - 256s 571ms/step - loss: 1.9973 - accuracy: 0.5409 - val_loss: 1.0930 - val_accuracy: 0.5841 - lr: 6.2500e-06
# Epoch 126/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9854 - accuracy: 0.5469
# Epoch 126: val_accuracy did not improve from 0.58747
# 448/448 [==============================] - 258s 575ms/step - loss: 1.9854 - accuracy: 0.5469 - val_loss: 1.0912 - val_accuracy: 0.5845 - lr: 6.2500e-06
# Epoch 127/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9931 - accuracy: 0.5468
# Epoch 127: val_accuracy did not improve from 0.58747
# 448/448 [==============================] - 259s 577ms/step - loss: 1.9931 - accuracy: 0.5468 - val_loss: 1.0883 - val_accuracy: 0.5869 - lr: 6.2500e-06
# Epoch 128/200
# 448/448 [==============================] - ETA: 0s - loss: 2.
200
# 448/448 [==============================] - ETA: 0s - loss: 1.9434 - accuracy: 0.5525
# Epoch 168: val_accuracy did not improve from 0.58915
# 448/448 [==============================] - 270s 602ms/step - loss: 1.9434 - accuracy: 0.5525 - val_loss: 1.0865 - val_accuracy: 0.5851 - lr: 3.1250e-06
# Epoch 169/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9680 - accuracy: 0.5464
# Epoch 169: val_accuracy did not improve from 0.58915
#
# Epoch 169: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 448/448 [==============================] - 271s 604ms/step - loss: 1.9680 - accuracy: 0.5464 - val_loss: 1.0947 - val_accuracy: 0.5836 - lr: 3.1250e-06
# Epoch 169: early stopping

# %%
save_model = model.save('Modular_100e_RAFDB_BetterBalance_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 3s 29ms/step
# Accuracy =  0.640625

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 48ms/step
# Accuracy =  0.71875
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.421875

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5831

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 58.31473214285714
# Angry 956/7178 acc: 50.2
# Disgust 111/7178 acc: 71.2
# Fear 1020/7178 acc: 26.1
# Happy 1773/7178 acc: 77.9
# Neutral 1233/7178 acc: 60.2
# Sad 1245/7178 acc: 45.1
# Surprise 830/7178 acc: 80.7

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 58.31473214285714
# Angry 956/7178 acc: 50.2
# Disgust 111/7178 acc: 71.2
# Fear 1020/7178 acc: 26.1
# Happy 1773/7178 acc: 77.9
# Neutral 1233/7178 acc: 60.2
# Sad 1245/7178 acc: 45.1
# Surprise 830/7178 acc: 80.7

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.47      0.50      0.48       956
#      Disgust       0.36      0.71      0.47       111
#         Fear       0.44      0.26      0.33      1020
#        Happy       0.86      0.78      0.82      1773
#      Neutral       0.51      0.60      0.55      1233
#          Sad       0.46      0.45      0.45      1245
#     Surprise       0.66      0.81      0.73       830
#
#     accuracy                           0.58      7168
#    macro avg       0.54      0.59      0.55      7168
# weighted avg       0.59      0.58      0.58      7168

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 449/449 [==============================] - 250s 553ms/step - loss: 1.1363 - accuracy: 0.5683
# 113/113 [==============================] - 7s 55ms/step - loss: 1.0948 - accuracy: 0.5832

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 46ms/step
# Accuracy =  0.671875
# 2/2 [==============================] - 0s 58ms/step
# Accuracy =  0.3125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4883

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 48.828125
# Angry 292/2100 acc: 60.6
# Disgust 290/2100 acc: 3.1
# Fear 295/2100 acc: 8.5
# Happy 290/2100 acc: 84.1
# Neutral 296/2100 acc: 87.2
# Sad 293/2100 acc: 20.1
# Surprise 292/2100 acc: 78.1

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 48.828125
# Angry 292/2100 acc: 60.6
# Disgust 290/2100 acc: 3.1
# Fear 295/2100 acc: 8.5
# Happy 290/2100 acc: 84.1
# Neutral 296/2100 acc: 87.2
# Sad 293/2100 acc: 20.1
# Surprise 292/2100 acc: 78.1

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.52      0.61      0.56       292
#      Disgust       0.69      0.03      0.06       290
#         Fear       0.45      0.08      0.14       295
#        Happy       0.66      0.84      0.74       290
#      Neutral       0.36      0.87      0.51       296
#          Sad       0.42      0.20      0.27       293
#     Surprise       0.54      0.78      0.64       292
#
#     accuracy                           0.49      2048
#    macro avg       0.52      0.49      0.42      2048
# weighted avg       0.52      0.49      0.42      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model (2).h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00005, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 32  2432        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 32  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 64  51264       ['max_pooling2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 128)  204928      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0          ['conv2d_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 128)  0          ['conv2d_5[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['max_pooling2d_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 100352)       0           ['max_pooling2d_5[0][0]']
#
#  dense (Dense)                  (None, 512)          51380736    ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 512)          51380736    ['flatten_1[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['dropout_1[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_4 (Dense)                (None, 7)            3591        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 103,379,591
# Trainable params: 103,379,591
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 2.9525 - accuracy: 0.5971
# Epoch 1: val_accuracy improved from -inf to 0.65185, saving model to best_model.h5
# 167/167 [==============================] - 156s 836ms/step - loss: 2.9525 - accuracy: 0.5971 - val_loss: 1.0024 - val_accuracy: 0.6518 - lr: 5.0000e-05
# Epoch 2/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8957 - accuracy: 0.5993
# Epoch 2: val_accuracy improved from 0.65185 to 0.66659, saving model to best_model.h5
# 167/167 [==============================] - 108s 644ms/step - loss: 2.8957 - accuracy: 0.5993 - val_loss: 0.9848 - val_accuracy: 0.6666 - lr: 5.0000e-05
# Epoch 3/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8640 - accuracy: 0.6061
# Epoch 3: val_accuracy did not improve from 0.66659
# 167/167 [==============================] - 105s 624ms/step - loss: 2.8640 - accuracy: 0.6061 - val_loss: 1.0106 - val_accuracy: 0.6490 - lr: 5.0000e-05
# Epoch 4/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8078 - accuracy: 0.6154
# Epoch 4: val_accuracy did not improve from 0.66659
# 167/167 [==============================] - 105s 626ms/step - loss: 2.8078 - accuracy: 0.6154 - val_loss: 1.0598 - val_accuracy: 0.6351 - lr: 5.0000e-05
# Epoch 5/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8716 - accuracy: 0.6056
# Epoch 5: val_accuracy did not improve from 0.66659
# 167/167 [==============================] - 106s 633ms/step - loss: 2.8716 - accuracy: 0.6056 - val_loss: 1.0427 - val_accuracy: 0.6413 - lr: 5.0000e-05
# Epoch 6/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8369 - accuracy: 0.6085
# Epoch 6: val_accuracy improved from 0.66659 to 0.66967, saving model to best_model.h5
# 167/167 [==============================] - 107s 638ms/step - loss: 2.8369 - accuracy: 0.6085 - val_loss: 0.9672 - val_accuracy: 0.6697 - lr: 5.0000e-05
# Epoch 7/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7911 - accuracy: 0.6128
# Epoch 7: val_accuracy did not improve from 0.66967
# 167/167 [==============================] - 105s 624ms/step - loss: 2.7911 - accuracy: 0.6128 - val_loss: 0.9856 - val_accuracy: 0.6609 - lr: 5.0000e-05
# Epoch 8/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8066 - accuracy: 0.6146
# Epoch 8: val_accuracy did not improve from 0.66967
# 167/167 [==============================] - 104s 622ms/step - loss: 2.8066 - accuracy: 0.6146 - val_loss: 1.0480 - val_accuracy: 0.6331 - lr: 5.0000e-05
# Epoch 9/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7696 - accuracy: 0.6171
# Epoch 9: val_accuracy did not improve from 0.66967
# 167/167 [==============================] - ETA: 0s - loss: 2.4654 - accuracy: 0.6530
# Epoch 43: val_accuracy did not improve from 0.68134
# 167/167 [==============================] - 106s 630ms/step - loss: 2.4654 - accuracy: 0.6530 - val_loss: 1.0096 - val_accuracy: 0.6527 - lr: 1.2500e-05
# Epoch 44/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4726 - accuracy: 0.6546
# Epoch 44: val_accuracy did not improve from 0.68134
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 106s 632ms/step - loss: 2.4726 - accuracy: 0.6546 - val_loss: 0.9906 - val_accuracy: 0.6642 - lr: 1.2500e-05
# Epoch 44: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 28ms/step
# Accuracy =  0.765625

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 50ms/step
# Accuracy =  0.765625
# 2/2 [==============================] - 0s 57ms/step
# Accuracy =  0.546875

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6635

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 66.3512323943662
# Angry 258/4606 acc: 66.7
# Disgust 260/4606 acc: 49.2
# Fear 105/4606 acc: 50.5
# Happy 1762/4606 acc: 69.7
# Neutral 956/4606 acc: 65.5
# Sad 725/4606 acc: 58.1
# Surprise 478/4606 acc: 81.0

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 66.3512323943662
# Angry 258/4606 acc: 66.7
# Disgust 260/4606 acc: 49.2
# Fear 105/4606 acc: 50.5
# Happy 1762/4606 acc: 69.7
# Neutral 956/4606 acc: 65.5
# Sad 725/4606 acc: 58.1
# Surprise 478/4606 acc: 81.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.51      0.67      0.58       258
#      Disgust       0.28      0.49      0.36       260
#         Fear       0.34      0.50      0.40       105
#        Happy       0.94      0.70      0.80      1762
#      Neutral       0.62      0.65      0.64       956
#          Sad       0.63      0.58      0.60       725
#     Surprise       0.63      0.81      0.71       478
#
#     accuracy                           0.66      4544
#    macro avg       0.56      0.63      0.58      4544
# weighted avg       0.72      0.66      0.68      4544

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 46ms/step
# Accuracy =  0.609375
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.359375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4819

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# Accuracy: 48.193359375
# Angry 298/2100 acc: 57.4
# Disgust 294/2100 acc: 29.9
# Fear 286/2100 acc: 22.0
# Happy 295/2100 acc: 65.4
# Neutral 286/2100 acc: 69.2
# Sad 296/2100 acc: 27.7
# Surprise 293/2100 acc: 65.5

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 48.193359375
# Angry 298/2100 acc: 57.4
# Disgust 294/2100 acc: 29.9
# Fear 286/2100 acc: 22.0
# Happy 295/2100 acc: 65.4
# Neutral 286/2100 acc: 69.2
# Sad 296/2100 acc: 27.7
# Surprise 293/2100 acc: 65.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.48      0.57      0.52       298
#      Disgust       0.55      0.30      0.39       294
#         Fear       0.52      0.22      0.31       286
#        Happy       0.76      0.65      0.70       295
#      Neutral       0.46      0.69      0.55       286
#          Sad       0.32      0.28      0.30       296
#     Surprise       0.41      0.66      0.50       293
#
#     accuracy                           0.48      2048
#    macro avg       0.50      0.48      0.47      2048
# weighted avg       0.50      0.48      0.47      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
