# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Faces 7/train/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Faces 7/test/'

# %%
IMG_HEIGHT =224
IMG_WIDTH = 224
CHANNELS = 3

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 20778 images belonging to 7 classes.
# Found 5160 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2691</td>
#       <td>1986</td>
#       <td>2628</td>
#       <td>3831</td>
#       <td>3906</td>
#       <td>2540</td>
#       <td>3196</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>662</td>
#       <td>494</td>
#       <td>661</td>
#       <td>960</td>
#       <td>972</td>
#       <td>624</td>
#       <td>787</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 20778
# 5160

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)


# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'anger', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}
# {0: 1.4515050167224082, 1: 1.9667673716012084, 2: 1.4863013698630136, 3: 1.019577133907596, 4: 1.0, 5: 1.537795275590551, 6: 1.2221526908635796}

# %%
class RepVGGBlock(layers.Layer):
      def __init__(self, out_channels, strides, kernel_size, name=None, **kwargs):
         super().__init__(name=name, **kwargs)
         self.out_channels = out_channels
         self.strides = strides
         self.kernel_size = kernel_size
         self.conv1 = Conv2D(out_channels, kernel_size, strides=strides, padding='same', use_bias=False)
         self.bn1 = BatchNormalization()
         self.relu = ReLU()
         self.conv2 = Conv2D(out_channels, kernel_size, padding='same', use_bias=False)
         self.bn2 = BatchNormalization()
         if strides == 1:
               self.identity_map = Activation('linear')
         else:
               self.identity_map = Conv2D(out_channels, kernel_size=1, strides=strides, padding='same', use_bias=False)
         
      def call(self, inputs):
         x = self.conv1(inputs)
         x = self.bn1(x)
         x = self.relu(x)
         x = self.conv2(x)
         x = self.bn2(x)
         identity_map = self.identity_map(inputs)
         return x + identity_map
      
      def get_config(self):
         config = super().get_config()
         config.update({
               'out_channels': self.out_channels,
               'strides': self.strides,
               'kernel_size': self.kernel_size,
         })
         return config

class GradientCheckpointing(layers.Layer):
      def __init__(self, checkpointing_depth, **kwargs):
         super().__init__(**kwargs)
         self.checkpointing_depth = checkpointing_depth

      def get_config(self):
         config = super().get_config()
         config.update({
               "checkpointing_depth": self.checkpointing_depth,
         })
         return config

      def call(self, inputs):
         if self.checkpointing_depth == 0:
               return inputs
         else:
               num_chunks = self.checkpointing_depth + 1
               chunk_size = inputs.shape[-1] // num_chunks
               remainder = inputs.shape[-1] % num_chunks
               if remainder != 0:
                  chunk_size += 1
               chunks = []
               for i in range(num_chunks):
                  start = i * chunk_size
                  end = start + chunk_size
                  if i == num_chunks - 1:
                     end = inputs.shape[-1]
                  chunk = inputs[..., start:end]
                  if i == 0:
                     chunk = tf.identity(chunk)
                  else:
                     chunk = tf.stop_gradient(chunk)
                  chunks.append(chunk)
         return tf.concat(chunks, axis=-1)

def create_repvgg_a0(checkpointing_depth=1):
      inputs = Input(shape=IMAGE_SHAPE)
      x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(inputs)
      x = BatchNormalization()(x)
      x = ReLU()(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=64, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)

      x = GlobalAveragePooling2D()(x)
      outputs = Dense(num_classes, activation='softmax')(x)  # number of classes in VGGFace2 dataset

      model = Model(inputs=inputs, outputs=outputs)

      return model

# %%
with strategy.scope():

    
   model = create_repvgg_a0()


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 112, 112, 64)      1792
#
#  batch_normalization (BatchN  (None, 112, 112, 64)     256
#  ormalization)
#
#  re_lu (ReLU)                (None, 112, 112, 64)      0
#
#  gradient_checkpointing (Gra  (None, 112, 112, 64)     0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 112, 112, 64)     74240
#
#  gradient_checkpointing_1 (G  (None, 112, 112, 64)     0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 56, 56, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 56, 56, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 56, 56, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 56, 56, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 28, 28, 256)      919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 28, 28, 256)      0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 28, 28, 256)      1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 28, 28, 256)      0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 28, 28, 256)      1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 28, 28, 256)      0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 14, 14, 512)      3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 14, 14, 512)      0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 14, 14, 512)      4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 14, 14, 512)      0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 14, 14, 512)      4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 14, 14, 512)      0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 14, 14, 512)      4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 14, 14, 512)      0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 14, 14, 512)      4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 324/324 [==============================] - ETA: 0s - loss: 2.5859 - accuracy: 0.2463
# Epoch 1: val_accuracy improved from -inf to 0.17656, saving model to best_model.h5
# 324/324 [==============================] - 256s 695ms/step - loss: 2.5859 - accuracy: 0.2463 - val_loss: 2.6097 - val_accuracy: 0.1766 - lr: 1.0000e-04
# Epoch 2/300
# 324/324 [==============================] - ETA: 0s - loss: 2.2052 - accuracy: 0.3638
# Epoch 2: val_accuracy improved from 0.17656 to 0.40488, saving model to best_model.h5
# 324/324 [==============================] - 235s 722ms/step - loss: 2.2052 - accuracy: 0.3638 - val_loss: 1.7907 - val_accuracy: 0.4049 - lr: 1.0000e-04
# Epoch 3/300
# 324/324 [==============================] - ETA: 0s - loss: 2.0157 - accuracy: 0.4257
# Epoch 3: val_accuracy did not improve from 0.40488
# 324/324 [==============================] - 235s 724ms/step - loss: 2.0157 - accuracy: 0.4257 - val_loss: 2.1638 - val_accuracy: 0.3387 - lr: 1.0000e-04
# Epoch 4/300
# 324/324 [==============================] - ETA: 0s - loss: 1.8602 - accuracy: 0.4822
# Epoch 4: val_accuracy improved from 0.40488 to 0.44355, saving model to best_model.h5
# 324/324 [==============================] - 236s 727ms/step - loss: 1.8602 - accuracy: 0.4822 - val_loss: 1.4284 - val_accuracy: 0.4436 - lr: 1.0000e-04
# Epoch 5/300
# 324/324 [==============================] - ETA: 0s - loss: 1.7353 - accuracy: 0.5132
# Epoch 5: val_accuracy improved from 0.44355 to 0.50273, saving model to best_model.h5
# 324/324 [==============================] - 239s 736ms/step - loss: 1.7353 - accuracy: 0.5132 - val_loss: 1.3244 - val_accuracy: 0.5027 - lr: 1.0000e-04
# Epoch 6/300
# 324/324 [==============================] - ETA: 0s - loss: 1.6322 - accuracy: 0.5426
# Epoch 6: val_accuracy did not improve from 0.50273
# 324/324 [==============================] - 234s 720ms/step - loss: 1.6322 - accuracy: 0.5426 - val_loss: 1.4878 - val_accuracy: 0.4311 - lr: 1.0000e-04
# Epoch 7/300
# 324/324 [==============================] - ETA: 0s - loss: 1.5524 - accuracy: 0.5663
# Epoch 7: val_accuracy did not improve from 0.50273
# 324/324 [==============================] - 234s 721ms/step - loss: 1.5524 - accuracy: 0.5663 - val_loss: 1.7679 - val_accuracy: 0.4918 - lr: 1.0000e-04
# Epoch 8/300
# 324/324 [==============================] - ETA: 0s - loss: 1.4942 - accuracy: 0.5811
# Epoch 8: val_accuracy improved from 0.50273 to 0.60762, saving model to best_model.h5
# 324/324 [==============================] - 238s 733ms/step - loss: 1.4942 - accuracy: 0.5811 - val_loss: 1.0215 - val_accuracy: 0.6076 - lr: 1.0000e-04
# Epoch 9/300
# 324/324 [==============================] - ETA: 0s - loss: 1.4341 - accuracy: 0.6053
# Epoch 9: val_accuracy did not improve from 0.60762
# 324/324 [==============================] - 239s 736ms/step - loss: 1.4341 - accuracy: 0.6053 - val_loss: 1.1193 - val_accuracy: 0.5820 - lr: 1.0000e-04
# Epoch 10/300
# 324/324 [==============================] - ETA: 0s - loss: 1.3754 - accuracy: 0.6208
# Epoch 10: val_accuracy did not improve from 0.60762
# 324/324 [==============================] - 238s 734ms/step - loss: 1.3754 - accuracy: 0.6208 - val_loss: 1.7456 - val_accuracy: 0.4152 - lr: 1.0000e-04
# Epoch 11/300
# 324/324 [==============================] - ETA: 0s - loss: 1.3477 - accuracy: 0.6297
# Epoch 11: val_accuracy improved from 0.60762 to 0.64043, saving model to best_model.h5
# 324/324 [==============================] - 233s 719ms/step - loss: 1.3477 - accuracy: 0.6297 - val_loss: 0.9773 - val_accuracy: 0.6404 - lr: 1.0000e-04
# Epoch 12/300
# 324/324 [==============================] - ETA: 0s - loss: 1.3142 - accuracy: 0.6394
# Epoch 12: val_accuracy improved from 0.64043 to 0.64160, saving model to best_model.h5
# 324/324 [==============================] - 239s 736ms/step - loss: 1.3142 - accuracy: 0.6394 - val_loss: 0.9203 - val_accuracy: 0.6416 - lr: 1.0000e-04
# Epoch 13/300
# 324/324 [==============================] - ETA: 0s - loss: 1.2912 - accuracy: 0.6423
# Epoch 13: val_accuracy did not improve from 0.64160
# 324/324 [==============================] - 234s 721ms/step - loss: 1.2912 - accuracy: 0.6423 - val_loss: 0.9986 - val_accuracy: 0.6246 - lr: 1.0000e-04
# Epoch 14/300
# 324/324 [==============================] - ETA: 0s - loss: 1.2568 - accuracy: 0.6524
# Epoch 14: val_accuracy did not improve from 0.64160
# 324/324 [==============================] - 233s 719ms/step - loss: 1.2568 - accuracy: 0.6524 - val_loss: 1.0399 - val_accuracy: 0.6193 - lr: 1.0000e-04
# Epoch 15/300
# 324/324 [==============================] - ETA: 0s - loss: 1.2342 - accuracy: 0.6574
# Epoch 15: val_accuracy did not improve from 0.64160
# 324/324 [==============================] - 236s 726ms/step - loss: 1.2342 - accuracy: 0.6574 - val_loss: 1.2211 - val_accuracy: 0.5566 - lr: 1.0000e-04
# Epoch 16/300
# 324/324 [==============================] - ETA: 0s - loss: 1.2225 - accuracy: 0.6641
# Epoch 16: val_accuracy improved from 0.64160 to 0.64297, saving model to best_model.h5
# 324/324 [==============================] - 234s 721ms/step - loss: 1.2225 - accuracy: 0.6641 - val_loss: 0.9489 - val_accuracy: 0.6430 - lr: 1.0000e-04
# Epoch 17/300
# 324/324 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.6709
# Epoch 17: val_accuracy did not improve from 0.64297
# 324/324 [==============================] - 234s 721ms/step - loss: 1.2062 - accuracy: 0.6709 - val_loss: 1.1515 - val_accuracy: 0.5941 - lr: 1.0000e-04
# Epoch 18/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1854 - accuracy: 0.6762
# Epoch 18: val_accuracy did not improve from 0.64297
# 324/324 [==============================] - 230s 709ms/step - loss: 1.1854 - accuracy: 0.6762 - val_loss: 0.9957 - val_accuracy: 0.6174 - lr: 1.0000e-04
# Epoch 19/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1681 - accuracy: 0.6811
# Epoch 19: val_accuracy improved from 0.64297 to 0.66855, saving model to best_model.h5
# 324/324 [==============================] - 230s 708ms/step - loss: 1.1681 - accuracy: 0.6811 - val_loss: 0.8658 - val_accuracy: 0.6686 - lr: 1.0000e-04
# Epoch 20/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1544 - accuracy: 0.6846
# Epoch 20: val_accuracy improved from 0.66855 to 0.68340, saving model to best_model.h5
# 324/324 [==============================] - 234s 723ms/step - loss: 1.1544 - accuracy: 0.6846 - val_loss: 0.8245 - val_accuracy: 0.6834 - lr: 1.0000e-04
# Epoch 21/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1374 - accuracy: 0.6902
# Epoch 21: val_accuracy did not improve from 0.68340
# 324/324 [==============================] - 233s 717ms/step - loss: 1.1374 - accuracy: 0.6902 - val_loss: 0.9017 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 22/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1183 - accuracy: 0.6923
# Epoch 22: val_accuracy did not improve from 0.68340
# 324/324 [==============================] - 233s 717ms/step - loss: 1.1183 - accuracy: 0.6923 - val_loss: 1.0207 - val_accuracy: 0.6215 - lr: 1.0000e-04
# Epoch 23/300
# 324/324 [==============================] - ETA: 0s - loss: 1.1108 - accuracy: 0.6965
# Epoch 23: val_accuracy did not improve from 0.68340
# 324/324 [==============================] - 231s 711ms/step - loss: 1.1108 - accuracy: 0.6965 - val_loss: 1.1161 - val_accuracy: 0.6162 - lr: 1.0000e-04
# Epoch 24/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0956 - accuracy: 0.7020
# Epoch 24: val_accuracy improved from 0.68340 to 0.69746, saving model to best_model.h5
# 324/324 [==============================] - 233s 717ms/step - loss: 1.0956 - accuracy: 0.7020 - val_loss: 0.8072 - val_accuracy: 0.6975 - lr: 1.0000e-04
# Epoch 25/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0791 - accuracy: 0.7102
# Epoch 25: val_accuracy did not improve from 0.69746
# 324/324 [==============================] - 234s 720ms/step - loss: 1.0791 - accuracy: 0.7102 - val_loss: 1.0198 - val_accuracy: 0.6564 - lr: 1.0000e-04
# Epoch 26/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0669 - accuracy: 0.7086
# Epoch 26: val_accuracy did not improve from 0.69746
# 324/324 [==============================] - 235s 725ms/step - loss: 1.0669 - accuracy: 0.7086 - val_loss: 0.9222 - val_accuracy: 0.6527 - lr: 1.0000e-04
# Epoch 27/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0638 - accuracy: 0.7107
# Epoch 27: val_accuracy did not improve from 0.69746
# 324/324 [==============================] - 233s 718ms/step - loss: 1.0638 - accuracy: 0.7107 - val_loss: 1.0374 - val_accuracy: 0.6477 - lr: 1.0000e-04
# Epoch 28/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0422 - accuracy: 0.7199
# Epoch 28: val_accuracy did not improve from 0.69746
# 324/324 [==============================] - 229s 707ms/step - loss: 1.0422 - accuracy: 0.7199 - val_loss: 0.9173 - val_accuracy: 0.6664 - lr: 1.0000e-04
# Epoch 29/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0299 - accuracy: 0.7212
# Epoch 29: val_accuracy did not improve from 0.69746
# 324/324 [==============================] - 234s 721ms/step - loss: 1.0299 - accuracy: 0.7212 - val_loss: 0.9558 - val_accuracy: 0.6516 - lr: 1.0000e-04
# Epoch 30/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0201 - accuracy: 0.7228
# Epoch 30: val_accuracy improved from 0.69746 to 0.70098, saving model to best_model.h5
# 324/324 [==============================] - 233s 717ms/step - loss: 1.0201 - accuracy: 0.7228 - val_loss: 0.8027 - val_accuracy: 0.7010 - lr: 1.0000e-04
# Epoch 31/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0119 - accuracy: 0.7264
# Epoch 31: val_accuracy did not improve from 0.70098
# 324/324 [==============================] - 234s 721ms/step - loss: 1.0119 - accuracy: 0.7264 - val_loss: 1.0319 - val_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 32/300
# 324/324 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.7272
# Epoch 32: val_accuracy did not improve from 0.70098
# 324/324 [==============================] - 233s 717ms/step - loss: 1.0029 - accuracy: 0.7272 - val_loss: 0.8642 - val_accuracy: 0.6941 - lr: 1.0000e-04
# Epoch 33/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9837 - accuracy: 0.7323
# Epoch 33: val_accuracy improved from 0.70098 to 0.70645, saving model to best_model.h5
# 324/324 [==============================] - 237s 730ms/step - loss: 0.9837 - accuracy: 0.7323 - val_loss: 0.8209 - val_accuracy: 0.7064 - lr: 1.0000e-04
# Epoch 34/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9797 - accuracy: 0.7374
# Epoch 34: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 229s 704ms/step - loss: 0.9797 - accuracy: 0.7374 - val_loss: 0.8579 - val_accuracy: 0.6947 - lr: 1.0000e-04
# Epoch 35/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9719 - accuracy: 0.7377
# Epoch 35: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 235s 724ms/step - loss: 0.9719 - accuracy: 0.7377 - val_loss: 0.8525 - val_accuracy: 0.6963 - lr: 1.0000e-04
# Epoch 36/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9578 - accuracy: 0.7402
# Epoch 36: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 235s 724ms/step - loss: 0.9578 - accuracy: 0.7402 - val_loss: 0.8740 - val_accuracy: 0.6846 - lr: 1.0000e-04
# Epoch 37/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0.7474
# Epoch 37: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 231s 713ms/step - loss: 0.9361 - accuracy: 0.7474 - val_loss: 0.8601 - val_accuracy: 0.6846 - lr: 1.0000e-04
# Epoch 38/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9341 - accuracy: 0.7492
# Epoch 38: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 229s 706ms/step - loss: 0.9341 - accuracy: 0.7492 - val_loss: 0.8491 - val_accuracy: 0.6832 - lr: 1.0000e-04
# Epoch 39/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.7504
# Epoch 39: val_accuracy did not improve from 0.70645
# 324/324 [==============================] - 230s 708ms/step - loss: 0.9271 - accuracy: 0.7504 - val_loss: 0.9364 - val_accuracy: 0.6730 - lr: 1.0000e-04
# Epoch 40/300
# 324/324 [==============================] - ETA: 0s - loss: 0.9120 - accuracy: 0.7506
# Epoch 40: val_accuracy improved from 0.70645 to 0.70703, saving model to best_model.h5
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 324/324 [==============================] - 235s 725ms/step - loss: 0.9120 - accuracy: 0.7506 - val_loss: 0.8038 - val_accuracy: 0.7070 - lr: 1.0000e-04
# Epoch 41/300
# 324/324 [==============================] - ETA: 0s - loss: 0.8320 - accuracy: 0.7758
# Epoch 41: val_accuracy improved from 0.70703 to 0.70742, saving model to best_model.h5
# 324/324 [==============================] - 233s 717ms/step - loss: 0.8320 - accuracy: 0.7758 - val_loss: 0.7947 - val_accuracy: 0.7074 - lr: 5.0000e-05
# Epoch 42/300
# 324/324 [==============================] - ETA: 0s - loss: 0.8048 - accuracy: 0.7870
# Epoch 42: val_accuracy improved from 0.70742 to 0.71816, saving model to best_model.h5
# 324/324 [==============================] - 232s 714ms/step - loss: 0.8048 - accuracy: 0.7870 - val_loss: 0.7880 - val_accuracy: 0.7182 - lr: 5.0000e-05
# Epoch 43/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7867 - accuracy: 0.7920
# Epoch 43: val_accuracy did not improve from 0.71816
# 324/324 [==============================] - 238s 732ms/step - loss: 0.7867 - accuracy: 0.7920 - val_loss: 0.8528 - val_accuracy: 0.7070 - lr: 5.0000e-05
# Epoch 44/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7741 - accuracy: 0.7938
# Epoch 44: val_accuracy did not improve from 0.71816
# 324/324 [==============================] - 235s 725ms/step - loss: 0.7741 - accuracy: 0.7938 - val_loss: 0.8110 - val_accuracy: 0.7105 - lr: 5.0000e-05
# Epoch 45/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7652 - accuracy: 0.7961
# Epoch 45: val_accuracy improved from 0.71816 to 0.71875, saving model to best_model.h5
# 324/324 [==============================] - 235s 725ms/step - loss: 0.7652 - accuracy: 0.7961 - val_loss: 0.8065 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 46/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7522 - accuracy: 0.7985
# Epoch 46: val_accuracy improved from 0.71875 to 0.72109, saving model to best_model.h5
# 324/324 [==============================] - 235s 724ms/step - loss: 0.7522 - accuracy: 0.7985 - val_loss: 0.8065 - val_accuracy: 0.7211 - lr: 5.0000e-05
# Epoch 47/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7501 - accuracy: 0.7995
# Epoch 47: val_accuracy improved from 0.72109 to 0.72559, saving model to best_model.h5
# 324/324 [==============================] - 233s 717ms/step - loss: 0.7501 - accuracy: 0.7995 - val_loss: 0.7972 - val_accuracy: 0.7256 - lr: 5.0000e-05
# Epoch 48/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7411 - accuracy: 0.8016
# Epoch 48: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 229s 706ms/step - loss: 0.7411 - accuracy: 0.8016 - val_loss: 0.7924 - val_accuracy: 0.7162 - lr: 5.0000e-05
# Epoch 49/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.8035
# Epoch 49: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 234s 722ms/step - loss: 0.7259 - accuracy: 0.8035 - val_loss: 0.8322 - val_accuracy: 0.7205 - lr: 5.0000e-05
# Epoch 50/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.8082
# Epoch 50: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 233s 719ms/step - loss: 0.7134 - accuracy: 0.8082 - val_loss: 0.8737 - val_accuracy: 0.7105 - lr: 5.0000e-05
# Epoch 51/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7037 - accuracy: 0.8117
# Epoch 51: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 232s 716ms/step - loss: 0.7037 - accuracy: 0.8117 - val_loss: 0.8432 - val_accuracy: 0.7051 - lr: 5.0000e-05
# Epoch 52/300
# 324/324 [==============================] - ETA: 0s - loss: 0.7006 - accuracy: 0.8129
# Epoch 52: val_accuracy did not improve from 0.72559
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 324/324 [==============================] - 235s 725ms/step - loss: 0.7006 - accuracy: 0.8129 - val_loss: 0.8670 - val_accuracy: 0.7158 - lr: 5.0000e-05
# Epoch 53/300
# 324/324 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.8314
# Epoch 53: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 231s 711ms/step - loss: 0.6236 - accuracy: 0.8314 - val_loss: 0.8418 - val_accuracy: 0.7201 - lr: 2.5000e-05
# Epoch 54/300
# 324/324 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.8370
# Epoch 54: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 227s 701ms/step - loss: 0.6093 - accuracy: 0.8370 - val_loss: 0.8603 - val_accuracy: 0.7166 - lr: 2.5000e-05
# Epoch 55/300
# 324/324 [==============================] - ETA: 0s - loss: 0.6000 - accuracy: 0.8411
# Epoch 55: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 227s 699ms/step - loss: 0.6000 - accuracy: 0.8411 - val_loss: 0.9017 - val_accuracy: 0.7160 - lr: 2.5000e-05
# Epoch 56/300
# 324/324 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.8386
# Epoch 56: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 226s 696ms/step - loss: 0.6018 - accuracy: 0.8386 - val_loss: 0.8811 - val_accuracy: 0.7096 - lr: 2.5000e-05
# Epoch 57/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5866 - accuracy: 0.8475
# Epoch 57: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 224s 692ms/step - loss: 0.5866 - accuracy: 0.8475 - val_loss: 0.8710 - val_accuracy: 0.7150 - lr: 2.5000e-05
# Epoch 58/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5719 - accuracy: 0.8495
# Epoch 58: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 226s 696ms/step - loss: 0.5719 - accuracy: 0.8495 - val_loss: 0.9028 - val_accuracy: 0.7104 - lr: 2.5000e-05
# Epoch 59/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5731 - accuracy: 0.8470
# Epoch 59: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 224s 692ms/step - loss: 0.5731 - accuracy: 0.8470 - val_loss: 0.8953 - val_accuracy: 0.7150 - lr: 2.5000e-05
# Epoch 60/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5584 - accuracy: 0.8529
# Epoch 60: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 228s 702ms/step - loss: 0.5584 - accuracy: 0.8529 - val_loss: 0.9304 - val_accuracy: 0.7145 - lr: 2.5000e-05
# Epoch 61/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.8541
# Epoch 61: val_accuracy did not improve from 0.72559
# 324/324 [==============================] - 229s 705ms/step - loss: 0.5511 - accuracy: 0.8541 - val_loss: 0.9123 - val_accuracy: 0.7125 - lr: 2.5000e-05
# Epoch 62/300
# 324/324 [==============================] - ETA: 0s - loss: 0.5390 - accuracy: 0.8576
# Epoch 62: val_accuracy did not improve from 0.72559
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 324/324 [==============================] - 226s 696ms/step - loss: 0.5390 - accuracy: 0.8576 - val_loss: 0.9186 - val_accuracy: 0.7059 - lr: 2.5000e-05
# Epoch 62: early stopping

# %%
save_model = model.save('REPVGG_106e2_rafdb_224.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 55ms/step
# Accuracy =  0.703125

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 53ms/step
# Accuracy =  0.859375
# 2/2 [==============================] - 0s 54ms/step
# Accuracy =  0.5625

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.7043

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 56ms/step
# Accuracy: 70.4296875
# anger 660/5160 acc: 57.9
# disgust 491/5160 acc: 60.3
# fear 658/5160 acc: 54.9
# happy 952/5160 acc: 93.6
# neutral 959/5160 acc: 83.4
# sad 619/5160 acc: 59.3
# surprise 781/5160 acc: 65.2

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 70.4296875
# anger 660/5160 acc: 57.9
# disgust 491/5160 acc: 60.3
# fear 658/5160 acc: 54.9
# happy 952/5160 acc: 93.6
# neutral 959/5160 acc: 83.4
# sad 619/5160 acc: 59.3
# surprise 781/5160 acc: 65.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.60      0.58      0.59       660
#      disgust       0.48      0.60      0.53       491
#         fear       0.62      0.55      0.58       658
#        happy       0.89      0.94      0.91       952
#      neutral       0.90      0.83      0.87       959
#          sad       0.59      0.59      0.59       619
#     surprise       0.66      0.65      0.65       781
#
#     accuracy                           0.70      5120
#    macro avg       0.68      0.68      0.68      5120
# weighted avg       0.71      0.70      0.71      5120

# %% [markdown]
# # Unseen batch

# %%
# custom_objects = {
#     'RepVGGBlock': RepVGGBlock,
#     'GradientCheckpointing': GradientCheckpointing
# }

# model = load_model('REPVGG_100e_FER.h5', custom_objects=custom_objects)

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 63ms/step
# Accuracy =  0.703125
# 2/2 [==============================] - 0s 62ms/step
# Accuracy =  0.5

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6133

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 53ms/step
# Accuracy: 61.328125
# Angry 292/2100 acc: 64.7
# Disgust 293/2100 acc: 71.7
# Fear 291/2100 acc: 54.0
# Happy 297/2100 acc: 70.0
# Neutral 292/2100 acc: 35.6
# Sad 291/2100 acc: 61.5
# Surprise 292/2100 acc: 71.6

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 61.328125
# Angry 292/2100 acc: 64.7
# Disgust 293/2100 acc: 71.7
# Fear 291/2100 acc: 54.0
# Happy 297/2100 acc: 70.0
# Neutral 292/2100 acc: 35.6
# Sad 291/2100 acc: 61.5
# Surprise 292/2100 acc: 71.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.62      0.65      0.63       292
#      Disgust       0.62      0.72      0.67       293
#         Fear       0.60      0.54      0.57       291
#        Happy       0.83      0.70      0.76       297
#      Neutral       0.61      0.36      0.45       292
#          Sad       0.55      0.62      0.58       291
#     Surprise       0.52      0.72      0.60       292
#
#     accuracy                           0.61      2048
#    macro avg       0.62      0.61      0.61      2048
# weighted avg       0.62      0.61      0.61      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (224, 224))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 200ms/step
# Predicted emotion class: neutral, probability: 0.717807948589325
# 1/1 [==============================] - 0s 195ms/step
# Predicted emotion class: surprise, probability: 0.9999442100524902
# 1/1 [==============================] - 0s 188ms/step
# Predicted emotion class: fear, probability: 0.5236051082611084
# 1/1 [==============================] - 0s 191ms/step
# Predicted emotion class: neutral, probability: 0.6739777326583862
# 1/1 [==============================] - 0s 188ms/step
# Predicted emotion class: happy, probability: 0.9999706745147705
# 1/1 [==============================] - 0s 194ms/step
# Predicted emotion class: angry, probability: 0.9999258518218994
# 1/1 [==============================] - 0s 180ms/step
# Predicted emotion class: angry, probability: 0.9897580146789551
# 1/1 [==============================] - 0s 187ms/step
# Predicted emotion class: angry, probability: 0.9739581346511841
# 1/1 [==============================] - 0s 176ms/step
# Predicted emotion class: surprise, probability: 0.46199744939804077

# %% [markdown]
# # Fine Tunning

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 7, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 1.8060075093867334, 1: 16.54816513761468, 2: 1.7610446668293875, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

    custom_objects = {
    'RepVGGBlock': RepVGGBlock,
    'GradientCheckpointing': GradientCheckpointing
}

    model = load_model('checkpoints_freeze/toy-model_1-epoch-78-val_accuracy-0.63.h5', custom_objects=custom_objects)
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    # for layer in base_model.layers:
    #     layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 1.4396 - accuracy: 0.6659
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.63.h5
# 448/448 [==============================] - 67s 106ms/step - loss: 1.4396 - accuracy: 0.6659 - val_loss: 1.0266 - val_accuracy: 0.6318 - lr: 1.0000e-05
# Epoch 2/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4192 - accuracy: 0.6714
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.4192 - accuracy: 0.6714 - val_loss: 1.0137 - val_accuracy: 0.6356 - lr: 1.0000e-05
# Epoch 3/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4242 - accuracy: 0.6684
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.63.h5
# 448/448 [==============================] - 59s 131ms/step - loss: 1.4242 - accuracy: 0.6684 - val_loss: 1.0300 - val_accuracy: 0.6318 - lr: 1.0000e-05
# Epoch 4/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4105 - accuracy: 0.6720
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 111ms/step - loss: 1.4105 - accuracy: 0.6720 - val_loss: 1.0144 - val_accuracy: 0.6378 - lr: 1.0000e-05
# Epoch 5/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4062 - accuracy: 0.6753
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.64.h5
# 448/448 [==============================] - 53s 119ms/step - loss: 1.4062 - accuracy: 0.6753 - val_loss: 1.0115 - val_accuracy: 0.6366 - lr: 1.0000e-05
# Epoch 6/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3998 - accuracy: 0.6752
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.64.h5
# 448/448 [==============================] - 63s 141ms/step - loss: 1.3998 - accuracy: 0.6752 - val_loss: 1.0224 - val_accuracy: 0.6352 - lr: 1.0000e-05
# Epoch 7/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3967 - accuracy: 0.6757
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.63.h5
# 448/448 [==============================] - 59s 130ms/step - loss: 1.3967 - accuracy: 0.6757 - val_loss: 1.0347 - val_accuracy: 0.6343 - lr: 1.0000e-05
# Epoch 8/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4062 - accuracy: 0.6737
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4062 - accuracy: 0.6737 - val_loss: 1.0170 - val_accuracy: 0.6384 - lr: 1.0000e-05
# Epoch 9/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3985 - accuracy: 0.6748
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 110ms/step - loss: 1.3985 - accuracy: 0.6748 - val_loss: 1.0266 - val_accuracy: 0.6363 - lr: 1.0000e-05
# Epoch 10/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.6775
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.64.h5
# 448/448 [==============================] - 53s 117ms/step - loss: 1.3871 - accuracy: 0.6775 - val_loss: 1.0235 - val_accuracy: 0.6360 - lr: 1.0000e-05
# Epoch 11/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4025 - accuracy: 0.6790
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.64.h5
# 448/448 [==============================] - 51s 114ms/step - loss: 1.4025 - accuracy: 0.6790 - val_loss: 1.0163 - val_accuracy: 0.6406 - lr: 1.0000e-05
# Epoch 12/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.6771
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.64.h5
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 448/448 [==============================] - 50s 111ms/step - loss: 1.4021 - accuracy: 0.6771 - val_loss: 1.0255 - val_accuracy: 0.6367 - lr: 1.0000e-05
# Epoch 13/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3831 - accuracy: 0.6778
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.64.h5
# 448/448 [==============================] - 52s 116ms/step - loss: 1.3831 - accuracy: 0.6778 - val_loss: 1.0180 - val_accuracy: 0.6394 - lr: 5.0000e-06
# Epoch 14/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3791 - accuracy: 0.6810
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.64.h5
# 448/448 [==============================] - 52s 115ms/step - loss: 1.3791 - accuracy: 0.6810 - val_loss: 1.0169 - val_accuracy: 0.6401 - lr: 5.0000e-06
# Epoch 15/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3719 - accuracy: 0.6800
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.64.h5
# 448/448 [==============================] - 51s 114ms/step - loss: 1.3719 - accuracy: 0.6800 - val_loss: 1.0198 - val_accuracy: 0.6402 - lr: 5.0000e-06
# Epoch 16/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3729 - accuracy: 0.6813
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.64.h5
# 448/448 [==============================] - 55s 121ms/step - loss: 1.3729 - accuracy: 0.6813 - val_loss: 1.0118 - val_accuracy: 0.6398 - lr: 5.0000e-06
# Epoch 17/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3791 - accuracy: 0.6818
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.64.h5
# 448/448 [==============================] - 51s 113ms/step - loss: 1.3791 - accuracy: 0.6818 - val_loss: 1.0161 - val_accuracy: 0.6398 - lr: 5.0000e-06
# Epoch 18/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3774 - accuracy: 0.6774
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3774 - accuracy: 0.6774 - val_loss: 1.0087 - val_accuracy: 0.6436 - lr: 5.0000e-06
# Epoch 19/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3576 - accuracy: 0.6858
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 111ms/step - loss: 1.3576 - accuracy: 0.6858 - val_loss: 1.0211 - val_accuracy: 0.6384 - lr: 5.0000e-06
# Epoch 20/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3661 - accuracy: 0.6815
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3661 - accuracy: 0.6815 - val_loss: 1.0142 - val_accuracy: 0.6392 - lr: 5.0000e-06
# Epoch 21/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3787 - accuracy: 0.6798
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 110ms/step - loss: 1.3787 - accuracy: 0.6798 - val_loss: 1.0122 - val_accuracy: 0.6415 - lr: 5.0000e-06
# Epoch 22/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3660 - accuracy: 0.6786
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.3660 - accuracy: 0.6786 - val_loss: 1.0073 - val_accuracy: 0.6405 - lr: 5.0000e-06
# Epoch 23/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3775 - accuracy: 0.6815
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.64.h5
# 448/448 [==============================] - 51s 113ms/step - loss: 1.3775 - accuracy: 0.6815 - val_loss: 1.0179 - val_accuracy: 0.6391 - lr: 5.0000e-06
# Epoch 24/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3638 - accuracy: 0.6803
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3638 - accuracy: 0.6803 - val_loss: 1.0062 - val_accuracy: 0.6408 - lr: 5.0000e-06
# Epoch 25/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3724 - accuracy: 0.6796
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.64.h5
# 448/448 [==============================] - 51s 113ms/step - loss: 1.3724 - accuracy: 0.6796 - val_loss: 1.0237 - val_accuracy: 0.6369 - lr: 5.0000e-06
# Epoch 26/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3600 - accuracy: 0.6809
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.3600 - accuracy: 0.6809 - val_loss: 1.0086 - val_accuracy: 0.6422 - lr: 5.0000e-06
# Epoch 27/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3514 - accuracy: 0.6866
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.3514 - accuracy: 0.6866 - val_loss: 1.0152 - val_accuracy: 0.6363 - lr: 5.0000e-06
# Epoch 28/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3542 - accuracy: 0.6810
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.64.h5
# 448/448 [==============================] - 48s 107ms/step - loss: 1.3542 - accuracy: 0.6810 - val_loss: 1.0247 - val_accuracy: 0.6384 - lr: 5.0000e-06
# Epoch 29/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3631 - accuracy: 0.6812
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3631 - accuracy: 0.6812 - val_loss: 1.0090 - val_accuracy: 0.6434 - lr: 5.0000e-06
# Epoch 30/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3844 - accuracy: 0.6800
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3844 - accuracy: 0.6800 - val_loss: 1.0166 - val_accuracy: 0.6405 - lr: 5.0000e-06
# Epoch 31/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3618 - accuracy: 0.6835
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.64.h5
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 448/448 [==============================] - 49s 110ms/step - loss: 1.3618 - accuracy: 0.6835 - val_loss: 1.0233 - val_accuracy: 0.6409 - lr: 5.0000e-06
# Epoch 32/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3408 - accuracy: 0.6862
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.64.h5
# 448/448 [==============================] - 48s 107ms/step - loss: 1.3408 - accuracy: 0.6862 - val_loss: 1.0082 - val_accuracy: 0.6429 - lr: 2.5000e-06
# Epoch 33/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3554 - accuracy: 0.6835
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.3554 - accuracy: 0.6835 - val_loss: 1.0089 - val_accuracy: 0.6427 - lr: 2.5000e-06
# Epoch 34/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3370 - accuracy: 0.6885
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.64.h5
# 448/448 [==============================] - 48s 108ms/step - loss: 1.3370 - accuracy: 0.6885 - val_loss: 1.0103 - val_accuracy: 0.6420 - lr: 2.5000e-06
# Epoch 35/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3447 - accuracy: 0.6866
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.64.h5
# 448/448 [==============================] - 46s 104ms/step - loss: 1.3447 - accuracy: 0.6866 - val_loss: 1.0174 - val_accuracy: 0.6392 - lr: 2.5000e-06
# Epoch 36/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3442 - accuracy: 0.6836
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.64.h5
# 448/448 [==============================] - 48s 108ms/step - loss: 1.3442 - accuracy: 0.6836 - val_loss: 1.0119 - val_accuracy: 0.6419 - lr: 2.5000e-06
# Epoch 37/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3408 - accuracy: 0.6879
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.64.h5
# 448/448 [==============================] - 47s 105ms/step - loss: 1.3408 - accuracy: 0.6879 - val_loss: 1.0205 - val_accuracy: 0.6417 - lr: 2.5000e-06
# Epoch 38/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3503 - accuracy: 0.6847
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.64.h5
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 448/448 [==============================] - 47s 104ms/step - loss: 1.3503 - accuracy: 0.6847 - val_loss: 1.0119 - val_accuracy: 0.6438 - lr: 2.5000e-06
# Epoch 39/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3451 - accuracy: 0.6855
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.64.h5
# 448/448 [==============================] - 48s 106ms/step - loss: 1.3451 - accuracy: 0.6855 - val_loss: 1.0113 - val_accuracy: 0.6423 - lr: 1.2500e-06
# Epoch 40/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3395 - accuracy: 0.6870
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.64.h5
# 448/448 [==============================] - 47s 106ms/step - loss: 1.3395 - accuracy: 0.6870 - val_loss: 1.0118 - val_accuracy: 0.6415 - lr: 1.2500e-06
# Epoch 41/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3279 - accuracy: 0.6890
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3279 - accuracy: 0.6890 - val_loss: 1.0117 - val_accuracy: 0.6416 - lr: 1.2500e-06
# Epoch 42/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3402 - accuracy: 0.6888
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 110ms/step - loss: 1.3402 - accuracy: 0.6888 - val_loss: 1.0144 - val_accuracy: 0.6420 - lr: 1.2500e-06
# Epoch 43/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3332 - accuracy: 0.6860
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 111ms/step - loss: 1.3332 - accuracy: 0.6860 - val_loss: 1.0141 - val_accuracy: 0.6422 - lr: 1.2500e-06
# Epoch 44/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3500 - accuracy: 0.6866
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.3500 - accuracy: 0.6866 - val_loss: 1.0140 - val_accuracy: 0.6410 - lr: 1.2500e-06
# Epoch 44: early stopping

# %%
save_model = model.save('REPVGG_FER2013_FINAL.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 15ms/step
# Accuracy =  0.578125

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.796875
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.5

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6409

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# Accuracy: 64.09040178571429
# Angry 956/7178 acc: 58.7
# Disgust 111/7178 acc: 67.6
# Fear 1023/7178 acc: 40.6
# Happy 1772/7178 acc: 81.5
# Neutral 1231/7178 acc: 66.7
# Sad 1244/7178 acc: 49.3
# Surprise 831/7178 acc: 80.0

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 64.09040178571429
# Angry 956/7178 acc: 58.7
# Disgust 111/7178 acc: 67.6
# Fear 1023/7178 acc: 40.6
# Happy 1772/7178 acc: 81.5
# Neutral 1231/7178 acc: 66.7
# Sad 1244/7178 acc: 49.3
# Surprise 831/7178 acc: 80.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.53      0.59      0.56       956
#      Disgust       0.58      0.68      0.62       111
#         Fear       0.50      0.41      0.45      1023
#        Happy       0.90      0.81      0.85      1772
#      Neutral       0.56      0.67      0.61      1231
#          Sad       0.53      0.49      0.51      1244
#     Surprise       0.72      0.80      0.76       831
#
#     accuracy                           0.64      7168
#    macro avg       0.62      0.63      0.62      7168
# weighted avg       0.64      0.64      0.64      7168

# %% [markdown]
# # Unseen batch

# %%
# model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.46875
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.1875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3022

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 64ms/step
# Accuracy: 30.224609375
# Angry 297/2100 acc: 72.4
# Disgust 288/2100 acc: 2.1
# Fear 292/2100 acc: 21.6
# Happy 294/2100 acc: 31.0
# Neutral 292/2100 acc: 16.4
# Sad 291/2100 acc: 42.3
# Surprise 294/2100 acc: 24.8

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 30.224609375
# Angry 297/2100 acc: 72.4
# Disgust 288/2100 acc: 2.1
# Fear 292/2100 acc: 21.6
# Happy 294/2100 acc: 31.0
# Neutral 292/2100 acc: 16.4
# Sad 291/2100 acc: 42.3
# Surprise 294/2100 acc: 24.8

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.25      0.72      0.37       297
#      Disgust       0.67      0.02      0.04       288
#         Fear       0.41      0.22      0.28       292
#        Happy       0.59      0.31      0.41       294
#      Neutral       0.21      0.16      0.18       292
#          Sad       0.28      0.42      0.34       291
#     Surprise       0.38      0.25      0.30       294
#
#     accuracy                           0.30      2048
#    macro avg       0.40      0.30      0.27      2048
# weighted avg       0.40      0.30      0.27      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: neutral, probability: 0.46993914246559143
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: surprise, probability: 0.9699739217758179
# 1/1 [==============================] - 0s 30ms/step
# Predicted emotion class: angry, probability: 0.5640920400619507
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: neutral, probability: 0.6709685921669006
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: happy, probability: 0.4932018518447876
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.9910394549369812
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: neutral, probability: 0.6006370186805725
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.6517034769058228
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: sad, probability: 0.3371565639972687

# %% [markdown]
# # Testing model with webcam

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Initialize the video capture object
cap = cv2.VideoCapture(0)

# Loop through each video frame
while True:
    # Read a video frame
    ret, frame = cap.read()
    
    # Convert the frame from BGR to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the frame
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Convert the frame from RGB to BGR format
    bgr_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2BGR)

    # Display the frame with the detected faces and their predictions
    cv2.imshow("Video", bgr_frame)

    # Wait for a key press and check if the 'q' key was pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: neutral, probability: 0.614880383014679
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: surprise, probability: 0.45024436712265015
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: neutral, probability: 0.6629235148429871
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: neutral, probability: 0.7383639812469482
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: surprise, probability: 0.8927065134048462
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: happy, probability: 0.4720451235771179
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.2925080358982086
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: neutral, probability: 0.7815211415290833
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: happy, probability: 0.8766227960586548
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6742027401924133
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.5347230434417725
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8128764033317566
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.55384761095047
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.6472067832946777
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: neutral, probability: 0.45845720171928406
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.5151231288909912
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8586417436599731
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9039210677146912
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8331711292266846
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.8288767337799072
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7746599316596985
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6465101838111877
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.8249043822288513
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.7315678596496582
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.8286228179931641
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.7148462533950806
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8278812766075134
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.6955409646034241
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.7878711819648743
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.7766291499137878
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7450538277626038
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.8863629102706909
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.7511348724365234
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.6660755276679993
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: neutral, probability: 0.3318617641925812
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.763209342956543
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.5980122089385986
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7305830121040344
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.9339655637741089
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9454752206802368
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9507946372032166
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8955776691436768
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.9506683349609375
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.6743981242179871
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8499769568443298
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7646028995513916
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.6870279312133789
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.6104749441146851
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: fear, probability: 0.5654517412185669
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.5328896641731262
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.7896185517311096
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.5796182751655579
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: neutral, probability: 0.7666369080543518
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.46183982491493225
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.5501497983932495
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.3476494252681732
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.6078948378562927
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.46425363421440125
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: sad, probability: 0.6687819361686707
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8299365639686584
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.9565891027450562
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.7529603242874146
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.7712515592575073
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.7782275080680847
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.619515061378479
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7764570713043213
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.6629430651664734
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.8624379634857178
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.5337609648704529
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.7495201230049133
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: surprise, probability: 0.883918821811676
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: surprise, probability: 0.9613320231437683
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: surprise, probability: 0.352223664522171
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7393133044242859
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.5782723426818848
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: neutral, probability: 0.605780839920044
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: surprise, probability: 0.65117347240448
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.6591726541519165
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.7725089192390442
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.887363076210022
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.749839186668396
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.6408641934394836
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.5693796873092651
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.7794881463050842
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7954109311103821
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8078789710998535
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8560226559638977
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8032443523406982
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7884488105773926
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7788184881210327
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.7655465006828308
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.733585000038147
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.6217589378356934
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.6149702072143555
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.955901563167572
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9068102836608887
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9184350371360779
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8529707193374634
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9167001247406006
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6956895589828491
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9020671248435974
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8686378598213196
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.934085488319397
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8843505382537842
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.9708573818206787
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.7661841511726379
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8448073267936707
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.5574427247047424
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: neutral, probability: 0.4929099678993225
# 1/1 [==============================] - 0s 32ms/step
# Predicted emotion class: sad, probability: 0.3599546551704407
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: neutral, probability: 0.497335821390152
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.47067031264305115
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: sad, probability: 0.3484094440937042
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.33279407024383545
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.5051202178001404
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.39217400550842285
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: sad, probability: 0.395851731300354
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: sad, probability: 0.4405875504016876
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.3939564526081085
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: sad, probability: 0.43067824840545654
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.35490018129348755
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.418232262134552
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: sad, probability: 0.4429190158843994
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: sad, probability: 0.47126883268356323
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.4177686870098114
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: sad, probability: 0.32507219910621643
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.4156995117664337
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: sad, probability: 0.43003368377685547
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.43261954188346863
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: neutral, probability: 0.3480275869369507
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.38587459921836853
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.5861164927482605
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.7792503237724304
# 1/1 [==============================] - 0s 29ms/step
# Predicted emotion class: angry, probability: 0.6857898831367493
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.5636879801750183
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7177303433418274
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.7604840993881226
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.8142381310462952
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8357818722724915
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8148025870323181
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8463459610939026
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.8370206952095032
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.8843400478363037
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8531402945518494
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8674834966659546
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8782362341880798
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.9678764939308167
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9614145159721375
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.9656186103820801
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9571662545204163
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.9211663603782654
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: angry, probability: 0.5926430225372314
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.43094003200531006
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6290596127510071
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7063027620315552
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.7673446536064148
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6487779021263123
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7275031208992004
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.7334293127059937
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6808150410652161
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.6147559881210327
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.6597102284431458
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.5891657471656799
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: neutral, probability: 0.49938562512397766
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8576942086219788
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.8624692559242249
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8219330906867981
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8486053943634033
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.848812460899353
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8366853594779968
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8714987635612488
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8709332942962646
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8346909880638123
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8492830395698547
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8629415035247803
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.7986695766448975
# 1/1 [==============================] - 0s 30ms/step
# Predicted emotion class: angry, probability: 0.6784362196922302
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.7380110621452332
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.955047607421875
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9419136643409729
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9419136643409729
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.8590655326843262
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9610578417778015
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.7766017317771912
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.7221195697784424
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.803581714630127
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.8362798690795898
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8219736218452454
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.8462097644805908
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.925247848033905
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.6564755439758301
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.7594762444496155
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9585672616958618
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.939009428024292
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9297428727149963
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9799357652664185
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9397405385971069
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.9665800333023071
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.9206083416938782
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.9082323312759399
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9873822331428528
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.9722914695739746
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.9707504510879517
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: angry, probability: 0.9387772083282471
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.9196861386299133
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: angry, probability: 0.9006531834602356
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: angry, probability: 0.9373965263366699
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.42883193492889404
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: surprise, probability: 0.5470656752586365
