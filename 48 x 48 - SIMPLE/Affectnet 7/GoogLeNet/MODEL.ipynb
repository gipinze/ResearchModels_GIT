# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Dense, concatenate, AveragePooling2D, Flatten, GlobalAveragePooling2D
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/train 7/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/test 7/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 22221 images belonging to 7 classes.
# Found 5545 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2093</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>520</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 22221
# 5545

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # PERFECT CODE

# %%
def inception_module(x, filters):
    tower_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
    tower_1 = Conv2D(filters[1], (3, 3), padding='same', activation='relu')(tower_1)
    
    tower_2 = Conv2D(filters[2], (1, 1), padding='same', activation='relu')(x)
    tower_2 = Conv2D(filters[3], (5, 5), padding='same', activation='relu')(tower_2)
    
    tower_3 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    tower_3 = Conv2D(filters[4], (1, 1), padding='same', activation='relu')(tower_3)
    
    tower_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(x)
    
    output = concatenate([tower_1, tower_2, tower_3, tower_4], axis=3)
    return output

# Define modified GoogLeNet model for 48x48x3 input images
def GoogLeNet(input_shape, num_classes):
    input_img = Input(shape=input_shape)
    
    # Stage 1: Convolution and MaxPooling
    x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(input_img)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 2: Convolution and MaxPooling
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 3: Inception modules
    x = inception_module(x, [64, 96, 128, 16, 32, 32])
    x = inception_module(x, [128, 128, 192, 32, 96, 64])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 4: Inception modules
    x = inception_module(x, [192, 96, 208, 16, 48, 64])
    x = inception_module(x, [160, 112, 224, 24, 64, 64])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 5: Inception modules
    x = inception_module(x, [128, 128, 256, 24, 64, 64])
    x = inception_module(x, [112, 144, 288, 32, 64, 64])
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 6: Final layers
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = inception_module(x, [384, 192, 384, 48, 128, 128])
    
    # Stage 7: Global average pooling and dense layers
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)
    x = Dense(num_classes, activation='softmax')(x)
    
    # Create model
    model = Model(inputs=input_img, outputs=x)
    return model

# %%
# Create the GoogLeNet model
input_shape = (48, 48, 3)  # Adjust input shape according to your image size and channels
num_classes = 7  # Adjust the number of classes based on your task
# Open the strategy scope
with strategy.scope():
    # Create an instance of the modified GoogLeNet model
    model = GoogLeNet(input_shape, num_classes)
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 12, 12, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 12, 12, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 320)   0           ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 192)    61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 6, 6, 208)    66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 320)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 6, 6, 96)     165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 6, 6, 16)     83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 6, 6, 48)     15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 6, 6, 64)     20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6, 6, 224)    0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 6, 6, 160)    36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 6, 6, 224)    50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 224)   0           ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 6, 6, 112)    161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 6, 24)     134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 6, 6, 64)     14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 64)     14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 6, 6, 264)    0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 264)   0           ['concatenate_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 3, 3, 128)    33920       ['max_pooling2d_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 256)    67840       ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 264)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 3, 3, 128)    147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 3, 3, 24)     153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3, 3, 280)    0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 3, 3, 112)    31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 3, 3, 288)    80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 280)   0           ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 3, 3, 144)    145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 3, 3, 32)     230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 3, 3, 64)     17984       ['max_pooling2d_9[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 3, 3, 64)     17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 3, 3, 304)    0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 3, 3, 256)    78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 3, 3, 320)    97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 3, 3, 304)   0           ['concatenate_5[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 160)    368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 3, 3, 32)     256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 128)    39040       ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 128)    39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 3, 3, 448)    0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 256)    114944      ['max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 320)    143680      ['max_pooling2d_11[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 448)   0           ['max_pooling2d_11[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 2, 2, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 2, 2, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_13[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 496)         0           ['concatenate_8[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 496)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,909,319
# Trainable params: 5,909,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 347/347 [==============================] - ETA: 0s - loss: 2.5168 - accuracy: 0.1252
# Epoch 1: val_accuracy improved from -inf to 0.13100, saving model to best_model.h5
# 347/347 [==============================] - 75s 167ms/step - loss: 2.5168 - accuracy: 0.1252 - val_loss: 1.9459 - val_accuracy: 0.1310 - lr: 1.0000e-04
# Epoch 2/400
# 347/347 [==============================] - ETA: 0s - loss: 2.4794 - accuracy: 0.1850
# Epoch 2: val_accuracy improved from 0.13100 to 0.17969, saving model to best_model.h5
# 347/347 [==============================] - 56s 161ms/step - loss: 2.4794 - accuracy: 0.1850 - val_loss: 1.9435 - val_accuracy: 0.1797 - lr: 1.0000e-04
# Epoch 3/400
# 347/347 [==============================] - ETA: 0s - loss: 2.3223 - accuracy: 0.2473
# Epoch 3: val_accuracy improved from 0.17969 to 0.20058, saving model to best_model.h5
# 347/347 [==============================] - 56s 161ms/step - loss: 2.3223 - accuracy: 0.2473 - val_loss: 1.9385 - val_accuracy: 0.2006 - lr: 1.0000e-04
# Epoch 4/400
# 347/347 [==============================] - ETA: 0s - loss: 2.1901 - accuracy: 0.2769
# Epoch 4: val_accuracy improved from 0.20058 to 0.24655, saving model to best_model.h5
# 347/347 [==============================] - 55s 158ms/step - loss: 2.1901 - accuracy: 0.2769 - val_loss: 1.9054 - val_accuracy: 0.2465 - lr: 1.0000e-04
# Epoch 5/400
# 347/347 [==============================] - ETA: 0s - loss: 2.1341 - accuracy: 0.2983
# Epoch 5: val_accuracy improved from 0.24655 to 0.31177, saving model to best_model.h5
# 347/347 [==============================] - 55s 159ms/step - loss: 2.1341 - accuracy: 0.2983 - val_loss: 1.6177 - val_accuracy: 0.3118 - lr: 1.0000e-04
# Epoch 6/400
# 347/347 [==============================] - ETA: 0s - loss: 2.0627 - accuracy: 0.3496
# Epoch 6: val_accuracy improved from 0.31177 to 0.34230, saving model to best_model.h5
# 347/347 [==============================] - 55s 159ms/step - loss: 2.0627 - accuracy: 0.3496 - val_loss: 1.6999 - val_accuracy: 0.3423 - lr: 1.0000e-04
# Epoch 7/400
# 347/347 [==============================] - ETA: 0s - loss: 1.9722 - accuracy: 0.3802
# Epoch 7: val_accuracy did not improve from 0.34230
# 347/347 [==============================] - 55s 157ms/step - loss: 1.9722 - accuracy: 0.3802 - val_loss: 1.7969 - val_accuracy: 0.3152 - lr: 1.0000e-04
# Epoch 8/400
# 347/347 [==============================] - ETA: 0s - loss: 1.9077 - accuracy: 0.4084
# Epoch 8: val_accuracy improved from 0.34230 to 0.39880, saving model to best_model.h5
# 347/347 [==============================] - 55s 158ms/step - loss: 1.9077 - accuracy: 0.4084 - val_loss: 1.4783 - val_accuracy: 0.3988 - lr: 1.0000e-04
# Epoch 9/400
# 347/347 [==============================] - ETA: 0s - loss: 1.8595 - accuracy: 0.4331
# Epoch 9: val_accuracy did not improve from 0.39880
# 347/347 [==============================] - 58s 166ms/step - loss: 1.8595 - accuracy: 0.4331 - val_loss: 1.6998 - val_accuracy: 0.3470 - lr: 1.0000e-04
# Epoch 10/400
# 347/347 [==============================] - ETA: 0s - loss: 1.7942 - accuracy: 0.4618
# Epoch 10: val_accuracy did not improve from 0.39880
# 347/347 [==============================] - 54s 154ms/step - loss: 1.7942 - accuracy: 0.4618 - val_loss: 1.5816 - val_accuracy: 0.3901 - lr: 1.0000e-04
# Epoch 11/400
# 347/347 [==============================] - ETA: 0s - loss: 1.7531 - accuracy: 0.4759
# Epoch 11: val_accuracy improved from 0.39880 to 0.41552, saving model to best_model.h5
# 347/347 [==============================] - 54s 155ms/step - loss: 1.7531 - accuracy: 0.4759 - val_loss: 1.4901 - val_accuracy: 0.4155 - lr: 1.0000e-04
# Epoch 12/400
# 347/347 [==============================] - ETA: 0s - loss: 1.7123 - accuracy: 0.4913
# Epoch 12: val_accuracy improved from 0.41552 to 0.46639, saving model to best_model.h5
# 347/347 [==============================] - 53s 153ms/step - loss: 1.7123 - accuracy: 0.4913 - val_loss: 1.3607 - val_accuracy: 0.4664 - lr: 1.0000e-04
# Epoch 13/400
# 347/347 [==============================] - ETA: 0s - loss: 1.6789 - accuracy: 0.5030
# Epoch 13: val_accuracy improved from 0.46639 to 0.47329, saving model to best_model.h5
# 347/347 [==============================] - 54s 154ms/step - loss: 1.6789 - accuracy: 0.5030 - val_loss: 1.3244 - val_accuracy: 0.4733 - lr: 1.0000e-04
# Epoch 14/400
# 347/347 [==============================] - ETA: 0s - loss: 1.6506 - accuracy: 0.5155
# Epoch 14: val_accuracy did not improve from 0.47329
# 347/347 [==============================] - 52s 149ms/step - loss: 1.6506 - accuracy: 0.5155 - val_loss: 1.4186 - val_accuracy: 0.4529 - lr: 1.0000e-04
# Epoch 15/400
# 347/347 [==============================] - ETA: 0s - loss: 1.6325 - accuracy: 0.5227
# Epoch 15: val_accuracy did not improve from 0.47329
# 347/347 [==============================] - 52s 149ms/step - loss: 1.6325 - accuracy: 0.5227 - val_loss: 1.4479 - val_accuracy: 0.4340 - lr: 1.0000e-04
# Epoch 16/400
# 347/347 [==============================] - ETA: 0s - loss: 1.6068 - accuracy: 0.5299
# Epoch 16: val_accuracy did not improve from 0.47329
# 347/347 [==============================] - 52s 150ms/step - loss: 1.6068 - accuracy: 0.5299 - val_loss: 1.3979 - val_accuracy: 0.4511 - lr: 1.0000e-04
# Epoch 17/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5886 - accuracy: 0.5340
# Epoch 17: val_accuracy did not improve from 0.47329
# 347/347 [==============================] - 52s 149ms/step - loss: 1.5886 - accuracy: 0.5340 - val_loss: 1.3861 - val_accuracy: 0.4609 - lr: 1.0000e-04
# Epoch 18/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5752 - accuracy: 0.5426
# Epoch 18: val_accuracy improved from 0.47329 to 0.48147, saving model to best_model.h5
# 347/347 [==============================] - 52s 150ms/step - loss: 1.5752 - accuracy: 0.5426 - val_loss: 1.3127 - val_accuracy: 0.4815 - lr: 1.0000e-04
# Epoch 19/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5506 - accuracy: 0.5491
# Epoch 19: val_accuracy did not improve from 0.48147
# 347/347 [==============================] - 51s 147ms/step - loss: 1.5506 - accuracy: 0.5491 - val_loss: 1.3266 - val_accuracy: 0.4757 - lr: 1.0000e-04
# Epoch 20/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5537 - accuracy: 0.5522
# Epoch 20: val_accuracy did not improve from 0.48147
# 347/347 [==============================] - 52s 149ms/step - loss: 1.5537 - accuracy: 0.5522 - val_loss: 1.4741 - val_accuracy: 0.4497 - lr: 1.0000e-04
# Epoch 21/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5332 - accuracy: 0.5578
# Epoch 21: val_accuracy improved from 0.48147 to 0.48547, saving model to best_model.h5
# 347/347 [==============================] - 51s 148ms/step - loss: 1.5332 - accuracy: 0.5578 - val_loss: 1.3200 - val_accuracy: 0.4855 - lr: 1.0000e-04
# Epoch 22/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5213 - accuracy: 0.5612
# Epoch 22: val_accuracy improved from 0.48547 to 0.54106, saving model to best_model.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.5213 - accuracy: 0.5612 - val_loss: 1.1675 - val_accuracy: 0.5411 - lr: 1.0000e-04
# Epoch 23/400
# 347/347 [==============================] - ETA: 0s - loss: 1.5075 - accuracy: 0.5663
# Epoch 23: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 51s 146ms/step - loss: 1.5075 - accuracy: 0.5663 - val_loss: 1.2728 - val_accuracy: 0.5016 - lr: 1.0000e-04
# Epoch 24/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4974 - accuracy: 0.5698
# Epoch 24: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 51s 146ms/step - loss: 1.4974 - accuracy: 0.5698 - val_loss: 1.2025 - val_accuracy: 0.5278 - lr: 1.0000e-04
# Epoch 25/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4696 - accuracy: 0.5783
# Epoch 25: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 51s 146ms/step - loss: 1.4696 - accuracy: 0.5783 - val_loss: 1.4612 - val_accuracy: 0.4544 - lr: 1.0000e-04
# Epoch 26/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4693 - accuracy: 0.5806
# Epoch 26: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 51s 146ms/step - loss: 1.4693 - accuracy: 0.5806 - val_loss: 1.3434 - val_accuracy: 0.4967 - lr: 1.0000e-04
# Epoch 27/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4476 - accuracy: 0.5849
# Epoch 27: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 51s 146ms/step - loss: 1.4476 - accuracy: 0.5849 - val_loss: 1.2562 - val_accuracy: 0.5331 - lr: 1.0000e-04
# Epoch 28/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4517 - accuracy: 0.5836
# Epoch 28: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 49s 142ms/step - loss: 1.4517 - accuracy: 0.5836 - val_loss: 1.4490 - val_accuracy: 0.4706 - lr: 1.0000e-04
# Epoch 29/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4325 - accuracy: 0.5908
# Epoch 29: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 50s 143ms/step - loss: 1.4325 - accuracy: 0.5908 - val_loss: 1.3285 - val_accuracy: 0.5024 - lr: 1.0000e-04
# Epoch 30/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4185 - accuracy: 0.5953
# Epoch 30: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 50s 143ms/step - loss: 1.4185 - accuracy: 0.5953 - val_loss: 1.2335 - val_accuracy: 0.5256 - lr: 1.0000e-04
# Epoch 31/400
# 347/347 [==============================] - ETA: 0s - loss: 1.4116 - accuracy: 0.5966
# Epoch 31: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 50s 143ms/step - loss: 1.4116 - accuracy: 0.5966 - val_loss: 1.2778 - val_accuracy: 0.5263 - lr: 1.0000e-04
# Epoch 32/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3932 - accuracy: 0.6049
# Epoch 32: val_accuracy did not improve from 0.54106
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 347/347 [==============================] - 50s 143ms/step - loss: 1.3932 - accuracy: 0.6049 - val_loss: 1.3132 - val_accuracy: 0.5109 - lr: 1.0000e-04
# Epoch 33/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3508 - accuracy: 0.6198
# Epoch 33: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3508 - accuracy: 0.6198 - val_loss: 1.2563 - val_accuracy: 0.5342 - lr: 5.0000e-05
# Epoch 34/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3407 - accuracy: 0.6194
# Epoch 34: val_accuracy did not improve from 0.54106
# 347/347 [==============================] - 49s 141ms/step - loss: 1.3407 - accuracy: 0.6194 - val_loss: 1.3045 - val_accuracy: 0.5225 - lr: 5.0000e-05
# Epoch 35/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3358 - accuracy: 0.6189
# Epoch 35: val_accuracy improved from 0.54106 to 0.54306, saving model to best_model.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3358 - accuracy: 0.6189 - val_loss: 1.2666 - val_accuracy: 0.5431 - lr: 5.0000e-05
# Epoch 36/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3252 - accuracy: 0.6233
# Epoch 36: val_accuracy did not improve from 0.54306
# 347/347 [==============================] - 50s 143ms/step - loss: 1.3252 - accuracy: 0.6233 - val_loss: 1.2475 - val_accuracy: 0.5391 - lr: 5.0000e-05
# Epoch 37/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3121 - accuracy: 0.6252
# Epoch 37: val_accuracy did not improve from 0.54306
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3121 - accuracy: 0.6252 - val_loss: 1.2864 - val_accuracy: 0.5400 - lr: 5.0000e-05
# Epoch 38/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3158 - accuracy: 0.6251
# Epoch 38: val_accuracy improved from 0.54306 to 0.54742, saving model to best_model.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.3158 - accuracy: 0.6251 - val_loss: 1.2483 - val_accuracy: 0.5474 - lr: 5.0000e-05
# Epoch 39/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3021 - accuracy: 0.6313
# Epoch 39: val_accuracy improved from 0.54742 to 0.55451, saving model to best_model.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.3021 - accuracy: 0.6313 - val_loss: 1.2121 - val_accuracy: 0.5545 - lr: 5.0000e-05
# Epoch 40/400
# 347/347 [==============================] - ETA: 0s - loss: 1.3010 - accuracy: 0.6283
# Epoch 40: val_accuracy did not improve from 0.55451
# 347/347 [==============================] - 50s 145ms/step - loss: 1.3010 - accuracy: 0.6283 - val_loss: 1.2286 - val_accuracy: 0.5427 - lr: 5.0000e-05
# Epoch 41/400
# 347/347 [==============================] - ETA: 0s - loss: 1.2876 - accuracy: 0.6349
# Epoch 41: val_accuracy did not improve from 0.55451
# 347/347 [==============================] - 50s 143ms/step - loss: 1.2876 - accuracy: 0.6349 - val_loss: 1.2125 - val_accuracy: 0.5420 - lr: 5.0000e-05
# Epoch 42/400
# 347/347 [==============================] - ETA: 0s - loss: 1.2899 - accuracy: 0.6370
# Epoch 42: val_accuracy did not improve from 0.55451
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 347/347 [==============================] - 50s 143ms/step - loss: 1.2899 - accuracy: 0.6370 - val_loss: 1.4017 - val_accuracy: 0.5036 - lr: 5.0000e-05
# Epoch 42: early stopping

# %%
save_model = model.save('GoogLeNet1.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model('best_model.h5')
model.summary()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 13ms/step
# Accuracy =  0.546875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.640625
# 2/2 [==============================] - 0s 35ms/step
# Accuracy =  0.375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5036

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# Accuracy: 50.36337209302325
# anger 712/5545 acc: 64.0
# disgust 515/5545 acc: 53.4
# fear 717/5545 acc: 61.6
# happy 1004/5545 acc: 68.2
# neutral 1020/5545 acc: 44.1
# sad 684/5545 acc: 33.5
# surprise 852/5545 acc: 27.6

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 50.36337209302325
# anger 712/5545 acc: 64.0
# disgust 515/5545 acc: 53.4
# fear 717/5545 acc: 61.6
# happy 1004/5545 acc: 68.2
# neutral 1020/5545 acc: 44.1
# sad 684/5545 acc: 33.5
# surprise 852/5545 acc: 27.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.38      0.64      0.48       712
#      disgust       0.28      0.53      0.36       515
#         fear       0.40      0.62      0.49       717
#        happy       0.93      0.68      0.79      1004
#      neutral       0.87      0.44      0.58      1020
#          sad       0.45      0.33      0.38       684
#     surprise       0.51      0.28      0.36       852
#
#     accuracy                           0.50      5504
#    macro avg       0.55      0.50      0.49      5504
# weighted avg       0.59      0.50      0.51      5504

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 348/348 [==============================] - 41s 116ms/step - loss: 0.9358 - accuracy: 0.6398
# 87/87 [==============================] - 8s 86ms/step - loss: 1.4018 - accuracy: 0.5032

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 40ms/step
# Top 1 Accuracy: 50.27%
# 2/2 [==============================] - 0s 62ms/step
# Top 2 Accuracy: 34.38%
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2127 - accuracy: 0.6094
# Loss: 1.2127048969268799
# Precision: 0.55
# Recall: 0.50
# F1-Score: 0.49

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 35ms/step
# Accuracy =  0.53125
# 2/2 [==============================] - 0s 35ms/step
# Accuracy =  0.234375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4028

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# Accuracy: 40.283203125
# Angry 297/2100 acc: 76.8
# Disgust 293/2100 acc: 65.2
# Fear 292/2100 acc: 77.4
# Happy 293/2100 acc: 2.7
# Neutral 290/2100 acc: 0.0
# Sad 289/2100 acc: 45.3
# Surprise 294/2100 acc: 13.9

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 40.283203125
# Angry 297/2100 acc: 76.8
# Disgust 293/2100 acc: 65.2
# Fear 292/2100 acc: 77.4
# Happy 293/2100 acc: 2.7
# Neutral 290/2100 acc: 0.0
# Sad 289/2100 acc: 45.3
# Surprise 294/2100 acc: 13.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.43      0.77      0.55       297
#      Disgust       0.41      0.65      0.51       293
#         Fear       0.35      0.77      0.48       292
#        Happy       1.00      0.03      0.05       293
#      Neutral       0.00      0.00      0.00       290
#          Sad       0.46      0.45      0.46       289
#     Surprise       0.38      0.14      0.20       294
#
#     accuracy                           0.40      2048
#    macro avg       0.43      0.40      0.32      2048
# weighted avg       0.43      0.40      0.32      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: sad, probability: 0.9950889945030212
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: surprise, probability: 0.9995642304420471
# 1/1 [==============================] - 0s 111ms/step
# Predicted emotion class: surprise, probability: 0.8853887915611267
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: sad, probability: 0.7385484576225281
# 1/1 [==============================] - 0s 101ms/step
# Predicted emotion class: happy, probability: 0.9999992847442627
# 1/1 [==============================] - 0s 113ms/step
# Predicted emotion class: angry, probability: 0.9996473789215088
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: angry, probability: 0.9465680122375488
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: neutral, probability: 0.7610039114952087
# 1/1 [==============================] - 0s 112ms/step
# Predicted emotion class: sad, probability: 0.8114776611328125

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 12, 12, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 12, 12, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 320)   0           ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 192)    61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 6, 6, 208)    66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 320)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 6, 6, 96)     165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 6, 6, 16)     83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 6, 6, 48)     15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 6, 6, 64)     20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6, 6, 224)    0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 6, 6, 160)    36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 6, 6, 224)    50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 224)   0           ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 6, 6, 112)    161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 6, 24)     134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 6, 6, 64)     14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 64)     14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 6, 6, 264)    0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 264)   0           ['concatenate_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 3, 3, 128)    33920       ['max_pooling2d_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 256)    67840       ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 264)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 3, 3, 128)    147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 3, 3, 24)     153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3, 3, 280)    0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 3, 3, 112)    31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 3, 3, 288)    80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 280)   0           ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 3, 3, 144)    145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 3, 3, 32)     230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 3, 3, 64)     17984       ['max_pooling2d_9[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 3, 3, 64)     17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 3, 3, 304)    0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 3, 3, 256)    78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 3, 3, 320)    97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 3, 3, 304)   0           ['concatenate_5[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 160)    368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 3, 3, 32)     256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 128)    39040       ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 128)    39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 3, 3, 448)    0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 256)    114944      ['max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 320)    143680      ['max_pooling2d_11[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 448)   0           ['max_pooling2d_11[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 2, 2, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 2, 2, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_13[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 496)         0           ['concatenate_8[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 496)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,909,319
# Trainable params: 5,909,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 347/347 [==============================] - ETA: 0s - loss: 1.2664 - accuracy: 0.6429
# Epoch 1: val_accuracy improved from -inf to 0.50363, saving model to best_model.h5
# 347/347 [==============================] - 57s 141ms/step - loss: 1.2664 - accuracy: 0.6429 - val_loss: 1.4074 - val_accuracy: 0.5036 - lr: 1.0000e-05
# Epoch 2/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2630 - accuracy: 0.6407
# Epoch 2: val_accuracy improved from 0.50363 to 0.52780, saving model to best_model.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2630 - accuracy: 0.6407 - val_loss: 1.3189 - val_accuracy: 0.5278 - lr: 1.0000e-05
# Epoch 3/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2557 - accuracy: 0.6464
# Epoch 3: val_accuracy improved from 0.52780 to 0.54233, saving model to best_model.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2557 - accuracy: 0.6464 - val_loss: 1.2828 - val_accuracy: 0.5423 - lr: 1.0000e-05
# Epoch 4/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2470 - accuracy: 0.6513
# Epoch 4: val_accuracy did not improve from 0.54233
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2470 - accuracy: 0.6513 - val_loss: 1.3331 - val_accuracy: 0.5322 - lr: 1.0000e-05
# Epoch 5/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2443 - accuracy: 0.6499
# Epoch 5: val_accuracy did not improve from 0.54233
# 347/347 [==============================] - 47s 134ms/step - loss: 1.2443 - accuracy: 0.6499 - val_loss: 1.4344 - val_accuracy: 0.5040 - lr: 1.0000e-05
# Epoch 6/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2399 - accuracy: 0.6481
# Epoch 6: val_accuracy did not improve from 0.54233
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2399 - accuracy: 0.6481 - val_loss: 1.3336 - val_accuracy: 0.5282 - lr: 1.0000e-05
# Epoch 7/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2395 - accuracy: 0.6493
# Epoch 7: val_accuracy did not improve from 0.54233
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2395 - accuracy: 0.6493 - val_loss: 1.3506 - val_accuracy: 0.5273 - lr: 1.0000e-05
# Epoch 8/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2371 - accuracy: 0.6496
# Epoch 8: val_accuracy improved from 0.54233 to 0.54342, saving model to best_model.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2371 - accuracy: 0.6496 - val_loss: 1.2840 - val_accuracy: 0.5434 - lr: 1.0000e-05
# Epoch 9/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2374 - accuracy: 0.6524
# Epoch 9: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2374 - accuracy: 0.6524 - val_loss: 1.3277 - val_accuracy: 0.5385 - lr: 1.0000e-05
# Epoch 10/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2370 - accuracy: 0.6498
# Epoch 10: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2370 - accuracy: 0.6498 - val_loss: 1.3565 - val_accuracy: 0.5280 - lr: 1.0000e-05
# Epoch 11/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2338 - accuracy: 0.6535
# Epoch 11: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2338 - accuracy: 0.6535 - val_loss: 1.3621 - val_accuracy: 0.5269 - lr: 1.0000e-05
# Epoch 12/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2239 - accuracy: 0.6541
# Epoch 12: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2239 - accuracy: 0.6541 - val_loss: 1.3318 - val_accuracy: 0.5329 - lr: 1.0000e-05
# Epoch 13/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2312 - accuracy: 0.6524
# Epoch 13: val_accuracy did not improve from 0.54342
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2312 - accuracy: 0.6524 - val_loss: 1.4085 - val_accuracy: 0.5140 - lr: 1.0000e-05
# Epoch 14/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2219 - accuracy: 0.6518
# Epoch 14: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2219 - accuracy: 0.6518 - val_loss: 1.3268 - val_accuracy: 0.5371 - lr: 5.0000e-06
# Epoch 15/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2191 - accuracy: 0.6555
# Epoch 15: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2191 - accuracy: 0.6555 - val_loss: 1.3106 - val_accuracy: 0.5391 - lr: 5.0000e-06
# Epoch 16/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2248 - accuracy: 0.6537
# Epoch 16: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2248 - accuracy: 0.6537 - val_loss: 1.3192 - val_accuracy: 0.5342 - lr: 5.0000e-06
# Epoch 17/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2146 - accuracy: 0.6595
# Epoch 17: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2146 - accuracy: 0.6595 - val_loss: 1.3169 - val_accuracy: 0.5389 - lr: 5.0000e-06
# Epoch 18/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2231 - accuracy: 0.6518
# Epoch 18: val_accuracy did not improve from 0.54342
# 347/347 [==============================] - 47s 135ms/step - loss: 1.2231 - accuracy: 0.6518 - val_loss: 1.3028 - val_accuracy: 0.5387 - lr: 5.0000e-06
# Epoch 19/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2204 - accuracy: 0.6570
# Epoch 19: val_accuracy improved from 0.54342 to 0.54397, saving model to best_model.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2204 - accuracy: 0.6570 - val_loss: 1.2855 - val_accuracy: 0.5440 - lr: 5.0000e-06
# Epoch 20/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2209 - accuracy: 0.6555
# Epoch 20: val_accuracy did not improve from 0.54397
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2209 - accuracy: 0.6555 - val_loss: 1.3065 - val_accuracy: 0.5363 - lr: 5.0000e-06
# Epoch 21/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2151 - accuracy: 0.6571
# Epoch 21: val_accuracy improved from 0.54397 to 0.54724, saving model to best_model.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2151 - accuracy: 0.6571 - val_loss: 1.2791 - val_accuracy: 0.5472 - lr: 5.0000e-06
# Epoch 22/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2160 - accuracy: 0.6597
# Epoch 22: val_accuracy did not improve from 0.54724
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2160 - accuracy: 0.6597 - val_loss: 1.3478 - val_accuracy: 0.5276 - lr: 5.0000e-06
# Epoch 23/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2208 - accuracy: 0.6562
# Epoch 23: val_accuracy did not improve from 0.54724
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2208 - accuracy: 0.6562 - val_loss: 1.2953 - val_accuracy: 0.5423 - lr: 5.0000e-06
# Epoch 24/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2135 - accuracy: 0.6602
# Epoch 24: val_accuracy did not improve from 0.54724
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2135 - accuracy: 0.6602 - val_loss: 1.3274 - val_accuracy: 0.5345 - lr: 5.0000e-06
# Epoch 25/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2046 - accuracy: 0.6631
# Epoch 25: val_accuracy improved from 0.54724 to 0.55160, saving model to best_model.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.2046 - accuracy: 0.6631 - val_loss: 1.2738 - val_accuracy: 0.5516 - lr: 5.0000e-06
# Epoch 26/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2095 - accuracy: 0.6583
# Epoch 26: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2095 - accuracy: 0.6583 - val_loss: 1.3223 - val_accuracy: 0.5371 - lr: 5.0000e-06
# Epoch 27/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2046 - accuracy: 0.6606
# Epoch 27: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 137ms/step - loss: 1.2046 - accuracy: 0.6606 - val_loss: 1.3473 - val_accuracy: 0.5312 - lr: 5.0000e-06
# Epoch 28/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2008 - accuracy: 0.6598
# Epoch 28: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2008 - accuracy: 0.6598 - val_loss: 1.3018 - val_accuracy: 0.5385 - lr: 5.0000e-06
# Epoch 29/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2016 - accuracy: 0.6611
# Epoch 29: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.2016 - accuracy: 0.6611 - val_loss: 1.3344 - val_accuracy: 0.5327 - lr: 5.0000e-06
# Epoch 30/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2099 - accuracy: 0.6598
# Epoch 30: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.2099 - accuracy: 0.6598 - val_loss: 1.3246 - val_accuracy: 0.5334 - lr: 5.0000e-06
# Epoch 31/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2076 - accuracy: 0.6607
# Epoch 31: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2076 - accuracy: 0.6607 - val_loss: 1.3346 - val_accuracy: 0.5302 - lr: 5.0000e-06
# Epoch 32/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2068 - accuracy: 0.6602
# Epoch 32: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2068 - accuracy: 0.6602 - val_loss: 1.3390 - val_accuracy: 0.5289 - lr: 5.0000e-06
# Epoch 33/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2055 - accuracy: 0.6611
# Epoch 33: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.2055 - accuracy: 0.6611 - val_loss: 1.2826 - val_accuracy: 0.5412 - lr: 5.0000e-06
# Epoch 34/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2070 - accuracy: 0.6575
# Epoch 34: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2070 - accuracy: 0.6575 - val_loss: 1.3224 - val_accuracy: 0.5334 - lr: 5.0000e-06
# Epoch 35/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2001 - accuracy: 0.6626
# Epoch 35: val_accuracy did not improve from 0.55160
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 347/347 [==============================] - 47s 136ms/step - loss: 1.2001 - accuracy: 0.6626 - val_loss: 1.3069 - val_accuracy: 0.5407 - lr: 5.0000e-06
# Epoch 36/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2011 - accuracy: 0.6615
# Epoch 36: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2011 - accuracy: 0.6615 - val_loss: 1.2872 - val_accuracy: 0.5458 - lr: 2.5000e-06
# Epoch 37/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2043 - accuracy: 0.6614
# Epoch 37: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.2043 - accuracy: 0.6614 - val_loss: 1.2700 - val_accuracy: 0.5489 - lr: 2.5000e-06
# Epoch 38/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1950 - accuracy: 0.6602
# Epoch 38: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1950 - accuracy: 0.6602 - val_loss: 1.2976 - val_accuracy: 0.5418 - lr: 2.5000e-06
# Epoch 39/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2043 - accuracy: 0.6604
# Epoch 39: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 137ms/step - loss: 1.2043 - accuracy: 0.6604 - val_loss: 1.3076 - val_accuracy: 0.5360 - lr: 2.5000e-06
# Epoch 40/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2042 - accuracy: 0.6630
# Epoch 40: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.2042 - accuracy: 0.6630 - val_loss: 1.3282 - val_accuracy: 0.5352 - lr: 2.5000e-06
# Epoch 41/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1959 - accuracy: 0.6619
# Epoch 41: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1959 - accuracy: 0.6619 - val_loss: 1.3422 - val_accuracy: 0.5312 - lr: 2.5000e-06
# Epoch 42/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.6660
# Epoch 42: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1931 - accuracy: 0.6660 - val_loss: 1.3389 - val_accuracy: 0.5325 - lr: 2.5000e-06
# Epoch 43/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1917 - accuracy: 0.6657
# Epoch 43: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1917 - accuracy: 0.6657 - val_loss: 1.3264 - val_accuracy: 0.5349 - lr: 2.5000e-06
# Epoch 44/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1967 - accuracy: 0.6612
# Epoch 44: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.1967 - accuracy: 0.6612 - val_loss: 1.3217 - val_accuracy: 0.5336 - lr: 2.5000e-06
# Epoch 45/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1905 - accuracy: 0.6652
# Epoch 45: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1905 - accuracy: 0.6652 - val_loss: 1.3271 - val_accuracy: 0.5349 - lr: 2.5000e-06
# Epoch 46/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1959 - accuracy: 0.6616
# Epoch 46: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 135ms/step - loss: 1.1959 - accuracy: 0.6616 - val_loss: 1.3156 - val_accuracy: 0.5372 - lr: 2.5000e-06
# Epoch 47/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1898 - accuracy: 0.6679
# Epoch 47: val_accuracy did not improve from 0.55160
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 347/347 [==============================] - 48s 138ms/step - loss: 1.1898 - accuracy: 0.6679 - val_loss: 1.3311 - val_accuracy: 0.5325 - lr: 2.5000e-06
# Epoch 48/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1990 - accuracy: 0.6622
# Epoch 48: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1990 - accuracy: 0.6622 - val_loss: 1.3353 - val_accuracy: 0.5303 - lr: 1.2500e-06
# Epoch 49/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1924 - accuracy: 0.6639
# Epoch 49: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 138ms/step - loss: 1.1924 - accuracy: 0.6639 - val_loss: 1.2879 - val_accuracy: 0.5441 - lr: 1.2500e-06
# Epoch 50/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1883 - accuracy: 0.6658
# Epoch 50: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1883 - accuracy: 0.6658 - val_loss: 1.3268 - val_accuracy: 0.5347 - lr: 1.2500e-06
# Epoch 51/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1866 - accuracy: 0.6626
# Epoch 51: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1866 - accuracy: 0.6626 - val_loss: 1.3135 - val_accuracy: 0.5376 - lr: 1.2500e-06
# Epoch 52/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.6670
# Epoch 52: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1868 - accuracy: 0.6670 - val_loss: 1.3277 - val_accuracy: 0.5352 - lr: 1.2500e-06
# Epoch 53/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1895 - accuracy: 0.6659
# Epoch 53: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1895 - accuracy: 0.6659 - val_loss: 1.2839 - val_accuracy: 0.5449 - lr: 1.2500e-06
# Epoch 54/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1949 - accuracy: 0.6676
# Epoch 54: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 47s 136ms/step - loss: 1.1949 - accuracy: 0.6676 - val_loss: 1.3469 - val_accuracy: 0.5271 - lr: 1.2500e-06
# Epoch 55/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1904 - accuracy: 0.6683
# Epoch 55: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1904 - accuracy: 0.6683 - val_loss: 1.3169 - val_accuracy: 0.5356 - lr: 1.2500e-06
# Epoch 56/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.6684
# Epoch 56: val_accuracy did not improve from 0.55160
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1868 - accuracy: 0.6684 - val_loss: 1.3344 - val_accuracy: 0.5329 - lr: 1.2500e-06
# Epoch 57/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1892 - accuracy: 0.6648
# Epoch 57: val_accuracy did not improve from 0.55160
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 347/347 [==============================] - 48s 137ms/step - loss: 1.1892 - accuracy: 0.6648 - val_loss: 1.3401 - val_accuracy: 0.5309 - lr: 1.2500e-06
# Epoch 57: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %%
model = load_model('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 68ms/step
# Accuracy =  0.5625

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 52ms/step
# Accuracy =  0.703125
# 2/2 [==============================] - 0s 52ms/step
# Accuracy =  0.375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5312

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 44ms/step
# Accuracy: 53.125
# anger 713/5545 acc: 57.6
# disgust 515/5545 acc: 47.0
# fear 717/5545 acc: 60.7
# happy 1002/5545 acc: 71.1
# neutral 1022/5545 acc: 53.6
# sad 683/5545 acc: 53.6
# surprise 852/5545 acc: 24.6

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 53.125
# anger 713/5545 acc: 57.6
# disgust 515/5545 acc: 47.0
# fear 717/5545 acc: 60.7
# happy 1002/5545 acc: 71.1
# neutral 1022/5545 acc: 53.6
# sad 683/5545 acc: 53.6
# surprise 852/5545 acc: 24.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.42      0.58      0.49       713
#      disgust       0.32      0.47      0.38       515
#         fear       0.41      0.61      0.49       717
#        happy       0.95      0.71      0.81      1002
#      neutral       0.85      0.54      0.66      1022
#          sad       0.39      0.54      0.45       683
#     surprise       0.55      0.25      0.34       852
#
#     accuracy                           0.53      5504
#    macro avg       0.56      0.53      0.52      5504
# weighted avg       0.60      0.53      0.54      5504

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 63ms/step
# Accuracy =  0.5625
# 2/2 [==============================] - 0s 62ms/step
# Accuracy =  0.3125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4194

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 54ms/step
# Accuracy: 41.943359375
# Angry 295/2100 acc: 71.9
# Disgust 293/2100 acc: 59.0
# Fear 290/2100 acc: 80.3
# Happy 287/2100 acc: 3.5
# Neutral 294/2100 acc: 0.3
# Sad 294/2100 acc: 61.2
# Surprise 295/2100 acc: 16.9

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 41.943359375
# Angry 295/2100 acc: 71.9
# Disgust 293/2100 acc: 59.0
# Fear 290/2100 acc: 80.3
# Happy 287/2100 acc: 3.5
# Neutral 294/2100 acc: 0.3
# Sad 294/2100 acc: 61.2
# Surprise 295/2100 acc: 16.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.52      0.72      0.60       295
#      Disgust       0.47      0.59      0.53       293
#         Fear       0.34      0.80      0.48       290
#        Happy       0.91      0.03      0.07       287
#      Neutral       0.17      0.00      0.01       294
#          Sad       0.39      0.61      0.48       294
#     Surprise       0.45      0.17      0.25       295
#
#     accuracy                           0.42      2048
#    macro avg       0.46      0.42      0.34      2048
# weighted avg       0.46      0.42      0.34      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 935ms/step
# Predicted emotion class: sad, probability: 0.6381509900093079
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: surprise, probability: 0.9913589954376221
# 1/1 [==============================] - 0s 37ms/step
# Predicted emotion class: surprise, probability: 0.7494197487831116
# 1/1 [==============================] - 0s 34ms/step
# Predicted emotion class: angry, probability: 0.3593408763408661
# 1/1 [==============================] - 0s 38ms/step
# Predicted emotion class: happy, probability: 0.9994934797286987
# 1/1 [==============================] - 0s 42ms/step
# Predicted emotion class: angry, probability: 0.8243364691734314
# 1/1 [==============================] - 0s 51ms/step
# Predicted emotion class: angry, probability: 0.9098782539367676
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.5012086033821106
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.8153152465820312
