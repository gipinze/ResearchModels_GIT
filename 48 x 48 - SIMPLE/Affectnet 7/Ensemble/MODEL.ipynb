# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D, concatenate, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
import cv2
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
## RAFDB
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/train 7/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/test 7/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 22221 images belonging to 7 classes.
# Found 5545 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2093</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>520</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 22221
# 5545

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'anger', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}
# {0: 1.4106529209621994, 1: 1.961299569995222, 2: 1.4169830859509838, 3: 1.0170961347869176, 4: 1.0, 5: 1.4959912536443147, 6: 1.1947031431897555}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

   # Define the input shape
   input_shape = (48, 48, 3)

   # Define the number of classes
   num_classes = 7

   # Define the input layer
   inputs = Input(shape=input_shape)

   # Define the first CNN model
   x1 = Conv2D(32, kernel_size=(3, 3), padding='same')(inputs)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(32, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = Conv2D(64, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(64, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = Conv2D(128, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(128, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = GlobalAveragePooling2D()(x1)
   x1 = Dense(512, activation='relu')(x1)
   x1 = Dropout(0.5)(x1)
   outputs1 = Dense(num_classes, activation='softmax')(x1)

   # Define the second CNN model
   x2 = Conv2D(32, kernel_size=(3, 3), padding='same')(inputs)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(32, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = Conv2D(64, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(64, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = Conv2D(128, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(128, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = GlobalAveragePooling2D()(x2)
   x2 = Dense(512, activation='relu')(x2)
   x2 = Dropout(0.5)(x2)
   outputs2 = Dense(num_classes, activation='softmax')(x2)

   # Define the third CNN model
   x3 = Conv2D(64, kernel_size=(3, 3), padding='same')(inputs)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(64, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = Conv2D(128, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(128, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = Conv2D(256, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(256, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = GlobalAveragePooling2D()(x3)
   x3 = Dense(512, activation='relu')(x3)
   x3 = Dropout(0.5)(x3)
   outputs3 = Dense(num_classes, activation='softmax')(x3)

   # Define the ensemble model
   outputs = tf.keras.layers.average([outputs1, outputs2, outputs3])
   model = Model(inputs=inputs, outputs=outputs)



   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 32)   896         ['input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 32)   896         ['input_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_6 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_12 (BatchN  (None, 48, 48, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation (Activation)        (None, 48, 48, 32)   0           ['batch_normalization[0][0]']
#
#  activation_6 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_6[0][0]']
#
#  activation_12 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 48, 48, 32)   9248        ['activation[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 32)   9248        ['activation_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 48, 48, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_13 (BatchN  (None, 48, 48, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_1 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_1[0][0]']
#
#  activation_7 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_7[0][0]']
#
#  activation_13 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 32)   0           ['activation_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 32)  0           ['activation_7[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 64)  0           ['activation_13[0][0]']
#
#  dropout (Dropout)              (None, 24, 24, 32)   0           ['max_pooling2d[0][0]']
#
#  dropout_4 (Dropout)            (None, 24, 24, 32)   0           ['max_pooling2d_3[0][0]']
#
#  dropout_8 (Dropout)            (None, 24, 24, 64)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 64)   18496       ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 24, 24, 64)   18496       ['dropout_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 24, 24, 128)  73856       ['dropout_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_14 (BatchN  (None, 24, 24, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]']
#
#  activation_8 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_8[0][0]']
#
#  activation_14 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_8[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 24, 24, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_15 (BatchN  (None, 24, 24, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_3 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_9 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_15 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_15[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_9[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 128)  0          ['activation_15[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 12, 64)   0           ['max_pooling2d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 12, 64)   0           ['max_pooling2d_4[0][0]']
#
#  dropout_9 (Dropout)            (None, 12, 12, 128)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  73856       ['dropout_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 256)  295168      ['dropout_9[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 12, 12, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_4[0][0]']
#
#  activation_10 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_10[0][0]']
#
#  activation_16 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  147584      ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 256)  590080      ['activation_16[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 12, 12, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_5[0][0]']
#
#  activation_11 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_11[0][0]']
#
#  activation_17 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 128)   0           ['activation_5[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 128)   0           ['activation_11[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 256)   0           ['activation_17[0][0]']
#
#  dropout_2 (Dropout)            (None, 6, 6, 128)    0           ['max_pooling2d_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 6, 6, 128)    0           ['max_pooling2d_5[0][0]']
#
#  dropout_10 (Dropout)           (None, 6, 6, 256)    0           ['max_pooling2d_8[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['dropout_2[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['dropout_6[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['dropout_10[0][0]']
#  obalAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          66048       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 512)          66048       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 512)          131584      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dropout_3 (Dropout)            (None, 512)          0           ['dense[0][0]']
#
#  dropout_7 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dropout_11 (Dropout)           (None, 512)          0           ['dense_4[0][0]']
#
#  dense_1 (Dense)                (None, 7)            3591        ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 7)            3591        ['dropout_7[0][0]']
#
#  dense_5 (Dense)                (None, 7)            3591        ['dropout_11[0][0]']
#
#  average (Average)              (None, 7)            0           ['dense_1[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'dense_5[0][0]']
#
# ==================================================================================================
# Total params: 2,001,045
# Trainable params: 1,997,461
# Non-trainable params: 3,584
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 84 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 84 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 347/347 [==============================] - ETA: 0s - loss: 2.5255 - accuracy: 0.1887
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.14.h5
# 347/347 [==============================] - 72s 160ms/step - loss: 2.5255 - accuracy: 0.1887 - val_loss: 1.9987 - val_accuracy: 0.1359 - lr: 1.0000e-04
# Epoch 2/300
# 347/347 [==============================] - ETA: 0s - loss: 2.3945 - accuracy: 0.2541
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.29.h5
# 347/347 [==============================] - 55s 157ms/step - loss: 2.3945 - accuracy: 0.2541 - val_loss: 1.8155 - val_accuracy: 0.2862 - lr: 1.0000e-04
# Epoch 3/300
# 347/347 [==============================] - ETA: 0s - loss: 2.3041 - accuracy: 0.2940
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.32.h5
# 347/347 [==============================] - 55s 159ms/step - loss: 2.3041 - accuracy: 0.2940 - val_loss: 1.7807 - val_accuracy: 0.3209 - lr: 1.0000e-04
# Epoch 4/300
# 347/347 [==============================] - ETA: 0s - loss: 2.2336 - accuracy: 0.3312
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.37.h5
# 347/347 [==============================] - 54s 156ms/step - loss: 2.2336 - accuracy: 0.3312 - val_loss: 1.5839 - val_accuracy: 0.3730 - lr: 1.0000e-04
# Epoch 5/300
# 347/347 [==============================] - ETA: 0s - loss: 2.1802 - accuracy: 0.3484
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.42.h5
# 347/347 [==============================] - 54s 155ms/step - loss: 2.1802 - accuracy: 0.3484 - val_loss: 1.5631 - val_accuracy: 0.4161 - lr: 1.0000e-04
# Epoch 6/300
# 347/347 [==============================] - ETA: 0s - loss: 2.1295 - accuracy: 0.3696
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.36.h5
# 347/347 [==============================] - 53s 153ms/step - loss: 2.1295 - accuracy: 0.3696 - val_loss: 1.6492 - val_accuracy: 0.3636 - lr: 1.0000e-04
# Epoch 7/300
# 347/347 [==============================] - ETA: 0s - loss: 2.0948 - accuracy: 0.3857
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.36.h5
# 347/347 [==============================] - 54s 155ms/step - loss: 2.0948 - accuracy: 0.3857 - val_loss: 1.5788 - val_accuracy: 0.3586 - lr: 1.0000e-04
# Epoch 8/300
# 347/347 [==============================] - ETA: 0s - loss: 2.0654 - accuracy: 0.4014
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.41.h5
# 347/347 [==============================] - 54s 157ms/step - loss: 2.0654 - accuracy: 0.4014 - val_loss: 1.5410 - val_accuracy: 0.4132 - lr: 1.0000e-04
# Epoch 9/300
# 347/347 [==============================] - ETA: 0s - loss: 2.0343 - accuracy: 0.4121
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.45.h5
# 347/347 [==============================] - 59s 170ms/step - loss: 2.0343 - accuracy: 0.4121 - val_loss: 1.4430 - val_accuracy: 0.4502 - lr: 1.0000e-04
# Epoch 10/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9949 - accuracy: 0.4319
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.40.h5
# 347/347 [==============================] - 57s 163ms/step - loss: 1.9949 - accuracy: 0.4319 - val_loss: 1.5324 - val_accuracy: 0.3964 - lr: 1.0000e-04
# Epoch 11/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9624 - accuracy: 0.4436
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.42.h5
# 347/347 [==============================] - 55s 156ms/step - loss: 1.9624 - accuracy: 0.4436 - val_loss: 1.4189 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 12/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9344 - accuracy: 0.4576
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.37.h5
# 347/347 [==============================] - 53s 153ms/step - loss: 1.9344 - accuracy: 0.4576 - val_loss: 1.6039 - val_accuracy: 0.3715 - lr: 1.0000e-04
# Epoch 13/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9071 - accuracy: 0.4645
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.48.h5
# 347/347 [==============================] - 54s 156ms/step - loss: 1.9071 - accuracy: 0.4645 - val_loss: 1.4237 - val_accuracy: 0.4831 - lr: 1.0000e-04
# Epoch 14/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8859 - accuracy: 0.4783
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.34.h5
# 347/347 [==============================] - 53s 151ms/step - loss: 1.8859 - accuracy: 0.4783 - val_loss: 1.7020 - val_accuracy: 0.3370 - lr: 1.0000e-04
# Epoch 15/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8646 - accuracy: 0.4882
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.49.h5
# 347/347 [==============================] - 52s 150ms/step - loss: 1.8646 - accuracy: 0.4882 - val_loss: 1.3788 - val_accuracy: 0.4907 - lr: 1.0000e-04
# Epoch 16/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8402 - accuracy: 0.4909
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.53.h5
# 347/347 [==============================] - 54s 155ms/step - loss: 1.8402 - accuracy: 0.4909 - val_loss: 1.3701 - val_accuracy: 0.5280 - lr: 1.0000e-04
# Epoch 17/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8261 - accuracy: 0.5001
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.55.h5
# 347/347 [==============================] - 56s 160ms/step - loss: 1.8261 - accuracy: 0.5001 - val_loss: 1.2797 - val_accuracy: 0.5451 - lr: 1.0000e-04
# Epoch 18/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7988 - accuracy: 0.5066
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.47.h5
# 347/347 [==============================] - 53s 152ms/step - loss: 1.7988 - accuracy: 0.5066 - val_loss: 1.4279 - val_accuracy: 0.4671 - lr: 1.0000e-04
# Epoch 19/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7809 - accuracy: 0.5135
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.53.h5
# 347/347 [==============================] - 52s 150ms/step - loss: 1.7809 - accuracy: 0.5135 - val_loss: 1.3034 - val_accuracy: 0.5298 - lr: 1.0000e-04
# Epoch 20/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7681 - accuracy: 0.5158
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.40.h5
# 347/347 [==============================] - 52s 149ms/step - loss: 1.7681 - accuracy: 0.5158 - val_loss: 1.5859 - val_accuracy: 0.3963 - lr: 1.0000e-04
# Epoch 21/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7477 - accuracy: 0.5219
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.55.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.7477 - accuracy: 0.5219 - val_loss: 1.2189 - val_accuracy: 0.5507 - lr: 1.0000e-04
# Epoch 22/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7417 - accuracy: 0.5217
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.51.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.7417 - accuracy: 0.5217 - val_loss: 1.2880 - val_accuracy: 0.5136 - lr: 1.0000e-04
# Epoch 23/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7152 - accuracy: 0.5318
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.47.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.7152 - accuracy: 0.5318 - val_loss: 1.4371 - val_accuracy: 0.4726 - lr: 1.0000e-04
# Epoch 24/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7000 - accuracy: 0.5415
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.56.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.7000 - accuracy: 0.5415 - val_loss: 1.2047 - val_accuracy: 0.5560 - lr: 1.0000e-04
# Epoch 25/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6807 - accuracy: 0.5417
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.54.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.6807 - accuracy: 0.5417 - val_loss: 1.2575 - val_accuracy: 0.5429 - lr: 1.0000e-04
# Epoch 26/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6722 - accuracy: 0.5443
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.55.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.6722 - accuracy: 0.5443 - val_loss: 1.3572 - val_accuracy: 0.5456 - lr: 1.0000e-04
# Epoch 27/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6591 - accuracy: 0.5490
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.45.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.6591 - accuracy: 0.5490 - val_loss: 1.2705 - val_accuracy: 0.4528 - lr: 1.0000e-04
# Epoch 28/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6566 - accuracy: 0.5463
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.48.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.6566 - accuracy: 0.5463 - val_loss: 1.2291 - val_accuracy: 0.4771 - lr: 1.0000e-04
# Epoch 29/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.5583
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.54.h5
# 347/347 [==============================] - 52s 149ms/step - loss: 1.6244 - accuracy: 0.5583 - val_loss: 1.2466 - val_accuracy: 0.5432 - lr: 1.0000e-04
# Epoch 30/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6252 - accuracy: 0.5561
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.54.h5
# 347/347 [==============================] - 53s 154ms/step - loss: 1.6252 - accuracy: 0.5561 - val_loss: 1.2584 - val_accuracy: 0.5420 - lr: 1.0000e-04
# Epoch 31/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6121 - accuracy: 0.5596
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.55.h5
# 347/347 [==============================] - 54s 154ms/step - loss: 1.6121 - accuracy: 0.5596 - val_loss: 1.2860 - val_accuracy: 0.5451 - lr: 1.0000e-04
# Epoch 32/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5914 - accuracy: 0.5645
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.58.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.5914 - accuracy: 0.5645 - val_loss: 1.2284 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 33/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5954 - accuracy: 0.5658
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.56.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.5954 - accuracy: 0.5658 - val_loss: 1.2140 - val_accuracy: 0.5605 - lr: 1.0000e-04
# Epoch 34/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5758 - accuracy: 0.5735
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.58.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.5758 - accuracy: 0.5735 - val_loss: 1.1609 - val_accuracy: 0.5825 - lr: 1.0000e-04
# Epoch 35/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5645 - accuracy: 0.5787
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.37.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.5645 - accuracy: 0.5787 - val_loss: 1.7279 - val_accuracy: 0.3676 - lr: 1.0000e-04
# Epoch 36/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5671 - accuracy: 0.5771
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.55.h5
# 347/347 [==============================] - 51s 148ms/step - loss: 1.5671 - accuracy: 0.5771 - val_loss: 1.1508 - val_accuracy: 0.5541 - lr: 1.0000e-04
# Epoch 37/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5517 - accuracy: 0.5793
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.53.h5
# 347/347 [==============================] - 52s 150ms/step - loss: 1.5517 - accuracy: 0.5793 - val_loss: 1.2331 - val_accuracy: 0.5293 - lr: 1.0000e-04
# Epoch 38/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5469 - accuracy: 0.5802
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.60.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.5469 - accuracy: 0.5802 - val_loss: 1.1447 - val_accuracy: 0.5952 - lr: 1.0000e-04
# Epoch 39/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5336 - accuracy: 0.5872
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.59.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.5336 - accuracy: 0.5872 - val_loss: 1.0866 - val_accuracy: 0.5888 - lr: 1.0000e-04
# Epoch 40/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5268 - accuracy: 0.5888
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.58.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.5268 - accuracy: 0.5888 - val_loss: 1.1141 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 41/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5186 - accuracy: 0.5922
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.53.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.5186 - accuracy: 0.5922 - val_loss: 1.2527 - val_accuracy: 0.5334 - lr: 1.0000e-04
# Epoch 42/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5089 - accuracy: 0.5943
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.61.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.5089 - accuracy: 0.5943 - val_loss: 1.1028 - val_accuracy: 0.6086 - lr: 1.0000e-04
# Epoch 43/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5090 - accuracy: 0.5920
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.49.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.5090 - accuracy: 0.5920 - val_loss: 1.2687 - val_accuracy: 0.4853 - lr: 1.0000e-04
# Epoch 44/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5027 - accuracy: 0.5920
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.59.h5
# 347/347 [==============================] - 51s 146ms/step - loss: 1.5027 - accuracy: 0.5920 - val_loss: 1.2050 - val_accuracy: 0.5867 - lr: 1.0000e-04
# Epoch 45/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4977 - accuracy: 0.5919
# Epoch 45: saving model to checkpoints_freeze\toy-model_1-epoch-45-val_accuracy-0.58.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.4977 - accuracy: 0.5919 - val_loss: 1.1582 - val_accuracy: 0.5787 - lr: 1.0000e-04
# Epoch 46/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4814 - accuracy: 0.5954
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.56.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.4814 - accuracy: 0.5954 - val_loss: 1.1215 - val_accuracy: 0.5605 - lr: 1.0000e-04
# Epoch 47/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4805 - accuracy: 0.6014
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.57.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.4805 - accuracy: 0.6014 - val_loss: 1.2096 - val_accuracy: 0.5736 - lr: 1.0000e-04
# Epoch 48/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4728 - accuracy: 0.6062
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.58.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.4728 - accuracy: 0.6062 - val_loss: 1.0955 - val_accuracy: 0.5816 - lr: 1.0000e-04
# Epoch 49/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4645 - accuracy: 0.6055
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.59.h5
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 347/347 [==============================] - 51s 147ms/step - loss: 1.4645 - accuracy: 0.6055 - val_loss: 1.1374 - val_accuracy: 0.5892 - lr: 1.0000e-04
# Epoch 50/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4331 - accuracy: 0.6152
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.61.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.4331 - accuracy: 0.6152 - val_loss: 1.0813 - val_accuracy: 0.6090 - lr: 5.0000e-05
# Epoch 51/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4288 - accuracy: 0.6198
# Epoch 51: saving model to checkpoints_freeze\toy-model_1-epoch-51-val_accuracy-0.62.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.4288 - accuracy: 0.6198 - val_loss: 1.0200 - val_accuracy: 0.6228 - lr: 5.0000e-05
# Epoch 52/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4173 - accuracy: 0.6219
# Epoch 52: saving model to checkpoints_freeze\toy-model_1-epoch-52-val_accuracy-0.62.h5
# 347/347 [==============================] - 52s 150ms/step - loss: 1.4173 - accuracy: 0.6219 - val_loss: 1.0143 - val_accuracy: 0.6188 - lr: 5.0000e-05
# Epoch 53/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4186 - accuracy: 0.6201
# Epoch 53: saving model to checkpoints_freeze\toy-model_1-epoch-53-val_accuracy-0.60.h5
# 347/347 [==============================] - 54s 155ms/step - loss: 1.4186 - accuracy: 0.6201 - val_loss: 1.0443 - val_accuracy: 0.6025 - lr: 5.0000e-05
# Epoch 54/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4141 - accuracy: 0.6231
# Epoch 54: saving model to checkpoints_freeze\toy-model_1-epoch-54-val_accuracy-0.60.h5
# 347/347 [==============================] - 51s 145ms/step - loss: 1.4141 - accuracy: 0.6231 - val_loss: 1.0965 - val_accuracy: 0.5994 - lr: 5.0000e-05
# Epoch 55/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4088 - accuracy: 0.6234
# Epoch 55: saving model to checkpoints_freeze\toy-model_1-epoch-55-val_accuracy-0.62.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 1.4088 - accuracy: 0.6234 - val_loss: 1.0339 - val_accuracy: 0.6161 - lr: 5.0000e-05
# Epoch 56/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4091 - accuracy: 0.6250
# Epoch 56: saving model to checkpoints_freeze\toy-model_1-epoch-56-val_accuracy-0.60.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.4091 - accuracy: 0.6250 - val_loss: 1.0505 - val_accuracy: 0.6003 - lr: 5.0000e-05
# Epoch 57/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3932 - accuracy: 0.6299
# Epoch 57: saving model to checkpoints_freeze\toy-model_1-epoch-57-val_accuracy-0.60.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3932 - accuracy: 0.6299 - val_loss: 1.0916 - val_accuracy: 0.6032 - lr: 5.0000e-05
# Epoch 58/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3959 - accuracy: 0.6266
# Epoch 58: saving model to checkpoints_freeze\toy-model_1-epoch-58-val_accuracy-0.62.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 1.3959 - accuracy: 0.6266 - val_loss: 1.0502 - val_accuracy: 0.6185 - lr: 5.0000e-05
# Epoch 59/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3939 - accuracy: 0.6267
# Epoch 59: saving model to checkpoints_freeze\toy-model_1-epoch-59-val_accuracy-0.61.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.3939 - accuracy: 0.6267 - val_loss: 1.0841 - val_accuracy: 0.6097 - lr: 5.0000e-05
# Epoch 60/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3857 - accuracy: 0.6294
# Epoch 60: saving model to checkpoints_freeze\toy-model_1-epoch-60-val_accuracy-0.60.h5
# 347/347 [==============================] - 56s 160ms/step - loss: 1.3857 - accuracy: 0.6294 - val_loss: 1.0595 - val_accuracy: 0.6005 - lr: 5.0000e-05
# Epoch 61/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3807 - accuracy: 0.6312
# Epoch 61: saving model to checkpoints_freeze\toy-model_1-epoch-61-val_accuracy-0.60.h5
# 347/347 [==============================] - 53s 151ms/step - loss: 1.3807 - accuracy: 0.6312 - val_loss: 1.0739 - val_accuracy: 0.5994 - lr: 5.0000e-05
# Epoch 62/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3891 - accuracy: 0.6277
# Epoch 62: saving model to checkpoints_freeze\toy-model_1-epoch-62-val_accuracy-0.62.h5
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 347/347 [==============================] - 51s 146ms/step - loss: 1.3891 - accuracy: 0.6277 - val_loss: 1.0384 - val_accuracy: 0.6170 - lr: 5.0000e-05
# Epoch 63/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3687 - accuracy: 0.6345
# Epoch 63: saving model to checkpoints_freeze\toy-model_1-epoch-63-val_accuracy-0.62.h5
# 347/347 [==============================] - 49s 139ms/step - loss: 1.3687 - accuracy: 0.6345 - val_loss: 1.0557 - val_accuracy: 0.6214 - lr: 2.5000e-05
# Epoch 64/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3653 - accuracy: 0.6381
# Epoch 64: saving model to checkpoints_freeze\toy-model_1-epoch-64-val_accuracy-0.62.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3653 - accuracy: 0.6381 - val_loss: 1.0333 - val_accuracy: 0.6225 - lr: 2.5000e-05
# Epoch 65/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3657 - accuracy: 0.6345
# Epoch 65: saving model to checkpoints_freeze\toy-model_1-epoch-65-val_accuracy-0.62.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3657 - accuracy: 0.6345 - val_loss: 1.0105 - val_accuracy: 0.6166 - lr: 2.5000e-05
# Epoch 66/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3604 - accuracy: 0.6400
# Epoch 66: saving model to checkpoints_freeze\toy-model_1-epoch-66-val_accuracy-0.62.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3604 - accuracy: 0.6400 - val_loss: 1.0477 - val_accuracy: 0.6210 - lr: 2.5000e-05
# Epoch 67/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3596 - accuracy: 0.6410
# Epoch 67: saving model to checkpoints_freeze\toy-model_1-epoch-67-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3596 - accuracy: 0.6410 - val_loss: 0.9951 - val_accuracy: 0.6324 - lr: 2.5000e-05
# Epoch 68/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3499 - accuracy: 0.6424
# Epoch 68: saving model to checkpoints_freeze\toy-model_1-epoch-68-val_accuracy-0.61.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.3499 - accuracy: 0.6424 - val_loss: 1.0608 - val_accuracy: 0.6068 - lr: 2.5000e-05
# Epoch 69/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3574 - accuracy: 0.6398
# Epoch 69: saving model to checkpoints_freeze\toy-model_1-epoch-69-val_accuracy-0.62.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.3574 - accuracy: 0.6398 - val_loss: 1.0272 - val_accuracy: 0.6159 - lr: 2.5000e-05
# Epoch 70/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3559 - accuracy: 0.6388
# Epoch 70: saving model to checkpoints_freeze\toy-model_1-epoch-70-val_accuracy-0.62.h5
# 347/347 [==============================] - 50s 142ms/step - loss: 1.3559 - accuracy: 0.6388 - val_loss: 1.0199 - val_accuracy: 0.6214 - lr: 2.5000e-05
# Epoch 71/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3541 - accuracy: 0.6376
# Epoch 71: saving model to checkpoints_freeze\toy-model_1-epoch-71-val_accuracy-0.63.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.3541 - accuracy: 0.6376 - val_loss: 1.0167 - val_accuracy: 0.6306 - lr: 2.5000e-05
# Epoch 72/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3510 - accuracy: 0.6372
# Epoch 72: saving model to checkpoints_freeze\toy-model_1-epoch-72-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3510 - accuracy: 0.6372 - val_loss: 1.0293 - val_accuracy: 0.6259 - lr: 2.5000e-05
# Epoch 73/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3572 - accuracy: 0.6375
# Epoch 73: saving model to checkpoints_freeze\toy-model_1-epoch-73-val_accuracy-0.62.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3572 - accuracy: 0.6375 - val_loss: 1.0698 - val_accuracy: 0.6186 - lr: 2.5000e-05
# Epoch 74/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3499 - accuracy: 0.6438
# Epoch 74: saving model to checkpoints_freeze\toy-model_1-epoch-74-val_accuracy-0.62.h5
# 347/347 [==============================] - 49s 142ms/step - loss: 1.3499 - accuracy: 0.6438 - val_loss: 1.0293 - val_accuracy: 0.6246 - lr: 2.5000e-05
# Epoch 75/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3446 - accuracy: 0.6439
# Epoch 75: saving model to checkpoints_freeze\toy-model_1-epoch-75-val_accuracy-0.62.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.3446 - accuracy: 0.6439 - val_loss: 1.0210 - val_accuracy: 0.6243 - lr: 2.5000e-05
# Epoch 76/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3487 - accuracy: 0.6409
# Epoch 76: saving model to checkpoints_freeze\toy-model_1-epoch-76-val_accuracy-0.63.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.3487 - accuracy: 0.6409 - val_loss: 1.0062 - val_accuracy: 0.6306 - lr: 2.5000e-05
# Epoch 77/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3466 - accuracy: 0.6402
# Epoch 77: saving model to checkpoints_freeze\toy-model_1-epoch-77-val_accuracy-0.64.h5
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 347/347 [==============================] - 49s 140ms/step - loss: 1.3466 - accuracy: 0.6402 - val_loss: 1.0278 - val_accuracy: 0.6352 - lr: 2.5000e-05
# Epoch 78/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3295 - accuracy: 0.6456
# Epoch 78: saving model to checkpoints_freeze\toy-model_1-epoch-78-val_accuracy-0.64.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3295 - accuracy: 0.6456 - val_loss: 0.9879 - val_accuracy: 0.6352 - lr: 1.2500e-05
# Epoch 79/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3318 - accuracy: 0.6468
# Epoch 79: saving model to checkpoints_freeze\toy-model_1-epoch-79-val_accuracy-0.62.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3318 - accuracy: 0.6468 - val_loss: 1.0546 - val_accuracy: 0.6215 - lr: 1.2500e-05
# Epoch 80/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3235 - accuracy: 0.6485
# Epoch 80: saving model to checkpoints_freeze\toy-model_1-epoch-80-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3235 - accuracy: 0.6485 - val_loss: 1.0132 - val_accuracy: 0.6315 - lr: 1.2500e-05
# Epoch 81/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3302 - accuracy: 0.6458
# Epoch 81: saving model to checkpoints_freeze\toy-model_1-epoch-81-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3302 - accuracy: 0.6458 - val_loss: 1.0086 - val_accuracy: 0.6303 - lr: 1.2500e-05
# Epoch 82/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3259 - accuracy: 0.6500
# Epoch 82: saving model to checkpoints_freeze\toy-model_1-epoch-82-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.3259 - accuracy: 0.6500 - val_loss: 1.0198 - val_accuracy: 0.6299 - lr: 1.2500e-05
# Epoch 83/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3241 - accuracy: 0.6497
# Epoch 83: saving model to checkpoints_freeze\toy-model_1-epoch-83-val_accuracy-0.62.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.3241 - accuracy: 0.6497 - val_loss: 1.0215 - val_accuracy: 0.6214 - lr: 1.2500e-05
# Epoch 84/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3296 - accuracy: 0.6428
# Epoch 84: saving model to checkpoints_freeze\toy-model_1-epoch-84-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 136ms/step - loss: 1.3296 - accuracy: 0.6428 - val_loss: 1.0491 - val_accuracy: 0.6257 - lr: 1.2500e-05
# Epoch 85/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3302 - accuracy: 0.6466
# Epoch 85: saving model to checkpoints_freeze\toy-model_1-epoch-85-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3302 - accuracy: 0.6466 - val_loss: 1.0247 - val_accuracy: 0.6265 - lr: 1.2500e-05
# Epoch 86/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3174 - accuracy: 0.6469
# Epoch 86: saving model to checkpoints_freeze\toy-model_1-epoch-86-val_accuracy-0.63.h5
# 347/347 [==============================] - 49s 139ms/step - loss: 1.3174 - accuracy: 0.6469 - val_loss: 1.0227 - val_accuracy: 0.6275 - lr: 1.2500e-05
# Epoch 87/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3242 - accuracy: 0.6459
# Epoch 87: saving model to checkpoints_freeze\toy-model_1-epoch-87-val_accuracy-0.63.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.3242 - accuracy: 0.6459 - val_loss: 1.0046 - val_accuracy: 0.6319 - lr: 1.2500e-05
# Epoch 88/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3255 - accuracy: 0.6501
# Epoch 88: saving model to checkpoints_freeze\toy-model_1-epoch-88-val_accuracy-0.63.h5
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 347/347 [==============================] - 48s 137ms/step - loss: 1.3255 - accuracy: 0.6501 - val_loss: 1.0206 - val_accuracy: 0.6268 - lr: 1.2500e-05
# Epoch 89/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3210 - accuracy: 0.6494
# Epoch 89: saving model to checkpoints_freeze\toy-model_1-epoch-89-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.3210 - accuracy: 0.6494 - val_loss: 1.0234 - val_accuracy: 0.6297 - lr: 6.2500e-06
# Epoch 90/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3166 - accuracy: 0.6535
# Epoch 90: saving model to checkpoints_freeze\toy-model_1-epoch-90-val_accuracy-0.63.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.3166 - accuracy: 0.6535 - val_loss: 1.0320 - val_accuracy: 0.6286 - lr: 6.2500e-06
# Epoch 91/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3151 - accuracy: 0.6519
# Epoch 91: saving model to checkpoints_freeze\toy-model_1-epoch-91-val_accuracy-0.63.h5
# 347/347 [==============================] - 51s 145ms/step - loss: 1.3151 - accuracy: 0.6519 - val_loss: 1.0221 - val_accuracy: 0.6290 - lr: 6.2500e-06
# Epoch 92/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3165 - accuracy: 0.6510
# Epoch 92: saving model to checkpoints_freeze\toy-model_1-epoch-92-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.3165 - accuracy: 0.6510 - val_loss: 1.0073 - val_accuracy: 0.6266 - lr: 6.2500e-06
# Epoch 93/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3191 - accuracy: 0.6506
# Epoch 93: saving model to checkpoints_freeze\toy-model_1-epoch-93-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.3191 - accuracy: 0.6506 - val_loss: 1.0229 - val_accuracy: 0.6292 - lr: 6.2500e-06
# Epoch 94/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3160 - accuracy: 0.6521
# Epoch 94: saving model to checkpoints_freeze\toy-model_1-epoch-94-val_accuracy-0.63.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.3160 - accuracy: 0.6521 - val_loss: 1.0153 - val_accuracy: 0.6270 - lr: 6.2500e-06
# Epoch 95/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3169 - accuracy: 0.6510
# Epoch 95: saving model to checkpoints_freeze\toy-model_1-epoch-95-val_accuracy-0.62.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.3169 - accuracy: 0.6510 - val_loss: 1.0400 - val_accuracy: 0.6230 - lr: 6.2500e-06
# Epoch 96/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3132 - accuracy: 0.6513
# Epoch 96: saving model to checkpoints_freeze\toy-model_1-epoch-96-val_accuracy-0.63.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.3132 - accuracy: 0.6513 - val_loss: 1.0226 - val_accuracy: 0.6265 - lr: 6.2500e-06
# Epoch 97/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3158 - accuracy: 0.6492
# Epoch 97: saving model to checkpoints_freeze\toy-model_1-epoch-97-val_accuracy-0.63.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.3158 - accuracy: 0.6492 - val_loss: 1.0168 - val_accuracy: 0.6281 - lr: 6.2500e-06
# Epoch 98/300
# 347/347 [==============================] - ETA: 0s - loss: 1.3130 - accuracy: 0.6502
# Epoch 98: saving model to checkpoints_freeze\toy-model_1-epoch-98-val_accuracy-0.63.h5
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 347/347 [==============================] - 48s 137ms/step - loss: 1.3130 - accuracy: 0.6502 - val_loss: 1.0041 - val_accuracy: 0.6326 - lr: 6.2500e-06
# Epoch 98: early stopping

# %%
save_model = model.save('EnsembleModel_100e_AffectNet.h5')

# %%
model = load_model("checkpoints_freeze/toy-model_1-epoch-20-val_accuracy-0.45.h5")

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 13ms/step
# Accuracy =  0.640625

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.78125
# 2/2 [==============================] - 0s 34ms/step
# Accuracy =  0.515625

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6334

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 66ms/step
# Accuracy: 63.33575581395349
# anger 716/5545 acc: 55.3
# disgust 517/5545 acc: 51.8
# fear 719/5545 acc: 65.0
# happy 1006/5545 acc: 90.1
# neutral 1015/5545 acc: 83.5
# sad 684/5545 acc: 51.8
# surprise 847/5545 acc: 29.2

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 63.33575581395349
# anger 716/5545 acc: 55.3
# disgust 517/5545 acc: 51.8
# fear 719/5545 acc: 65.0
# happy 1006/5545 acc: 90.1
# neutral 1015/5545 acc: 83.5
# sad 684/5545 acc: 51.8
# surprise 847/5545 acc: 29.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.52      0.55      0.54       716
#      disgust       0.45      0.52      0.48       517
#         fear       0.45      0.65      0.53       719
#        happy       0.88      0.90      0.89      1006
#      neutral       0.87      0.84      0.85      1015
#          sad       0.46      0.52      0.49       684
#     surprise       0.73      0.29      0.42       847
#
#     accuracy                           0.63      5504
#    macro avg       0.62      0.61      0.60      5504
# weighted avg       0.66      0.63      0.63      5504

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 35ms/step
# Accuracy =  0.53125
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.265625

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4092

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 63ms/step
# Accuracy: 40.91796875
# Angry 291/2100 acc: 53.6
# Disgust 293/2100 acc: 66.6
# Fear 288/2100 acc: 65.3
# Happy 296/2100 acc: 20.6
# Neutral 294/2100 acc: 2.0
# Sad 294/2100 acc: 62.9
# Surprise 292/2100 acc: 16.1

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 40.91796875
# Angry 291/2100 acc: 53.6
# Disgust 293/2100 acc: 66.6
# Fear 288/2100 acc: 65.3
# Happy 296/2100 acc: 20.6
# Neutral 294/2100 acc: 2.0
# Sad 294/2100 acc: 62.9
# Surprise 292/2100 acc: 16.1

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.43      0.54      0.48       291
#      Disgust       0.38      0.67      0.49       293
#         Fear       0.37      0.65      0.47       288
#        Happy       0.73      0.21      0.32       296
#      Neutral       0.19      0.02      0.04       294
#          Sad       0.38      0.63      0.47       294
#     Surprise       0.64      0.16      0.26       292
#
#     accuracy                           0.41      2048
#    macro avg       0.45      0.41      0.36      2048
# weighted avg       0.45      0.41      0.36      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: surprise, probability: 0.8437747955322266
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: happy, probability: 0.36709341406822205
# 1/1 [==============================] - 0s 97ms/step
# Predicted emotion class: fear, probability: 0.404416024684906
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: disgust, probability: 0.5003921985626221
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: angry, probability: 0.38605996966362
# 1/1 [==============================] - 0s 102ms/step
# Predicted emotion class: angry, probability: 0.6816534996032715
# 1/1 [==============================] - 0s 112ms/step
# Predicted emotion class: angry, probability: 0.5195986032485962
# 1/1 [==============================] - 0s 132ms/step
# Predicted emotion class: neutral, probability: 0.2666916847229004
# 1/1 [==============================] - 0s 95ms/step
# Predicted emotion class: angry, probability: 0.5524265170097351

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 7s 7s/step
# Predicted emotion class: disgust, probability: 0.14389488101005554
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.144127756357193
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: disgust, probability: 0.14397892355918884
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14381533861160278
# 1/1 [==============================] - 0s 116ms/step
# Predicted emotion class: disgust, probability: 0.14386671781539917
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14407561719417572
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: disgust, probability: 0.14387725293636322
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.1437917947769165
# 1/1 [==============================] - 0s 104ms/step
# Predicted emotion class: fear, probability: 0.14365749061107635

# %% [markdown]
# # Test with webcam

# %%
# Load the pre-trained model
model = load_model('EnsembleModel_100e_FER.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Convert the frame to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the image
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Display the image with the detected faces and their predictions
    cv2.imshow("Webcam", rgb_frame)

    # Exit the loop if the user presses the 'q' key
    if cv2.waitKey(1) == ord('q'):
        break

# Release the webcam and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
