# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D, concatenate, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
import cv2
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/train 7/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/test 7/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 22221 images belonging to 7 classes.
# Found 5545 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2093</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>520</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 22221
# 5545

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'anger', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}
# {0: 1.4106529209621994, 1: 1.961299569995222, 2: 1.4169830859509838, 3: 1.0170961347869176, 4: 1.0, 5: 1.4959912536443147, 6: 1.1947031431897555}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

   # Define input shape
   input_shape = (48, 48, 3)

   # Define input tensor
   input_tensor = tf.keras.Input(shape=input_shape)

   # Define shared convolutional layers
   conv1 = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
   conv2 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv1)
   conv3 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv2)

   # Define branch for face detection
   face_detection_branch = MaxPooling2D(pool_size=(2, 2))(conv3)
   face_detection_branch = Conv2D(128, (3, 3), padding='same', activation='relu')(face_detection_branch)
   face_detection_branch = Flatten()(face_detection_branch)
   face_detection_branch = Dense(64, activation='relu')(face_detection_branch)

   # Define branch for emotion recognition with attention mechanism
   emotion_recognition_branch = Conv2D(128, (3, 3), padding='same', activation='relu')(conv3)
   emotion_recognition_branch = MaxPooling2D(pool_size=(2, 2))(emotion_recognition_branch)
   emotion_recognition_branch = Conv2D(256, (3, 3), padding='same', activation='relu')(emotion_recognition_branch)
   emotion_recognition_branch = MaxPooling2D(pool_size=(2, 2))(emotion_recognition_branch)
   attention_size = 32
   num_heads = 4
   attention_layer = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=attention_size)(emotion_recognition_branch, emotion_recognition_branch)
   attention_layer = tf.keras.layers.LayerNormalization()(attention_layer)
   emotion_recognition_branch = Dense(128, activation='relu')(attention_layer)
   emotion_recognition_branch = Dropout(0.5)(emotion_recognition_branch)
   # Flatten the output of the emotion recognition branch
   emotion_recognition_branch = Flatten()(emotion_recognition_branch)

   # Merge the two branches
   merged = tf.keras.layers.concatenate([face_detection_branch, emotion_recognition_branch])

   # Define output layer
   output = Dense(7, activation='softmax')(merged)

   # Create the model
   model = Model(inputs=input_tensor, outputs=output)


   model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 32)   896         ['input_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 64)   18496       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 48, 48, 64)   36928       ['conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 48, 48, 128)  73856       ['conv2d_8[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 24, 24, 128)  0          ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 24, 24, 256)  295168      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 256)  0          ['conv2d_11[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 12, 12, 256)  131712     ['max_pooling2d_5[0][0]',
#  eadAttention)                                                    'max_pooling2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 64)  0           ['conv2d_8[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 12, 12, 256)  512        ['multi_head_attention_1[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  dense_4 (Dense)                (None, 12, 12, 128)  32896       ['layer_normalization_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 73728)        0           ['conv2d_9[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 12, 128)  0           ['dense_4[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4718656     ['flatten_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 18432)        0           ['dropout_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 18496)        0           ['dense_3[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  dense_5 (Dense)                (None, 7)            129479      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 5,512,455
# Trainable params: 5,512,455
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 347/347 [==============================] - ETA: 0s - loss: 2.5191 - accuracy: 0.1404
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.18.h5
# 347/347 [==============================] - 57s 151ms/step - loss: 2.5191 - accuracy: 0.1404 - val_loss: 1.9459 - val_accuracy: 0.1819 - lr: 0.0010
# Epoch 2/300
# 347/347 [==============================] - ETA: 0s - loss: 2.5165 - accuracy: 0.1408
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.13.h5
# 347/347 [==============================] - 51s 146ms/step - loss: 2.5165 - accuracy: 0.1408 - val_loss: 1.9460 - val_accuracy: 0.1255 - lr: 0.0010
# Epoch 3/300
# 347/347 [==============================] - ETA: 0s - loss: 2.5120 - accuracy: 0.1501
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.15.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 2.5120 - accuracy: 0.1501 - val_loss: 1.9424 - val_accuracy: 0.1453 - lr: 0.0010
# Epoch 4/300
# 347/347 [==============================] - ETA: 0s - loss: 2.4900 - accuracy: 0.1993
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.24.h5
# 347/347 [==============================] - 51s 146ms/step - loss: 2.4900 - accuracy: 0.1993 - val_loss: 1.8793 - val_accuracy: 0.2364 - lr: 0.0010
# Epoch 5/300
# 347/347 [==============================] - ETA: 0s - loss: 2.4118 - accuracy: 0.2427
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.27.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 2.4118 - accuracy: 0.2427 - val_loss: 1.7872 - val_accuracy: 0.2658 - lr: 0.0010
# Epoch 6/300
# 347/347 [==============================] - ETA: 0s - loss: 2.2873 - accuracy: 0.2741
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.23.h5
# 347/347 [==============================] - 50s 145ms/step - loss: 2.2873 - accuracy: 0.2741 - val_loss: 1.9855 - val_accuracy: 0.2315 - lr: 0.0010
# Epoch 7/300
# 347/347 [==============================] - ETA: 0s - loss: 2.2086 - accuracy: 0.3121
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.26.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 2.2086 - accuracy: 0.3121 - val_loss: 1.9043 - val_accuracy: 0.2649 - lr: 0.0010
# Epoch 8/300
# 347/347 [==============================] - ETA: 0s - loss: 2.1411 - accuracy: 0.3323
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.29.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 2.1411 - accuracy: 0.3323 - val_loss: 1.8574 - val_accuracy: 0.2865 - lr: 0.0010
# Epoch 9/300
# 347/347 [==============================] - ETA: 0s - loss: 2.0760 - accuracy: 0.3576
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.37.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 2.0760 - accuracy: 0.3576 - val_loss: 1.5670 - val_accuracy: 0.3690 - lr: 0.0010
# Epoch 10/300
# 347/347 [==============================] - ETA: 0s - loss: 2.0248 - accuracy: 0.3819
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.38.h5
# 347/347 [==============================] - 50s 143ms/step - loss: 2.0248 - accuracy: 0.3819 - val_loss: 1.6062 - val_accuracy: 0.3781 - lr: 0.0010
# Epoch 11/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9684 - accuracy: 0.4013
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.43.h5
# 347/347 [==============================] - 49s 141ms/step - loss: 1.9684 - accuracy: 0.4013 - val_loss: 1.4599 - val_accuracy: 0.4302 - lr: 0.0010
# Epoch 12/300
# 347/347 [==============================] - ETA: 0s - loss: 1.9325 - accuracy: 0.4200
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.35.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.9325 - accuracy: 0.4200 - val_loss: 1.7348 - val_accuracy: 0.3494 - lr: 0.0010
# Epoch 13/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8894 - accuracy: 0.4362
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.42.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.8894 - accuracy: 0.4362 - val_loss: 1.5167 - val_accuracy: 0.4168 - lr: 0.0010
# Epoch 14/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8517 - accuracy: 0.4464
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.42.h5
# 347/347 [==============================] - 49s 140ms/step - loss: 1.8517 - accuracy: 0.4464 - val_loss: 1.4431 - val_accuracy: 0.4204 - lr: 0.0010
# Epoch 15/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8270 - accuracy: 0.4637
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.39.h5
# 347/347 [==============================] - 48s 139ms/step - loss: 1.8270 - accuracy: 0.4637 - val_loss: 1.6969 - val_accuracy: 0.3868 - lr: 0.0010
# Epoch 16/300
# 347/347 [==============================] - ETA: 0s - loss: 1.8076 - accuracy: 0.4670
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.42.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.8076 - accuracy: 0.4670 - val_loss: 1.5741 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 17/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7891 - accuracy: 0.4727
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.44.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.7891 - accuracy: 0.4727 - val_loss: 1.4747 - val_accuracy: 0.4395 - lr: 0.0010
# Epoch 18/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7675 - accuracy: 0.4820
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.40.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.7675 - accuracy: 0.4820 - val_loss: 1.5468 - val_accuracy: 0.3953 - lr: 0.0010
# Epoch 19/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7463 - accuracy: 0.4886
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.44.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.7463 - accuracy: 0.4886 - val_loss: 1.4652 - val_accuracy: 0.4388 - lr: 0.0010
# Epoch 20/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7304 - accuracy: 0.4922
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.47.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.7304 - accuracy: 0.4922 - val_loss: 1.3422 - val_accuracy: 0.4698 - lr: 0.0010
# Epoch 21/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7213 - accuracy: 0.5014
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.51.h5
# 347/347 [==============================] - 48s 138ms/step - loss: 1.7213 - accuracy: 0.5014 - val_loss: 1.2518 - val_accuracy: 0.5078 - lr: 0.0010
# Epoch 22/300
# 347/347 [==============================] - ETA: 0s - loss: 1.7013 - accuracy: 0.5055
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.46.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.7013 - accuracy: 0.5055 - val_loss: 1.4224 - val_accuracy: 0.4604 - lr: 0.0010
# Epoch 23/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6904 - accuracy: 0.5120
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.47.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.6904 - accuracy: 0.5120 - val_loss: 1.4157 - val_accuracy: 0.4673 - lr: 0.0010
# Epoch 24/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6754 - accuracy: 0.5116
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.43.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.6754 - accuracy: 0.5116 - val_loss: 1.5751 - val_accuracy: 0.4273 - lr: 0.0010
# Epoch 25/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6657 - accuracy: 0.5183
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.46.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.6657 - accuracy: 0.5183 - val_loss: 1.4420 - val_accuracy: 0.4584 - lr: 0.0010
# Epoch 26/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6427 - accuracy: 0.5278
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.48.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.6427 - accuracy: 0.5278 - val_loss: 1.3757 - val_accuracy: 0.4802 - lr: 0.0010
# Epoch 27/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6290 - accuracy: 0.5295
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.45.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.6290 - accuracy: 0.5295 - val_loss: 1.4820 - val_accuracy: 0.4524 - lr: 0.0010
# Epoch 28/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6281 - accuracy: 0.5292
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.47.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.6281 - accuracy: 0.5292 - val_loss: 1.3840 - val_accuracy: 0.4700 - lr: 0.0010
# Epoch 29/300
# 347/347 [==============================] - ETA: 0s - loss: 1.6209 - accuracy: 0.5301
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.44.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.6209 - accuracy: 0.5301 - val_loss: 1.4834 - val_accuracy: 0.4415 - lr: 0.0010
# Epoch 30/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5968 - accuracy: 0.5391
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.45.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.5968 - accuracy: 0.5391 - val_loss: 1.4664 - val_accuracy: 0.4486 - lr: 0.0010
# Epoch 31/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5890 - accuracy: 0.5424
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.49.h5
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 347/347 [==============================] - 48s 137ms/step - loss: 1.5890 - accuracy: 0.5424 - val_loss: 1.3515 - val_accuracy: 0.4944 - lr: 0.0010
# Epoch 32/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5456 - accuracy: 0.5554
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.52.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.5456 - accuracy: 0.5554 - val_loss: 1.2422 - val_accuracy: 0.5223 - lr: 5.0000e-04
# Epoch 33/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5397 - accuracy: 0.5592
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.49.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.5397 - accuracy: 0.5592 - val_loss: 1.3861 - val_accuracy: 0.4922 - lr: 5.0000e-04
# Epoch 34/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5328 - accuracy: 0.5596
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.46.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.5328 - accuracy: 0.5596 - val_loss: 1.4863 - val_accuracy: 0.4608 - lr: 5.0000e-04
# Epoch 35/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5208 - accuracy: 0.5647
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.48.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.5208 - accuracy: 0.5647 - val_loss: 1.3772 - val_accuracy: 0.4775 - lr: 5.0000e-04
# Epoch 36/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5202 - accuracy: 0.5686
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.48.h5
# 347/347 [==============================] - 48s 137ms/step - loss: 1.5202 - accuracy: 0.5686 - val_loss: 1.4142 - val_accuracy: 0.4827 - lr: 5.0000e-04
# Epoch 37/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5061 - accuracy: 0.5712
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.52.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.5061 - accuracy: 0.5712 - val_loss: 1.2889 - val_accuracy: 0.5209 - lr: 5.0000e-04
# Epoch 38/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5077 - accuracy: 0.5703
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.48.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.5077 - accuracy: 0.5703 - val_loss: 1.4491 - val_accuracy: 0.4818 - lr: 5.0000e-04
# Epoch 39/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5065 - accuracy: 0.5715
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.50.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.5065 - accuracy: 0.5715 - val_loss: 1.3550 - val_accuracy: 0.5049 - lr: 5.0000e-04
# Epoch 40/300
# 347/347 [==============================] - ETA: 0s - loss: 1.5011 - accuracy: 0.5761
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.49.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.5011 - accuracy: 0.5761 - val_loss: 1.3986 - val_accuracy: 0.4880 - lr: 5.0000e-04
# Epoch 41/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4915 - accuracy: 0.5774
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.50.h5
# 347/347 [==============================] - 47s 136ms/step - loss: 1.4915 - accuracy: 0.5774 - val_loss: 1.3781 - val_accuracy: 0.5007 - lr: 5.0000e-04
# Epoch 42/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4842 - accuracy: 0.5773
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.48.h5
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 347/347 [==============================] - 47s 136ms/step - loss: 1.4842 - accuracy: 0.5773 - val_loss: 1.4763 - val_accuracy: 0.4780 - lr: 5.0000e-04
# Epoch 43/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4712 - accuracy: 0.5853
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.46.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.4712 - accuracy: 0.5853 - val_loss: 1.5366 - val_accuracy: 0.4604 - lr: 2.5000e-04
# Epoch 44/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4564 - accuracy: 0.5855
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.52.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.4564 - accuracy: 0.5855 - val_loss: 1.3441 - val_accuracy: 0.5222 - lr: 2.5000e-04
# Epoch 45/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4550 - accuracy: 0.5893
# Epoch 45: saving model to checkpoints_freeze\toy-model_1-epoch-45-val_accuracy-0.47.h5
# 347/347 [==============================] - 50s 144ms/step - loss: 1.4550 - accuracy: 0.5893 - val_loss: 1.4927 - val_accuracy: 0.4737 - lr: 2.5000e-04
# Epoch 46/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4492 - accuracy: 0.5890
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.44.h5
# 347/347 [==============================] - 51s 147ms/step - loss: 1.4492 - accuracy: 0.5890 - val_loss: 1.6623 - val_accuracy: 0.4426 - lr: 2.5000e-04
# Epoch 47/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4499 - accuracy: 0.5853
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.47.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.4499 - accuracy: 0.5853 - val_loss: 1.4979 - val_accuracy: 0.4717 - lr: 2.5000e-04
# Epoch 48/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4443 - accuracy: 0.5907
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.46.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.4443 - accuracy: 0.5907 - val_loss: 1.5534 - val_accuracy: 0.4635 - lr: 2.5000e-04
# Epoch 49/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4377 - accuracy: 0.5898
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.49.h5
# 347/347 [==============================] - 47s 134ms/step - loss: 1.4377 - accuracy: 0.5898 - val_loss: 1.4235 - val_accuracy: 0.4938 - lr: 2.5000e-04
# Epoch 50/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4270 - accuracy: 0.5944
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.47.h5
# 347/347 [==============================] - 47s 134ms/step - loss: 1.4270 - accuracy: 0.5944 - val_loss: 1.4864 - val_accuracy: 0.4742 - lr: 2.5000e-04
# Epoch 51/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4294 - accuracy: 0.5929
# Epoch 51: saving model to checkpoints_freeze\toy-model_1-epoch-51-val_accuracy-0.48.h5
# 347/347 [==============================] - 47s 135ms/step - loss: 1.4294 - accuracy: 0.5929 - val_loss: 1.4632 - val_accuracy: 0.4786 - lr: 2.5000e-04
# Epoch 52/300
# 347/347 [==============================] - ETA: 0s - loss: 1.4249 - accuracy: 0.5950
# Epoch 52: saving model to checkpoints_freeze\toy-model_1-epoch-52-val_accuracy-0.52.h5
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 347/347 [==============================] - 47s 134ms/step - loss: 1.4249 - accuracy: 0.5950 - val_loss: 1.3152 - val_accuracy: 0.5173 - lr: 2.5000e-04
# Epoch 52: early stopping

# %%
save_model = model.save('SMMB_100e_AffectNet.h5')

# %%
model = load_model("EnsembleModel_100e_FER.h5")

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 12ms/step
# Accuracy =  0.5

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 71ms/step
# Accuracy =  0.671875
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5178

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 46ms/step
# Accuracy: 51.78052325581395
# anger 718/5545 acc: 49.0
# disgust 517/5545 acc: 48.0
# fear 718/5545 acc: 64.5
# happy 1003/5545 acc: 75.2
# neutral 1015/5545 acc: 53.4
# sad 683/5545 acc: 43.8
# surprise 850/5545 acc: 22.6

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 51.78052325581395
# anger 718/5545 acc: 49.0
# disgust 517/5545 acc: 48.0
# fear 718/5545 acc: 64.5
# happy 1003/5545 acc: 75.2
# neutral 1015/5545 acc: 53.4
# sad 683/5545 acc: 43.8
# surprise 850/5545 acc: 22.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.43      0.49      0.46       718
#      disgust       0.29      0.48      0.36       517
#         fear       0.38      0.64      0.48       718
#        happy       0.92      0.75      0.83      1003
#      neutral       0.86      0.53      0.66      1015
#          sad       0.40      0.44      0.42       683
#     surprise       0.45      0.23      0.30       850
#
#     accuracy                           0.52      5504
#    macro avg       0.53      0.51      0.50      5504
# weighted avg       0.58      0.52      0.53      5504

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 73ms/step
# Accuracy =  0.53125
# 2/2 [==============================] - 0s 70ms/step
# Accuracy =  0.265625

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3921

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 53ms/step
# Accuracy: 39.208984375
# Angry 291/2100 acc: 59.1
# Disgust 294/2100 acc: 61.9
# Fear 287/2100 acc: 72.1
# Happy 291/2100 acc: 14.4
# Neutral 295/2100 acc: 0.3
# Sad 297/2100 acc: 55.9
# Surprise 293/2100 acc: 11.3

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 39.208984375
# Angry 291/2100 acc: 59.1
# Disgust 294/2100 acc: 61.9
# Fear 287/2100 acc: 72.1
# Happy 291/2100 acc: 14.4
# Neutral 295/2100 acc: 0.3
# Sad 297/2100 acc: 55.9
# Surprise 293/2100 acc: 11.3

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.48      0.59      0.53       291
#      Disgust       0.36      0.62      0.45       294
#         Fear       0.37      0.72      0.49       287
#        Happy       0.81      0.14      0.24       291
#      Neutral       0.05      0.00      0.01       295
#          Sad       0.38      0.56      0.45       297
#     Surprise       0.33      0.11      0.17       293
#
#     accuracy                           0.39      2048
#    macro avg       0.39      0.39      0.33      2048
# weighted avg       0.39      0.39      0.33      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 7s 7s/step
# Predicted emotion class: disgust, probability: 0.14389488101005554
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.144127756357193
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: disgust, probability: 0.14397892355918884
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14381533861160278
# 1/1 [==============================] - 0s 116ms/step
# Predicted emotion class: disgust, probability: 0.14386671781539917
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14407561719417572
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: disgust, probability: 0.14387725293636322
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.1437917947769165
# 1/1 [==============================] - 0s 104ms/step
# Predicted emotion class: fear, probability: 0.14365749061107635

# %% [markdown]
# # Test with webcam

# %%
# Load the pre-trained model
model = load_model('EnsembleModel_100e_FER.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Convert the frame to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the image
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Display the image with the detected faces and their predictions
    cv2.imshow("Webcam", rgb_frame)

    # Exit the loop if the user presses the 'q' key
    if cv2.waitKey(1) == ord('q'):
        break

# Release the webcam and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
