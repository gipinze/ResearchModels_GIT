# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
import tensorflow as tf
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
import keras.backend as K
import random
from keras.models import Model, Sequential, load_model
from keras.optimizers import Adam
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from collections import Counter
import matplotlib.pyplot as plt
from IPython.display import Image, HTML
import pandas as pd
import numpy as np
from keras.metrics import AUC, Precision, Recall, Accuracy
from sklearn.metrics import f1_score
from keras.callbacks import LambdaCallback
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report

# %%
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT =48
IMG_WIDTH = 48
CHANNELS = 3

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

    model = Sequential()

    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,3)))

    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(7, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 2,489,671
# Trainable params: 2,489,671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 167/167 [==============================] - ETA: 0s - loss: 5.2157 - accuracy: 0.1703
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.29.h5
# 167/167 [==============================] - 33s 77ms/step - loss: 5.2157 - accuracy: 0.1703 - val_loss: 1.9194 - val_accuracy: 0.2901 - lr: 0.0010
# Epoch 2/300
# 167/167 [==============================] - ETA: 0s - loss: 5.1010 - accuracy: 0.3024
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.27.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 5.1010 - accuracy: 0.3024 - val_loss: 1.8806 - val_accuracy: 0.2738 - lr: 0.0010
# Epoch 3/300
# 167/167 [==============================] - ETA: 0s - loss: 5.0401 - accuracy: 0.2902
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.23.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 5.0401 - accuracy: 0.2902 - val_loss: 1.9476 - val_accuracy: 0.2322 - lr: 0.0010
# Epoch 4/300
# 167/167 [==============================] - ETA: 0s - loss: 4.9719 - accuracy: 0.3023
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.26.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.9719 - accuracy: 0.3023 - val_loss: 1.9785 - val_accuracy: 0.2570 - lr: 0.0010
# Epoch 5/300
# 167/167 [==============================] - ETA: 0s - loss: 4.9034 - accuracy: 0.2946
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.28.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 4.9034 - accuracy: 0.2946 - val_loss: 1.8198 - val_accuracy: 0.2819 - lr: 0.0010
# Epoch 6/300
# 167/167 [==============================] - ETA: 0s - loss: 4.8881 - accuracy: 0.2818
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.33.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 4.8881 - accuracy: 0.2818 - val_loss: 1.7824 - val_accuracy: 0.3330 - lr: 0.0010
# Epoch 7/300
# 167/167 [==============================] - ETA: 0s - loss: 4.8249 - accuracy: 0.2942
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.29.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 4.8249 - accuracy: 0.2942 - val_loss: 1.9020 - val_accuracy: 0.2940 - lr: 0.0010
# Epoch 8/300
# 167/167 [==============================] - ETA: 0s - loss: 4.7792 - accuracy: 0.2950
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.35.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 4.7792 - accuracy: 0.2950 - val_loss: 1.7036 - val_accuracy: 0.3526 - lr: 0.0010
# Epoch 9/300
# 167/167 [==============================] - ETA: 0s - loss: 4.6482 - accuracy: 0.3270
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.31.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 4.6482 - accuracy: 0.3270 - val_loss: 1.7981 - val_accuracy: 0.3123 - lr: 0.0010
# Epoch 10/300
# 167/167 [==============================] - ETA: 0s - loss: 4.5822 - accuracy: 0.3374
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.39.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 4.5822 - accuracy: 0.3374 - val_loss: 1.6607 - val_accuracy: 0.3853 - lr: 0.0010
# Epoch 11/300
# 167/167 [==============================] - ETA: 0s - loss: 4.4145 - accuracy: 0.3823
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.35.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 4.4145 - accuracy: 0.3823 - val_loss: 1.8474 - val_accuracy: 0.3521 - lr: 0.0010
# Epoch 12/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2862 - accuracy: 0.4001
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.47.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 4.2862 - accuracy: 0.4001 - val_loss: 1.4554 - val_accuracy: 0.4676 - lr: 0.0010
# Epoch 13/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2515 - accuracy: 0.4148
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 4.2515 - accuracy: 0.4148 - val_loss: 1.3878 - val_accuracy: 0.5073 - lr: 0.0010
# Epoch 14/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1443 - accuracy: 0.4388
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.50.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 4.1443 - accuracy: 0.4388 - val_loss: 1.4233 - val_accuracy: 0.4989 - lr: 0.0010
# Epoch 15/300
# 167/167 [==============================] - ETA: 0s - loss: 4.0647 - accuracy: 0.4547
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.55.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 4.0647 - accuracy: 0.4547 - val_loss: 1.2600 - val_accuracy: 0.5519 - lr: 0.0010
# Epoch 16/300
# 167/167 [==============================] - ETA: 0s - loss: 3.9529 - accuracy: 0.4678
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.56.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.9529 - accuracy: 0.4678 - val_loss: 1.2186 - val_accuracy: 0.5643 - lr: 0.0010
# Epoch 17/300
# 167/167 [==============================] - ETA: 0s - loss: 3.9296 - accuracy: 0.4771
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.9296 - accuracy: 0.4771 - val_loss: 1.3132 - val_accuracy: 0.5390 - lr: 0.0010
# Epoch 18/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8291 - accuracy: 0.4987
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.55.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.8291 - accuracy: 0.4987 - val_loss: 1.2757 - val_accuracy: 0.5511 - lr: 0.0010
# Epoch 19/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8084 - accuracy: 0.4975
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.57.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.8084 - accuracy: 0.4975 - val_loss: 1.2228 - val_accuracy: 0.5662 - lr: 0.0010
# Epoch 20/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6790 - accuracy: 0.5190
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.53.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.6790 - accuracy: 0.5190 - val_loss: 1.2973 - val_accuracy: 0.5255 - lr: 0.0010
# Epoch 21/300
# 166/167 [============================>.] - ETA: 0s - loss: 3.6776 - accuracy: 0.5136
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.61.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.6752 - accuracy: 0.5144 - val_loss: 1.1153 - val_accuracy: 0.6063 - lr: 0.0010
# Epoch 22/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6864 - accuracy: 0.5299
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.58.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.6864 - accuracy: 0.5299 - val_loss: 1.2225 - val_accuracy: 0.5797 - lr: 0.0010
# Epoch 23/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6595 - accuracy: 0.5255
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.56.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.6595 - accuracy: 0.5255 - val_loss: 1.2250 - val_accuracy: 0.5640 - lr: 0.0010
# Epoch 24/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5879 - accuracy: 0.5363
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.49.h5
# 167/167 [==============================] - 19s 111ms/step - loss: 3.5879 - accuracy: 0.5363 - val_loss: 1.4486 - val_accuracy: 0.4883 - lr: 0.0010
# Epoch 25/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5438 - accuracy: 0.5508
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.57.h5
# 167/167 [==============================] - 19s 114ms/step - loss: 3.5438 - accuracy: 0.5508 - val_loss: 1.2106 - val_accuracy: 0.5722 - lr: 0.0010
# Epoch 26/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4939 - accuracy: 0.5434
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.59.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.4939 - accuracy: 0.5434 - val_loss: 1.1348 - val_accuracy: 0.5878 - lr: 0.0010
# Epoch 27/300
# 166/167 [============================>.] - ETA: 0s - loss: 3.5017 - accuracy: 0.5494
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.59.h5
# 167/167 [==============================] - 11s 68ms/step - loss: 3.5021 - accuracy: 0.5493 - val_loss: 1.1456 - val_accuracy: 0.5891 - lr: 0.0010
# Epoch 28/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4522 - accuracy: 0.5619
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.61.h5
# 167/167 [==============================] - 11s 68ms/step - loss: 3.4522 - accuracy: 0.5619 - val_loss: 1.0860 - val_accuracy: 0.6092 - lr: 0.0010
# Epoch 29/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3488 - accuracy: 0.5632
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 68ms/step - loss: 3.3488 - accuracy: 0.5632 - val_loss: 1.0044 - val_accuracy: 0.6452 - lr: 0.0010
# Epoch 30/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3442 - accuracy: 0.5629
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.61.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.3442 - accuracy: 0.5629 - val_loss: 1.0453 - val_accuracy: 0.6114 - lr: 0.0010
# Epoch 31/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3155 - accuracy: 0.5641
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.64.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.3155 - accuracy: 0.5641 - val_loss: 1.0121 - val_accuracy: 0.6380 - lr: 0.0010
# Epoch 32/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2922 - accuracy: 0.5689
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.58.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2922 - accuracy: 0.5689 - val_loss: 1.1632 - val_accuracy: 0.5803 - lr: 0.0010
# Epoch 33/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3202 - accuracy: 0.5679
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.63.h5
# 167/167 [==============================] - 16s 96ms/step - loss: 3.3202 - accuracy: 0.5679 - val_loss: 1.0122 - val_accuracy: 0.6261 - lr: 0.0010
# Epoch 34/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2481 - accuracy: 0.5768
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.58.h5
# 167/167 [==============================] - 18s 110ms/step - loss: 3.2481 - accuracy: 0.5768 - val_loss: 1.1415 - val_accuracy: 0.5816 - lr: 0.0010
# Epoch 35/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2706 - accuracy: 0.5754
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.64.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2706 - accuracy: 0.5754 - val_loss: 1.0012 - val_accuracy: 0.6417 - lr: 0.0010
# Epoch 36/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3026 - accuracy: 0.5748
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.63.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3026 - accuracy: 0.5748 - val_loss: 1.0008 - val_accuracy: 0.6334 - lr: 0.0010
# Epoch 37/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2150 - accuracy: 0.5819
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.63.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2150 - accuracy: 0.5819 - val_loss: 1.0124 - val_accuracy: 0.6320 - lr: 0.0010
# Epoch 38/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2322 - accuracy: 0.5788
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.61.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2322 - accuracy: 0.5788 - val_loss: 1.0602 - val_accuracy: 0.6140 - lr: 0.0010
# Epoch 39/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1930 - accuracy: 0.5845
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.59.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.1930 - accuracy: 0.5845 - val_loss: 1.1259 - val_accuracy: 0.5882 - lr: 0.0010
# Epoch 40/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2047 - accuracy: 0.5804
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.63.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.2047 - accuracy: 0.5804 - val_loss: 1.0557 - val_accuracy: 0.6261 - lr: 0.0010
# Epoch 41/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1765 - accuracy: 0.5912
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.65.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.1765 - accuracy: 0.5912 - val_loss: 0.9829 - val_accuracy: 0.6534 - lr: 0.0010
# Epoch 42/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1361 - accuracy: 0.5951
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.60.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.1361 - accuracy: 0.5951 - val_loss: 1.0940 - val_accuracy: 0.5968 - lr: 0.0010
# Epoch 43/300
# 166/167 [============================>.] - ETA: 0s - loss: 3.1509 - accuracy: 0.5851
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.63.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 3.1523 - accuracy: 0.5856 - val_loss: 1.0420 - val_accuracy: 0.6340 - lr: 0.0010
# Epoch 44/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0963 - accuracy: 0.5972
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.66.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 3.0963 - accuracy: 0.5972 - val_loss: 0.9440 - val_accuracy: 0.6615 - lr: 0.0010
# Epoch 45/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1067 - accuracy: 0.6016
# Epoch 45: saving model to checkpoints_freeze\toy-model_1-epoch-45-val_accuracy-0.62.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.1067 - accuracy: 0.6016 - val_loss: 1.0245 - val_accuracy: 0.6199 - lr: 0.0010
# Epoch 46/300
# 166/167 [============================>.] - ETA: 0s - loss: 3.0870 - accuracy: 0.5956
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 3.0839 - accuracy: 0.5955 - val_loss: 0.9637 - val_accuracy: 0.6518 - lr: 0.0010
# Epoch 47/300
# 167/167 [==============================] - ETA: 0s - loss: 2.9883 - accuracy: 0.6070
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 2.9883 - accuracy: 0.6070 - val_loss: 0.9655 - val_accuracy: 0.6477 - lr: 0.0010
# Epoch 48/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0684 - accuracy: 0.6017
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.0684 - accuracy: 0.6017 - val_loss: 0.9659 - val_accuracy: 0.6527 - lr: 0.0010
# Epoch 49/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0528 - accuracy: 0.6035
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.64.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.0528 - accuracy: 0.6035 - val_loss: 1.0119 - val_accuracy: 0.6430 - lr: 0.0010
# Epoch 50/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0802 - accuracy: 0.6047
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.59.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 3.0802 - accuracy: 0.6047 - val_loss: 1.1244 - val_accuracy: 0.5942 - lr: 0.0010
# Epoch 51/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0015 - accuracy: 0.6111
# Epoch 51: saving model to checkpoints_freeze\toy-model_1-epoch-51-val_accuracy-0.61.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 3.0015 - accuracy: 0.6111 - val_loss: 1.0653 - val_accuracy: 0.6142 - lr: 0.0010
# Epoch 52/300
# 167/167 [==============================] - ETA: 0s - loss: 2.9626 - accuracy: 0.6099
# Epoch 52: saving model to checkpoints_freeze\toy-model_1-epoch-52-val_accuracy-0.62.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.9626 - accuracy: 0.6099 - val_loss: 1.0615 - val_accuracy: 0.6162 - lr: 0.0010
# Epoch 53/300
# 167/167 [==============================] - ETA: 0s - loss: 2.9446 - accuracy: 0.6103
# Epoch 53: saving model to checkpoints_freeze\toy-model_1-epoch-53-val_accuracy-0.64.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.9446 - accuracy: 0.6103 - val_loss: 1.0090 - val_accuracy: 0.6404 - lr: 0.0010
# Epoch 54/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0325 - accuracy: 0.6075
# Epoch 54: saving model to checkpoints_freeze\toy-model_1-epoch-54-val_accuracy-0.64.h5
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 167/167 [==============================] - 11s 66ms/step - loss: 3.0325 - accuracy: 0.6075 - val_loss: 0.9767 - val_accuracy: 0.6384 - lr: 0.0010
# Epoch 55/300
# 167/167 [==============================] - ETA: 0s - loss: 2.9167 - accuracy: 0.6126
# Epoch 55: saving model to checkpoints_freeze\toy-model_1-epoch-55-val_accuracy-0.62.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.9167 - accuracy: 0.6126 - val_loss: 1.0251 - val_accuracy: 0.6202 - lr: 5.0000e-04
# Epoch 56/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8126 - accuracy: 0.6343
# Epoch 56: saving model to checkpoints_freeze\toy-model_1-epoch-56-val_accuracy-0.62.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.8126 - accuracy: 0.6343 - val_loss: 1.0428 - val_accuracy: 0.6155 - lr: 5.0000e-04
# Epoch 57/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8643 - accuracy: 0.6284
# Epoch 57: saving model to checkpoints_freeze\toy-model_1-epoch-57-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.8643 - accuracy: 0.6284 - val_loss: 0.9595 - val_accuracy: 0.6505 - lr: 5.0000e-04
# Epoch 58/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8310 - accuracy: 0.6247
# Epoch 58: saving model to checkpoints_freeze\toy-model_1-epoch-58-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.8310 - accuracy: 0.6247 - val_loss: 0.9827 - val_accuracy: 0.6459 - lr: 5.0000e-04
# Epoch 59/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7624 - accuracy: 0.6380
# Epoch 59: saving model to checkpoints_freeze\toy-model_1-epoch-59-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.7624 - accuracy: 0.6380 - val_loss: 0.9201 - val_accuracy: 0.6675 - lr: 5.0000e-04
# Epoch 60/300
# 167/167 [==============================] - ETA: 0s - loss: 2.8071 - accuracy: 0.6324
# Epoch 60: saving model to checkpoints_freeze\toy-model_1-epoch-60-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.8071 - accuracy: 0.6324 - val_loss: 0.9297 - val_accuracy: 0.6655 - lr: 5.0000e-04
# Epoch 61/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7499 - accuracy: 0.6352
# Epoch 61: saving model to checkpoints_freeze\toy-model_1-epoch-61-val_accuracy-0.66.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.7499 - accuracy: 0.6352 - val_loss: 0.9590 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 62/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7709 - accuracy: 0.6322
# Epoch 62: saving model to checkpoints_freeze\toy-model_1-epoch-62-val_accuracy-0.60.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.7709 - accuracy: 0.6322 - val_loss: 1.0592 - val_accuracy: 0.6021 - lr: 5.0000e-04
# Epoch 63/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7695 - accuracy: 0.6346
# Epoch 63: saving model to checkpoints_freeze\toy-model_1-epoch-63-val_accuracy-0.66.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.7695 - accuracy: 0.6346 - val_loss: 0.9347 - val_accuracy: 0.6629 - lr: 5.0000e-04
# Epoch 64/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7411 - accuracy: 0.6411
# Epoch 64: saving model to checkpoints_freeze\toy-model_1-epoch-64-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.7411 - accuracy: 0.6411 - val_loss: 0.9505 - val_accuracy: 0.6525 - lr: 5.0000e-04
# Epoch 65/300
# 167/167 [==============================] - ETA: 0s - loss: 2.7180 - accuracy: 0.6392
# Epoch 65: saving model to checkpoints_freeze\toy-model_1-epoch-65-val_accuracy-0.68.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.7180 - accuracy: 0.6392 - val_loss: 0.8825 - val_accuracy: 0.6789 - lr: 5.0000e-04
# Epoch 66/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6823 - accuracy: 0.6416
# Epoch 66: saving model to checkpoints_freeze\toy-model_1-epoch-66-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 67ms/step - loss: 2.6823 - accuracy: 0.6416 - val_loss: 0.8739 - val_accuracy: 0.6857 - lr: 5.0000e-04
# Epoch 67/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6935 - accuracy: 0.6453
# Epoch 67: saving model to checkpoints_freeze\toy-model_1-epoch-67-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.6935 - accuracy: 0.6453 - val_loss: 0.8695 - val_accuracy: 0.6921 - lr: 5.0000e-04
# Epoch 68/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6570 - accuracy: 0.6443
# Epoch 68: saving model to checkpoints_freeze\toy-model_1-epoch-68-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.6570 - accuracy: 0.6443 - val_loss: 0.8933 - val_accuracy: 0.6871 - lr: 5.0000e-04
# Epoch 69/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6894 - accuracy: 0.6413
# Epoch 69: saving model to checkpoints_freeze\toy-model_1-epoch-69-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.6894 - accuracy: 0.6413 - val_loss: 0.9414 - val_accuracy: 0.6699 - lr: 5.0000e-04
# Epoch 70/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6550 - accuracy: 0.6500
# Epoch 70: saving model to checkpoints_freeze\toy-model_1-epoch-70-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6550 - accuracy: 0.6500 - val_loss: 0.9476 - val_accuracy: 0.6664 - lr: 5.0000e-04
# Epoch 71/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6582 - accuracy: 0.6510
# Epoch 71: saving model to checkpoints_freeze\toy-model_1-epoch-71-val_accuracy-0.64.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6582 - accuracy: 0.6510 - val_loss: 0.9850 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 72/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6685 - accuracy: 0.6482
# Epoch 72: saving model to checkpoints_freeze\toy-model_1-epoch-72-val_accuracy-0.65.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6685 - accuracy: 0.6482 - val_loss: 0.9813 - val_accuracy: 0.6459 - lr: 5.0000e-04
# Epoch 73/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6207 - accuracy: 0.6492
# Epoch 73: saving model to checkpoints_freeze\toy-model_1-epoch-73-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6207 - accuracy: 0.6492 - val_loss: 0.9174 - val_accuracy: 0.6710 - lr: 5.0000e-04
# Epoch 74/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6726 - accuracy: 0.6456
# Epoch 74: saving model to checkpoints_freeze\toy-model_1-epoch-74-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6726 - accuracy: 0.6456 - val_loss: 0.8816 - val_accuracy: 0.6862 - lr: 5.0000e-04
# Epoch 75/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6377 - accuracy: 0.6515
# Epoch 75: saving model to checkpoints_freeze\toy-model_1-epoch-75-val_accuracy-0.66.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6377 - accuracy: 0.6515 - val_loss: 0.9350 - val_accuracy: 0.6574 - lr: 5.0000e-04
# Epoch 76/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6715 - accuracy: 0.6455
# Epoch 76: saving model to checkpoints_freeze\toy-model_1-epoch-76-val_accuracy-0.68.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.6715 - accuracy: 0.6455 - val_loss: 0.8919 - val_accuracy: 0.6807 - lr: 5.0000e-04
# Epoch 77/300
# 167/167 [==============================] - ETA: 0s - loss: 2.6400 - accuracy: 0.6462
# Epoch 77: saving model to checkpoints_freeze\toy-model_1-epoch-77-val_accuracy-0.62.h5
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 167/167 [==============================] - 11s 66ms/step - loss: 2.6400 - accuracy: 0.6462 - val_loss: 1.0533 - val_accuracy: 0.6243 - lr: 5.0000e-04
# Epoch 78/300
# 167/167 [==============================] - ETA: 0s - loss: 2.5795 - accuracy: 0.6558
# Epoch 78: saving model to checkpoints_freeze\toy-model_1-epoch-78-val_accuracy-0.68.h5
# 167/167 [==============================] - 11s 66ms/step - loss: 2.5795 - accuracy: 0.6558 - val_loss: 0.9020 - val_accuracy: 0.6842 - lr: 2.5000e-04
# Epoch 79/300
# 167/167 [==============================] - ETA: 0s - loss: 2.5372 - accuracy: 0.6645
# Epoch 79: saving model to checkpoints_freeze\toy-model_1-epoch-79-val_accuracy-0.70.h5
# 167/167 [==============================] - 11s 65ms/step - loss: 2.5372 - accuracy: 0.6645 - val_loss: 0.8709 - val_accuracy: 0.6954 - lr: 2.5000e-04
# Epoch 80/300
# 167/167 [==============================] - ETA: 0s - loss: 2.5456 - accuracy: 0.6667
# Epoch 80: saving model to checkpoints_freeze\toy-model_1-epoch-80-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.5456 - accuracy: 0.6667 - val_loss: 0.8887 - val_accuracy: 0.6868 - lr: 2.5000e-04
# Epoch 81/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4989 - accuracy: 0.6604
# Epoch 81: saving model to checkpoints_freeze\toy-model_1-epoch-81-val_accuracy-0.68.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.4989 - accuracy: 0.6604 - val_loss: 0.9004 - val_accuracy: 0.6844 - lr: 2.5000e-04
# Epoch 82/300
# 166/167 [============================>.] - ETA: 0s - loss: 2.5445 - accuracy: 0.6629
# Epoch 82: saving model to checkpoints_freeze\toy-model_1-epoch-82-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.5379 - accuracy: 0.6631 - val_loss: 0.8788 - val_accuracy: 0.6888 - lr: 2.5000e-04
# Epoch 83/300
# 167/167 [==============================] - ETA: 0s - loss: 2.5051 - accuracy: 0.6585
# Epoch 83: saving model to checkpoints_freeze\toy-model_1-epoch-83-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.5051 - accuracy: 0.6585 - val_loss: 0.8725 - val_accuracy: 0.6945 - lr: 2.5000e-04
# Epoch 84/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4696 - accuracy: 0.6672
# Epoch 84: saving model to checkpoints_freeze\toy-model_1-epoch-84-val_accuracy-0.69.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.4696 - accuracy: 0.6672 - val_loss: 0.8768 - val_accuracy: 0.6910 - lr: 2.5000e-04
# Epoch 85/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4783 - accuracy: 0.6645
# Epoch 85: saving model to checkpoints_freeze\toy-model_1-epoch-85-val_accuracy-0.67.h5
# 167/167 [==============================] - 11s 64ms/step - loss: 2.4783 - accuracy: 0.6645 - val_loss: 0.9212 - val_accuracy: 0.6719 - lr: 2.5000e-04
# Epoch 86/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4890 - accuracy: 0.6660
# Epoch 86: saving model to checkpoints_freeze\toy-model_1-epoch-86-val_accuracy-0.69.h5
# 167/167 [==============================] - 16s 97ms/step - loss: 2.4890 - accuracy: 0.6660 - val_loss: 0.8799 - val_accuracy: 0.6912 - lr: 2.5000e-04
# Epoch 87/300
# 167/167 [==============================] - ETA: 0s - loss: 2.4954 - accuracy: 0.6638
# Epoch 87: saving model to checkpoints_freeze\toy-model_1-epoch-87-val_accuracy-0.67.h5
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 167/167 [==============================] - 14s 81ms/step - loss: 2.4954 - accuracy: 0.6638 - val_loss: 0.9127 - val_accuracy: 0.6728 - lr: 2.5000e-04
# Epoch 87: early stopping

# %%
save_model = model.save('Sequential1_AffectNet.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 6ms/step
# Accuracy =  0.71875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 18ms/step
# Accuracy =  0.828125
# 2/2 [==============================] - 0s 17ms/step
# Accuracy =  0.578125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6710

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# Accuracy: 67.09947183098592
# Angry 260/4606 acc: 73.1
# Disgust 261/4606 acc: 64.0
# Fear 106/4606 acc: 59.4
# Happy 1763/4606 acc: 74.8
# Neutral 951/4606 acc: 52.9
# Sad 720/4606 acc: 67.4
# Surprise 483/4606 acc: 66.7

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 67.09947183098592
# Angry 260/4606 acc: 73.1
# Disgust 261/4606 acc: 64.0
# Fear 106/4606 acc: 59.4
# Happy 1763/4606 acc: 74.8
# Neutral 951/4606 acc: 52.9
# Sad 720/4606 acc: 67.4
# Surprise 483/4606 acc: 66.7

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.54      0.73      0.62       260
#      Disgust       0.28      0.64      0.39       261
#         Fear       0.21      0.59      0.31       106
#        Happy       0.95      0.75      0.84      1763
#      Neutral       0.76      0.53      0.62       951
#          Sad       0.60      0.67      0.63       720
#     Surprise       0.75      0.67      0.70       483
#
#     accuracy                           0.67      4544
#    macro avg       0.58      0.65      0.59      4544
# weighted avg       0.75      0.67      0.70      4544

# %% [markdown]
# # Unseen Batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 18ms/step
# Accuracy =  0.625
# 2/2 [==============================] - 0s 17ms/step
# Accuracy =  0.359375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4805

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 19ms/step
# Accuracy: 48.046875
# Angry 292/2100 acc: 69.2
# Disgust 293/2100 acc: 41.3
# Fear 293/2100 acc: 40.6
# Happy 293/2100 acc: 57.7
# Neutral 292/2100 acc: 44.2
# Sad 288/2100 acc: 38.2
# Surprise 297/2100 acc: 45.1

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 48.046875
# Angry 292/2100 acc: 69.2
# Disgust 293/2100 acc: 41.3
# Fear 293/2100 acc: 40.6
# Happy 293/2100 acc: 57.7
# Neutral 292/2100 acc: 44.2
# Sad 288/2100 acc: 38.2
# Surprise 297/2100 acc: 45.1

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.40      0.69      0.51       292
#      Disgust       0.41      0.41      0.41       293
#         Fear       0.43      0.41      0.42       293
#        Happy       0.69      0.58      0.63       293
#      Neutral       0.58      0.44      0.50       292
#          Sad       0.47      0.38      0.42       288
#     Surprise       0.49      0.45      0.47       297
#
#     accuracy                           0.48      2048
#    macro avg       0.50      0.48      0.48      2048
# weighted avg       0.50      0.48      0.48      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Test with video

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
model = load_model('ModularMNN_191e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Initialize the video capture object
cap = cv2.VideoCapture(0)

# Loop through each video frame
while True:
    # Read a video frame
    ret, frame = cap.read()
    
    # Convert the frame from BGR to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the frame
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Convert the frame from RGB to BGR format
    bgr_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2BGR)

    # Display the frame with the detected faces and their predictions
    cv2.imshow("Video", bgr_frame)

    # Wait for a key press and check if the 'q' key or the 'Esc' key was pressed
    key = cv2.waitKey(1)
    if key == ord('q') or key == 27:
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
