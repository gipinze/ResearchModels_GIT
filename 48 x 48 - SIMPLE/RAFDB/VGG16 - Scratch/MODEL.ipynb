# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input
from keras_vggface.vggface import VGGFace

from keras.applications import VGG19
from keras.layers import Dense, Dropout, Flatten, Activation, Input
from keras import regularizers
from keras.models import Model, load_model

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}

# %%
with strategy.scope():

    # Load the VGG19 model
    base_model = VGG16( 
        weights=None,
        include_top=False, 
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = False
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    x = base_model(inputs)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu')(x) 
    predictions = Dense(7, activation='softmax')(x)

    # Compile the model
    model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,879,815
# Trainable params: 165,127
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=30,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/30
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 5.2830 - accuracy: 0.1302
# Epoch 1: val_accuracy improved from -inf to 0.34419, saving model to best_model.h5
# 167/167 [==============================] - 27s 101ms/step - loss: 5.2830 - accuracy: 0.1302 - val_loss: 1.9452 - val_accuracy: 0.3442 - lr: 1.0000e-04
# Epoch 2/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2859 - accuracy: 0.3050
# Epoch 2: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 17s 100ms/step - loss: 5.2859 - accuracy: 0.3050 - val_loss: 1.9454 - val_accuracy: 0.1287 - lr: 1.0000e-04
# Epoch 3/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2916 - accuracy: 0.1009
# Epoch 3: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 98ms/step - loss: 5.2916 - accuracy: 0.1009 - val_loss: 1.9454 - val_accuracy: 0.1450 - lr: 1.0000e-04
# Epoch 4/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2925 - accuracy: 0.2558
# Epoch 4: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 98ms/step - loss: 5.2925 - accuracy: 0.2558 - val_loss: 1.9472 - val_accuracy: 0.0557 - lr: 1.0000e-04
# Epoch 5/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2913 - accuracy: 0.1815
# Epoch 5: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 98ms/step - loss: 5.2913 - accuracy: 0.1815 - val_loss: 1.9454 - val_accuracy: 0.2344 - lr: 1.0000e-04
# Epoch 6/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2885 - accuracy: 0.1142
# Epoch 6: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 98ms/step - loss: 5.2885 - accuracy: 0.1142 - val_loss: 1.9464 - val_accuracy: 0.1045 - lr: 1.0000e-04
# Epoch 7/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2869 - accuracy: 0.0940
# Epoch 7: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 94ms/step - loss: 5.2869 - accuracy: 0.0940 - val_loss: 1.9461 - val_accuracy: 0.0911 - lr: 1.0000e-04
# Epoch 8/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2886 - accuracy: 0.1859
# Epoch 8: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 98ms/step - loss: 5.2886 - accuracy: 0.1859 - val_loss: 1.9454 - val_accuracy: 0.1822 - lr: 1.0000e-04
# Epoch 9/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2931 - accuracy: 0.2793
# Epoch 9: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 97ms/step - loss: 5.2931 - accuracy: 0.2793 - val_loss: 1.9457 - val_accuracy: 0.1829 - lr: 1.0000e-04
# Epoch 10/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2888 - accuracy: 0.1711
# Epoch 10: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 93ms/step - loss: 5.2888 - accuracy: 0.1711 - val_loss: 1.9463 - val_accuracy: 0.1204 - lr: 1.0000e-04
# Epoch 11/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2871 - accuracy: 0.1339
# Epoch 11: val_accuracy did not improve from 0.34419
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 167/167 [==============================] - 16s 93ms/step - loss: 5.2871 - accuracy: 0.1339 - val_loss: 1.9457 - val_accuracy: 0.1574 - lr: 1.0000e-04
# Epoch 12/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2954 - accuracy: 0.2466
# Epoch 12: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 93ms/step - loss: 5.2954 - accuracy: 0.2466 - val_loss: 1.9454 - val_accuracy: 0.2260 - lr: 5.0000e-05
# Epoch 13/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2976 - accuracy: 0.1965
# Epoch 13: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 95ms/step - loss: 5.2976 - accuracy: 0.1965 - val_loss: 1.9459 - val_accuracy: 0.1569 - lr: 5.0000e-05
# Epoch 14/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2942 - accuracy: 0.1067
# Epoch 14: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 15s 90ms/step - loss: 5.2942 - accuracy: 0.1067 - val_loss: 1.9463 - val_accuracy: 0.1235 - lr: 5.0000e-05
# Epoch 15/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2933 - accuracy: 0.1801
# Epoch 15: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 15s 92ms/step - loss: 5.2933 - accuracy: 0.1801 - val_loss: 1.9457 - val_accuracy: 0.2165 - lr: 5.0000e-05
# Epoch 16/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2957 - accuracy: 0.1531
# Epoch 16: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 15s 91ms/step - loss: 5.2957 - accuracy: 0.1531 - val_loss: 1.9457 - val_accuracy: 0.2047 - lr: 5.0000e-05
# Epoch 17/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2954 - accuracy: 0.1984
# Epoch 17: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 15s 92ms/step - loss: 5.2954 - accuracy: 0.1984 - val_loss: 1.9466 - val_accuracy: 0.1182 - lr: 5.0000e-05
# Epoch 18/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2924 - accuracy: 0.1153
# Epoch 18: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 94ms/step - loss: 5.2924 - accuracy: 0.1153 - val_loss: 1.9456 - val_accuracy: 0.2311 - lr: 5.0000e-05
# Epoch 19/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2848 - accuracy: 0.2270
# Epoch 19: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 16s 94ms/step - loss: 5.2848 - accuracy: 0.2270 - val_loss: 1.9454 - val_accuracy: 0.2269 - lr: 5.0000e-05
# Epoch 20/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2777 - accuracy: 0.2573
# Epoch 20: val_accuracy did not improve from 0.34419
# 167/167 [==============================] - 15s 93ms/step - loss: 5.2777 - accuracy: 0.2573 - val_loss: 1.9454 - val_accuracy: 0.2141 - lr: 5.0000e-05
# Epoch 21/30
# 167/167 [==============================] - ETA: 0s - loss: 5.2891 - accuracy: 0.2459
# Epoch 21: val_accuracy did not improve from 0.34419
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 15s 93ms/step - loss: 5.2891 - accuracy: 0.2459 - val_loss: 1.9453 - val_accuracy: 0.2234 - lr: 5.0000e-05
# Epoch 21: early stopping

# %%
save_model = model.save('VGG16_SCRATCH_50e_FER.h5')

# %%
model = load_model("VGG16_Scract_100e_TF_FT_RAFDB.h5")

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 10ms/step
# Accuracy =  0.265625

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 19ms/step
# Accuracy =  0.328125
# 2/2 [==============================] - 0s 15ms/step
# Accuracy =  0.109375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.2243

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 22.425176056338028
# Angry 261/4606 acc: 10.7
# Disgust 259/4606 acc: 0.0
# Fear 106/4606 acc: 28.3
# Happy 1758/4606 acc: 36.6
# Neutral 948/4606 acc: 1.1
# Sad 732/4606 acc: 0.0
# Surprise 480/4606 acc: 64.2

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 22.425176056338028
# Angry 261/4606 acc: 10.7
# Disgust 259/4606 acc: 0.0
# Fear 106/4606 acc: 28.3
# Happy 1758/4606 acc: 36.6
# Neutral 948/4606 acc: 1.1
# Sad 732/4606 acc: 0.0
# Surprise 480/4606 acc: 64.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.17      0.11      0.13       261
#      Disgust       0.00      0.00      0.00       259
#         Fear       0.08      0.28      0.13       106
#        Happy       0.46      0.37      0.41      1758
#      Neutral       0.31      0.01      0.02       948
#          Sad       0.00      0.00      0.00       732
#     Surprise       0.12      0.64      0.20       480
#
#     accuracy                           0.22      4544
#    macro avg       0.16      0.20      0.13      4544
# weighted avg       0.27      0.22      0.19      4544
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Test with images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: surprise, probability: 0.14429448544979095
# 1/1 [==============================] - 0s 97ms/step
# Predicted emotion class: surprise, probability: 0.1451665461063385
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: surprise, probability: 0.14478012919425964
# 1/1 [==============================] - 0s 99ms/step
# Predicted emotion class: surprise, probability: 0.14396755397319794
# 1/1 [==============================] - 0s 94ms/step
# Predicted emotion class: surprise, probability: 0.14401733875274658
# 1/1 [==============================] - 0s 97ms/step
# Predicted emotion class: surprise, probability: 0.14500053226947784
# 1/1 [==============================] - 0s 95ms/step
# Predicted emotion class: surprise, probability: 0.14401309192180634
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: fear, probability: 0.14308440685272217
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: happy, probability: 0.14349456131458282

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.25
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.046875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.1582

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# Accuracy: 15.8203125
# Angry 292/2100 acc: 8.6
# Disgust 292/2100 acc: 0.0
# Fear 294/2100 acc: 8.2
# Happy 294/2100 acc: 6.8
# Neutral 293/2100 acc: 0.0
# Sad 295/2100 acc: 0.0
# Surprise 288/2100 acc: 88.5

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 15.8203125
# Angry 292/2100 acc: 8.6
# Disgust 292/2100 acc: 0.0
# Fear 294/2100 acc: 8.2
# Happy 294/2100 acc: 6.8
# Neutral 293/2100 acc: 0.0
# Sad 295/2100 acc: 0.0
# Surprise 288/2100 acc: 88.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.27      0.09      0.13       292
#      Disgust       0.00      0.00      0.00       292
#         Fear       0.17      0.08      0.11       294
#        Happy       0.13      0.07      0.09       294
#      Neutral       0.00      0.00      0.00       293
#          Sad       0.00      0.00      0.00       295
#     Surprise       0.15      0.89      0.26       288
#
#     accuracy                           0.16      2048
#    macro avg       0.10      0.16      0.08      2048
# weighted avg       0.10      0.16      0.08      2048
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\darks\anaconda3\envs\Tensorflow210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,879,815
# Trainable params: 14,879,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 32 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 32 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 166/167 [============================>.] - ETA: 0s - loss: 5.2662 - accuracy: 0.1401
# Epoch 1: val_accuracy improved from 0.34419 to 0.38424, saving model to best_model.h5
# 167/167 [==============================] - 19s 76ms/step - loss: 5.2624 - accuracy: 0.1409 - val_loss: 1.8603 - val_accuracy: 0.3842 - lr: 1.0000e-04
# Epoch 2/200
# 167/167 [==============================] - ETA: 0s - loss: 5.1334 - accuracy: 0.2992
# Epoch 2: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 73ms/step - loss: 5.1334 - accuracy: 0.2992 - val_loss: 2.1014 - val_accuracy: 0.3323 - lr: 1.0000e-04
# Epoch 3/200
# 167/167 [==============================] - ETA: 0s - loss: 5.1319 - accuracy: 0.3053
# Epoch 3: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 73ms/step - loss: 5.1319 - accuracy: 0.3053 - val_loss: 1.8581 - val_accuracy: 0.3629 - lr: 1.0000e-04
# Epoch 4/200
# 167/167 [==============================] - ETA: 0s - loss: 5.0846 - accuracy: 0.3369
# Epoch 4: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 73ms/step - loss: 5.0846 - accuracy: 0.3369 - val_loss: 1.8135 - val_accuracy: 0.3638 - lr: 1.0000e-04
# Epoch 5/200
# 167/167 [==============================] - ETA: 0s - loss: 5.0611 - accuracy: 0.3146
# Epoch 5: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 5.0611 - accuracy: 0.3146 - val_loss: 1.8905 - val_accuracy: 0.2971 - lr: 1.0000e-04
# Epoch 6/200
# 167/167 [==============================] - ETA: 0s - loss: 5.0539 - accuracy: 0.3159
# Epoch 6: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 76ms/step - loss: 5.0539 - accuracy: 0.3159 - val_loss: 1.9863 - val_accuracy: 0.2544 - lr: 1.0000e-04
# Epoch 7/200
# 167/167 [==============================] - ETA: 0s - loss: 5.0249 - accuracy: 0.3073
# Epoch 7: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 75ms/step - loss: 5.0249 - accuracy: 0.3073 - val_loss: 1.8378 - val_accuracy: 0.2993 - lr: 1.0000e-04
# Epoch 8/200
# 167/167 [==============================] - ETA: 0s - loss: 4.9898 - accuracy: 0.3059
# Epoch 8: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 75ms/step - loss: 4.9898 - accuracy: 0.3059 - val_loss: 2.0303 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 9/200
# 167/167 [==============================] - ETA: 0s - loss: 4.9888 - accuracy: 0.2913
# Epoch 9: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 75ms/step - loss: 4.9888 - accuracy: 0.2913 - val_loss: 1.8109 - val_accuracy: 0.3178 - lr: 1.0000e-04
# Epoch 10/200
# 167/167 [==============================] - ETA: 0s - loss: 4.9367 - accuracy: 0.2802
# Epoch 10: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.9367 - accuracy: 0.2802 - val_loss: 1.9231 - val_accuracy: 0.2689 - lr: 1.0000e-04
# Epoch 11/200
# 167/167 [==============================] - ETA: 0s - loss: 4.8942 - accuracy: 0.3235
# Epoch 11: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 75ms/step - loss: 4.8942 - accuracy: 0.3235 - val_loss: 1.9725 - val_accuracy: 0.2592 - lr: 1.0000e-04
# Epoch 12/200
# 167/167 [==============================] - ETA: 0s - loss: 4.8799 - accuracy: 0.2889
# Epoch 12: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.8799 - accuracy: 0.2889 - val_loss: 1.8372 - val_accuracy: 0.3156 - lr: 1.0000e-04
# Epoch 13/200
# 167/167 [==============================] - ETA: 0s - loss: 4.8614 - accuracy: 0.3080
# Epoch 13: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 77ms/step - loss: 4.8614 - accuracy: 0.3080 - val_loss: 1.9008 - val_accuracy: 0.2837 - lr: 1.0000e-04
# Epoch 14/200
# 167/167 [==============================] - ETA: 0s - loss: 4.8163 - accuracy: 0.3192
# Epoch 14: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.8163 - accuracy: 0.3192 - val_loss: 1.8941 - val_accuracy: 0.2467 - lr: 1.0000e-04
# Epoch 15/200
# 167/167 [==============================] - ETA: 0s - loss: 4.8160 - accuracy: 0.2758
# Epoch 15: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 76ms/step - loss: 4.8160 - accuracy: 0.2758 - val_loss: 1.7611 - val_accuracy: 0.2940 - lr: 1.0000e-04
# Epoch 16/200
# 167/167 [==============================] - ETA: 0s - loss: 4.7378 - accuracy: 0.3063
# Epoch 16: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.7378 - accuracy: 0.3063 - val_loss: 1.7832 - val_accuracy: 0.2874 - lr: 1.0000e-04
# Epoch 17/200
# 167/167 [==============================] - ETA: 0s - loss: 4.7280 - accuracy: 0.2926
# Epoch 17: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.7280 - accuracy: 0.2926 - val_loss: 1.8671 - val_accuracy: 0.2918 - lr: 1.0000e-04
# Epoch 18/200
# 167/167 [==============================] - ETA: 0s - loss: 4.6788 - accuracy: 0.3174
# Epoch 18: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 73ms/step - loss: 4.6788 - accuracy: 0.3174 - val_loss: 1.9690 - val_accuracy: 0.1472 - lr: 1.0000e-04
# Epoch 19/200
# 167/167 [==============================] - ETA: 0s - loss: 4.6714 - accuracy: 0.3012
# Epoch 19: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.6714 - accuracy: 0.3012 - val_loss: 1.9469 - val_accuracy: 0.2601 - lr: 1.0000e-04
# Epoch 20/200
# 167/167 [==============================] - ETA: 0s - loss: 4.6077 - accuracy: 0.3119
# Epoch 20: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.6077 - accuracy: 0.3119 - val_loss: 1.8950 - val_accuracy: 0.2762 - lr: 1.0000e-04
# Epoch 21/200
# 167/167 [==============================] - ETA: 0s - loss: 4.5422 - accuracy: 0.3393
# Epoch 21: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 13s 75ms/step - loss: 4.5422 - accuracy: 0.3393 - val_loss: 1.7589 - val_accuracy: 0.3178 - lr: 1.0000e-04
# Epoch 22/200
# 167/167 [==============================] - ETA: 0s - loss: 4.4857 - accuracy: 0.3692
# Epoch 22: val_accuracy did not improve from 0.38424
# 167/167 [==============================] - 12s 74ms/step - loss: 4.4857 - accuracy: 0.3692 - val_loss: 1.8228 - val_accuracy: 0.3321 - lr: 1.0000e-04
# Epoch 23/200
# 167/167 [==============================] - ETA: 0s - loss: 4.4286 - accuracy: 0.3844
# Epoch 23: val_accuracy improved from 0.38424 to 0.45224, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.4286 - accuracy: 0.3844 - val_loss: 1.5365 - val_accuracy: 0.4522 - lr: 1.0000e-04
# Epoch 24/200
# 167/167 [==============================] - ETA: 0s - loss: 4.3244 - accuracy: 0.3988
# Epoch 24: val_accuracy did not improve from 0.45224
# 167/167 [==============================] - 13s 79ms/step - loss: 4.3244 - accuracy: 0.3988 - val_loss: 1.7648 - val_accuracy: 0.3482 - lr: 1.0000e-04
# Epoch 25/200
# 167/167 [==============================] - ETA: 0s - loss: 4.2250 - accuracy: 0.4189
# Epoch 25: val_accuracy improved from 0.45224 to 0.45599, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.2250 - accuracy: 0.4189 - val_loss: 1.4585 - val_accuracy: 0.4560 - lr: 1.0000e-04
# Epoch 26/200
# 167/167 [==============================] - ETA: 0s - loss: 4.1683 - accuracy: 0.4485
# Epoch 26: val_accuracy did not improve from 0.45599
# 167/167 [==============================] - 13s 77ms/step - loss: 4.1683 - accuracy: 0.4485 - val_loss: 1.5361 - val_accuracy: 0.4509 - lr: 1.0000e-04
# Epoch 27/200
# 167/167 [==============================] - ETA: 0s - loss: 4.1177 - accuracy: 0.4521
# Epoch 27: val_accuracy improved from 0.45599 to 0.49802, saving model to best_model.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 4.1177 - accuracy: 0.4521 - val_loss: 1.3917 - val_accuracy: 0.4980 - lr: 1.0000e-04
# Epoch 28/200
# 167/167 [==============================] - ETA: 0s - loss: 4.0551 - accuracy: 0.4481
# Epoch 28: val_accuracy improved from 0.49802 to 0.51871, saving model to best_model.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 4.0551 - accuracy: 0.4481 - val_loss: 1.4118 - val_accuracy: 0.5187 - lr: 1.0000e-04
# Epoch 29/200
# 167/167 [==============================] - ETA: 0s - loss: 3.9889 - accuracy: 0.4766
# Epoch 29: val_accuracy improved from 0.51871 to 0.53741, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.9889 - accuracy: 0.4766 - val_loss: 1.3527 - val_accuracy: 0.5374 - lr: 1.0000e-04
# Epoch 30/200
# 166/167 [============================>.] - ETA: 0s - loss: 3.9144 - accuracy: 0.4840
# Epoch 30: val_accuracy did not improve from 0.53741
# 167/167 [==============================] - 13s 77ms/step - loss: 3.9089 - accuracy: 0.4848 - val_loss: 1.4737 - val_accuracy: 0.4564 - lr: 1.0000e-04
# Epoch 31/200
# 167/167 [==============================] - ETA: 0s - loss: 3.8446 - accuracy: 0.4930
# Epoch 31: val_accuracy did not improve from 0.53741
# 167/167 [==============================] - 13s 76ms/step - loss: 3.8446 - accuracy: 0.4930 - val_loss: 1.3151 - val_accuracy: 0.5244 - lr: 1.0000e-04
# Epoch 32/200
# 167/167 [==============================] - ETA: 0s - loss: 3.7799 - accuracy: 0.4993
# Epoch 32: val_accuracy improved from 0.53741 to 0.56536, saving model to best_model.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.7799 - accuracy: 0.4993 - val_loss: 1.2222 - val_accuracy: 0.5654 - lr: 1.0000e-04
# Epoch 33/200
# 167/167 [==============================] - ETA: 0s - loss: 3.7060 - accuracy: 0.5175
# Epoch 33: val_accuracy did not improve from 0.56536
# 167/167 [==============================] - 13s 75ms/step - loss: 3.7060 - accuracy: 0.5175 - val_loss: 1.5232 - val_accuracy: 0.4648 - lr: 1.0000e-04
# Epoch 34/200
# 167/167 [==============================] - ETA: 0s - loss: 3.6600 - accuracy: 0.5166
# Epoch 34: val_accuracy did not improve from 0.56536
# 167/167 [==============================] - 13s 76ms/step - loss: 3.6600 - accuracy: 0.5166 - val_loss: 1.2361 - val_accuracy: 0.5491 - lr: 1.0000e-04
# Epoch 35/200
# 167/167 [==============================] - ETA: 0s - loss: 3.5856 - accuracy: 0.5309
# Epoch 35: val_accuracy did not improve from 0.56536
# 167/167 [==============================] - 13s 76ms/step - loss: 3.5856 - accuracy: 0.5309 - val_loss: 1.3359 - val_accuracy: 0.5207 - lr: 1.0000e-04
# Epoch 36/200
# 167/167 [==============================] - ETA: 0s - loss: 3.5516 - accuracy: 0.5426
# Epoch 36: val_accuracy did not improve from 0.56536
# 167/167 [==============================] - 13s 76ms/step - loss: 3.5516 - accuracy: 0.5426 - val_loss: 1.2283 - val_accuracy: 0.5583 - lr: 1.0000e-04
# Epoch 37/200
# 167/167 [==============================] - ETA: 0s - loss: 3.4460 - accuracy: 0.5510
# Epoch 37: val_accuracy improved from 0.56536 to 0.59133, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.4460 - accuracy: 0.5510 - val_loss: 1.1632 - val_accuracy: 0.5913 - lr: 1.0000e-04
# Epoch 38/200
# 167/167 [==============================] - ETA: 0s - loss: 3.3982 - accuracy: 0.5663
# Epoch 38: val_accuracy did not improve from 0.59133
# 167/167 [==============================] - 13s 76ms/step - loss: 3.3982 - accuracy: 0.5663 - val_loss: 1.2367 - val_accuracy: 0.5577 - lr: 1.0000e-04
# Epoch 39/200
# 167/167 [==============================] - ETA: 0s - loss: 3.3126 - accuracy: 0.5752
# Epoch 39: val_accuracy did not improve from 0.59133
# 167/167 [==============================] - 12s 74ms/step - loss: 3.3126 - accuracy: 0.5752 - val_loss: 1.1857 - val_accuracy: 0.5654 - lr: 1.0000e-04
# Epoch 40/200
# 167/167 [==============================] - ETA: 0s - loss: 3.2529 - accuracy: 0.5762
# Epoch 40: val_accuracy did not improve from 0.59133
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2529 - accuracy: 0.5762 - val_loss: 1.1703 - val_accuracy: 0.5794 - lr: 1.0000e-04
# Epoch 41/200
# 167/167 [==============================] - ETA: 0s - loss: 3.1437 - accuracy: 0.5951
# Epoch 41: val_accuracy improved from 0.59133 to 0.59551, saving model to best_model.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.1437 - accuracy: 0.5951 - val_loss: 1.1258 - val_accuracy: 0.5955 - lr: 1.0000e-04
# Epoch 42/200
# 167/167 [==============================] - ETA: 0s - loss: 3.1408 - accuracy: 0.5972
# Epoch 42: val_accuracy did not improve from 0.59551
# 167/167 [==============================] - 13s 75ms/step - loss: 3.1408 - accuracy: 0.5972 - val_loss: 1.1516 - val_accuracy: 0.5880 - lr: 1.0000e-04
# Epoch 43/200
# 167/167 [==============================] - ETA: 0s - loss: 3.1021 - accuracy: 0.6001
# Epoch 43: val_accuracy improved from 0.59551 to 0.62940, saving model to best_model.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.1021 - accuracy: 0.6001 - val_loss: 1.0601 - val_accuracy: 0.6294 - lr: 1.0000e-04
# Epoch 44/200
# 167/167 [==============================] - ETA: 0s - loss: 3.0178 - accuracy: 0.6106
# Epoch 44: val_accuracy improved from 0.62940 to 0.64701, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.0178 - accuracy: 0.6106 - val_loss: 1.0000 - val_accuracy: 0.6470 - lr: 1.0000e-04
# Epoch 45/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9682 - accuracy: 0.6225
# Epoch 45: val_accuracy did not improve from 0.64701
# 167/167 [==============================] - 13s 75ms/step - loss: 2.9682 - accuracy: 0.6225 - val_loss: 1.0422 - val_accuracy: 0.6078 - lr: 1.0000e-04
# Epoch 46/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9845 - accuracy: 0.6166
# Epoch 46: val_accuracy did not improve from 0.64701
# 167/167 [==============================] - 13s 77ms/step - loss: 2.9845 - accuracy: 0.6166 - val_loss: 1.0262 - val_accuracy: 0.6186 - lr: 1.0000e-04
# Epoch 47/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8954 - accuracy: 0.6293
# Epoch 47: val_accuracy did not improve from 0.64701
# 167/167 [==============================] - 13s 76ms/step - loss: 2.8954 - accuracy: 0.6293 - val_loss: 1.0349 - val_accuracy: 0.6360 - lr: 1.0000e-04
# Epoch 48/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8490 - accuracy: 0.6352
# Epoch 48: val_accuracy did not improve from 0.64701
# 167/167 [==============================] - 12s 74ms/step - loss: 2.8490 - accuracy: 0.6352 - val_loss: 1.1229 - val_accuracy: 0.5876 - lr: 1.0000e-04
# Epoch 49/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7715 - accuracy: 0.6475
# Epoch 49: val_accuracy did not improve from 0.64701
# 167/167 [==============================] - 12s 73ms/step - loss: 2.7715 - accuracy: 0.6475 - val_loss: 1.1401 - val_accuracy: 0.6023 - lr: 1.0000e-04
# Epoch 50/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7562 - accuracy: 0.6422
# Epoch 50: val_accuracy improved from 0.64701 to 0.66285, saving model to best_model.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 2.7562 - accuracy: 0.6422 - val_loss: 1.0078 - val_accuracy: 0.6629 - lr: 1.0000e-04
# Epoch 51/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6963 - accuracy: 0.6516
# Epoch 51: val_accuracy did not improve from 0.66285
# 167/167 [==============================] - 12s 73ms/step - loss: 2.6963 - accuracy: 0.6516 - val_loss: 0.9905 - val_accuracy: 0.6461 - lr: 1.0000e-04
# Epoch 52/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6600 - accuracy: 0.6525
# Epoch 52: val_accuracy improved from 0.66285 to 0.69256, saving model to best_model.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 2.6600 - accuracy: 0.6525 - val_loss: 0.8739 - val_accuracy: 0.6926 - lr: 1.0000e-04
# Epoch 53/200
# 166/167 [============================>.] - ETA: 0s - loss: 2.6074 - accuracy: 0.6594
# Epoch 53: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 12s 74ms/step - loss: 2.6120 - accuracy: 0.6592 - val_loss: 0.8961 - val_accuracy: 0.6794 - lr: 1.0000e-04
# Epoch 54/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5972 - accuracy: 0.6645
# Epoch 54: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 12s 74ms/step - loss: 2.5972 - accuracy: 0.6645 - val_loss: 0.9647 - val_accuracy: 0.6626 - lr: 1.0000e-04
# Epoch 55/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5149 - accuracy: 0.6731
# Epoch 55: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 12s 75ms/step - loss: 2.5149 - accuracy: 0.6731 - val_loss: 1.0335 - val_accuracy: 0.6369 - lr: 1.0000e-04
# Epoch 56/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4648 - accuracy: 0.6717
# Epoch 56: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 77ms/step - loss: 2.4648 - accuracy: 0.6717 - val_loss: 0.8594 - val_accuracy: 0.6915 - lr: 1.0000e-04
# Epoch 57/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4440 - accuracy: 0.6768
# Epoch 57: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 75ms/step - loss: 2.4440 - accuracy: 0.6768 - val_loss: 0.9152 - val_accuracy: 0.6805 - lr: 1.0000e-04
# Epoch 58/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3663 - accuracy: 0.6802
# Epoch 58: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 12s 75ms/step - loss: 2.3663 - accuracy: 0.6802 - val_loss: 0.9407 - val_accuracy: 0.6774 - lr: 1.0000e-04
# Epoch 59/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3929 - accuracy: 0.6789
# Epoch 59: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 75ms/step - loss: 2.3929 - accuracy: 0.6789 - val_loss: 0.9256 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 60/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3670 - accuracy: 0.6816
# Epoch 60: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 75ms/step - loss: 2.3670 - accuracy: 0.6816 - val_loss: 0.9041 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 61/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3414 - accuracy: 0.6794
# Epoch 61: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 12s 74ms/step - loss: 2.3414 - accuracy: 0.6794 - val_loss: 0.9413 - val_accuracy: 0.6734 - lr: 1.0000e-04
# Epoch 62/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2987 - accuracy: 0.6899
# Epoch 62: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 77ms/step - loss: 2.2987 - accuracy: 0.6899 - val_loss: 0.9893 - val_accuracy: 0.6679 - lr: 1.0000e-04
# Epoch 63/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2297 - accuracy: 0.6980
# Epoch 63: val_accuracy did not improve from 0.69256
# 167/167 [==============================] - 13s 75ms/step - loss: 2.2297 - accuracy: 0.6980 - val_loss: 1.0335 - val_accuracy: 0.6389 - lr: 1.0000e-04
# Epoch 64/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1211 - accuracy: 0.7073
# Epoch 64: val_accuracy improved from 0.69256 to 0.70180, saving model to best_model.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 2.1211 - accuracy: 0.7073 - val_loss: 0.8704 - val_accuracy: 0.7018 - lr: 1.0000e-04
# Epoch 65/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2140 - accuracy: 0.7050
# Epoch 65: val_accuracy did not improve from 0.70180
# 167/167 [==============================] - 12s 74ms/step - loss: 2.2140 - accuracy: 0.7050 - val_loss: 0.9614 - val_accuracy: 0.6697 - lr: 1.0000e-04
# Epoch 66/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1160 - accuracy: 0.7075
# Epoch 66: val_accuracy did not improve from 0.70180
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 167/167 [==============================] - 12s 74ms/step - loss: 2.1160 - accuracy: 0.7075 - val_loss: 0.8668 - val_accuracy: 0.6948 - lr: 1.0000e-04
# Epoch 67/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0079 - accuracy: 0.7210
# Epoch 67: val_accuracy improved from 0.70180 to 0.70753, saving model to best_model.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 2.0079 - accuracy: 0.7210 - val_loss: 0.8496 - val_accuracy: 0.7075 - lr: 5.0000e-05
# Epoch 68/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8806 - accuracy: 0.7290
# Epoch 68: val_accuracy did not improve from 0.70753
# 167/167 [==============================] - 13s 76ms/step - loss: 1.8806 - accuracy: 0.7290 - val_loss: 0.9450 - val_accuracy: 0.6835 - lr: 5.0000e-05
# Epoch 69/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8257 - accuracy: 0.7396
# Epoch 69: val_accuracy did not improve from 0.70753
# 167/167 [==============================] - 12s 74ms/step - loss: 1.8257 - accuracy: 0.7396 - val_loss: 0.8925 - val_accuracy: 0.6981 - lr: 5.0000e-05
# Epoch 70/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7978 - accuracy: 0.7455
# Epoch 70: val_accuracy did not improve from 0.70753
# 167/167 [==============================] - 13s 76ms/step - loss: 1.7978 - accuracy: 0.7455 - val_loss: 0.9082 - val_accuracy: 0.6895 - lr: 5.0000e-05
# Epoch 71/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7863 - accuracy: 0.7457
# Epoch 71: val_accuracy improved from 0.70753 to 0.71919, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 1.7863 - accuracy: 0.7457 - val_loss: 0.8306 - val_accuracy: 0.7192 - lr: 5.0000e-05
# Epoch 72/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7620 - accuracy: 0.7507
# Epoch 72: val_accuracy did not improve from 0.71919
# 167/167 [==============================] - 13s 75ms/step - loss: 1.7620 - accuracy: 0.7507 - val_loss: 0.9429 - val_accuracy: 0.6778 - lr: 5.0000e-05
# Epoch 73/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7278 - accuracy: 0.7567
# Epoch 73: val_accuracy did not improve from 0.71919
# 167/167 [==============================] - 13s 75ms/step - loss: 1.7278 - accuracy: 0.7567 - val_loss: 0.8782 - val_accuracy: 0.7062 - lr: 5.0000e-05
# Epoch 74/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8172 - accuracy: 0.7478
# Epoch 74: val_accuracy improved from 0.71919 to 0.72183, saving model to best_model.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 1.8172 - accuracy: 0.7478 - val_loss: 0.8291 - val_accuracy: 0.7218 - lr: 5.0000e-05
# Epoch 75/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6696 - accuracy: 0.7556
# Epoch 75: val_accuracy did not improve from 0.72183
# 167/167 [==============================] - 13s 76ms/step - loss: 1.6696 - accuracy: 0.7556 - val_loss: 0.8884 - val_accuracy: 0.6948 - lr: 5.0000e-05
# Epoch 76/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6670 - accuracy: 0.7630
# Epoch 76: val_accuracy did not improve from 0.72183
# 167/167 [==============================] - 13s 77ms/step - loss: 1.6670 - accuracy: 0.7630 - val_loss: 0.8996 - val_accuracy: 0.6985 - lr: 5.0000e-05
# Epoch 77/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7073 - accuracy: 0.7494
# Epoch 77: val_accuracy did not improve from 0.72183
# 167/167 [==============================] - 13s 75ms/step - loss: 1.7073 - accuracy: 0.7494 - val_loss: 0.8644 - val_accuracy: 0.7199 - lr: 5.0000e-05
# Epoch 78/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.7617
# Epoch 78: val_accuracy improved from 0.72183 to 0.72271, saving model to best_model.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 1.6244 - accuracy: 0.7617 - val_loss: 0.8289 - val_accuracy: 0.7227 - lr: 5.0000e-05
# Epoch 79/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6730 - accuracy: 0.7540
# Epoch 79: val_accuracy did not improve from 0.72271
# 167/167 [==============================] - 13s 78ms/step - loss: 1.6730 - accuracy: 0.7540 - val_loss: 0.8703 - val_accuracy: 0.7108 - lr: 5.0000e-05
# Epoch 80/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6504 - accuracy: 0.7590
# Epoch 80: val_accuracy did not improve from 0.72271
# 167/167 [==============================] - 13s 75ms/step - loss: 1.6504 - accuracy: 0.7590 - val_loss: 0.8241 - val_accuracy: 0.7218 - lr: 5.0000e-05
# Epoch 81/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6100 - accuracy: 0.7658
# Epoch 81: val_accuracy improved from 0.72271 to 0.73107, saving model to best_model.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 1.6100 - accuracy: 0.7658 - val_loss: 0.8247 - val_accuracy: 0.7311 - lr: 5.0000e-05
# Epoch 82/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5301 - accuracy: 0.7700
# Epoch 82: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 76ms/step - loss: 1.5301 - accuracy: 0.7700 - val_loss: 0.9252 - val_accuracy: 0.7016 - lr: 5.0000e-05
# Epoch 83/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5913 - accuracy: 0.7685
# Epoch 83: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 12s 74ms/step - loss: 1.5913 - accuracy: 0.7685 - val_loss: 0.8551 - val_accuracy: 0.7192 - lr: 5.0000e-05
# Epoch 84/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5348 - accuracy: 0.7725
# Epoch 84: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 77ms/step - loss: 1.5348 - accuracy: 0.7725 - val_loss: 0.9058 - val_accuracy: 0.7102 - lr: 5.0000e-05
# Epoch 85/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4819 - accuracy: 0.7781
# Epoch 85: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 75ms/step - loss: 1.4819 - accuracy: 0.7781 - val_loss: 0.9098 - val_accuracy: 0.7106 - lr: 5.0000e-05
# Epoch 86/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4266 - accuracy: 0.7837
# Epoch 86: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 79ms/step - loss: 1.4266 - accuracy: 0.7837 - val_loss: 0.9093 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 87/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5311 - accuracy: 0.7677
# Epoch 87: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 78ms/step - loss: 1.5311 - accuracy: 0.7677 - val_loss: 0.9088 - val_accuracy: 0.7020 - lr: 5.0000e-05
# Epoch 88/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4458 - accuracy: 0.7816
# Epoch 88: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 77ms/step - loss: 1.4458 - accuracy: 0.7816 - val_loss: 0.8488 - val_accuracy: 0.7221 - lr: 5.0000e-05
# Epoch 89/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4726 - accuracy: 0.7799
# Epoch 89: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 76ms/step - loss: 1.4726 - accuracy: 0.7799 - val_loss: 0.8669 - val_accuracy: 0.7221 - lr: 5.0000e-05
# Epoch 90/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4388 - accuracy: 0.7788
# Epoch 90: val_accuracy did not improve from 0.73107
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 13s 77ms/step - loss: 1.4388 - accuracy: 0.7788 - val_loss: 0.8684 - val_accuracy: 0.7194 - lr: 5.0000e-05
# Epoch 91/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3050 - accuracy: 0.7963
# Epoch 91: val_accuracy did not improve from 0.73107
# 167/167 [==============================] - 13s 75ms/step - loss: 1.3050 - accuracy: 0.7963 - val_loss: 0.8633 - val_accuracy: 0.7311 - lr: 2.5000e-05
# Epoch 92/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2706 - accuracy: 0.8026
# Epoch 92: val_accuracy improved from 0.73107 to 0.73393, saving model to best_model.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 1.2706 - accuracy: 0.8026 - val_loss: 0.8524 - val_accuracy: 0.7339 - lr: 2.5000e-05
# Epoch 93/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2617 - accuracy: 0.8036
# Epoch 93: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 12s 74ms/step - loss: 1.2617 - accuracy: 0.8036 - val_loss: 0.9885 - val_accuracy: 0.6873 - lr: 2.5000e-05
# Epoch 94/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2747 - accuracy: 0.8030
# Epoch 94: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 12s 74ms/step - loss: 1.2747 - accuracy: 0.8030 - val_loss: 0.9241 - val_accuracy: 0.7073 - lr: 2.5000e-05
# Epoch 95/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2638 - accuracy: 0.7996
# Epoch 95: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 12s 74ms/step - loss: 1.2638 - accuracy: 0.7996 - val_loss: 0.8803 - val_accuracy: 0.7260 - lr: 2.5000e-05
# Epoch 96/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3085 - accuracy: 0.7971
# Epoch 96: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 12s 74ms/step - loss: 1.3085 - accuracy: 0.7971 - val_loss: 0.8612 - val_accuracy: 0.7240 - lr: 2.5000e-05
# Epoch 97/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2110 - accuracy: 0.8112
# Epoch 97: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 13s 76ms/step - loss: 1.2110 - accuracy: 0.8112 - val_loss: 0.9456 - val_accuracy: 0.7095 - lr: 2.5000e-05
# Epoch 98/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2025 - accuracy: 0.8136
# Epoch 98: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 13s 77ms/step - loss: 1.2025 - accuracy: 0.8136 - val_loss: 0.8810 - val_accuracy: 0.7317 - lr: 2.5000e-05
# Epoch 99/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2445 - accuracy: 0.8052
# Epoch 99: val_accuracy did not improve from 0.73393
# 167/167 [==============================] - 13s 78ms/step - loss: 1.2445 - accuracy: 0.8052 - val_loss: 0.8968 - val_accuracy: 0.7157 - lr: 2.5000e-05
# Epoch 100/200
# 166/167 [============================>.] - ETA: 0s - loss: 1.1816 - accuracy: 0.8103
# Epoch 100: val_accuracy did not improve from 0.73393
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 13s 76ms/step - loss: 1.1797 - accuracy: 0.8107 - val_loss: 0.8898 - val_accuracy: 0.7284 - lr: 2.5000e-05
# Epoch 100: early stopping

# %%
save_model = model.save('VGG16_Scract_100e_TF_FT_RAFDB.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 1s 87ms/step
# Accuracy =  0.671875

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.84375
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.5625

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.7295

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 72.95334507042254
# Angry 259/4606 acc: 77.6
# Disgust 260/4606 acc: 48.5
# Fear 105/4606 acc: 48.6
# Happy 1765/4606 acc: 81.7
# Neutral 942/4606 acc: 56.8
# Sad 730/4606 acc: 78.5
# Surprise 483/4606 acc: 80.1

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 72.95334507042254
# Angry 259/4606 acc: 77.6
# Disgust 260/4606 acc: 48.5
# Fear 105/4606 acc: 48.6
# Happy 1765/4606 acc: 81.7
# Neutral 942/4606 acc: 56.8
# Sad 730/4606 acc: 78.5
# Surprise 483/4606 acc: 80.1

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.59      0.78      0.67       259
#      Disgust       0.42      0.48      0.45       260
#         Fear       0.43      0.49      0.46       105
#        Happy       0.94      0.82      0.87      1765
#      Neutral       0.75      0.57      0.64       942
#          Sad       0.56      0.78      0.66       730
#     Surprise       0.75      0.80      0.77       483
#
#     accuracy                           0.73      4544
#    macro avg       0.63      0.67      0.65      4544
# weighted avg       0.76      0.73      0.74      4544

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 40ms/step
# Accuracy =  0.59375
# 2/2 [==============================] - 0s 86ms/step
# Accuracy =  0.3125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4736

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# Accuracy: 47.36328125
# Angry 289/2100 acc: 65.7
# Disgust 290/2100 acc: 33.8
# Fear 293/2100 acc: 15.7
# Happy 292/2100 acc: 53.8
# Neutral 296/2100 acc: 45.6
# Sad 294/2100 acc: 51.0
# Surprise 294/2100 acc: 66.0

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 47.36328125
# Angry 289/2100 acc: 65.7
# Disgust 290/2100 acc: 33.8
# Fear 293/2100 acc: 15.7
# Happy 292/2100 acc: 53.8
# Neutral 296/2100 acc: 45.6
# Sad 294/2100 acc: 51.0
# Surprise 294/2100 acc: 66.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.42      0.66      0.51       289
#      Disgust       0.45      0.34      0.39       290
#         Fear       0.46      0.16      0.23       293
#        Happy       0.66      0.54      0.59       292
#      Neutral       0.53      0.46      0.49       296
#          Sad       0.40      0.51      0.45       294
#     Surprise       0.47      0.66      0.55       294
#
#     accuracy                           0.47      2048
#    macro avg       0.48      0.47      0.46      2048
# weighted avg       0.48      0.47      0.46      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
