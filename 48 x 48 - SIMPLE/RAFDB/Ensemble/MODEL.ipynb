# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D, concatenate, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
import cv2
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
## RAFDB
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

   # Define the input shape
   input_shape = (48, 48, 3)

   # Define the number of classes
   num_classes = 7

   # Define the input layer
   inputs = Input(shape=input_shape)

   # Define the first CNN model
   x1 = Conv2D(32, kernel_size=(3, 3), padding='same')(inputs)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(32, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = Conv2D(64, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(64, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = Conv2D(128, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = Conv2D(128, kernel_size=(3, 3), padding='same')(x1)
   x1 = BatchNormalization()(x1)
   x1 = Activation('relu')(x1)
   x1 = MaxPooling2D(pool_size=(2, 2))(x1)
   x1 = Dropout(0.25)(x1)

   x1 = GlobalAveragePooling2D()(x1)
   x1 = Dense(512, activation='relu')(x1)
   x1 = Dropout(0.5)(x1)
   outputs1 = Dense(num_classes, activation='softmax')(x1)

   # Define the second CNN model
   x2 = Conv2D(32, kernel_size=(3, 3), padding='same')(inputs)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(32, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = Conv2D(64, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(64, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = Conv2D(128, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = Conv2D(128, kernel_size=(3, 3), padding='same')(x2)
   x2 = BatchNormalization()(x2)
   x2 = Activation('relu')(x2)
   x2 = MaxPooling2D(pool_size=(2, 2))(x2)
   x2 = Dropout(0.25)(x2)

   x2 = GlobalAveragePooling2D()(x2)
   x2 = Dense(512, activation='relu')(x2)
   x2 = Dropout(0.5)(x2)
   outputs2 = Dense(num_classes, activation='softmax')(x2)

   # Define the third CNN model
   x3 = Conv2D(64, kernel_size=(3, 3), padding='same')(inputs)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(64, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = Conv2D(128, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(128, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = Conv2D(256, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = Conv2D(256, kernel_size=(3, 3), padding='same')(x3)
   x3 = BatchNormalization()(x3)
   x3 = Activation('relu')(x3)
   x3 = MaxPooling2D(pool_size=(2, 2))(x3)
   x3 = Dropout(0.25)(x3)

   x3 = GlobalAveragePooling2D()(x3)
   x3 = Dense(512, activation='relu')(x3)
   x3 = Dropout(0.5)(x3)
   outputs3 = Dense(num_classes, activation='softmax')(x3)

   # Define the ensemble model
   outputs = tf.keras.layers.average([outputs1, outputs2, outputs3])
   model = Model(inputs=inputs, outputs=outputs)


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 32)   896         ['input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 32)   896         ['input_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_6 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_12 (BatchN  (None, 48, 48, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation (Activation)        (None, 48, 48, 32)   0           ['batch_normalization[0][0]']
#
#  activation_6 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_6[0][0]']
#
#  activation_12 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 48, 48, 32)   9248        ['activation[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 32)   9248        ['activation_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 48, 48, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_13 (BatchN  (None, 48, 48, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_1 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_1[0][0]']
#
#  activation_7 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_7[0][0]']
#
#  activation_13 (Activation)     (None, 48, 48, 64)   0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 32)   0           ['activation_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 32)  0           ['activation_7[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 64)  0           ['activation_13[0][0]']
#
#  dropout (Dropout)              (None, 24, 24, 32)   0           ['max_pooling2d[0][0]']
#
#  dropout_4 (Dropout)            (None, 24, 24, 32)   0           ['max_pooling2d_3[0][0]']
#
#  dropout_8 (Dropout)            (None, 24, 24, 64)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 64)   18496       ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 24, 24, 64)   18496       ['dropout_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 24, 24, 128)  73856       ['dropout_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_14 (BatchN  (None, 24, 24, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]']
#
#  activation_8 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_8[0][0]']
#
#  activation_14 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_8[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 24, 24, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_15 (BatchN  (None, 24, 24, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_3 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_9 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_15 (Activation)     (None, 24, 24, 128)  0           ['batch_normalization_15[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_9[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 128)  0          ['activation_15[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 12, 64)   0           ['max_pooling2d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 12, 64)   0           ['max_pooling2d_4[0][0]']
#
#  dropout_9 (Dropout)            (None, 12, 12, 128)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  73856       ['dropout_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 256)  295168      ['dropout_9[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 12, 12, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_4[0][0]']
#
#  activation_10 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_10[0][0]']
#
#  activation_16 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  147584      ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 256)  590080      ['activation_16[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 12, 12, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_5[0][0]']
#
#  activation_11 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_11[0][0]']
#
#  activation_17 (Activation)     (None, 12, 12, 256)  0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 128)   0           ['activation_5[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 128)   0           ['activation_11[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 256)   0           ['activation_17[0][0]']
#
#  dropout_2 (Dropout)            (None, 6, 6, 128)    0           ['max_pooling2d_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 6, 6, 128)    0           ['max_pooling2d_5[0][0]']
#
#  dropout_10 (Dropout)           (None, 6, 6, 256)    0           ['max_pooling2d_8[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['dropout_2[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['dropout_6[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['dropout_10[0][0]']
#  obalAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          66048       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 512)          66048       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 512)          131584      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dropout_3 (Dropout)            (None, 512)          0           ['dense[0][0]']
#
#  dropout_7 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dropout_11 (Dropout)           (None, 512)          0           ['dense_4[0][0]']
#
#  dense_1 (Dense)                (None, 7)            3591        ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 7)            3591        ['dropout_7[0][0]']
#
#  dense_5 (Dense)                (None, 7)            3591        ['dropout_11[0][0]']
#
#  average (Average)              (None, 7)            0           ['dense_1[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'dense_5[0][0]']
#
# ==================================================================================================
# Total params: 2,001,045
# Trainable params: 1,997,461
# Non-trainable params: 3,584
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 84 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 84 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 5.2631 - accuracy: 0.2204
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.39.h5
# 167/167 [==============================] - 34s 91ms/step - loss: 5.2631 - accuracy: 0.2204 - val_loss: 1.7398 - val_accuracy: 0.3884 - lr: 1.0000e-04
# Epoch 2/300
# 167/167 [==============================] - ETA: 0s - loss: 5.1369 - accuracy: 0.2337
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.38.h5
# 167/167 [==============================] - 14s 85ms/step - loss: 5.1369 - accuracy: 0.2337 - val_loss: 1.7028 - val_accuracy: 0.3842 - lr: 1.0000e-04
# Epoch 3/300
# 167/167 [==============================] - ETA: 0s - loss: 5.0457 - accuracy: 0.2516
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.36.h5
# 167/167 [==============================] - 14s 84ms/step - loss:
300
# 167/167 [==============================] - ETA: 0s - loss: 3.6161 - accuracy: 0.5777
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.53.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 3.6161 - accuracy: 0.5777 - val_loss: 1.3897 - val_accuracy: 0.5348 - lr: 5.0000e-05
# Epoch 47/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5668 - accuracy: 0.5804
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.61.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 3.5668 - accuracy: 0.5804 - val_loss: 1.2784 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 48/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5633 - accuracy: 0.5849
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 3.5633 - accuracy: 0.5849 - val_loss: 1.2697 - val_accuracy: 0.6008 - lr: 5.0000e-05
# Epoch 49/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5471 - accuracy: 0.5827
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.5471 - accuracy: 0.5827 - val_loss: 1.3418 - val_accuracy: 0.6019 - lr: 5.0000e-05
# Epoch 50/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5460 - accuracy: 0.5867
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.5460 - accuracy: 0.5867 - val_loss: 1.2839 - val_accuracy: 0.5995 - lr: 5.0000e-05
# Epoch 51/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5377 - accuracy: 0.5915
# Epoch 51: saving model to checkpoints_freeze\toy-model_1-epoch-51-val_accuracy-0.59.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.5377 - accuracy: 0.5915 - val_loss: 1.2918 - val_accuracy: 0.5915 - lr: 5.0000e-05
# Epoch 52/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5223 - accuracy: 0.5852
# Epoch 52: saving model to checkpoints_freeze\toy-model_1-epoch-52-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.5223 - accuracy: 0.5852 - val_loss: 1.3150 - val_accuracy: 0.6012 - lr: 5.0000e-05
# Epoch 53/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4865 - accuracy: 0.5923
# Epoch 53: saving model to checkpoints_freeze\toy-model_1-epoch-53-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 81ms/step - loss: 3.4865 - accuracy: 0.5923 - val_loss: 1.2929 - val_accuracy: 0.5962 - lr: 5.0000e-05
# Epoch 54/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4867 - accuracy: 0.5948
# Epoch 54: saving model to checkpoints_freeze\toy-model_1-epoch-54-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.4867 - accuracy: 0.5948 - val_loss: 1.3059 - val_accuracy: 0.6151 - lr: 5.0000e-05
# Epoch 55/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4840 - accuracy: 0.5893
# Epoch 55: saving model to checkpoints_freeze\toy-model_1-epoch-55-val_accuracy-0.61.h5
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 12s 74ms/step - loss: 3.4840 - accuracy: 0.5893 - val_loss: 1.2698 - val_accuracy: 0.6127 - lr: 5.0000e-05
# Epoch 56/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3926 - accuracy: 0.6026
# Epoch 56: saving model to checkpoints_freeze\toy-model_1-epoch-56-val_accuracy-0.59.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.3926 - accuracy: 0.6026 - val_loss: 1.3132 - val_accuracy: 0.5933 - lr: 2.5000e-05
# Epoch 57/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4319 - accuracy: 0.6042
# Epoch 57: saving model to checkpoints_freeze\toy-model_1-epoch-57-val_accuracy-0.61.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.4319 - accuracy: 0.6042 - val_loss: 1.2716 - val_accuracy: 0.6089 - lr: 2.5000e-05
# Epoch 58/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4090 - accuracy: 0.6016
# Epoch 58: saving model to checkpoints_freeze\toy-model_1-epoch-58-val_accuracy-0.56.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.4090 - accuracy: 0.6016 - val_loss: 1.3572 - val_accuracy: 0.5649 - lr: 2.5000e-05
# Epoch 59/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4239 - accuracy: 0.5962
# Epoch 59: saving model to checkpoints_freeze\toy-model_1-epoch-59-val_accuracy-0.62.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.4239 - accuracy: 0.5962 - val_loss: 1.2558 - val_accuracy: 0.6182 - lr: 2.5000e-05
# Epoch 60/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4079 - accuracy: 0.5994
# Epoch 60: saving model to checkpoints_freeze\toy-model_1-epoch-60-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.4079 - accuracy: 0.5994 - val_loss: 1.1970 - val_accuracy: 0.6391 - lr: 2.5000e-05
# Epoch 61/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4105 - accuracy: 0.6080
# Epoch 61: saving model to checkpoints_freeze\toy-model_1-epoch-61-val_accuracy-0.63.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.4105 - accuracy: 0.6080 - val_loss: 1.2490 - val_accuracy: 0.6276 - lr: 2.5000e-05
# Epoch 62/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3930 - accuracy: 0.6013
# Epoch 62: saving model to checkpoints_freeze\toy-model_1-epoch-62-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.3930 - accuracy: 0.6013 - val_loss: 1.2557 - val_accuracy: 0.6259 - lr: 2.5000e-05
# Epoch 63/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3923 - accuracy: 0.5981
# Epoch 63: saving model to checkpoints_freeze\toy-model_1-epoch-63-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.3923 - accuracy: 0.5981 - val_loss: 1.2220 - val_accuracy: 0.6360 - lr: 2.5000e-05
# Epoch 64/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3659 - accuracy: 0.6055
# Epoch 64: saving model to checkpoints_freeze\toy-model_1-epoch-64-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.3659 - accuracy: 0.6055 - val_loss: 1.2181 - val_accuracy: 0.6439 - lr: 2.5000e-05
# Epoch 65/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3970 - accuracy: 0.6032
# Epoch 65: saving model to checkpoints_freeze\toy-model_1-epoch-65-val_accuracy-0.60.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.3970 - accuracy: 0.6032 - val_loss: 1.2824 - val_accuracy: 0.5979 - lr: 2.5000e-05
# Epoch 66/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3869 - accuracy: 0.6065
# Epoch 66: saving model to checkpoints_freeze\toy-model_1-epoch-66-val_accuracy-0.62.h5
# 167/167 [==============================] - 12s 75ms/step - loss: 3.3869 - accuracy: 0.6065 - val_loss: 1.2564 - val_accuracy: 0.6171 - lr: 2.5000e-05
# Epoch 67/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3615 - accuracy: 0.6114
# Epoch 67: saving model to checkpoints_freeze\toy-model_1-epoch-67-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 3.3615 - accuracy: 0.6114 - val_loss: 1.2535 - val_accuracy: 0.6155 - lr: 2.5000e-05
# Epoch 68/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3686 - accuracy: 0.6082
# Epoch 68: saving model to checkpoints_freeze\toy-model_1-epoch-68-val_accuracy-0.61.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 3.3686 - accuracy: 0.6082 - val_loss: 1.2763 - val_accuracy: 0.6107 - lr: 2.5000e-05
# Epoch 69/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3805 - accuracy: 0.6030
# Epoch 69: saving model to checkpoints_freeze\toy-model_1-epoch-69-val_accuracy-0.62.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 3.3805 - accuracy: 0.6030 - val_loss: 1.2451 - val_accuracy: 0.6228 - lr: 2.5000e-05
# Epoch 70/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3276 - accuracy: 0.6056
# Epoch 70: saving model to checkpoints_freeze\toy-model_1-epoch-70-val_accuracy-0.60.h5
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 13s 77ms/step - loss: 3.3276 - accuracy: 0.6056 - val_loss: 1.3046 - val_accuracy: 0.5982 - lr: 2.5000e-05
# Epoch 71/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3064 - accuracy: 0.6182
# Epoch 71: saving model to checkpoints_freeze\toy-model_1-epoch-71-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 3.3064 - accuracy: 0.6182 - val_loss: 1.2039 - val_accuracy: 0.6391 - lr: 1.2500e-05
# Epoch 72/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3054 - accuracy: 0.6162
# Epoch 72: saving model to checkpoints_freeze\toy-model_1-epoch-72-val_accuracy-0.58.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.3054 - accuracy: 0.6162 - val_loss: 1.3071 - val_accuracy: 0.5849 - lr: 1.2500e-05
# Epoch 73/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2746 - accuracy: 0.6207
# Epoch 73: saving model to checkpoints_freeze\toy-model_1-epoch-73-val_accuracy-0.64.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 3.2746 - accuracy: 0.6207 - val_loss: 1.2144 - val_accuracy: 0.6364 - lr: 1.2500e-05
# Epoch 74/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2977 - accuracy: 0.6161
# Epoch 74: saving model to checkpoints_freeze\toy-model_1-epoch-74-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 3.2977 - accuracy: 0.6161 - val_loss: 1.2285 - val_accuracy: 0.6241 - lr: 1.2500e-05
# Epoch 75/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2783 - accuracy: 0.6210
# Epoch 75: saving model to checkpoints_freeze\toy-model_1-epoch-75-val_accuracy-0.65.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 3.2783 - accuracy: 0.6210 - val_loss: 1.1890 - val_accuracy: 0.6468 - lr: 1.2500e-05
# Epoch 76/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2683 - accuracy: 0.6196
# Epoch 76: saving model to checkpoints_freeze\toy-model_1-epoch-76-val_accuracy-0.65.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2683 - accuracy: 0.6196 - val_loss: 1.1971 - val_accuracy: 0.6477 - lr: 1.2500e-05
# Epoch 77/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2963 - accuracy: 0.6113
# Epoch 77: saving model to checkpoints_freeze\toy-model_1-epoch-77-val_accuracy-0.63.h5
# 167/167 [==============================] - 15s 92ms/step - loss: 3.2963 - accuracy: 0.6113 - val_loss: 1.2177 - val_accuracy: 0.6285 - lr: 1.2500e-05
# Epoch 78/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2911 - accuracy: 0.6170
# Epoch 78: saving model to checkpoints_freeze\toy-model_1-epoch-78-val_accuracy-0.63.h5
# 167/167 [==============================] - 18s 106ms/step - loss: 3.2911 - accuracy: 0.6170 - val_loss: 1.2274 - val_accuracy: 0.6261 - lr: 1.2500e-05
# Epoch 79/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2838 - accuracy: 0.6123
# Epoch 79: saving model to checkpoints_freeze\toy-model_1-epoch-79-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2838 - accuracy: 0.6123 - val_loss: 1.2422 - val_accuracy: 0.6191 - lr: 1.2500e-05
# Epoch 80/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2802 - accuracy: 0.6158
# Epoch 80: saving model to checkpoints_freeze\toy-model_1-epoch-80-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.2802 - accuracy: 0.6158 - val_loss: 1.2232 - val_accuracy: 0.6235 - lr: 1.2500e-05
# Epoch 81/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2792 - accuracy: 0.6129
# Epoch 81: saving model to checkpoints_freeze\toy-model_1-epoch-81-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.2792 - accuracy: 0.6129 - val_loss: 1.2199 - val_accuracy: 0.6285 - lr: 1.2500e-05
# Epoch 82/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2788 - accuracy: 0.6249
# Epoch 82: saving model to checkpoints_freeze\toy-model_1-epoch-82-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2788 - accuracy: 0.6249 - val_loss: 1.2271 - val_accuracy: 0.6259 - lr: 1.2500e-05
# Epoch 83/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2999 - accuracy: 0.6047
# Epoch 83: saving model to checkpoints_freeze\toy-model_1-epoch-83-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2999 - accuracy: 0.6047 - val_loss: 1.2179 - val_accuracy: 0.6281 - lr: 1.2500e-05
# Epoch 84/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2642 - accuracy: 0.6120
# Epoch 84: saving model to checkpoints_freeze\toy-model_1-epoch-84-val_accuracy-0.62.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2642 - accuracy: 0.6120 - val_loss: 1.2251 - val_accuracy: 0.6246 - lr: 1.2500e-05
# Epoch 85/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2973 - accuracy: 0.6109
# Epoch 85: saving model to checkpoints_freeze\toy-model_1-epoch-85-val_accuracy-0.62.h5
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 13s 79ms/step - loss: 3.2973 - accuracy: 0.6109 - val_loss: 1.2365 - val_accuracy: 0.6182 - lr: 1.2500e-05
# Epoch 86/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2663 - accuracy: 0.6153
# Epoch 86: saving model to checkpoints_freeze\toy-model_1-epoch-86-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.2663 - accuracy: 0.6153 - val_loss: 1.2080 - val_accuracy: 0.6351 - lr: 6.2500e-06
# Epoch 87/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2473 - accuracy: 0.6241
# Epoch 87: saving model to checkpoints_freeze\toy-model_1-epoch-87-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 3.2473 - accuracy: 0.6241 - val_loss: 1.2287 - val_accuracy: 0.6292 - lr: 6.2500e-06
# Epoch 88/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2453 - accuracy: 0.6201
# Epoch 88: saving model to checkpoints_freeze\toy-model_1-epoch-88-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2453 - accuracy: 0.6201 - val_loss: 1.1962 - val_accuracy: 0.6404 - lr: 6.2500e-06
# Epoch 89/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2570 - accuracy: 0.6213
# Epoch 89: saving model to checkpoints_freeze\toy-model_1-epoch-89-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.2570 - accuracy: 0.6213 - val_loss: 1.1998 - val_accuracy: 0.6408 - lr: 6.2500e-06
# Epoch 90/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2325 - accuracy: 0.6245
# Epoch 90: saving model to checkpoints_freeze\toy-model_1-epoch-90-val_accuracy-0.65.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.2325 - accuracy: 0.6245 - val_loss: 1.1923 - val_accuracy: 0.6457 - lr: 6.2500e-06
# Epoch 91/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2732 - accuracy: 0.6165
# Epoch 91: saving model to checkpoints_freeze\toy-model_1-epoch-91-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2732 - accuracy: 0.6165 - val_loss: 1.2009 - val_accuracy: 0.6437 - lr: 6.2500e-06
# Epoch 92/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2480 - accuracy: 0.6257
# Epoch 92: saving model to checkpoints_freeze\toy-model_1-epoch-92-val_accuracy-0.64.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.2480 - accuracy: 0.6257 - val_loss: 1.1987 - val_accuracy: 0.6424 - lr: 6.2500e-06
# Epoch 93/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2238 - accuracy: 0.6250
# Epoch 93: saving model to checkpoints_freeze\toy-model_1-epoch-93-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 3.2238 - accuracy: 0.6250 - val_loss: 1.2102 - val_accuracy: 0.6338 - lr: 6.2500e-06
# Epoch 94/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2346 - accuracy: 0.6271
# Epoch 94: saving model to checkpoints_freeze\toy-model_1-epoch-94-val_accuracy-0.63.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2346 - accuracy: 0.6271 - val_loss: 1.2135 - val_accuracy: 0.6314 - lr: 6.2500e-06
# Epoch 95/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2408 - accuracy: 0.6283
# Epoch 95: saving model to checkpoints_freeze\toy-model_1-epoch-95-val_accuracy-0.64.h5
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2408 - accuracy: 0.6283 - val_loss: 1.1925 - val_accuracy: 0.6419 - lr: 6.2500e-06
# Epoch 95: early stopping

# %%
save_model = model.save('EnsembleModel_100e_RAFDB.h5')

# %%
model = load_model("checkpoints_freeze/toy-model_1-epoch-20-val_accuracy-0.45.h5")

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 2s 75ms/step
# Accuracy =  0.796875
# 2/2 [==============================] - 0s 110ms/step
# Accuracy =  0.515625

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6415

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# Accuracy: 64.15052816901408
# Angry 258/4606 acc: 74.4
# Disgust 262/4606 acc: 48.1
# Fear 107/4606 acc: 49.5
# Happy 1767/4606 acc: 77.3
# Neutral 944/4606 acc: 53.8
# Sad 728/4606 acc: 54.0
# Surprise 478/4606 acc: 57.9

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 64.15052816901408
# Angry 258/4606 acc: 74.4
# Disgust 262/4606 acc: 48.1
# Fear 107/4606 acc: 49.5
# Happy 1767/4606 acc: 77.3
# Neutral 944/4606 acc: 53.8
# Sad 728/4606 acc: 54.0
# Surprise 478/4606 acc: 57.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.38      0.74      0.50       258
#      Disgust       0.26      0.48      0.34       262
#         Fear       0.23      0.50      0.31       107
#        Happy       0.89      0.77      0.83      1767
#      Neutral       0.68      0.54      0.60       944
#          Sad       0.58      0.54      0.56       728
#     Surprise       0.76      0.58      0.66       478
#
#     accuracy                           0.64      4544
#    macro avg       0.54      0.59      0.54      4544
# weighted avg       0.70      0.64      0.66      4544

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 62ms/step
# Accuracy =  0.546875
# 2/2 [==============================] - 0s 34ms/step
# Accuracy =  0.234375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4004

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# Accuracy: 40.0390625
# Angry 292/2100 acc: 75.3
# Disgust 296/2100 acc: 23.3
# Fear 293/2100 acc: 17.4
# Happy 291/2100 acc: 38.5
# Neutral 292/2100 acc: 51.7
# Sad 296/2100 acc: 23.3
# Surprise 288/2100 acc: 51.4

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 40.0390625
# Angry 292/2100 acc: 75.3
# Disgust 296/2100 acc: 23.3
# Fear 293/2100 acc: 17.4
# Happy 291/2100 acc: 38.5
# Neutral 292/2100 acc: 51.7
# Sad 296/2100 acc: 23.3
# Surprise 288/2100 acc: 51.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.29      0.75      0.42       292
#      Disgust       0.39      0.23      0.29       296
#         Fear       0.40      0.17      0.24       293
#        Happy       0.64      0.38      0.48       291
#      Neutral       0.50      0.52      0.51       292
#          Sad       0.35      0.23      0.28       296
#     Surprise       0.49      0.51      0.50       288
#
#     accuracy                           0.40      2048
#    macro avg       0.44      0.40      0.39      2048
# weighted avg       0.44      0.40      0.39      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: surprise, probability: 0.8437747955322266
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: happy, probability: 0.36709341406822205
# 1/1 [==============================] - 0s 97ms/step
# Predicted emotion class: fear, probability: 0.404416024684906
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: disgust, probability: 0.5003921985626221
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: angry, probability: 0.38605996966362
# 1/1 [==============================] - 0s 102ms/step
# Predicted emotion class: angry, probability: 0.6816534996032715
# 1/1 [==============================] - 0s 112ms/step
# Predicted emotion class: angry, probability: 0.5195986032485962
# 1/1 [==============================] - 0s 132ms/step
# Predicted emotion class: neutral, probability: 0.2666916847229004
# 1/1 [==============================] - 0s 95ms/step
# Predicted emotion class: angry, probability: 0.5524265170097351

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 7s 7s/step
# Predicted emotion class: disgust, probability: 0.14389488101005554
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.144127756357193
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: disgust, probability: 0.14397892355918884
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14381533861160278
# 1/1 [==============================] - 0s 116ms/step
# Predicted emotion class: disgust, probability: 0.14386671781539917
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: disgust, probability: 0.14407561719417572
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: disgust, probability: 0.14387725293636322
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.1437917947769165
# 1/1 [==============================] - 0s 104ms/step
# Predicted emotion class: fear, probability: 0.14365749061107635

# %% [markdown]
# # Test with webcam

# %%
# Load the pre-trained model
model = load_model('EnsembleModel_100e_FER.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Convert the frame to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the image
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Display the image with the detected faces and their predictions
    cv2.imshow("Webcam", rgb_frame)

    # Exit the loop if the user presses the 'q' key
    if cv2.waitKey(1) == ord('q'):
        break

# Release the webcam and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
