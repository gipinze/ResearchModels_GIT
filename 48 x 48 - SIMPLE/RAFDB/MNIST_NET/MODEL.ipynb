# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
def mnist_net():
    inputs = Input(shape=(48, 48, 3))

    x = Conv2D(96, (3, 3), padding='same', activation='relu', kernel_initializer='uniform')(inputs)
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(128, (1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(256, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(256, (1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(256, (1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(256, (1, 1), padding='same', activation='relu')(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(7, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Open the strategy scope
with strategy.scope():
    # Compile the model
    model = mnist_net()
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 96)        2688
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 128)       110720
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       16512
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 128)      0
#  )
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 256)       65792
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 512)       1180160
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 512)       2359808
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 256)       131328
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 512)         1180160
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 256)         131328
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 18,328,455
# Trainable params: 18,328,455
# Non-trainable params: 0
# _________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     
print(class_weights)

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 167/167 [==============================] - ETA: 0s - loss: 5.2863 - accuracy: 0.2226
# Epoch 1: val_accuracy improved from -inf to 0.10541, saving model to best_model.h5
# 167/167 [==============================] - 32s 110ms/step - loss: 5.2863 - accuracy: 0.2226 - val_loss: 1.9465 - val_accuracy: 0.1054 - lr: 1.0000e-04
# Epoch 2/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2947 - accuracy: 0.0970
# Epoch 2: val_accuracy did not improve from 0.10541
# 167/167 [==============================] - 16s 95ms/step - loss: 5.2947 - accuracy: 0.0970 - val_loss: 1.9454 - val_accuracy: 0.1050 - lr: 1.0000e-04
# Epoch 3/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2910 - accuracy: 0.1675
# Epoch 3: val_accuracy improved from 0.10541 to 0.38820, saving model to best_model.h5
# 167/167 [==============================] - 15s 90ms/step - loss: 5.2910 - accuracy: 0.1675 - val_loss: 1.9430 - val_accuracy: 0.3882 - lr: 1.0000e-04
# Epoch 4/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2972 - accuracy: 0.2849
# Epoch 4: val_accuracy did not improve from 0.38820
# 167/167 [==============================] - 15s 89ms/step - loss: 5.2972 - accuracy: 0.2849 - val_loss: 1.9451 - val_accuracy: 0.2456 - lr: 1.0000e-04
# Epoch 5/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2963 - accuracy: 0.1187
# Epoch 5: val_accuracy did not improve from 0.38820
# 167/167 [==============================] - 14s 86ms/step - loss: 5.2963 - accuracy: 0.1187 - val_loss: 1.9437 - val_accuracy: 0.1059 - lr: 1.0000e-04
# Epoch 6/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2830 - accuracy: 0.1518
# Epoch 6: val_accuracy did not improve from 0.38820
# 167/167 [==============================] - 15s 87ms/step - loss: 5.2830 - accuracy: 0.1518 - val_loss: 1.9481 - val_accuracy: 0.0550 - lr: 1.0000e-04
# Epoch 7/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2467 - accuracy: 0.1539
# Epoch 7: val_accuracy improved from 0.38820 to 0.38930, saving model to best_model.h5
# 167/167 [==============================] - 15s 90ms/step - loss: 5.2467 - accuracy: 0.1539 - val_loss: 1.8495 - val_accuracy: 0.3893 - lr: 1.0000e-04
# Epoch 8/400
# 167/167 [==============================] - ETA: 0s - loss: 5.1341 - accuracy: 0.2912
# Epoch 8: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 86ms/step - loss: 5.1341 - accuracy: 0.2912 - val_loss: 1.8713 - val_accuracy: 0.3622 - lr: 1.0000e-04
# Epoch 9/400
# 167/167 [==============================] - ETA: 0s - loss: 5.1146 - accuracy: 0.3106
# Epoch 9: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 15s 87ms/step - loss: 5.1146 - accuracy: 0.3106 - val_loss: 1.8068 - val_accuracy: 0.3737 - lr: 1.0000e-04
# Epoch 10/400
# 167/167 [==============================] - ETA: 0s - loss: 5.0795 - accuracy: 0.3300
# Epoch 10: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 15s 87ms/step - loss: 5.0795 - accuracy: 0.3300 - val_loss: 1.9532 - val_accuracy: 0.2964 - lr: 1.0000e-04
# Epoch 11/400
# 167/167 [==============================] - ETA: 0s - loss: 5.0535 - accuracy: 0.3089
# Epoch 11: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 86ms/step - loss: 5.0535 - accuracy: 0.3089 - val_loss: 1.8863 - val_accuracy: 0.2731 - lr: 1.0000e-04
# Epoch 12/400
# 167/167 [==============================] - ETA: 0s - loss: 5.0264 - accuracy: 0.2887
# Epoch 12: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 86ms/step - loss: 5.0264 - accuracy: 0.2887 - val_loss: 1.8517 - val_accuracy: 0.3156 - lr: 1.0000e-04
# Epoch 13/400
# 167/167 [==============================] - ETA: 0s - loss: 5.0317 - accuracy: 0.2995
# Epoch 13: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 85ms/step - loss: 5.0317 - accuracy: 0.2995 - val_loss: 1.9349 - val_accuracy: 0.2491 - lr: 1.0000e-04
# Epoch 14/400
# 167/167 [==============================] - ETA: 0s - loss: 5.0094 - accuracy: 0.2623
# Epoch 14: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 83ms/step - loss: 5.0094 - accuracy: 0.2623 - val_loss: 2.0497 - val_accuracy: 0.1408 - lr: 1.0000e-04
# Epoch 15/400
# 167/167 [==============================] - ETA: 0s - loss: 4.9896 - accuracy: 0.2823
# Epoch 15: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s 85ms/step - loss: 4.9896 - accuracy: 0.2823 - val_loss: 1.8974 - val_accuracy: 0.2520 - lr: 1.0000e-04
# Epoch 16/400
# 167/167 [==============================] - ETA: 0s - loss: 4.9576 - accuracy: 0.2682
# Epoch 16: val_accuracy did not improve from 0.38930
# 167/167 [==============================] - 14s
saving model to best_model.h5
# 167/167 [==============================] - 14s 83ms/step - loss: 3.8310 - accuracy: 0.5034 - val_loss: 1.3135 - val_accuracy: 0.5379 - lr: 5.0000e-05
# Epoch 43/400
# 167/167 [==============================] - ETA: 0s - loss: 3.7557 - accuracy: 0.5078
# Epoch 43: val_accuracy did not improve from 0.53785
# 167/167 [==============================] - 14s 82ms/step - loss: 3.7557 - accuracy: 0.5078 - val_loss: 1.3625 - val_accuracy: 0.4991 - lr: 5.0000e-05
# Epoch 44/400
# 167/167 [==============================] - ETA: 0s - loss: 3.6934 - accuracy: 0.5228
# Epoch 44: val_accuracy improved from 0.53785 to 0.56624, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 3.6934 - accuracy: 0.5228 - val_loss: 1.2102 - val_accuracy: 0.5662 - lr: 5.0000e-05
# Epoch 45/400
# 167/167 [==============================] - ETA: 0s - loss: 3.6428 - accuracy: 0.5364
# Epoch 45: val_accuracy did not improve from 0.56624
# 167/167 [==============================] - 14s 82ms/step - loss: 3.6428 - accuracy: 0.5364 - val_loss: 1.3285 - val_accuracy: 0.5207 - lr: 5.0000e-05
# Epoch 46/400
# 167/167 [==============================] - ETA: 0s - loss: 3.5833 - accuracy: 0.5439
# Epoch 46: val_accuracy improved from 0.56624 to 0.57504, saving model to best_model.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 3.5833 - accuracy: 0.5439 - val_loss: 1.1755 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 47/400
# 167/167 [==============================] - ETA: 0s - loss: 3.5819 - accuracy: 0.5403
# Epoch 47: val_accuracy improved from 0.57504 to 0.61092, saving model to best_model.h5
# 167/167 [==============================] - 14s 83ms/step - loss: 3.5819 - accuracy: 0.5403 - val_loss: 1.0928 - val_accuracy: 0.6109 - lr: 5.0000e-05
# Epoch 48/400
# 167/167 [==============================] - ETA: 0s - loss: 3.4726 - accuracy: 0.5561
# Epoch 48: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 83ms/step - loss: 3.4726 - accuracy: 0.5561 - val_loss: 1.1272 - val_accuracy: 0.5834 - lr: 5.0000e-05
# Epoch 49/400
# 167/167 [==============================] - ETA: 0s - loss: 3.4403 - accuracy: 0.5593
# Epoch 49: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 81ms/step - loss: 3.4403 - accuracy: 0.5593 - val_loss: 1.4624 - val_accuracy: 0.4804 - lr: 5.0000e-05
# Epoch 50/400
# 167/167 [==============================] - ETA: 0s - loss: 3.4038 - accuracy: 0.5635
# Epoch 50: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 81ms/step - loss: 3.4038 - accuracy: 0.5635 - val_loss: 1.1806 - val_accuracy: 0.5799 - lr: 5.0000e-05
# Epoch 51/400
# 167/167 [==============================] - ETA: 0s - loss: 3.3301 - accuracy: 0.5696
# Epoch 51: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 82ms/step - loss: 3.3301 - accuracy: 0.5696 - val_loss: 1.1253 - val_accuracy: 0.5986 - lr: 5.0000e-05
# Epoch 52/400
# 167/167 [==============================] - ETA: 0s - loss: 3.3249 - accuracy: 0.5713
# Epoch 52: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 82ms/step - loss: 3.3249 - accuracy: 0.5713 - val_loss: 1.2777 - val_accuracy: 0.5495 - lr: 5.0000e-05
# Epoch 53/400
# 167/167 [==============================] - ETA: 0s - loss: 3.2676 - accuracy: 0.5834
# Epoch 53: val_accuracy did not improve from 0.61092
# 167/167 [==============================] - 14s 81ms/step - loss: 3.2676 - accuracy: 0.5834 - val_loss: 1.1075 - val_accuracy: 0.5995 - lr: 5.0000e-05
# Epoch 54/400
# 167/167 [==============================] - ETA: 0s - loss: 3.2650 - accuracy: 0.5807
# Epoch 54: val_accuracy improved from 0.61092 to 0.63666, saving model to best_model.h5
# 167/167 [==============================] - 14s 83ms/step - loss: 3.2650 - accuracy: 0.5807 - val_loss: 1.0020 - val_accuracy: 0.6367 - lr: 5.0000e-05
# Epoch 55/400
# 167/167 [==============================] - ETA: 0s - loss: 3.1770 - accuracy: 0.5925
# Epoch 55: val_accuracy did not improve from 0.63666
# 167/167 [==============================] - 14s 82ms/step - loss: 3.1770 - accuracy: 0.5925 - val_loss: 1.1996 - val_accuracy: 0.5645 - lr: 5.0000e-05
# Epoch 56/400
# 167/167 [==============================] - ETA: 0s - loss: 3.1776 - accuracy: 0.5872
# Epoch 56: val_accuracy did not improve from 0.63666
# 167/167 [==============================] - 14s 81ms/step - loss: 3.1776 - accuracy: 0.5872 - val_loss: 1.1580 - val_accuracy: 0.5940 - lr: 5.0000e-05
# Epoch 57/400
# 167/167 [==============================] - ETA: 0s - loss: 3.1099 - accuracy: 0.6046
# Epoch 57: val_accuracy did not improve from 0.63666
# 167/167 [==============================] - 13s 80ms/step - loss: 3.1099 - accuracy: 0.6046 - val_loss: 1.1609 - val_accuracy: 0.5876 - lr: 5.0000e-05
# Epoch 58/400
# 167/167 [==============================] - ETA: 0s - loss: 3.0524 - accuracy: 0.6041
# Epoch 58: val_accuracy did not improve from 0.63666
# 167/167 [==============================] - 14s 82ms/step - loss: 3.0524 - accuracy: 0.6041 - val_loss: 1.0016 - val_accuracy: 0.6272 - lr: 5.0000e-05
# Epoch 59/400
# 167/167 [==============================] - ETA: 0s - loss: 2.9878 - accuracy: 0.6122
# Epoch 59: val_accuracy did not improve from 0.63666
# 167/167 [==============================] - 14s 81ms/step - loss: 2.9878 - accuracy: 0.6122 - val_loss: 1.0154 - val_accuracy: 0.6296 - lr: 5.0000e-05
# Epoch 60/400
# 167/167 [==============================] - ETA: 0s - loss: 2.9536 - accuracy: 0.6163
# Epoch 60: val_accuracy improved from 0.63666 to 0.66813, saving model to best_model.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 2.9536 - accuracy: 0.6163 - val_loss: 0.8988 - val_accuracy: 0.6681 - lr: 5.0000e-05
# Epoch 61/400
# 167/167 [==============================] - ETA: 0s - loss: 2.9417 - accuracy: 0.6196
# Epoch 61: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 81ms/step - loss: 2.9417 - accuracy: 0.6196 - val_loss: 1.0166 - val_accuracy: 0.6287 - lr: 5.0000e-05
# Epoch 62/400
# 167/167 [==============================] - ETA: 0s - loss: 2.9336 - accuracy: 0.6226
# Epoch 62: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 81ms/step - loss: 2.9336 - accuracy: 0.6226 - val_loss: 1.0844 - val_accuracy: 0.6263 - lr: 5.0000e-05
# Epoch 63/400
# 167/167 [==============================] - ETA: 0s - loss: 2.8972 - accuracy: 0.6150
# Epoch 63: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 82ms/step - loss: 2.8972 - accuracy: 0.6150 - val_loss: 1.0345 - val_accuracy: 0.6285 - lr: 5.0000e-05
# Epoch 64/400
# 167/167 [==============================] - ETA: 0s - loss: 2.8742 - accuracy: 0.6345
# Epoch 64: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 81ms/step - loss: 2.8742 - accuracy: 0.6345 - val_loss: 1.0605 - val_accuracy: 0.6180 - lr: 5.0000e-05
# Epoch 65/400
# 167/167 [==============================] - ETA: 0s - loss: 2.8368 - accuracy: 0.6304
# Epoch 65: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 13s 80ms/step - loss: 2.8368 - accuracy: 0.6304 - val_loss: 1.0104 - val_accuracy: 0.6356 - lr: 5.0000e-05
# Epoch 66/400
# 167/167 [==============================] - ETA: 0s - loss: 2.8274 - accuracy: 0.6312
# Epoch 66: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 82ms/step - loss: 2.8274 - accuracy: 0.6312 - val_loss: 0.9996 - val_accuracy: 0.6406 - lr: 5.0000e-05
# Epoch 67/400
# 167/167 [==============================] - ETA: 0s - loss: 2.7836 - accuracy: 0.6443
# Epoch 67: val_accuracy did not improve from 0.66813
# 167/167 [==============================] - 14s 81ms/step - loss: 2.7836 - accuracy: 0.6443 - val_loss: 1.0659 - val_accuracy: 0.6243 - lr: 5.0000e-05
# Epoch 68/400
# 167/167 [==============================] - ETA: 0s - loss: 2.7224 - accuracy: 0.6442
# Epoch 68: val_accuracy improved from 0.66813 to 0.67077, saving model to best_model.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 2.7224 - accuracy: 0.6442 - val_loss: 0.9221 - val_accuracy: 0.6708 - lr: 5.0000e-05
# Epoch 69/400
# 167/167 [==============================] - ETA: 0s - loss: 2.7027 - accuracy: 0.6520
# Epoch 69: val_accuracy did not improve from 0.67077
# 167/167 [==============================] - 13s 80ms/step - loss: 2.7027 - accuracy: 0.6520 - val_loss: 1.0667 - val_accuracy: 0.6175 - lr: 5.0000e-05
# Epoch 70/400
# 167/167 [==============================] - ETA: 0s - loss: 2.6813 - accuracy: 0.6542
# Epoch 70: val_accuracy did not improve from 0.67077
# 167/167 [==============================] - 13s 79ms/step - loss: 2.6813 - accuracy: 0.6542 - val_loss: 0.8846 - val_accuracy: 0.6701 - lr: 5.0000e-05
# Epoch 71/400
# 167/167 [==============================] - ETA: 0s - loss: 2.6655 - accuracy: 0.6609
# Epoch 71: val_accuracy improved from 0.67077 to 0.68332, saving model to best_model.h5
# 167/167 [==============================] - 14s 83ms/step - loss: 2.6655 - accuracy: 0.6609 - val_loss: 0.8936 - val_accuracy: 0.6833 - lr: 5.0000e-05
# Epoch 72/400
# 167/167 [==============================] - ETA: 0s - loss: 2.6217 - accuracy: 0.6585
# Epoch 72: val_accuracy did not improve from 0.68332
# 167/167 [==============================] - 14s 81ms/step - loss: 2.6217 - accuracy: 0.6585 - val_loss: 0.9947 - val_accuracy: 0.6338 - lr: 5.0000e-05
# Epoch 73/400
# 167/167 [==============================] - ETA: 0s - loss: 2.5629 - accuracy: 0.6659
# Epoch 73: val_accuracy improved from 0.68332 to 0.68926, saving model to best_model.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 2.5629 - accuracy: 0.6659 - val_loss: 0.8672 - val_accuracy: 0.6893 - lr: 5.0000e-05
# Epoch 74/400
# 167/167 [==============================] - ETA: 0s - loss: 2.6088 - accuracy: 0.6622
# Epoch 74: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 14s 82ms/step - loss: 2.6088 - accuracy: 0.6622 - val_loss: 0.9363 - val_accuracy: 0.6547 - lr: 5.0000e-05
# Epoch 75/400
# 167/167 [==============================] - ETA: 0s - loss: 2.5052 - accuracy: 0.6721
# Epoch 75: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.5052 - accuracy: 0.6721 - val_loss: 0.9975 - val_accuracy: 0.6532 - lr: 5.0000e-05
# Epoch 76/400
# 167/167 [==============================] - ETA: 0s - loss: 2.5054 - accuracy: 0.6716
# Epoch 76: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.5054 - accuracy: 0.6716 - val_loss: 0.9091 - val_accuracy: 0.6794 - lr: 5.0000e-05
# Epoch 77/400
# 167/167 [==============================] - ETA: 0s - loss: 2.4890 - accuracy: 0.6684
# Epoch 77: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 14s 84ms/step - loss: 2.4890 - accuracy: 0.6684 - val_loss: 1.0183 - val_accuracy: 0.6591 - lr: 5.0000e-05
# Epoch 78/400
# 167/167 [==============================] - ETA: 0s - loss: 2.4685 - accuracy: 0.6732
# Epoch 78: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.4685 - accuracy: 0.6732 - val_loss: 1.0057 - val_accuracy: 0.6503 - lr: 5.0000e-05
# Epoch 79/400
# 167/167 [==============================] - ETA: 0s - loss: 2.4246 - accuracy: 0.6752
# Epoch 79: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.4246 - accuracy: 0.6752 - val_loss: 0.9233 - val_accuracy: 0.6695 - lr: 5.0000e-05
# Epoch 80/400
# 167/167 [==============================] - ETA: 0s - loss: 2.4313 - accuracy: 0.6778
# Epoch 80: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 14s 81ms/step - loss: 2.4313 - accuracy: 0.6778 - val_loss: 0.9184 - val_accuracy: 0.6708 - lr: 5.0000e-05
# Epoch 81/400
# 167/167 [==============================] - ETA: 0s - loss: 2.3846 - accuracy: 0.6848
# Epoch 81: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 14s 81ms/step - loss: 2.3846 - accuracy: 0.6848 - val_loss: 1.2560 - val_accuracy: 0.5755 - lr: 5.0000e-05
# Epoch 82/400
# 167/167 [==============================] - ETA: 0s - loss: 2.3526 - accuracy: 0.6840
# Epoch 82: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 14s 81ms/step - loss: 2.3526 - accuracy: 0.6840 - val_loss: 0.9132 - val_accuracy: 0.6664 - lr: 5.0000e-05
# Epoch 83/400
# 167/167 [==============================] - ETA: 0s - loss: 2.3023 - accuracy: 0.6942
# Epoch 83: val_accuracy did not improve from 0.68926
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 14s 81ms/step - loss: 2.3023 - accuracy: 0.6942 - val_loss: 0.8925 - val_accuracy: 0.6800 - lr: 5.0000e-05
# Epoch 84/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1592 - accuracy: 0.7030
# Epoch 84: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.1592 - accuracy: 0.7030 - val_loss: 0.9174 - val_accuracy: 0.6798 - lr: 2.5000e-05
# Epoch 85/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1994 - accuracy: 0.7024
# Epoch 85: val_accuracy did not improve from 0.68926
# 167/167 [==============================] - 13s 80ms/step - loss: 2.1994 - accuracy: 0.7024 - val_loss: 0.8864 - val_accuracy: 0.6855 - lr: 2.5000e-05
# Epoch 86/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1382 - accuracy: 0.7096
# Epoch 86: val_accuracy improved from 0.68926 to 0.69762, saving model to best_model.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 2.1382 - accuracy: 0.7096 - val_loss: 0.8864 - val_accuracy: 0.6976 - lr: 2.5000e-05
# Epoch 87/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1374 - accuracy: 0.7123
# Epoch 87: val_accuracy did not improve from 0.69762
# 167/167 [==============================] - 13s 80ms/step - loss: 2.1374 - accuracy: 0.7123 - val_loss: 0.8849 - val_accuracy: 0.6807 - lr: 2.5000e-05
# Epoch 88/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1123 - accuracy: 0.7161
# Epoch 88: val_accuracy did not improve from 0.69762
# 167/167 [==============================] - 14s 82ms/step - loss: 2.1123 - accuracy: 0.7161 - val_loss: 1.0068 - val_accuracy: 0.6503 - lr: 2.5000e-05
# Epoch 89/400
# 167/167 [==============================] - ETA: 0s - loss: 2.1206 - accuracy: 0.7172
# Epoch 89: val_accuracy did not improve from 0.69762
# 167/167 [==============================] - 14s 82ms/step - loss: 2.1206 - accuracy: 0.7172 - val_loss: 0.9207 - val_accuracy: 0.6857 - lr: 2.5000e-05
# Epoch 90/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0852 - accuracy: 0.7179
# Epoch 90: val_accuracy did not improve from 0.69762
# 167/167 [==============================] - 14s 81ms/step - loss: 2.0852 - accuracy: 0.7179 - val_loss: 0.8934 - val_accuracy: 0.6921 - lr: 2.5000e-05
# Epoch 91/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0498 - accuracy: 0.7197
# Epoch 91: val_accuracy did not improve from 0.69762
# 167/167 [==============================] - 13s 79ms/step - loss: 2.0498 - accuracy: 0.7197 - val_loss: 0.9090 - val_accuracy: 0.6886 - lr: 2.5000e-05
# Epoch 92/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0497 - accuracy: 0.7263
# Epoch 92: val_accuracy improved from 0.69762 to 0.70224, saving model to best_model.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 2.0497 - accuracy: 0.7263 - val_loss: 0.8671 - val_accuracy: 0.7022 - lr: 2.5000e-05
# Epoch 93/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0087 - accuracy: 0.7274
# Epoch 93: val_accuracy improved from 0.70224 to 0.71347, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 2.0087 - accuracy: 0.7274 - val_loss: 0.8588 - val_accuracy: 0.7135 - lr: 2.5000e-05
# Epoch 94/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0485 - accuracy: 0.7192
# Epoch 94: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 2.0485 - accuracy: 0.7192 - val_loss: 0.9161 - val_accuracy: 0.6932 - lr: 2.5000e-05
# Epoch 95/400
# 167/167 [==============================] - ETA: 0s - loss: 2.0213 - accuracy: 0.7236
# Epoch 95: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 82ms/step - loss: 2.0213 - accuracy: 0.7236 - val_loss: 0.9386 - val_accuracy: 0.6776 - lr: 2.5000e-05
# Epoch 96/400
# 167/167 [==============================] - ETA: 0s - loss: 1.9799 - accuracy: 0.7291
# Epoch 96: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 1.9799 - accuracy: 0.7291 - val_loss: 0.8878 - val_accuracy: 0.6904 - lr: 2.5000e-05
# Epoch 97/400
# 167/167 [==============================] - ETA: 0s - loss: 1.9834 - accuracy: 0.7259
# Epoch 97: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 1.9834 - accuracy: 0.7259 - val_loss: 0.9072 - val_accuracy: 0.6855 - lr: 2.5000e-05
# Epoch 98/400
# 167/167 [==============================] - ETA: 0s - loss: 1.9424 - accuracy: 0.7295
# Epoch 98: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 1.9424 - accuracy: 0.7295 - val_loss: 0.8839 - val_accuracy: 0.7011 - lr: 2.5000e-05
# Epoch 99/400
# 167/167 [==============================] - ETA: 0s - loss: 1.9544 - accuracy: 0.7332
# Epoch 99: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 1.9544 - accuracy: 0.7332 - val_loss: 0.9408 - val_accuracy: 0.6805 - lr: 2.5000e-05
# Epoch 100/400
# 167/167 [==============================] - ETA: 0s - loss: 1.9368 - accuracy: 0.7339
# Epoch 100: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 13s 80ms/step - loss: 1.9368 - accuracy: 0.7339 - val_loss: 0.8980 - val_accuracy: 0.7000 - lr: 2.5000e-05
# Epoch 101/400
# 167/167 [==============================] - ETA: 0s - loss: 1.8613 - accuracy: 0.7371
# Epoch 101: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 13s 80ms/step - loss: 1.8613 - accuracy: 0.7371 - val_loss: 0.8790 - val_accuracy: 0.7058 - lr: 2.5000e-05
# Epoch 102/400
# 167/167 [==============================] - ETA: 0s - loss: 1.8977 - accuracy: 0.7367
# Epoch 102: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 81ms/step - loss: 1.8977 - accuracy: 0.7367 - val_loss: 0.9120 - val_accuracy: 0.6926 - lr: 2.5000e-05
# Epoch 103/400
# 167/167 [==============================] - ETA: 0s - loss: 1.8327 - accuracy: 0.7428
# Epoch 103: val_accuracy did not improve from 0.71347
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 14s 81ms/step - loss: 1.8327 - accuracy: 0.7428 - val_loss: 0.8825 - val_accuracy: 0.6983 - lr: 2.5000e-05
# Epoch 104/400
# 167/167 [==============================] - ETA: 0s - loss: 1.8173 - accuracy: 0.7486
# Epoch 104: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 13s 80ms/step - loss: 1.8173 - accuracy: 0.7486 - val_loss: 0.8536 - val_accuracy: 0.7095 - lr: 1.2500e-05
# Epoch 105/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7947 - accuracy: 0.7494
# Epoch 105: val_accuracy did not improve from 0.71347
# 167/167 [==============================] - 14s 82ms/step - loss: 1.7947 - accuracy: 0.7494 - val_loss: 0.8810 - val_accuracy: 0.7005 - lr: 1.2500e-05
# Epoch 106/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7638 - accuracy: 0.7521
# Epoch 106: val_accuracy improved from 0.71347 to 0.71501, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 1.7638 - accuracy: 0.7521 - val_loss: 0.8576 - val_accuracy: 0.7150 - lr: 1.2500e-05
# Epoch 107/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7597 - accuracy: 0.7508
# Epoch 107: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 14s 81ms/step - loss: 1.7597 - accuracy: 0.7508 - val_loss: 0.9393 - val_accuracy: 0.6807 - lr: 1.2500e-05
# Epoch 108/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7369 - accuracy: 0.7511
# Epoch 108: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 14s 81ms/step - loss: 1.7369 - accuracy: 0.7511 - val_loss: 0.8559 - val_accuracy: 0.7099 - lr: 1.2500e-05
# Epoch 109/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7260 - accuracy: 0.7541
# Epoch 109: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 13s 80ms/step - loss: 1.7260 - accuracy: 0.7541 - val_loss: 0.9074 - val_accuracy: 0.6879 - lr: 1.2500e-05
# Epoch 110/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7100 - accuracy: 0.7552
# Epoch 110: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 14s 82ms/step - loss: 1.7100 - accuracy: 0.7552 - val_loss: 0.8738 - val_accuracy: 0.7097 - lr: 1.2500e-05
# Epoch 111/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6967 - accuracy: 0.7549
# Epoch 111: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 13s 80ms/step - loss: 1.6967 - accuracy: 0.7549 - val_loss: 0.9394 - val_accuracy: 0.6862 - lr: 1.2500e-05
# Epoch 112/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7495 - accuracy: 0.7571
# Epoch 112: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 13s 79ms/step - loss: 1.7495 - accuracy: 0.7571 - val_loss: 0.9765 - val_accuracy: 0.6703 - lr: 1.2500e-05
# Epoch 113/400
# 167/167 [==============================] - ETA: 0s - loss: 1.7070 - accuracy: 0.7581
# Epoch 113: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 13s 80ms/step - loss: 1.7070 - accuracy: 0.7581 - val_loss: 1.0063 - val_accuracy: 0.6692 - lr: 1.2500e-05
# Epoch 114/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6859 - accuracy: 0.7547
# Epoch 114: val_accuracy did not improve from 0.71501
#
# Epoch 114: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 13s 79ms/step - loss: 1.6859 - accuracy: 0.7547 - val_loss: 0.9015 - val_accuracy: 0.7005 - lr: 1.2500e-05
# Epoch 115/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6417 - accuracy: 0.7689
# Epoch 115: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 14s 81ms/step - loss: 1.6417 - accuracy: 0.7689 - val_loss: 0.8978 - val_accuracy: 0.7022 - lr: 6.2500e-06
# Epoch 116/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6491 - accuracy: 0.7604
# Epoch 116: val_accuracy did not improve from 0.71501
# 167/167 [==============================] - 13s 80ms/step - loss: 1.6491 - accuracy: 0.7604 - val_loss: 0.8743 - val_accuracy: 0.7088 - lr: 6.2500e-06
# Epoch 117/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6153 - accuracy: 0.7682
# Epoch 117: val_accuracy improved from 0.71501 to 0.71545, saving model to best_model.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 1.6153 - accuracy: 0.7682 - val_loss: 0.8740 - val_accuracy: 0.7154 - lr: 6.2500e-06
# Epoch 118/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6660 - accuracy: 0.7555
# Epoch 118: val_accuracy did not improve from 0.71545
# 167/167 [==============================] - 13s 80ms/step - loss: 1.6660 - accuracy: 0.7555 - val_loss: 0.9219 - val_accuracy: 0.6998 - lr: 6.2500e-06
# Epoch 119/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6215 - accuracy: 0.7629
# Epoch 119: val_accuracy did not improve from 0.71545
# 167/167 [==============================] - 13s 79ms/step - loss: 1.6215 - accuracy: 0.7629 - val_loss: 0.9006 - val_accuracy: 0.7053 - lr: 6.2500e-06
# Epoch 120/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6097 - accuracy: 0.7715
# Epoch 120: val_accuracy did not improve from 0.71545
# 167/167 [==============================] - 13s 79ms/step - loss: 1.6097 - accuracy: 0.7715 - val_loss: 0.8813 - val_accuracy: 0.7080 - lr: 6.2500e-06
# Epoch 121/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6014 - accuracy: 0.7629
# Epoch 121: val_accuracy did not improve from 0.71545
# 167/167 [==============================] - 13s 79ms/step - loss: 1.6014 - accuracy: 0.7629 - val_loss: 0.8659 - val_accuracy: 0.7137 - lr: 6.2500e-06
# Epoch 122/400
# 167/167 [==============================] - ETA: 0s - loss: 1.6317 - accuracy: 0.7665
# Epoch 122: val_accuracy did not improve from 0.71545
# 167/167 [==============================] - 13s 80ms/step - loss: 1.
400
# 167/167 [==============================] - ETA: 0s - loss: 1.5467 - accuracy: 0.7751
# Epoch 137: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 14s 81ms/step - loss: 1.5467 - accuracy: 0.7751 - val_loss: 0.8795 - val_accuracy: 0.7121 - lr: 3.1250e-06
# Epoch 138/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5464 - accuracy: 0.7777
# Epoch 138: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 13s 80ms/step - loss: 1.5464 - accuracy: 0.7777 - val_loss: 0.8853 - val_accuracy: 0.7102 - lr: 3.1250e-06
# Epoch 139/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5644 - accuracy: 0.7696
# Epoch 139: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 13s 80ms/step - loss: 1.5644 - accuracy: 0.7696 - val_loss: 0.8545 - val_accuracy: 0.7199 - lr: 3.1250e-06
# Epoch 140/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5127 - accuracy: 0.7820
# Epoch 140: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 14s 82ms/step - loss: 1.5127 - accuracy: 0.7820 - val_loss: 0.8756 - val_accuracy: 0.7163 - lr: 3.1250e-06
# Epoch 141/400
# 167/167 [==============================] - ETA: 0s - loss: 1.4984 - accuracy: 0.7766
# Epoch 141: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 13s 80ms/step - loss: 1.4984 - accuracy: 0.7766 - val_loss: 0.8727 - val_accuracy: 0.7161 - lr: 3.1250e-06
# Epoch 142/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5499 - accuracy: 0.7805
# Epoch 142: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 13s 80ms/step - loss: 1.5499 - accuracy: 0.7805 - val_loss: 0.8792 - val_accuracy: 0.7148 - lr: 3.1250e-06
# Epoch 143/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5479 - accuracy: 0.7754
# Epoch 143: val_accuracy did not improve from 0.72535
# 167/167 [==============================] - 13s 80ms/step - loss: 1.5479 - accuracy: 0.7754 - val_loss: 0.9044 - val_accuracy: 0.7058 - lr: 3.1250e-06
# Epoch 144/400
# 167/167 [==============================] - ETA: 0s - loss: 1.5494 - accuracy: 0.7764
# Epoch 144: val_accuracy did not improve from 0.72535
#
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 167/167 [==============================] - 13s 79ms/step - loss: 1.5494 - accuracy: 0.7764 - val_loss: 0.8966 - val_accuracy: 0.7080 - lr: 3.1250e-06
# Epoch 144: early stopping

# %%
save_model = model.save('MNIST_NET.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 10ms/step
# Accuracy =  0.609375

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.859375
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.609375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.7077

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 70.77464788732394
# Angry 256/4606 acc: 73.8
# Disgust 263/4606 acc: 58.9
# Fear 107/4606 acc: 55.1
# Happy 1769/4606 acc: 76.4
# Neutral 946/4606 acc: 59.8
# Sad 724/4606 acc: 71.7
# Surprise 479/4606 acc: 78.5

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 70.77464788732394
# Angry 256/4606 acc: 73.8
# Disgust 263/4606 acc: 58.9
# Fear 107/4606 acc: 55.1
# Happy 1769/4606 acc: 76.4
# Neutral 946/4606 acc: 59.8
# Sad 724/4606 acc: 71.7
# Surprise 479/4606 acc: 78.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.56      0.74      0.64       256
#      Disgust       0.35      0.59      0.44       263
#         Fear       0.35      0.55      0.43       107
#        Happy       0.96      0.76      0.85      1769
#      Neutral       0.71      0.60      0.65       946
#          Sad       0.59      0.72      0.64       724
#     Surprise       0.75      0.78      0.77       479
#
#     accuracy                           0.71      4544
#    macro avg       0.61      0.68      0.63      4544
# weighted avg       0.75      0.71      0.72      4544

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 168/168 [==============================] - 10s 61ms/step - loss: 0.5867 - accuracy: 0.7883
# 72/72 [==============================] - 3s 32ms/step - loss: 0.8938 - accuracy: 0.7086

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# Top 1 Accuracy: 70.88%
# 2/2 [==============================] - 0s 44ms/step
# Top 2 Accuracy: 42.19%
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0406 - accuracy: 0.6719
# Loss: 1.0406453609466553
# Precision: 0.61
# Recall: 0.68
# F1-Score: 0.63

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 46ms/step
# Accuracy =  0.640625
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5269

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# Accuracy: 52.685546875
# Angry 291/2100 acc: 68.7
# Disgust 291/2100 acc: 35.7
# Fear 293/2100 acc: 29.7
# Happy 294/2100 acc: 60.5
# Neutral 294/2100 acc: 50.0
# Sad 292/2100 acc: 49.3
# Surprise 293/2100 acc: 74.7

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 52.685546875
# Angry 291/2100 acc: 68.7
# Disgust 291/2100 acc: 35.7
# Fear 293/2100 acc: 29.7
# Happy 294/2100 acc: 60.5
# Neutral 294/2100 acc: 50.0
# Sad 292/2100 acc: 49.3
# Surprise 293/2100 acc: 74.7

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.50      0.69      0.58       291
#      Disgust       0.47      0.36      0.41       291
#         Fear       0.43      0.30      0.35       293
#        Happy       0.79      0.61      0.69       294
#      Neutral       0.58      0.50      0.54       294
#          Sad       0.45      0.49      0.47       292
#     Surprise       0.52      0.75      0.61       293
#
#     accuracy                           0.53      2048
#    macro avg       0.53      0.53      0.52      2048
# weighted avg       0.53      0.53      0.52      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
