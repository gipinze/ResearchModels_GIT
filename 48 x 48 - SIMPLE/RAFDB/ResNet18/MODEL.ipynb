# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # PERFECT CODE

# %%
import tensorflow as tf

def basic_block(x, in_channels, out_channels, stride=1):
    expansion = 1
    identity = x
    
    x = tf.keras.layers.Conv2D(
        out_channels,
        kernel_size=3,
        strides=stride,
        padding='same',
        use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    
    x = tf.keras.layers.Conv2D(
        out_channels,
        kernel_size=3,
        strides=1,
        padding='same',
        use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    if stride != 1 or in_channels != out_channels:
        identity = tf.keras.layers.Conv2D(
            out_channels * expansion,
            kernel_size=1,
            strides=stride,
            use_bias=False)(identity)
        identity = tf.keras.layers.BatchNormalization()(identity)
    
    x = tf.keras.layers.Add()([x, identity])
    x = tf.keras.layers.ReLU()(x)
    
    return x

def make_layer(x, block, out_channels, num_blocks, stride):
    x = block(x, x.shape[-1], out_channels, stride)
    for _ in range(1, num_blocks):
        x = block(x, out_channels, out_channels, 1)
    return x

def ResNet18(input_shape=(48, 48, 3), num_classes=7):
    inputs = tf.keras.Input(shape=input_shape)
    
    x = tf.keras.layers.Conv2D(
        64,
        kernel_size=3,
        strides=1,
        padding='same',
        use_bias=False)(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    
    x = make_layer(x, basic_block, 64, 2, 1)
    x = make_layer(x, basic_block, 128, 2, 2)
    x = make_layer(x, basic_block, 256, 2, 2)
    x = make_layer(x, basic_block, 512, 2, 2)
    
    x = tf.keras.layers.GlobalAveragePooling2D()(x)


# #     x = GlobalAveragePooling2D()(x)
#     x = Dropout(0.5)(x)  # Dropout layer for regularization
#     x = Dense(512)(x)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = Dropout(0.5)(x)  # Additional dropout layer

# #     # Add weight regularization to the dense layers
#     x = Dense(256)(x)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = Dropout(0.5)(x)
#     x = Dense(128)(x)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)

    # # Additional improvements
    x = tf.keras.layers.Dropout(0.2)(x)  # Apply dropout for regularization

    x = tf.keras.layers.Dense(1024, activation='relu')(x)  # Increase model capacity
    x = tf.keras.layers.Dropout(0.5)(x)  # Additional dropout
    
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# Creating an instance of ResNet18
model = ResNet18()

# Creating dummy input
dummy_input = tf.random.normal((1, 48, 48, 3))

# Checking the output shape
output = model(dummy_input)
print(output.shape)
# Out:
# (1, 7)

# %%
# import tensorflow as tf

# def basic_block(x, in_channels, out_channels, stride=1):
#     expansion = 1
#     identity = x
    
#     x = tf.keras.layers.Conv2D(
#         out_channels,
#         kernel_size=3,
#         strides=stride,
#         padding='same',
#         use_bias=False)(x)
#     x = tf.keras.layers.BatchNormalization()(x)
#     x = tf.keras.layers.ReLU()(x)
    
#     x = tf.keras.layers.Conv2D(
#         out_channels,
#         kernel_size=3,
#         strides=1,
#         padding='same',
#         use_bias=False)(x)
#     x = tf.keras.layers.BatchNormalization()(x)
    
#     if stride != 1 or in_channels != out_channels:
#         identity = tf.keras.layers.Conv2D(
#             out_channels * expansion,
#             kernel_size=1,
#             strides=stride,
#             use_bias=False)(identity)
#         identity = tf.keras.layers.BatchNormalization()(identity)
    
#     x = tf.keras.layers.Add()([x, identity])
#     x = tf.keras.layers.ReLU()(x)
    
#     return x

# def make_layer(x, block, out_channels, num_blocks, stride):
#     x = block(x, x.shape[-1], out_channels, stride)
#     for _ in range(1, num_blocks):
#         x = block(x, out_channels, out_channels, 1)
#     return x

# def ResNet18(input_shape=(48, 48, 3), num_classes=7):
#     inputs = tf.keras.Input(shape=input_shape)
    
#     x = tf.keras.layers.Conv2D(
#         64,
#         kernel_size=3,
#         strides=1,
#         padding='same',
#         use_bias=False)(inputs)
#     x = tf.keras.layers.BatchNormalization()(x)
#     x = tf.keras.layers.ReLU()(x)
    
#     x = make_layer(x, basic_block, 64, 2, 1)
#     x = make_layer(x, basic_block, 128, 2, 2)
#     x = make_layer(x, basic_block, 256, 2, 2)
#     x = make_layer(x, basic_block, 512, 2, 2)
    
#     x = tf.keras.layers.GlobalAveragePooling2D()(x)


# # #     x = GlobalAveragePooling2D()(x)
# #     x = Dropout(0.5)(x)  # Dropout layer for regularization
# #     x = Dense(512)(x)
# #     x = BatchNormalization()(x)
# #     x = Activation('relu')(x)
# #     x = Dropout(0.5)(x)  # Additional dropout layer

# # #     # Add weight regularization to the dense layers
# #     x = Dense(256)(x)
# #     x = BatchNormalization()(x)
# #     x = Activation('relu')(x)
# #     x = Dropout(0.5)(x)
# #     x = Dense(128)(x)
# #     x = BatchNormalization()(x)
# #     x = Activation('relu')(x)

#     # # Additional improvements
#     x = tf.keras.layers.Dropout(0.5)(x)  # Apply dropout for regularization
#     x = tf.keras.layers.Dense(1024, activation='relu')(x)  # Increase model capacity

#     # x = tf.keras.layers.Dense(4096, activation='relu')(x)  # Increase model capacity
#     x = tf.keras.layers.Dropout(0.5)(x)  # Additional dropout
    
#     outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
#     model = tf.keras.Model(inputs=inputs, outputs=outputs)
#     return model

# # Creating an instance of ResNet18
# model = ResNet18()

# # Creating dummy input
# dummy_input = tf.random.normal((1, 48, 48, 3))

# # Checking the output shape
# output = model(dummy_input)
# print(output.shape)

# %%
# Open the strategy scope
with strategy.scope():
    model = ResNet18()
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d_40 (Conv2D)             (None, 48, 48, 64)   1728        ['input_3[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 48, 48, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 48, 48, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_35[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 48, 48, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 48, 48, 64)   0           ['batch_normalization_42[0][0]',
#                                                                   're_lu_34[0][0]']
#
#  re_lu_36 (ReLU)                (None, 48, 48, 64)   0           ['add_16[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_36[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 48, 48, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_37[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 48, 48, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 48, 48, 64)   0           ['batch_normalization_44[0][0]',
#                                                                   're_lu_36[0][0]']
#
#  re_lu_38 (ReLU)                (None, 48, 48, 64)   0           ['add_17[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 24, 24, 128)  73728       ['re_lu_38[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 24, 24, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 24, 24, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_39[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 24, 24, 128)  8192        ['re_lu_38[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 24, 24, 128)  512        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 24, 24, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 24, 24, 128)  0           ['batch_normalization_46[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  re_lu_40 (ReLU)                (None, 24, 24, 128)  0           ['add_18[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_40[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 24, 24, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 24, 24, 128)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_41[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 24, 24, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 24, 24, 128)  0           ['batch_normalization_49[0][0]',
#                                                                   're_lu_40[0][0]']
#
#  re_lu_42 (ReLU)                (None, 24, 24, 128)  0           ['add_19[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 256)  294912      ['re_lu_42[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_43[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 256)  32768       ['re_lu_42[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_51[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  re_lu_44 (ReLU)                (None, 12, 12, 256)  0           ['add_20[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_44[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_45[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_54[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_54[0][0]',
#                                                                   're_lu_44[0][0]']
#
#  re_lu_46 (ReLU)                (None, 12, 12, 256)  0           ['add_21[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 6, 6, 512)    1179648     ['re_lu_46[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 6, 6, 512)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_47[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 6, 6, 512)    131072      ['re_lu_46[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_57[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_57[0][0]']
#
#  re_lu_48 (ReLU)                (None, 6, 6, 512)    0           ['add_22[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_48[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 6, 6, 512)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_49[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_59[0][0]',
#                                                                   're_lu_48[0][0]']
#
#  re_lu_50 (ReLU)                (None, 6, 6, 512)    0           ['add_23[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 512)         0           ['re_lu_50[0][0]']
#  obalAveragePooling2D)
#
#  dropout_4 (Dropout)            (None, 512)          0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1024)         525312      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 7)            7175        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 11,710,919
# Trainable params: 11,701,319
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 64 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 64 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 5.7132 - accuracy: 0.1913
# Epoch 1: val_accuracy improved from -inf to 0.38908, saving model to best_model.h5
# 167/167 [==============================] - 29s 120ms/step - loss: 5.7132 - accuracy: 0.1913 - val_loss: 1.6869 - val_accuracy: 0.3891 - lr: 1.0000e-04
# Epoch 2/400
# 167/167 [==============================] - ETA: 0s - loss: 5.2543 - accuracy: 0.2172
# Epoch 2: val_accuracy improved from 0.38908 to 0.39173, saving model to best_model.h5
# 167/167 [==============================] - 18s 109ms/step - loss: 5.2543 - accuracy: 0.2172 - val_loss: 1.7105 - val_accuracy: 0.3917 - lr: 1.0000e-04
# Epoch 3/400
# 167/167 [==============================] - ETA: 0s - loss: 5.1246 - accuracy: 0.2415
# Epoch 3: val_accuracy did not improve from 0.39173
# 167/167 [==============================] -
# Epoch 65/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1654 - accuracy: 0.8199
# Epoch 65: val_accuracy did not improve from 0.74516
# 167/167 [==============================] - 17s 104ms/step - loss: 1.1654 - accuracy: 0.8199 - val_loss: 0.8620 - val_accuracy: 0.7201 - lr: 1.2500e-05
# Epoch 66/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1252 - accuracy: 0.8183
# Epoch 66: val_accuracy did not improve from 0.74516
# 167/167 [==============================] - 18s 106ms/step - loss: 1.1252 - accuracy: 0.8183 - val_loss: 0.8706 - val_accuracy: 0.7221 - lr: 1.2500e-05
# Epoch 67/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1172 - accuracy: 0.8258
# Epoch 67: val_accuracy improved from 0.74516 to 0.74758, saving model to best_model.h5
# 167/167 [==============================] - 18s 106ms/step - loss: 1.1172 - accuracy: 0.8258 - val_loss: 0.8166 - val_accuracy: 0.7476 - lr: 1.2500e-05
# Epoch 68/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1257 - accuracy: 0.8199
# Epoch 68: val_accuracy did not improve from 0.74758
# 167/167 [==============================] - 17s 103ms/step - loss: 1.1257 - accuracy: 0.8199 - val_loss: 0.8497 - val_accuracy: 0.7353 - lr: 1.2500e-05
# Epoch 69/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1190 - accuracy: 0.8293
# Epoch 69: val_accuracy did not improve from 0.74758
# 167/167 [==============================] - 17s 99ms/step - loss: 1.1190 - accuracy: 0.8293 - val_loss: 0.8460 - val_accuracy: 0.7287 - lr: 1.2500e-05
# Epoch 70/400
# 167/167 [==============================] - ETA: 0s - loss: 1.0748 - accuracy: 0.8229
# Epoch 70: val_accuracy improved from 0.74758 to 0.75968, saving model to best_model.h5
# 167/167 [==============================] - 17s 103ms/step - loss: 1.0748 - accuracy: 0.8229 - val_loss: 0.7842 - val_accuracy: 0.7597 - lr: 1.2500e-05
# Epoch 71/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1197 - accuracy: 0.8176
# Epoch 71: val_accuracy did not improve from 0.75968
# 167/167 [==============================] - 17s 101ms/step - loss: 1.1197 - accuracy: 0.8176 - val_loss: 0.8025 - val_accuracy: 0.7493 - lr: 1.2500e-05
# Epoch 72/400
# 167/167 [==============================] - ETA: 0s - loss: 1.0797 - accuracy: 0.8258
# Epoch 72: val_accuracy did not improve from 0.75968
# 167/167 [==============================] - 18s 109ms/step - loss: 1.0797 - accuracy: 0.8258 - val_loss: 0.8302 - val_accuracy: 0.7449 - lr: 1.2500e-05
# Epoch 73/400
# 167/167 [==============================] - ETA: 0s - loss: 1.1096 - accuracy: 0.8237
# Epoch 73: val_accuracy did not improve from 0.75968
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 17s 104ms/step - loss: 1.1096 - accuracy: 0.8237 - val_loss: 1.0122 - val_accuracy: 0.6890 - lr: 1.2500e-05
# Epoch 73: early stopping

# %%
save_model = model.save('RESNET18_1.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model('best_model.h5')
model.summary()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 24ms/step
# Accuracy =  0.671875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 55ms/step
# Accuracy =  0.796875
# 2/2 [==============================] - 0s 101ms/step
# Accuracy =  0.484375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6899

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# Accuracy: 68.99207746478874
# Angry 258/4606 acc: 70.9
# Disgust 262/4606 acc: 64.5
# Fear 105/4606 acc: 65.7
# Happy 1767/4606 acc: 76.5
# Neutral 946/4606 acc: 55.3
# Sad 727/4606 acc: 74.4
# Surprise 479/4606 acc: 62.4

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 68.99207746478874
# Angry 258/4606 acc: 70.9
# Disgust 262/4606 acc: 64.5
# Fear 105/4606 acc: 65.7
# Happy 1767/4606 acc: 76.5
# Neutral 946/4606 acc: 55.3
# Sad 727/4606 acc: 74.4
# Surprise 479/4606 acc: 62.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.57      0.71      0.63       258
#      Disgust       0.31      0.65      0.42       262
#         Fear       0.23      0.66      0.34       105
#        Happy       0.96      0.76      0.85      1767
#      Neutral       0.77      0.55      0.64       946
#          Sad       0.60      0.74      0.66       727
#     Surprise       0.78      0.62      0.69       479
#
#     accuracy                           0.69      4544
#    macro avg       0.60      0.67      0.61      4544
# weighted avg       0.77      0.69      0.71      4544

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 168/168 [==============================] - 13s 76ms/step - loss: 0.5450 - accuracy: 0.8002
# 72/72 [==============================] - 3s 36ms/step - loss: 1.0139 - accuracy: 0.6878

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# Top 1 Accuracy: 68.97%
# 2/2 [==============================] - 0s 45ms/step
# Top 2 Accuracy: 35.94%
# 2/2 [==============================] - 0s 100ms/step - loss: 0.9693 - accuracy: 0.5938
# Loss: 0.9692960977554321
# Precision: 0.60
# Recall: 0.67
# F1-Score: 0.61

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.640625
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.4375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5229

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 76ms/step
# Accuracy: 52.294921875
# Angry 295/2100 acc: 71.5
# Disgust 291/2100 acc: 45.7
# Fear 293/2100 acc: 57.3
# Happy 294/2100 acc: 49.7
# Neutral 290/2100 acc: 50.3
# Sad 292/2100 acc: 48.3
# Surprise 293/2100 acc: 43.0

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 52.294921875
# Angry 295/2100 acc: 71.5
# Disgust 291/2100 acc: 45.7
# Fear 293/2100 acc: 57.3
# Happy 294/2100 acc: 49.7
# Neutral 290/2100 acc: 50.3
# Sad 292/2100 acc: 48.3
# Surprise 293/2100 acc: 43.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.56      0.72      0.63       295
#      Disgust       0.48      0.46      0.47       291
#         Fear       0.45      0.57      0.50       293
#        Happy       0.70      0.50      0.58       294
#      Neutral       0.60      0.50      0.55       290
#          Sad       0.40      0.48      0.44       292
#     Surprise       0.58      0.43      0.50       293
#
#     accuracy                           0.52      2048
#    macro avg       0.54      0.52      0.52      2048
# weighted avg       0.54      0.52      0.52      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: neutral, probability: 0.5341139435768127
# 1/1 [==============================] - 0s 127ms/step
# Predicted emotion class: fear, probability: 0.9724294543266296
# 1/1 [==============================] - 0s 143ms/step
# Predicted emotion class: fear, probability: 0.9998494386672974
# 1/1 [==============================] - 0s 127ms/step
# Predicted emotion class: sad, probability: 0.822394073009491
# 1/1 [==============================] - 0s 179ms/step
# Predicted emotion class: happy, probability: 0.9995455145835876
# 1/1 [==============================] - 0s 121ms/step
# Predicted emotion class: angry, probability: 0.9996426105499268
# 1/1 [==============================] - 0s 111ms/step
# Predicted emotion class: angry, probability: 0.888522744178772
# 1/1 [==============================] - 0s 114ms/step
# Predicted emotion class: neutral, probability: 0.6071460843086243
# 1/1 [==============================] - 0s 118ms/step
# Predicted emotion class: angry, probability: 0.4823733866214752

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d_40 (Conv2D)             (None, 48, 48, 64)   1728        ['input_3[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 48, 48, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 48, 48, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_35[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 48, 48, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 48, 48, 64)   0           ['batch_normalization_42[0][0]',
#                                                                   're_lu_34[0][0]']
#
#  re_lu_36 (ReLU)                (None, 48, 48, 64)   0           ['add_16[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_36[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 48, 48, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 48, 48, 64)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 48, 48, 64)   36864       ['re_lu_37[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 48, 48, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 48, 48, 64)   0           ['batch_normalization_44[0][0]',
#                                                                   're_lu_36[0][0]']
#
#  re_lu_38 (ReLU)                (None, 48, 48, 64)   0           ['add_17[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 24, 24, 128)  73728       ['re_lu_38[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 24, 24, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 24, 24, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_39[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 24, 24, 128)  8192        ['re_lu_38[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 24, 24, 128)  512        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 24, 24, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 24, 24, 128)  0           ['batch_normalization_46[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  re_lu_40 (ReLU)                (None, 24, 24, 128)  0           ['add_18[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_40[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 24, 24, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 24, 24, 128)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 24, 24, 128)  147456      ['re_lu_41[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 24, 24, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 24, 24, 128)  0           ['batch_normalization_49[0][0]',
#                                                                   're_lu_40[0][0]']
#
#  re_lu_42 (ReLU)                (None, 24, 24, 128)  0           ['add_19[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 256)  294912      ['re_lu_42[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_43[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 256)  32768       ['re_lu_42[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_51[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  re_lu_44 (ReLU)                (None, 12, 12, 256)  0           ['add_20[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_44[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 256)  589824      ['re_lu_45[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_54[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 12, 12, 256)  0           ['batch_normalization_54[0][0]',
#                                                                   're_lu_44[0][0]']
#
#  re_lu_46 (ReLU)                (None, 12, 12, 256)  0           ['add_21[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 6, 6, 512)    1179648     ['re_lu_46[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 6, 6, 512)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_47[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 6, 6, 512)    131072      ['re_lu_46[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_57[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_57[0][0]']
#
#  re_lu_48 (ReLU)                (None, 6, 6, 512)    0           ['add_22[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_48[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 6, 6, 512)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 6, 6, 512)    2359296     ['re_lu_49[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 6, 6, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 6, 6, 512)    0           ['batch_normalization_59[0][0]',
#                                                                   're_lu_48[0][0]']
#
#  re_lu_50 (ReLU)                (None, 6, 6, 512)    0           ['add_23[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 512)         0           ['re_lu_50[0][0]']
#  obalAveragePooling2D)
#
#  dropout_4 (Dropout)            (None, 512)          0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1024)         525312      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 7)            7175        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 11,710,919
# Trainable params: 11,701,319
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=100,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/100
# INFO:tensorflow:batch_all_reduce: 64 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 64 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 1.0993 - accuracy: 0.8246
# Epoch 1: val_accuracy improved from -inf to 0.75792, saving model to best_model.h5
# 167/167 [==============================] - 32s 134ms/step - loss: 1.0993 - accuracy: 0.8246 - val_loss: 0.7746 - val_accuracy: 0.7579 - lr: 1.0000e-05
# Epoch 2/100
# 167/167 [==============================] - ETA: 0s - loss: 1.0596 - accuracy: 0.8320
# Epoch 2: val_accuracy did not improve from 0.75792
# 167/167 [==============================] - 71s 426ms/step - loss: 1.0596 - accuracy: 0.8320 - val_loss: 0.8340 - val_accuracy: 0.7377 - lr: 1.0000e-05
# Epoch 3/100
# 167/167 [==============================] - ETA: 0s - loss: 1.0334 - accuracy: 0.8343
# Epoch 3: val_accuracy did not improve from 0.75792
# 167/167 [==============================] - 19s 111ms/step - loss: 1.0334 - accuracy: 0.8343 - val_loss: 0.8154 - val_accuracy: 0.7465 - lr: 1.0000e-05
# Epoch 4/100
# 167/167 [==============================] - ETA: 0s - loss: 1.0497 - accuracy: 0.8305
# Epoch 4: val_accuracy did not improve from 0.75792
# 167/167 [==============================] - 19s 111ms/step - loss: 1.0497 - accuracy: 0.8305 - val_loss: 0.8615 - val_accuracy: 0.7291 - lr: 1.0000e-05
# Epoch 5/100
# 167/167 [==============================] - ETA: 0s - loss: 1.0310 - accuracy: 0.8349
# Epoch 5: val_accuracy did not improve from 0.75792
# 167/167 [==============================] -
100
# 167/167 [==============================] - ETA: 0s - loss: 0.9469 - accuracy: 0.8434
# Epoch 20: val_accuracy did not improve from 0.75792
# 167/167 [==============================] - 19s 113ms/step - loss: 0.9469 - accuracy: 0.8434 - val_loss: 0.8620 - val_accuracy: 0.7405 - lr: 5.0000e-06
# Epoch 21/100
# 167/167 [==============================] - ETA: 0s - loss: 0.9194 - accuracy: 0.8473
# Epoch 21: val_accuracy did not improve from 0.75792
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 167/167 [==============================] - 19s 114ms/step - loss: 0.9194 - accuracy: 0.8473 - val_loss: 0.8575 - val_accuracy: 0.7434 - lr: 5.0000e-06
# Epoch 21: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 114ms/step
# Accuracy =  0.75

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.859375
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.578125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.7414

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# Accuracy: 74.14172535211267
# Angry 255/4606 acc: 72.2
# Disgust 259/4606 acc: 48.3
# Fear 105/4606 acc: 60.0
# Happy 1768/4606 acc: 81.0
# Neutral 950/4606 acc: 67.3
# Sad 732/4606 acc: 76.6
# Surprise 475/4606 acc: 76.8

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 74.14172535211267
# Angry 255/4606 acc: 72.2
# Disgust 259/4606 acc: 48.3
# Fear 105/4606 acc: 60.0
# Happy 1768/4606 acc: 81.0
# Neutral 950/4606 acc: 67.3
# Sad 732/4606 acc: 76.6
# Surprise 475/4606 acc: 76.8

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.63      0.72      0.68       255
#      Disgust       0.43      0.48      0.45       259
#         Fear       0.37      0.60      0.46       105
#        Happy       0.95      0.81      0.88      1768
#      Neutral       0.72      0.67      0.69       950
#          Sad       0.60      0.77      0.67       732
#     Surprise       0.79      0.77      0.78       475
#
#     accuracy                           0.74      4544
#    macro avg       0.64      0.69      0.66      4544
# weighted avg       0.77      0.74      0.75      4544

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.6875
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.421875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5420

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# Accuracy: 54.19921875
# Angry 289/2100 acc: 70.6
# Disgust 294/2100 acc: 28.6
# Fear 296/2100 acc: 39.9
# Happy 291/2100 acc: 64.9
# Neutral 289/2100 acc: 65.1
# Sad 293/2100 acc: 54.6
# Surprise 296/2100 acc: 56.4

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 54.19921875
# Angry 289/2100 acc: 70.6
# Disgust 294/2100 acc: 28.6
# Fear 296/2100 acc: 39.9
# Happy 291/2100 acc: 64.9
# Neutral 289/2100 acc: 65.1
# Sad 293/2100 acc: 54.6
# Surprise 296/2100 acc: 56.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.53      0.71      0.60       289
#      Disgust       0.61      0.29      0.39       294
#         Fear       0.55      0.40      0.46       296
#        Happy       0.69      0.65      0.67       291
#      Neutral       0.58      0.65      0.61       289
#          Sad       0.39      0.55      0.46       293
#     Surprise       0.55      0.56      0.56       296
#
#     accuracy                           0.54      2048
#    macro avg       0.56      0.54      0.54      2048
# weighted avg       0.56      0.54      0.54      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 246ms/step
# Predicted emotion class: sad, probability: 0.9175994396209717
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: surprise, probability: 0.985683262348175
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: fear, probability: 0.9997178912162781
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: sad, probability: 0.5991581678390503
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: happy, probability: 0.9999982118606567
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.9988099336624146
# 1/1 [==============================] - 0s 29ms/step
# Predicted emotion class: disgust, probability: 0.5417836904525757
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.6423261761665344
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: disgust, probability: 0.2929406762123108
