# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation, MaxPooling2D, Flatten
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
# RAFDB
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
# validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT =48
IMG_WIDTH = 48
CHANNELS = 3

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 6.87953795379538, 1: 6.800978792822186, 2: 16.81048387096774, 3: 1.0, 4: 1.8595004460303302, 5: 2.421022067363531, 6: 3.679611650485437}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
def alexnet(input_shape=(48, 48, 3), num_classes=7):
    # Define the input placeholder as a tensor with the input shape
    inputs = tf.keras.layers.Input(input_shape)

    # Define the AlexNet architecture
    x = tf.keras.layers.Conv2D(96, kernel_size=(11, 11), strides=(4, 4), activation='relu')(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Conv2D(256, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = tf.keras.layers.Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = tf.keras.layers.Conv2D(256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name='alexnet')

    return model

# %%
with strategy.scope():

    
    model = alexnet(input_shape=(48, 48, 3), num_classes=7)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "alexnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 10, 10, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 96)         0
#  )
#
#  batch_normalization (BatchN  (None, 4, 4, 96)         384
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 256)         614656
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 256)         884992
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 7)                 28679
#
# =================================================================
# Total params: 21,612,295
# Trainable params: 21,611,079
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 22 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 5.1504 - accuracy: 0.2522
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.06.h5
# 167/167 [==============================] - 28s 95ms/step - loss: 5.1504 - accuracy: 0.2522 - val_loss: 1.9433 - val_accuracy: 0.0574 - lr: 1.0000e-04
# Epoch 2/300
# 167/167 [==============================] - ETA: 0s - loss: 5.0490 - accuracy: 0.2475
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.38.h5
# 167/167 [==============================] - 14s 85ms/step - loss: 5.0490 - accuracy: 0.2475 - val_loss: 1.9131 - val_accuracy: 0.3820 - lr: 1.0000e-04
# Epoch 3/300
# 167/167 [==============================] - ETA: 0s - loss: 5.0061 - accuracy: 0.2689
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.21.h5
# 167/167 [==============================] - 15s 88ms/step - loss: 5.0061 - accuracy: 0.2689 - val_loss: 1.9221 - val_accuracy: 0.2102 - lr: 1.0000e-04
# Epoch 4/300
# 167/167 [==============================] - ETA: 0s - loss: 4.9128 - accuracy: 0.2872
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.40.h5
# 167/167 [==============================] - 14s 85ms/step - loss: 4.9128 - accuracy: 0.2872 - val_loss: 1.6977 - val_accuracy: 0.3959 - lr: 1.0000e-04
# Epoch 5/300
# 167/167 [==============================] - ETA: 0s - loss: 4.8436 - accuracy: 0.2912
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.33.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 4.8436 - accuracy: 0.2912 - val_loss: 1.7612 - val_accuracy: 0.3314 - lr: 1.0000e-04
# Epoch 6/300
# 167/167 [==============================] - ETA: 0s - loss: 4.7687 - accuracy: 0.3184
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.26.h5
# 167/167 [==============================] - 14s 84ms/step - loss: 4.7687 - accuracy: 0.3184 - val_loss: 1.7969 - val_accuracy: 0.2614 - lr: 1.0000e-04
# Epoch 7/300
# 167/167 [==============================] - ETA: 0s - loss: 4.7393 - accuracy: 0.3219
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.23.h5
# 167/167 [==============================] - 15s 90ms/step - loss: 4.7393 - accuracy: 0.3219 - val_loss: 1.9464 - val_accuracy: 0.2326 - lr: 1.0000e-04
# Epoch 8/300
# 167/167 [==============================] - ETA: 0s - loss: 4.7140 - accuracy: 0.3373
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.41.h5
# 167/167 [==============================] - 16s 93ms/step - loss: 4.7140 - accuracy: 0.3373 - val_loss: 1.6140 - val_accuracy: 0.4082 - lr: 1.0000e-04
# Epoch 9/300
# 167/167 [==============================] - ETA: 0s - loss: 4.6447 - accuracy: 0.3565
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.42.h5
# 167/167 [==============================] - 14s 83ms/step - loss: 4.6447 - accuracy: 0.3565 - val_loss: 1.5952 - val_accuracy: 0.4162 - lr: 1.0000e-04
# Epoch 10/300
# 167/167 [==============================] - ETA: 0s - loss: 4.6006 - accuracy: 0.3640
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.37.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 4.6006 - accuracy: 0.3640 - val_loss: 1.6996 - val_accuracy: 0.3702 - lr: 1.0000e-04
# Epoch 11/300
# 167/167 [==============================] - ETA: 0s - loss: 4.5955 - accuracy: 0.3615
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.25.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 4.5955 - accuracy: 0.3615 - val_loss: 1.8507 - val_accuracy: 0.2548 - lr: 1.0000e-04
# Epoch 12/300
# 167/167 [==============================] - ETA: 0s - loss: 4.5385 - accuracy: 0.3741
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.40.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 4.5385 - accuracy: 0.3741 - val_loss: 1.6374 - val_accuracy: 0.4016 - lr: 1.0000e-04
# Epoch 13/300
# 167/167 [==============================] - ETA: 0s - loss: 4.4787 - accuracy: 0.3860
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.38.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 4.4787 - accuracy: 0.3860 - val_loss: 1.6670 - val_accuracy: 0.3752 - lr: 1.0000e-04
# Epoch 14/300
# 167/167 [==============================] - ETA: 0s - loss: 4.4738 - accuracy: 0.3846
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.33.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.4738 - accuracy: 0.3846 - val_loss: 1.7794 - val_accuracy: 0.3321 - lr: 1.0000e-04
# Epoch 15/300
# 167/167 [==============================] - ETA: 0s - loss: 4.4004 - accuracy: 0.4026
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.42.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 4.4004 - accuracy: 0.4026 - val_loss: 1.5567 - val_accuracy: 0.4155 - lr: 1.0000e-04
# Epoch 16/300
# 167/167 [==============================] - ETA: 0s - loss: 4.3816 - accuracy: 0.3967
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.36.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.3816 - accuracy: 0.3967 - val_loss: 1.7321 - val_accuracy: 0.3636 - lr: 1.0000e-04
# Epoch 17/300
# 167/167 [==============================] - ETA: 0s - loss: 4.3610 - accuracy: 0.4077
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.48.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 4.3610 - accuracy: 0.4077 - val_loss: 1.4744 - val_accuracy: 0.4767 - lr: 1.0000e-04
# Epoch 18/300
# 167/167 [==============================] - ETA: 0s - loss: 4.3336 - accuracy: 0.4127
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.53.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 4.3336 - accuracy: 0.4127 - val_loss: 1.3737 - val_accuracy: 0.5279 - lr: 1.0000e-04
# Epoch 19/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2941 - accuracy: 0.4178
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.44.h5
# 167/167 [==============================] - 13s 77ms/step - loss: 4.2941 - accuracy: 0.4178 - val_loss: 1.5144 - val_accuracy: 0.4399 - lr: 1.0000e-04
# Epoch 20/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2325 - accuracy: 0.4202
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.53.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 4.2325 - accuracy: 0.4202 - val_loss: 1.2800 - val_accuracy: 0.5337 - lr: 1.0000e-04
# Epoch 21/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2338 - accuracy: 0.4287
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.52.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 4.2338 - accuracy: 0.4287 - val_loss: 1.3535 - val_accuracy: 0.5183 - lr: 1.0000e-04
# Epoch 22/300
# 167/167 [==============================] - ETA: 0s - loss: 4.2120 - accuracy: 0.4272
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.36.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 4.2120 - accuracy: 0.4272 - val_loss: 1.7172 - val_accuracy: 0.3570 - lr: 1.0000e-04
# Epoch 23/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1967 - accuracy: 0.4269
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.43.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 4.1967 - accuracy: 0.4269 - val_loss: 1.5391 - val_accuracy: 0.4322 - lr: 1.0000e-04
# Epoch 24/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1602 - accuracy: 0.4175
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.49.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 4.1602 - accuracy: 0.4175 - val_loss: 1.4189 - val_accuracy: 0.4912 - lr: 1.0000e-04
# Epoch 25/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1207 - accuracy: 0.4334
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.33.h5
# 167/167 [==============================] - 13s 71ms/step - loss: 4.1207 - accuracy: 0.4334 - val_loss: 1.8163 - val_accuracy: 0.3253 - lr: 1.0000e-04
# Epoch 26/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1065 - accuracy: 0.4372
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.52.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 4.1065 - accuracy: 0.4372 - val_loss: 1.3352 - val_accuracy: 0.5231 - lr: 1.0000e-04
# Epoch 27/300
# 167/167 [==============================] - ETA: 0s - loss: 4.1111 - accuracy: 0.4377
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.43.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 4.1111 - accuracy: 0.4377 - val_loss: 1.5183 - val_accuracy: 0.4329 - lr: 1.0000e-04
# Epoch 28/300
# 167/167 [==============================] - ETA: 0s - loss: 4.0638 - accuracy: 0.4402
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.45.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 4.0638 - accuracy: 0.4402 - val_loss: 1.4755 - val_accuracy: 0.4544 - lr: 1.0000e-04
# Epoch 29/300
# 167/167 [==============================] - ETA: 0s - loss: 4.0383 - accuracy: 0.4497
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.48.h5
# 167/167 [==============================] - 12s 75ms/step - loss: 4.0383 - accuracy: 0.4497 - val_loss: 1.3905 - val_accuracy: 0.4833 - lr: 1.0000e-04
# Epoch 30/300
# 167/167 [==============================] - ETA: 0s - loss: 4.0731 - accuracy: 0.4378
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.44.h5
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 167/167 [==============================] - 12s 74ms/step - loss: 4.0731 - accuracy: 0.4378 - val_loss: 1.5718 - val_accuracy: 0.4408 - lr: 1.0000e-04
# Epoch 31/300
# 167/167 [==============================] - ETA: 0s - loss: 3.9139 - accuracy: 0.4625
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.44.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.9139 - accuracy: 0.4625 - val_loss: 1.4542 - val_accuracy: 0.4441 - lr: 5.0000e-05
# Epoch 32/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8747 - accuracy: 0.4614
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.47.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.8747 - accuracy: 0.4614 - val_loss: 1.4096 - val_accuracy: 0.4714 - lr: 5.0000e-05
# Epoch 33/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8569 - accuracy: 0.4669
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.49.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.8569 - accuracy: 0.4669 - val_loss: 1.3894 - val_accuracy: 0.4883 - lr: 5.0000e-05
# Epoch 34/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8666 - accuracy: 0.4627
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.48.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.8666 - accuracy: 0.4627 - val_loss: 1.4605 - val_accuracy: 0.4802 - lr: 5.0000e-05
# Epoch 35/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7965 - accuracy: 0.4669
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.41.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.7965 - accuracy: 0.4669 - val_loss: 1.5874 - val_accuracy: 0.4144 - lr: 5.0000e-05
# Epoch 36/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7788 - accuracy: 0.4789
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.44.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.7788 - accuracy: 0.4789 - val_loss: 1.5317 - val_accuracy: 0.4373 - lr: 5.0000e-05
# Epoch 37/300
# 167/167 [==============================] - ETA: 0s - loss: 3.8250 - accuracy: 0.4706
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.8250 - accuracy: 0.4706 - val_loss: 1.3724 - val_accuracy: 0.5079 - lr: 5.0000e-05
# Epoch 38/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7379 - accuracy: 0.4739
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.7379 - accuracy: 0.4739 - val_loss: 1.2660 - val_accuracy: 0.5405 - lr: 5.0000e-05
# Epoch 39/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7483 - accuracy: 0.4746
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.50.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.7483 - accuracy: 0.4746 - val_loss: 1.3508 - val_accuracy: 0.5040 - lr: 5.0000e-05
# Epoch 40/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7572 - accuracy: 0.4785
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.45.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.7572 - accuracy: 0.4785 - val_loss: 1.4996 - val_accuracy: 0.4474 - lr: 5.0000e-05
# Epoch 41/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7379 - accuracy: 0.4742
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.53.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.7379 - accuracy: 0.4742 - val_loss: 1.2916 - val_accuracy: 0.5341 - lr: 5.0000e-05
# Epoch 42/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7059 - accuracy: 0.4759
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.51.h5
# 167/167 [==============================] - 13s 74ms/step - loss: 3.7059 - accuracy: 0.4759 - val_loss: 1.3511 - val_accuracy: 0.5095 - lr: 5.0000e-05
# Epoch 43/300
# 167/167 [==============================] - ETA: 0s - loss: 3.7149 - accuracy: 0.4763
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.50.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.7149 - accuracy: 0.4763 - val_loss: 1.3584 - val_accuracy: 0.5040 - lr: 5.0000e-05
# Epoch 44/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6869 - accuracy: 0.4811
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.6869 - accuracy: 0.4811 - val_loss: 1.3160 - val_accuracy: 0.5121 - lr: 5.0000e-05
# Epoch 45/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6312 - accuracy: 0.4851
# Epoch 45: saving model to checkpoints_freeze\toy-model_1-epoch-45-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.6312 - accuracy: 0.4851 - val_loss: 1.3106 - val_accuracy: 0.5163 - lr: 5.0000e-05
# Epoch 46/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6136 - accuracy: 0.4790
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.6136 - accuracy: 0.4790 - val_loss: 1.3224 - val_accuracy: 0.5097 - lr: 5.0000e-05
# Epoch 47/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6654 - accuracy: 0.4875
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.48.h5
# 167/167 [==============================] - 12s 75ms/step - loss: 3.6654 - accuracy: 0.4875 - val_loss: 1.3898 - val_accuracy: 0.4778 - lr: 5.0000e-05
# Epoch 48/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6178 - accuracy: 0.4861
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.6178 - accuracy: 0.4861 - val_loss: 1.2400 - val_accuracy: 0.5447 - lr: 5.0000e-05
# Epoch 49/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6274 - accuracy: 0.4864
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.42.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.6274 - accuracy: 0.4864 - val_loss: 1.5024 - val_accuracy: 0.4241 - lr: 5.0000e-05
# Epoch 50/300
# 167/167 [==============================] - ETA: 0s - loss: 3.6151 - accuracy: 0.4847
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.56.h5
# 167/167 [==============================] - 13s 76ms/step - loss: 3.6151 - accuracy: 0.4847 - val_loss: 1.2280 - val_accuracy: 0.5552 - lr: 5.0000e-05
# Epoch 51/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5639 - accuracy: 0.4863
# Epoch 51: saving model to checkpoints_freeze\toy-model_1-epoch-51-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.5639 - accuracy: 0.4863 - val_loss: 1.3441 - val_accuracy: 0.5070 - lr: 5.0000e-05
# Epoch 52/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5751 - accuracy: 0.4859
# Epoch 52: saving model to checkpoints_freeze\toy-model_1-epoch-52-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.5751 - accuracy: 0.4859 - val_loss: 1.3124 - val_accuracy: 0.5216 - lr: 5.0000e-05
# Epoch 53/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5556 - accuracy: 0.4947
# Epoch 53: saving model to checkpoints_freeze\toy-model_1-epoch-53-val_accuracy-0.49.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 3.5556 - accuracy: 0.4947 - val_loss: 1.3763 - val_accuracy: 0.4894 - lr: 5.0000e-05
# Epoch 54/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5702 - accuracy: 0.4847
# Epoch 54: saving model to checkpoints_freeze\toy-model_1-epoch-54-val_accuracy-0.38.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.5702 - accuracy: 0.4847 - val_loss: 1.6423 - val_accuracy: 0.3829 - lr: 5.0000e-05
# Epoch 55/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5277 - accuracy: 0.4920
# Epoch 55: saving model to checkpoints_freeze\toy-model_1-epoch-55-val_accuracy-0.49.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.5277 - accuracy: 0.4920 - val_loss: 1.3547 - val_accuracy: 0.4877 - lr: 5.0000e-05
# Epoch 56/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5496 - accuracy: 0.4909
# Epoch 56: saving model to checkpoints_freeze\toy-model_1-epoch-56-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.5496 - accuracy: 0.4909 - val_loss: 1.2925 - val_accuracy: 0.5218 - lr: 5.0000e-05
# Epoch 57/300
# 167/167 [==============================] - ETA: 0s - loss: 3.5122 - accuracy: 0.4895
# Epoch 57: saving model to checkpoints_freeze\toy-model_1-epoch-57-val_accuracy-0.49.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.5122 - accuracy: 0.4895 - val_loss: 1.3904 - val_accuracy: 0.4927 - lr: 5.0000e-05
# Epoch 58/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4636 - accuracy: 0.4964
# Epoch 58: saving model to checkpoints_freeze\toy-model_1-epoch-58-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 73ms/step - loss: 3.4636 - accuracy: 0.4964 - val_loss: 1.2785 - val_accuracy: 0.5198 - lr: 5.0000e-05
# Epoch 59/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4864 - accuracy: 0.4980
# Epoch 59: saving model to checkpoints_freeze\toy-model_1-epoch-59-val_accuracy-0.48.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.4864 - accuracy: 0.4980 - val_loss: 1.3634 - val_accuracy: 0.4798 - lr: 5.0000e-05
# Epoch 60/300
# 167/167 [==============================] - ETA: 0s - loss: 3.4619 - accuracy: 0.4929
# Epoch 60: saving model to checkpoints_freeze\toy-model_1-epoch-60-val_accuracy-0.53.h5
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 12s 73ms/step - loss: 3.4619 - accuracy: 0.4929 - val_loss: 1.2839 - val_accuracy: 0.5290 - lr: 5.0000e-05
# Epoch 61/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3827 - accuracy: 0.5159
# Epoch 61: saving model to checkpoints_freeze\toy-model_1-epoch-61-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.3827 - accuracy: 0.5159 - val_loss: 1.2317 - val_accuracy: 0.5447 - lr: 2.5000e-05
# Epoch 62/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3992 - accuracy: 0.5019
# Epoch 62: saving model to checkpoints_freeze\toy-model_1-epoch-62-val_accuracy-0.53.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3992 - accuracy: 0.5019 - val_loss: 1.2823 - val_accuracy: 0.5277 - lr: 2.5000e-05
# Epoch 63/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3643 - accuracy: 0.5057
# Epoch 63: saving model to checkpoints_freeze\toy-model_1-epoch-63-val_accuracy-0.53.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3643 - accuracy: 0.5057 - val_loss: 1.2637 - val_accuracy: 0.5266 - lr: 2.5000e-05
# Epoch 64/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3617 - accuracy: 0.5083
# Epoch 64: saving model to checkpoints_freeze\toy-model_1-epoch-64-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3617 - accuracy: 0.5083 - val_loss: 1.2774 - val_accuracy: 0.5172 - lr: 2.5000e-05
# Epoch 65/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3134 - accuracy: 0.5155
# Epoch 65: saving model to checkpoints_freeze\toy-model_1-epoch-65-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3134 - accuracy: 0.5155 - val_loss: 1.2433 - val_accuracy: 0.5368 - lr: 2.5000e-05
# Epoch 66/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3123 - accuracy: 0.5154
# Epoch 66: saving model to checkpoints_freeze\toy-model_1-epoch-66-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.3123 - accuracy: 0.5154 - val_loss: 1.2852 - val_accuracy: 0.5202 - lr: 2.5000e-05
# Epoch 67/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2984 - accuracy: 0.5146
# Epoch 67: saving model to checkpoints_freeze\toy-model_1-epoch-67-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.2984 - accuracy: 0.5146 - val_loss: 1.3002 - val_accuracy: 0.5143 - lr: 2.5000e-05
# Epoch 68/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2762 - accuracy: 0.5198
# Epoch 68: saving model to checkpoints_freeze\toy-model_1-epoch-68-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2762 - accuracy: 0.5198 - val_loss: 1.3066 - val_accuracy: 0.5231 - lr: 2.5000e-05
# Epoch 69/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3288 - accuracy: 0.5085
# Epoch 69: saving model to checkpoints_freeze\toy-model_1-epoch-69-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.3288 - accuracy: 0.5085 - val_loss: 1.2482 - val_accuracy: 0.5352 - lr: 2.5000e-05
# Epoch 70/300
# 167/167 [==============================] - ETA: 0s - loss: 3.3455 - accuracy: 0.5147
# Epoch 70: saving model to checkpoints_freeze\toy-model_1-epoch-70-val_accuracy-0.57.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.3455 - accuracy: 0.5147 - val_loss: 1.1858 - val_accuracy: 0.5744 - lr: 2.5000e-05
# Epoch 71/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2492 - accuracy: 0.5180
# Epoch 71: saving model to checkpoints_freeze\toy-model_1-epoch-71-val_accuracy-0.50.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.2492 - accuracy: 0.5180 - val_loss: 1.3528 - val_accuracy: 0.5033 - lr: 2.5000e-05
# Epoch 72/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2428 - accuracy: 0.5262
# Epoch 72: saving model to checkpoints_freeze\toy-model_1-epoch-72-val_accuracy-0.55.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.2428 - accuracy: 0.5262 - val_loss: 1.2390 - val_accuracy: 0.5469 - lr: 2.5000e-05
# Epoch 73/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2551 - accuracy: 0.5275
# Epoch 73: saving model to checkpoints_freeze\toy-model_1-epoch-73-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2551 - accuracy: 0.5275 - val_loss: 1.3183 - val_accuracy: 0.5079 - lr: 2.5000e-05
# Epoch 74/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2229 - accuracy: 0.5128
# Epoch 74: saving model to checkpoints_freeze\toy-model_1-epoch-74-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2229 - accuracy: 0.5128 - val_loss: 1.2854 - val_accuracy: 0.5216 - lr: 2.5000e-05
# Epoch 75/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2172 - accuracy: 0.5244
# Epoch 75: saving model to checkpoints_freeze\toy-model_1-epoch-75-val_accuracy-0.52.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.2172 - accuracy: 0.5244 - val_loss: 1.3069 - val_accuracy: 0.5185 - lr: 2.5000e-05
# Epoch 76/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2122 - accuracy: 0.5314
# Epoch 76: saving model to checkpoints_freeze\toy-model_1-epoch-76-val_accuracy-0.53.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.2122 - accuracy: 0.5314 - val_loss: 1.2677 - val_accuracy: 0.5332 - lr: 2.5000e-05
# Epoch 77/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2226 - accuracy: 0.5250
# Epoch 77: saving model to checkpoints_freeze\toy-model_1-epoch-77-val_accuracy-0.53.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.2226 - accuracy: 0.5250 - val_loss: 1.2581 - val_accuracy: 0.5260 - lr: 2.5000e-05
# Epoch 78/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2008 - accuracy: 0.5207
# Epoch 78: saving model to checkpoints_freeze\toy-model_1-epoch-78-val_accuracy-0.52.h5
# 167/167 [==============================] - 13s 75ms/step - loss: 3.2008 - accuracy: 0.5207 - val_loss: 1.2875 - val_accuracy: 0.5227 - lr: 2.5000e-05
# Epoch 79/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1439 - accuracy: 0.5247
# Epoch 79: saving model to checkpoints_freeze\toy-model_1-epoch-79-val_accuracy-0.56.h5
# 167/167 [==============================] - 12s 74ms/step - loss: 3.1439 - accuracy: 0.5247 - val_loss: 1.2000 - val_accuracy: 0.5616 - lr: 2.5000e-05
# Epoch 80/300
# 167/167 [==============================] - ETA: 0s - loss: 3.2284 - accuracy: 0.5247
# Epoch 80: saving model to checkpoints_freeze\toy-model_1-epoch-80-val_accuracy-0.52.h5
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 13s 78ms/step - loss: 3.2284 - accuracy: 0.5247 - val_loss: 1.2933 - val_accuracy: 0.5216 - lr: 2.5000e-05
# Epoch 81/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1839 - accuracy: 0.5275
# Epoch 81: saving model to checkpoints_freeze\toy-model_1-epoch-81-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.1839 - accuracy: 0.5275 - val_loss: 1.3072 - val_accuracy: 0.5143 - lr: 1.2500e-05
# Epoch 82/300
# 166/167 [============================>.] - ETA: 0s - loss: 3.1786 - accuracy: 0.5322
# Epoch 82: saving model to checkpoints_freeze\toy-model_1-epoch-82-val_accuracy-0.57.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.1783 - accuracy: 0.5324 - val_loss: 1.1869 - val_accuracy: 0.5698 - lr: 1.2500e-05
# Epoch 83/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1707 - accuracy: 0.5260
# Epoch 83: saving model to checkpoints_freeze\toy-model_1-epoch-83-val_accuracy-0.50.h5
# 167/167 [==============================] - 12s 72ms/step - loss: 3.1707 - accuracy: 0.5260 - val_loss: 1.3571 - val_accuracy: 0.4958 - lr: 1.2500e-05
# Epoch 84/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1300 - accuracy: 0.5372
# Epoch 84: saving model to checkpoints_freeze\toy-model_1-epoch-84-val_accuracy-0.52.h5
# 167/167 [==============================] - 11s 68ms/step - loss: 3.1300 - accuracy: 0.5372 - val_loss: 1.2812 - val_accuracy: 0.5246 - lr: 1.2500e-05
# Epoch 85/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1057 - accuracy: 0.5350
# Epoch 85: saving model to checkpoints_freeze\toy-model_1-epoch-85-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.1057 - accuracy: 0.5350 - val_loss: 1.3114 - val_accuracy: 0.5134 - lr: 1.2500e-05
# Epoch 86/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0826 - accuracy: 0.5331
# Epoch 86: saving model to checkpoints_freeze\toy-model_1-epoch-86-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.0826 - accuracy: 0.5331 - val_loss: 1.3224 - val_accuracy: 0.5084 - lr: 1.2500e-05
# Epoch 87/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1144 - accuracy: 0.5384
# Epoch 87: saving model to checkpoints_freeze\toy-model_1-epoch-87-val_accuracy-0.54.h5
# 167/167 [==============================] - 12s 69ms/step - loss: 3.1144 - accuracy: 0.5384 - val_loss: 1.2482 - val_accuracy: 0.5359 - lr: 1.2500e-05
# Epoch 88/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1017 - accuracy: 0.5324
# Epoch 88: saving model to checkpoints_freeze\toy-model_1-epoch-88-val_accuracy-0.56.h5
# 167/167 [==============================] - 12s 70ms/step - loss: 3.1017 - accuracy: 0.5324 - val_loss: 1.1962 - val_accuracy: 0.5638 - lr: 1.2500e-05
# Epoch 89/300
# 167/167 [==============================] - ETA: 0s - loss: 3.1189 - accuracy: 0.5382
# Epoch 89: saving model to checkpoints_freeze\toy-model_1-epoch-89-val_accuracy-0.51.h5
# 167/167 [==============================] - 12s 71ms/step - loss: 3.1189 - accuracy: 0.5382 - val_loss: 1.3204 - val_accuracy: 0.5055 - lr: 1.2500e-05
# Epoch 90/300
# 167/167 [==============================] - ETA: 0s - loss: 3.0801 - accuracy: 0.5457
# Epoch 90: saving model to checkpoints_freeze\toy-model_1-epoch-90-val_accuracy-0.53.h5
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 12s 70ms/step - loss: 3.0801 - accuracy: 0.5457 - val_loss: 1.2667 - val_accuracy: 0.5339 - lr: 1.2500e-05
# Epoch 90: early stopping

# %%
save_model = model.save('ALEXNET_100e.h5')

# %%
custom_objects = {
    'RepVGGBlock': RepVGGBlock,
    'GradientCheckpointing': GradientCheckpointing
}

model = load_model("REPVGG_100e_FER.h5", custom_objects=custom_objects)

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 5ms/step
# Accuracy =  0.484375

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 22ms/step
# Accuracy =  0.65625
# 2/2 [==============================] - 0s 51ms/step
# Accuracy =  0.34375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5343

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# Accuracy: 53.433098591549296
# Angry 259/4606 acc: 58.7
# Disgust 259/4606 acc: 33.6
# Fear 107/4606 acc: 43.0
# Happy 1764/4606 acc: 61.7
# Neutral 945/4606 acc: 44.1
# Sad 731/4606 acc: 43.4
# Surprise 479/4606 acc: 67.0

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 53.433098591549296
# Angry 259/4606 acc: 58.7
# Disgust 259/4606 acc: 33.6
# Fear 107/4606 acc: 43.0
# Happy 1764/4606 acc: 61.7
# Neutral 945/4606 acc: 44.1
# Sad 731/4606 acc: 43.4
# Surprise 479/4606 acc: 67.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.30      0.59      0.40       259
#      Disgust       0.22      0.34      0.27       259
#         Fear       0.16      0.43      0.23       107
#        Happy       0.85      0.62      0.72      1764
#      Neutral       0.53      0.44      0.48       945
#          Sad       0.53      0.43      0.48       731
#     Surprise       0.45      0.67      0.54       479
#
#     accuracy                           0.53      4544
#    macro avg       0.44      0.50      0.45      4544
# weighted avg       0.61      0.53      0.56      4544

# %% [markdown]
# # Unseen batch

# %%
# custom_objects = {
#     'RepVGGBlock': RepVGGBlock,
#     'GradientCheckpointing': GradientCheckpointing
# }

# model = load_model('REPVGG_100e_FER.h5', custom_objects=custom_objects)

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 22ms/step
# Accuracy =  0.453125
# 2/2 [==============================] - 0s 83ms/step
# Accuracy =  0.1875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3228

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# Accuracy: 32.275390625
# Angry 297/2100 acc: 65.7
# Disgust 293/2100 acc: 16.7
# Fear 293/2100 acc: 29.4
# Happy 291/2100 acc: 29.9
# Neutral 291/2100 acc: 23.4
# Sad 295/2100 acc: 10.8
# Surprise 288/2100 acc: 50.0

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 32.275390625
# Angry 297/2100 acc: 65.7
# Disgust 293/2100 acc: 16.7
# Fear 293/2100 acc: 29.4
# Happy 291/2100 acc: 29.9
# Neutral 291/2100 acc: 23.4
# Sad 295/2100 acc: 10.8
# Surprise 288/2100 acc: 50.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.32      0.66      0.43       297
#      Disgust       0.29      0.17      0.21       293
#         Fear       0.22      0.29      0.25       293
#        Happy       0.64      0.30      0.41       291
#      Neutral       0.36      0.23      0.28       291
#          Sad       0.35      0.11      0.17       295
#     Surprise       0.32      0.50      0.39       288
#
#     accuracy                           0.32      2048
#    macro avg       0.36      0.32      0.31      2048
# weighted avg       0.36      0.32      0.30      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 536ms/step
# Predicted emotion class: surprise, probability: 0.8632804751396179
# 1/1 [==============================] - 0s 122ms/step
# Predicted emotion class: neutral, probability: 0.4362144470214844
# 1/1 [==============================] - 0s 132ms/step
# Predicted emotion class: fear, probability: 0.5499020218849182
# 1/1 [==============================] - 0s 126ms/step
# Predicted emotion class: sad, probability: 0.38755857944488525
# 1/1 [==============================] - 0s 125ms/step
# Predicted emotion class: happy, probability: 0.49175041913986206
# 1/1 [==============================] - 0s 119ms/step
# Predicted emotion class: angry, probability: 0.9839269518852234
# 1/1 [==============================] - 0s 125ms/step
# Predicted emotion class: angry, probability: 0.8697988390922546
# 1/1 [==============================] - 0s 110ms/step
# Predicted emotion class: surprise, probability: 0.28166496753692627
# 1/1 [==============================] - 0s 129ms/step
# Predicted emotion class: neutral, probability: 0.589051365852356

# %% [markdown]
# # Fine Tunning

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 7, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
with strategy.scope():

    custom_objects = {
    'RepVGGBlock': RepVGGBlock,
    'GradientCheckpointing': GradientCheckpointing
}

    model = load_model('checkpoints_freeze/toy-model_1-epoch-78-val_accuracy-0.63.h5', custom_objects=custom_objects)
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    # for layer in base_model.layers:
    #     layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('REPVGG_FER2013_FINAL.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
# model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Testing model with webcam

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Initialize the video capture object
cap = cv2.VideoCapture(0)

# Loop through each video frame
while True:
    # Read a video frame
    ret, frame = cap.read()
    
    # Convert the frame from BGR to RGB format
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_image = rgb_frame[y:y+h, x:x+w, :]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to a numpy array
        normalized_image = resized_image.astype('float32') / 255.0

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Draw a rectangle around the detected face
        cv2.rectangle(rgb_frame, (x, y), (x+w, y+h), (0, 255, 0), 1)

        # Display the predicted emotion class and its corresponding probability on the frame
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(rgb_frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Convert the frame from RGB to BGR format
    bgr_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2BGR)

    # Display the frame with the detected faces and their predictions
    cv2.imshow("Video", bgr_frame)

    # Wait for a key press and check if the 'q' key was pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
