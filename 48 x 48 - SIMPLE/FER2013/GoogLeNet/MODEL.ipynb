# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Dense, concatenate, AveragePooling2D, Flatten, GlobalAveragePooling2D
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # PERFECT CODE

# %%
def inception_module(x, filters):
    tower_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
    tower_1 = Conv2D(filters[1], (3, 3), padding='same', activation='relu')(tower_1)
    
    tower_2 = Conv2D(filters[2], (1, 1), padding='same', activation='relu')(x)
    tower_2 = Conv2D(filters[3], (5, 5), padding='same', activation='relu')(tower_2)
    
    tower_3 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    tower_3 = Conv2D(filters[4], (1, 1), padding='same', activation='relu')(tower_3)
    
    tower_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(x)
    
    output = concatenate([tower_1, tower_2, tower_3, tower_4], axis=3)
    return output

# Define modified GoogLeNet model for 48x48x3 input images
def GoogLeNet(input_shape, num_classes):
    input_img = Input(shape=input_shape)
    
    # Stage 1: Convolution and MaxPooling
    x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(input_img)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 2: Convolution and MaxPooling
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 3: Inception modules
    x = inception_module(x, [64, 96, 128, 16, 32, 32])
    x = inception_module(x, [128, 128, 192, 32, 96, 64])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 4: Inception modules
    x = inception_module(x, [192, 96, 208, 16, 48, 64])
    x = inception_module(x, [160, 112, 224, 24, 64, 64])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 5: Inception modules
    x = inception_module(x, [128, 128, 256, 24, 64, 64])
    x = inception_module(x, [112, 144, 288, 32, 64, 64])
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)
    
    # Stage 6: Final layers
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = inception_module(x, [384, 192, 384, 48, 128, 128])
    
    # Stage 7: Global average pooling and dense layers
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)
    x = Dense(num_classes, activation='softmax')(x)
    
    # Create model
    model = Model(inputs=input_img, outputs=x)
    return model

# %%
# Create the GoogLeNet model
input_shape = (48, 48, 3)  # Adjust input shape according to your image size and channels
num_classes = 7  # Adjust the number of classes based on your task
# Open the strategy scope
with strategy.scope():
    # Create an instance of the modified GoogLeNet model
    model = GoogLeNet(input_shape, num_classes)
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 12, 12, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 12, 12, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 320)   0           ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 192)    61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 6, 6, 208)    66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 320)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 6, 6, 96)     165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 6, 6, 16)     83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 6, 6, 48)     15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 6, 6, 64)     20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6, 6, 224)    0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 6, 6, 160)    36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 6, 6, 224)    50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 224)   0           ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 6, 6, 112)    161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 6, 24)     134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 6, 6, 64)     14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 64)     14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 6, 6, 264)    0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 264)   0           ['concatenate_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 3, 3, 128)    33920       ['max_pooling2d_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 256)    67840       ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 264)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 3, 3, 128)    147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 3, 3, 24)     153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3, 3, 280)    0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 3, 3, 112)    31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 3, 3, 288)    80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 280)   0           ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 3, 3, 144)    145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 3, 3, 32)     230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 3, 3, 64)     17984       ['max_pooling2d_9[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 3, 3, 64)     17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 3, 3, 304)    0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 3, 3, 256)    78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 3, 3, 320)    97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 3, 3, 304)   0           ['concatenate_5[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 160)    368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 3, 3, 32)     256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 128)    39040       ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 128)    39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 3, 3, 448)    0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 256)    114944      ['max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 320)    143680      ['max_pooling2d_11[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 448)   0           ['max_pooling2d_11[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 2, 2, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 2, 2, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_13[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 496)         0           ['concatenate_8[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 496)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,909,319
# Trainable params: 5,909,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 448/448 [==============================] - ETA: 0s - loss: 3.4179 - accuracy: 0.1398
# Epoch 1: val_accuracy improved from -inf to 0.18764, saving model to best_model.h5
# 448/448 [==============================] - 287s 590ms/step - loss: 3.4179 - accuracy: 0.1398 - val_loss: 1.9252 - val_accuracy: 0.1876 - lr: 1.0000e-04
# Epoch 2/400
# 448/448 [==============================] - ETA: 0s - loss: 3.3747 - accuracy: 0.1790
# Epoch 2: val_accuracy did not improve from 0.18764
# 448/448 [==============================] - 32s 71ms/step - loss: 3.3747 - accuracy: 0.1790 - val_loss: 1.9698 - val_accuracy: 0.1765 - lr: 1.0000e-04
# Epoch 3/400
# 448/448 [==============================] - ETA: 0s - loss: 3.2708 - accuracy: 0.1985
# Epoch 3: val_accuracy did not improve from 0.18764
# 448/448 [==============================] - 32s 71ms/step - loss: 3.2708 - accuracy: 0.1985 - val_loss: 1.8125 - val_accuracy: 0.1212 - lr: 1.0000e-04
# Epoch 4/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1804 - accuracy: 0.2074
# Epoch 4: val_accuracy improved from 0.18764 to 0.22866, saving model to best_model.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 3.1804 - accuracy: 0.2074 - val_loss: 1.7928 - val_accuracy: 0.2287 - lr: 1.0000e-04
# Epoch 5/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1208 - accuracy: 0.2290
# Epoch 5: val_accuracy did not improve from 0.22866
# 448/448 [==============================] - 30s 66ms/step - loss: 3.1208 - accuracy: 0.2290 - val_loss: 1.7908 - val_accuracy: 0.2003 - lr: 1.0000e-04
# Epoch 6/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0643 - accuracy: 0.2455
# Epoch 6: val_accuracy improved from 0.22866 to 0.27400, saving model to best_model.h5
# 448/448 [==============================] - 32s 72ms/step - loss: 3.0643 - accuracy: 0.2455 - val_loss: 1.7562 - val_accuracy: 0.2740 - lr: 1.0000e-04
# Epoch 7/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0055 - accuracy: 0.2711
# Epoch 7: val_accuracy improved from 0.27400 to 0.30985, saving model to best_model.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 3.0055 - accuracy: 0.2711 - val_loss: 1.7266 - val_accuracy: 0.3098 - lr: 1.0000e-04
# Epoch 8/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9654 - accuracy: 0.2974
# Epoch 8: val_accuracy improved from 0.30985 to 0.32031, saving model to best_model.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 2.9654 - accuracy: 0.2974 - val_loss: 1.6832 - val_accuracy: 0.3203 - lr: 1.0000e-04
# Epoch 9/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9031 - accuracy: 0.3140
# Epoch 9: val_accuracy improved from 0.32031 to 0.34515, saving model to best_model.h5
# 448/448 [==============================] - 30s 68ms/step - loss: 2.9031 - accuracy: 0.3140 - val_loss: 1.6588 - val_accuracy: 0.3451 - lr: 1.0000e-04
# Epoch 10/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8350 - accuracy: 0.3491
# Epoch 10: val_accuracy improved from 0.34515 to 0.41853, saving model to best_model.h5
# 448/448 [==============================] - 33s 74ms/step - loss: 2.8350 - accuracy: 0.3491 - val_loss: 1.5377 - val_accuracy: 0.4185 - lr: 1.0000e-04
# Epoch 11/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.7483 - accuracy: 0.3797
# Epoch 11: val_accuracy improved from 0.41853 to 0.43485, saving model to best_model.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 2.7483 - accuracy: 0.3798 - val_loss: 1.4796 - val_accuracy: 0.4348 - lr: 1.0000e-04
# Epoch 12/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6629 - accuracy: 0.3991
# Epoch 12: val_accuracy did not improve from 0.43485
# 448/448 [==============================] - 32s 71ms/step - loss: 2.6629 - accuracy: 0.3991 - val_loss: 1.6109 - val_accuracy: 0.3841 - lr: 1.0000e-04
# Epoch 13/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5919 - accuracy: 0.4231
# Epoch 13: val_accuracy improved from 0.43485 to 0.45033, saving model to best_model.h5
# 448/448 [==============================] - 32s 72ms/step - loss: 2.5919 - accuracy: 0.4231 - val_loss: 1.4550 - val_accuracy: 0.4503 - lr: 1.0000e-04
# Epoch 14/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5279 - accuracy: 0.4382
# Epoch 14: val_accuracy improved from 0.45033 to 0.48270, saving model to best_model.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 2.5279 - accuracy: 0.4382 - val_loss: 1.3425 - val_accuracy: 0.4827 - lr: 1.0000e-04
# Epoch 15/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5150 - accuracy: 0.4345
# Epoch 15: val_accuracy improved from 0.48270 to 0.48786, saving model to best_model.h5
# 448/448 [==============================] - 32s 71ms/step - loss: 2.5150 - accuracy: 0.4345 - val_loss: 1.3384 - val_accuracy: 0.4879 - lr: 1.0000e-04
# Epoch 16/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.4623 - accuracy: 0.4474
# Epoch 16: val_accuracy did not improve from 0.48786
# 448/448 [==============================] - 32s 71ms/step - loss: 2.4623 - accuracy: 0.4473 - val_loss: 1.3540 - val_accuracy: 0.4777 - lr: 1.0000e-04
# Epoch 17/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4336 - accuracy: 0.4554
# Epoch 17: val_accuracy did not improve from 0.48786
# 448/448 [==============================] - 31s 70ms/step - loss: 2.4336 - accuracy: 0.4554 - val_loss: 1.3507 - val_accuracy: 0.4747 - lr: 1.0000e-04
# Epoch 18/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.3878 - accuracy: 0.4659
# Epoch 18: val_accuracy improved from 0.48786 to 0.51521, saving model to best_model.h5
# 448/448 [==============================] - 32s 72ms/step - loss: 2.3869 - accuracy: 0.4660 - val_loss: 1.2529 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 19/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.3554 - accuracy: 0.4714
# Epoch 19: val_accuracy did not improve from 0.51521
# 448/448 [==============================] - 32s 72ms/step - loss: 2.3575 - accuracy: 0.4713 - val_loss: 1.3067 - val_accuracy: 0.4951 - lr: 1.0000e-04
# Epoch 20/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3498 - accuracy: 0.4716
# Epoch 20: val_accuracy did not improve from 0.51521
# 448/448 [==============================] - 32s 71ms/step - loss: 2.3498 - accuracy: 0.4716 - val_loss: 1.2769 - val_accuracy: 0.5043 - lr: 1.0000e-04
# Epoch 21/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3299 - accuracy: 0.4799
# Epoch 21: val_accuracy improved from 0.51521 to 0.51855, saving model to best_model.h5
# 448/448 [==============================] - 32s 71ms/step - loss: 2.3299 - accuracy: 0.4799 - val_loss: 1.2550 - val_accuracy: 0.5186 - lr: 1.0000e-04
# Epoch 22/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2763 - accuracy: 0.4948
# Epoch 22: val_accuracy did not improve from 0.51855
# 448/448 [==============================] - 32s 71ms/step - loss: 2.2763 - accuracy: 0.4948 - val_loss: 1.2560 - val_accuracy: 0.5148 - lr: 1.0000e-04
# Epoch 23/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2583 - accuracy: 0.4999
# Epoch 23: val_accuracy did not improve from 0.51855
# 448/448 [==============================] - 31s 69ms/step - loss: 2.2583 - accuracy: 0.4999 - val_loss: 1.3724 - val_accuracy: 0.4683 - lr: 1.0000e-04
# Epoch 24/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2322 - accuracy: 0.5010
# Epoch 24: val_accuracy did not improve from 0.51855
# 448/448 [==============================] - 31s 70ms/step - loss: 2.2322 - accuracy: 0.5010 - val_loss: 1.2947 - val_accuracy: 0.5029 - lr: 1.0000e-04
# Epoch 25/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2167 - accuracy: 0.4966
# Epoch 25: val_accuracy improved from 0.51855 to 0.54674, saving model to best_model.h5
# 448/448 [==============================] - 32s 70ms/step - loss: 2.2167 - accuracy: 0.4966 - val_loss: 1.1802 - val_accuracy: 0.5467 - lr: 1.0000e-04
# Epoch 26/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1837 - accuracy: 0.5151
# Epoch 26: val_accuracy did not improve from 0.54674
# 448/448 [==============================] - 31s 70ms/step - loss: 2.1837 - accuracy: 0.5151 - val_loss: 1.1993 - val_accuracy: 0.5385 - lr: 1.0000e-04
# Epoch 27/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1789 - accuracy: 0.5188
# Epoch 27: val_accuracy improved from 0.54674 to 0.55064, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 2.1789 - accuracy: 0.5188 - val_loss: 1.1815 - val_accuracy: 0.5506 - lr: 1.0000e-04
# Epoch 28/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.1427 - accuracy: 0.5148
# Epoch 28: val_accuracy did not improve from 0.55064
# 448/448 [==============================] - 31s 70ms/step - loss: 2.1427 - accuracy: 0.5147 - val_loss: 1.1966 - val_accuracy: 0.5306 - lr: 1.0000e-04
# Epoch 29/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1324 - accuracy: 0.5209
# Epoch 29: val_accuracy improved from 0.55064 to 0.55287, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 2.1324 - accuracy: 0.5209 - val_loss: 1.1711 - val_accuracy: 0.5529 - lr: 1.0000e-04
# Epoch 30/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0967 - accuracy: 0.5291
# Epoch 30: val_accuracy did not improve from 0.55287
# 448/448 [==============================] - 31s 69ms/step - loss: 2.0967 - accuracy: 0.5291 - val_loss: 1.2421 - val_accuracy: 0.5251 - lr: 1.0000e-04
# Epoch 31/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0910 - accuracy: 0.5303
# Epoch 31: val_accuracy did not improve from 0.55287
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0910 - accuracy: 0.5303 - val_loss: 1.1545 - val_accuracy: 0.5473 - lr: 1.0000e-04
# Epoch 32/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.0590 - accuracy: 0.5352
# Epoch 32: val_accuracy improved from 0.55287 to 0.55511, saving model to best_model.h5
# 448/448 [==============================] - 32s 71ms/step - loss: 2.0584 - accuracy: 0.5353 - val_loss: 1.1449 - val_accuracy: 0.5551 - lr: 1.0000e-04
# Epoch 33/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0735 - accuracy: 0.5335
# Epoch 33: val_accuracy improved from 0.55511 to 0.55580, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0735 - accuracy: 0.5335 - val_loss: 1.1276 - val_accuracy: 0.5558 - lr: 1.0000e-04
# Epoch 34/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0395 - accuracy: 0.5427
# Epoch 34: val_accuracy did not improve from 0.55580
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0395 - accuracy: 0.5427 - val_loss: 1.1590 - val_accuracy: 0.5506 - lr: 1.0000e-04
# Epoch 35/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0257 - accuracy: 0.5426
# Epoch 35: val_accuracy did not improve from 0.55580
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0257 - accuracy: 0.5426 - val_loss: 1.1644 - val_accuracy: 0.5484 - lr: 1.0000e-04
# Epoch 36/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0397 - accuracy: 0.5373
# Epoch 36: val_accuracy improved from 0.55580 to 0.56055, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0397 - accuracy: 0.5373 - val_loss: 1.1459 - val_accuracy: 0.5605 - lr: 1.0000e-04
# Epoch 37/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0038 - accuracy: 0.5467
# Epoch 37: val_accuracy did not improve from 0.56055
# 448/448 [==============================] - 31s 70ms/step - loss: 2.0038 - accuracy: 0.5467 - val_loss: 1.1282 - val_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 38/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.9842 - accuracy: 0.5540
# Epoch 38: val_accuracy did not improve from 0.56055
# 448/448 [==============================] - 31s 70ms/step - loss: 1.9845 - accuracy: 0.5540 - val_loss: 1.1789 - val_accuracy: 0.5603 - lr: 1.0000e-04
# Epoch 39/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9835 - accuracy: 0.5547
# Epoch 39: val_accuracy improved from 0.56055 to 0.57617, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 1.9835 - accuracy: 0.5547 - val_loss: 1.1044 - val_accuracy: 0.5762 - lr: 1.0000e-04
# Epoch 40/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9657 - accuracy: 0.5544
# Epoch 40: val_accuracy did not improve from 0.57617
# 448/448 [==============================] - 32s 70ms/step - loss: 1.9657 - accuracy: 0.5544 - val_loss: 1.1787 - val_accuracy: 0.5564 - lr: 1.0000e-04
# Epoch 41/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9404 - accuracy: 0.5597
# Epoch 41: val_accuracy did not improve from 0.57617
# 448/448 [==============================] - 31s 68ms/step - loss: 1.9404 - accuracy: 0.5597 - val_loss: 1.1093 - val_accuracy: 0.5707 - lr: 1.0000e-04
# Epoch 42/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9258 - accuracy: 0.5597
# Epoch 42: val_accuracy did not improve from 0.57617
# 448/448 [==============================] - 31s 69ms/step - loss: 1.9258 - accuracy: 0.5597 - val_loss: 1.1480 - val_accuracy: 0.5707 - lr: 1.0000e-04
# Epoch 43/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9515 - accuracy: 0.5587
# Epoch 43: val_accuracy improved from 0.57617 to 0.57882, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 1.9515 - accuracy: 0.5587 - val_loss: 1.1019 - val_accuracy: 0.5788 - lr: 1.0000e-04
# Epoch 44/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8858 - accuracy: 0.5695
# Epoch 44: val_accuracy did not improve from 0.57882
# 448/448 [==============================] - 31s 69ms/step - loss: 1.8858 - accuracy: 0.5695 - val_loss: 1.1253 - val_accuracy: 0.5724 - lr: 1.0000e-04
# Epoch 45/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9260 - accuracy: 0.5666
# Epoch 45: val_accuracy did not improve from 0.57882
# 448/448 [==============================] - 31s 70ms/step - loss: 1.9260 - accuracy: 0.5666 - val_loss: 1.1276 - val_accuracy: 0.5714 - lr: 1.0000e-04
# Epoch 46/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8822 - accuracy: 0.5766
# Epoch 46: val_accuracy improved from 0.57882 to 0.58008, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 1.8822 - accuracy: 0.5766 - val_loss: 1.0988 - val_accuracy: 0.5801 - lr: 1.0000e-04
# Epoch 47/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8774 - accuracy: 0.5726
# Epoch 47: val_accuracy did not improve from 0.58008
# 448/448 [==============================] - 32s 71ms/step - loss: 1.8774 - accuracy: 0.5726 - val_loss: 1.1302 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 57: val_accuracy improved from 0.60170 to 0.61147, saving model to best_model.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7757 - accuracy: 0.5912 - val_loss: 1.0111 - val_accuracy: 0.6115 - lr: 1.0000e-04
# Epoch 58/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.7782 - accuracy: 0.5912
# Epoch 58: val_accuracy did not improve from 0.61147
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7781 - accuracy: 0.5909 - val_loss: 1.0249 - val_accuracy: 0.6092 - lr: 1.0000e-04
# Epoch 59/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7613 - accuracy: 0.5979
# Epoch 59: val_accuracy did not improve from 0.61147
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7613 - accuracy: 0.5979 - val_loss: 1.0882 - val_accuracy: 0.5879 - lr: 1.0000e-04
# Epoch 60/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7399 - accuracy: 0.6000
# Epoch 60: val_accuracy did not improve from 0.61147
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7399 - accuracy: 0.6000 - val_loss: 1.0551 - val_accuracy: 0.5975 - lr: 1.0000e-04
# Epoch 61/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7465 - accuracy: 0.6002
# Epoch 61: val_accuracy did not improve from 0.61147
# 448/448 [==============================] - 31s 68ms/step - loss: 1.7465 - accuracy: 0.6002 - val_loss: 1.0336 - val_accuracy: 0.6083 - lr: 1.0000e-04
# Epoch 62/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7480 - accuracy: 0.5992
# Epoch 62: val_accuracy did not improve from 0.61147
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7480 - accuracy: 0.5992 - val_loss: 1.0595 - val_accuracy: 0.5986 - lr: 1.0000e-04
# Epoch 63/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7039 - accuracy: 0.6086
# Epoch 63: val_accuracy improved from 0.61147 to 0.61942, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 1.7039 - accuracy: 0.6086 - val_loss: 1.0207 - val_accuracy: 0.6194 - lr: 1.0000e-04
# Epoch 64/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7199 - accuracy: 0.6027
# Epoch 64: val_accuracy did not improve from 0.61942
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7199 - accuracy: 0.6027 - val_loss: 1.0749 - val_accuracy: 0.5996 - lr: 1.0000e-04
# Epoch 65/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7356 - accuracy: 0.6024
# Epoch 65: val_accuracy improved from 0.61942 to 0.62123, saving model to best_model.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 1.7356 - accuracy: 0.6024 - val_loss: 1.0139 - val_accuracy: 0.6212 - lr: 1.0000e-04
# Epoch 66/400
# 448/448 [==============================] - ETA: 0s - loss: 1.7100 - accuracy: 0.6092
# Epoch 66: val_accuracy did not improve from 0.62123
# 448/448 [==============================] - 30s 68ms/step - loss: 1.7100 - accuracy: 0.6092 - val_loss: 1.0604 - val_accuracy: 0.6053 - lr: 1.0000e-04
# Epoch 67/400
# 448/448 [==============================] - ETA: 0s - loss: 1.6734 - accuracy: 0.6142
# Epoch 67: val_accuracy did not improve from 0.62123
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 114/400
# 448/448 [==============================] - ETA: 0s - loss: 1.3160 - accuracy: 0.6877
# Epoch 114: val_accuracy did not improve from 0.64718
# 448/448 [==============================] - 30s 67ms/step - loss: 1.3160 - accuracy: 0.6877 - val_loss: 1.0173 - val_accuracy: 0.6422 - lr: 1.2500e-05
# Epoch 115/400
# 448/448 [==============================] - ETA: 0s - loss: 1.3047 - accuracy: 0.6911
# Epoch 115: val_accuracy improved from 0.64718 to 0.64788, saving model to best_model.h5
# 448/448 [==============================] - 30s 66ms/step - loss: 1.3047 - accuracy: 0.6911 - val_loss: 1.0086 - val_accuracy: 0.6479 - lr: 1.2500e-05
# Epoch 116/400
# 448/448 [==============================] - ETA: 0s - loss: 1.2995 - accuracy: 0.6910
# Epoch 116: val_accuracy did not improve from 0.64788
# 448/448 [==============================] - 30s 68ms/step - loss: 1.2995 - accuracy: 0.6910 - val_loss: 1.0208 - val_accuracy: 0.6444 - lr: 1.2500e-05
# Epoch 117/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.3056 - accuracy: 0.6905
# Epoch 117: val_accuracy did not improve from 0.64788
# 448/448 [==============================] - 29s 65ms/step - loss: 1.3053 - accuracy: 0.6906 - val_loss: 1.0285 - val_accuracy: 0.6433 - lr: 1.2500e-05
# Epoch 118/400
# 448/448 [==============================] - ETA: 0s - loss: 1.2838 - accuracy: 0.6925
# Epoch 118: val_accuracy did not improve from 0.64788
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2838 - accuracy: 0.6925 - val_loss: 1.0106 - val_accuracy: 0.6466 - lr: 1.2500e-05
# Epoch 119/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.2871 - accuracy: 0.6959
# Epoch 119: val_accuracy did not improve from 0.64788
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2868 - accuracy: 0.6960 - val_loss: 1.0167 - val_accuracy: 0.6449 - lr: 1.2500e-05
# Epoch 119: early stopping

# %%
save_model = model.save('GoogLeNet1.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model('best_model.h5')
model.summary()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 3s 21ms/step
# Accuracy =  0.6875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 65ms/step
# Accuracy =  0.859375
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.53125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6890

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# Accuracy: 68.90404929577466
# Angry 255/4606 acc: 63.1
# Disgust 261/4606 acc: 49.4
# Fear 104/4606 acc: 48.1
# Happy 1766/4606 acc: 75.4
# Neutral 952/4606 acc: 60.4
# Sad 728/4606 acc: 68.7
# Surprise 478/4606 acc: 80.3

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 68.90404929577466
# Angry 255/4606 acc: 63.1
# Disgust 261/4606 acc: 49.4
# Fear 104/4606 acc: 48.1
# Happy 1766/4606 acc: 75.4
# Neutral 952/4606 acc: 60.4
# Sad 728/4606 acc: 68.7
# Surprise 478/4606 acc: 80.3

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.57      0.63      0.60       255
#      Disgust       0.33      0.49      0.40       261
#         Fear       0.28      0.48      0.35       104
#        Happy       0.96      0.75      0.84      1766
#      Neutral       0.69      0.60      0.64       952
#          Sad       0.57      0.69      0.62       728
#     Surprise       0.66      0.80      0.73       478
#
#     accuracy                           0.69      4544
#    macro avg       0.58      0.64      0.60      4544
# weighted avg       0.73      0.69      0.70      4544

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 168/168 [==============================] - 10s 58ms/step - loss: 0.6079 - accuracy: 0.7740
# 72/72 [==============================] - 2s 30ms/step - loss: 0.9202 - accuracy: 0.6895

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# Top 1 Accuracy: 68.93%
# 2/2 [==============================] - 0s 38ms/step
# Top 2 Accuracy: 45.31%
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8183 - accuracy: 0.7188
# Loss: 0.8182899355888367
# Precision: 0.58
# Recall: 0.64
# F1-Score: 0.60

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.609375
# 2/2 [==============================] - 0s 64ms/step
# Accuracy =  0.359375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4741

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 47.412109375
# Angry 292/2100 acc: 64.0
# Disgust 293/2100 acc: 38.9
# Fear 287/2100 acc: 27.2
# Happy 292/2100 acc: 36.0
# Neutral 296/2100 acc: 41.6
# Sad 294/2100 acc: 51.4
# Surprise 294/2100 acc: 72.4

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 47.412109375
# Angry 292/2100 acc: 64.0
# Disgust 293/2100 acc: 38.9
# Fear 287/2100 acc: 27.2
# Happy 292/2100 acc: 36.0
# Neutral 296/2100 acc: 41.6
# Sad 294/2100 acc: 51.4
# Surprise 294/2100 acc: 72.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.51      0.64      0.57       292
#      Disgust       0.49      0.39      0.43       293
#         Fear       0.40      0.27      0.32       287
#        Happy       0.78      0.36      0.49       292
#      Neutral       0.54      0.42      0.47       296
#          Sad       0.35      0.51      0.42       294
#     Surprise       0.46      0.72      0.57       294
#
#     accuracy                           0.47      2048
#    macro avg       0.50      0.47      0.47      2048
# weighted avg       0.50      0.47      0.47      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: sad, probability: 0.9950889945030212
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: surprise, probability: 0.9995642304420471
# 1/1 [==============================] - 0s 111ms/step
# Predicted emotion class: surprise, probability: 0.8853887915611267
# 1/1 [==============================] - 0s 105ms/step
# Predicted emotion class: sad, probability: 0.7385484576225281
# 1/1 [==============================] - 0s 101ms/step
# Predicted emotion class: happy, probability: 0.9999992847442627
# 1/1 [==============================] - 0s 113ms/step
# Predicted emotion class: angry, probability: 0.9996473789215088
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: angry, probability: 0.9465680122375488
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: neutral, probability: 0.7610039114952087
# 1/1 [==============================] - 0s 112ms/step
# Predicted emotion class: sad, probability: 0.8114776611328125

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 12, 12, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 12, 12, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 12, 12, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 320)   0           ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 192)    61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 6, 6, 208)    66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 320)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 6, 6, 96)     165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 6, 6, 16)     83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 6, 6, 48)     15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 6, 6, 64)     20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6, 6, 224)    0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 6, 6, 160)    36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 6, 6, 224)    50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 224)   0           ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 6, 6, 112)    161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 6, 24)     134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 6, 6, 64)     14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 64)     14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 6, 6, 264)    0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 264)   0           ['concatenate_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 3, 3, 128)    33920       ['max_pooling2d_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 256)    67840       ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 264)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 3, 3, 128)    147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 3, 3, 24)     153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 3, 3, 64)     16960       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3, 3, 280)    0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 3, 3, 112)    31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 3, 3, 288)    80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 280)   0           ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 3, 3, 144)    145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 3, 3, 32)     230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 3, 3, 64)     17984       ['max_pooling2d_9[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 3, 3, 64)     17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 3, 3, 304)    0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 3, 3, 256)    78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 3, 3, 320)    97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 3, 3, 304)   0           ['concatenate_5[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 160)    368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 3, 3, 32)     256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 128)    39040       ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 128)    39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 3, 3, 448)    0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 2, 2, 256)    114944      ['max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 320)    143680      ['max_pooling2d_11[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 448)   0           ['max_pooling2d_11[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 2, 2, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 2, 2, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 2, 2, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    57472       ['max_pooling2d_13[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 496)         0           ['concatenate_8[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 496)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,909,319
# Trainable params: 5,909,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 1.2928 - accuracy: 0.6914
# Epoch 1: val_accuracy improved from -inf to 0.64216, saving model to best_model.h5
# 448/448 [==============================] - 43s 77ms/step - loss: 1.2928 - accuracy: 0.6914 - val_loss: 1.0380 - val_accuracy: 0.6422 - lr: 1.0000e-05
# Epoch 2/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2928 - accuracy: 0.6952
# Epoch 2: val_accuracy improved from 0.64216 to 0.64453, saving model to best_model.h5
# 448/448 [==============================] - 32s 71ms/step - loss: 1.2928 - accuracy: 0.6952 - val_loss: 1.0202 - val_accuracy: 0.6445 - lr: 1.0000e-05
# Epoch 3/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2717 - accuracy: 0.6962
# Epoch 3: val_accuracy improved from 0.64453 to 0.64634, saving model to best_model.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2717 - accuracy: 0.6962 - val_loss: 1.0145 - val_accuracy: 0.6463 - lr: 1.0000e-05
# Epoch 4/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2789 - accuracy: 0.6951
# Epoch 4: val_accuracy did not improve from 0.64634
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2789 - accuracy: 0.6951 - val_loss: 1.0329 - val_accuracy: 0.6433 - lr: 1.0000e-05
# Epoch 5/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2841 - accuracy: 0.6938
# Epoch 5: val_accuracy did not improve from 0.64634
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2841 - accuracy: 0.6938 - val_loss: 1.0371 - val_accuracy: 0.6402 - lr: 1.0000e-05
# Epoch 6/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2843 - accuracy: 0.6968
# Epoch 6: val_accuracy did not improve from 0.64634
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2843 - accuracy: 0.6968 - val_loss: 1.0282 - val_accuracy: 0.6447 - lr: 1.0000e-05
# Epoch 7/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2738 - accuracy: 0.6969
# Epoch 7: val_accuracy did not improve from 0.64634
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2738 - accuracy: 0.6969 - val_loss: 1.0242 - val_accuracy: 0.6462 - lr: 1.0000e-05
# Epoch 8/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2873 - accuracy: 0.6888
# Epoch 8: val_accuracy improved from 0.64634 to 0.64704, saving model to best_model.h5
# 448/448 [==============================] - 30s 68ms/step - loss: 1.2873 - accuracy: 0.6888 - val_loss: 1.0175 - val_accuracy: 0.6470 - lr: 1.0000e-05
# Epoch 9/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2776 - accuracy: 0.6916
# Epoch 9: val_accuracy did not improve from 0.64704
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2776 - accuracy: 0.6917 - val_loss: 1.0221 - val_accuracy: 0.6452 - lr: 1.0000e-05
# Epoch 10/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2867 - accuracy: 0.6916
# Epoch 10: val_accuracy did not improve from 0.64704
# 448/448 [==============================] - 37s 83ms/step - loss: 1.2867 - accuracy: 0.6916 - val_loss: 1.0115 - val_accuracy: 0.6447 - lr: 1.0000e-05
# Epoch 11/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2717 - accuracy: 0.6967
# Epoch 11: val_accuracy did not improve from 0.64704
# 448/448 [==============================] - 31s 70ms/step - loss: 1.2717 - accuracy: 0.6967 - val_loss: 1.0308 - val_accuracy: 0.6455 - lr: 1.0000e-05
# Epoch 12/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2684 - accuracy: 0.6975
# Epoch 12: val_accuracy improved from 0.64704 to 0.64858, saving model to best_model.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 1.2684 - accuracy: 0.6975 - val_loss: 1.0141 - val_accuracy: 0.6486 - lr: 1.0000e-05
# Epoch 13/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2721 - accuracy: 0.6974
# Epoch 13: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2721 - accuracy: 0.6974 - val_loss: 1.0184 - val_accuracy: 0.6469 - lr: 1.0000e-05
# Epoch 14/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2651 - accuracy: 0.6969
# Epoch 14: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2651 - accuracy: 0.6969 - val_loss: 1.0463 - val_accuracy: 0.6443 - lr: 1.0000e-05
# Epoch 15/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2689 - accuracy: 0.6982
# Epoch 15: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 31s 69ms/step - loss: 1.2691 - accuracy: 0.6981 - val_loss: 1.0349 - val_accuracy: 0.6426 - lr: 1.0000e-05
# Epoch 16/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2629 - accuracy: 0.6990
# Epoch 16: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 68ms/step - loss: 1.2629 - accuracy: 0.6990 - val_loss: 1.0209 - val_accuracy: 0.6475 - lr: 1.0000e-05
# Epoch 17/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2597 - accuracy: 0.6981
# Epoch 17: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2597 - accuracy: 0.6981 - val_loss: 1.0404 - val_accuracy: 0.6422 - lr: 1.0000e-05
# Epoch 18/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2520 - accuracy: 0.7006
# Epoch 18: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2520 - accuracy: 0.7006 - val_loss: 1.0263 - val_accuracy: 0.6470 - lr: 1.0000e-05
# Epoch 19/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2461 - accuracy: 0.7019
# Epoch 19: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 29s 66ms/step - loss: 1.2461 - accuracy: 0.7019 - val_loss: 1.0293 - val_accuracy: 0.6461 - lr: 1.0000e-05
# Epoch 20/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2726 - accuracy: 0.7008
# Epoch 20: val_accuracy did not improve from 0.64858
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 448/448 [==============================] - 29s 65ms/step - loss: 1.2726 - accuracy: 0.7008 - val_loss: 1.0235 - val_accuracy: 0.6445 - lr: 1.0000e-05
# Epoch 21/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2596 - accuracy: 0.7011
# Epoch 21: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2596 - accuracy: 0.7011 - val_loss: 1.0177 - val_accuracy: 0.6465 - lr: 5.0000e-06
# Epoch 22/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2479 - accuracy: 0.7005
# Epoch 22: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2480 - accuracy: 0.7007 - val_loss: 1.0282 - val_accuracy: 0.6443 - lr: 5.0000e-06
# Epoch 23/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2507 - accuracy: 0.7011
# Epoch 23: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2507 - accuracy: 0.7011 - val_loss: 1.0243 - val_accuracy: 0.6444 - lr: 5.0000e-06
# Epoch 24/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2385 - accuracy: 0.7036
# Epoch 24: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 29s 65ms/step - loss: 1.2385 - accuracy: 0.7036 - val_loss: 1.0298 - val_accuracy: 0.6440 - lr: 5.0000e-06
# Epoch 25/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2329 - accuracy: 0.7018
# Epoch 25: val_accuracy did not improve from 0.64858
# 448/448 [==============================] - 29s 66ms/step - loss: 1.2330 - accuracy: 0.7017 - val_loss: 1.0291 - val_accuracy: 0.6436 - lr: 5.0000e-06
# Epoch 26/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2428 - accuracy: 0.7035
# Epoch 26: val_accuracy improved from 0.64858 to 0.65011, saving model to best_model.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2431 - accuracy: 0.7035 - val_loss: 1.0170 - val_accuracy: 0.6501 - lr: 5.0000e-06
# Epoch 27/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2442 - accuracy: 0.7032
# Epoch 27: val_accuracy did not improve from 0.65011
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2442 - accuracy: 0.7032 - val_loss: 1.0335 - val_accuracy: 0.6434 - lr: 5.0000e-06
# Epoch 28/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.2466 - accuracy: 0.7035
# Epoch 28: val_accuracy did not improve from 0.65011
# 448/448 [==============================] - 30s 66ms/step - loss: 1.2465 - accuracy: 0.7035 - val_loss: 1.0180 - val_accuracy: 0.6489 - lr: 5.0000e-06
# Epoch 29/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2412 - accuracy: 0.7036
# Epoch 29: val_accuracy did not improve from 0.65011
# 448/448 [==============================] - 29s 65ms/step - loss: 1.2412 - accuracy: 0.7036 - val_loss: 1.0232 - val_accuracy: 0.6490 - lr: 5.0000e-06
# Epoch 30/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2426 - accuracy: 0.7045
# Epoch 30: val_accuracy did not improve from 0.65011
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 448/448 [==============================] - 29s 65ms/step - loss: 1.2426 - accuracy: 0.7045 - val_loss: 1.0288 - val_accuracy: 0.6447 - lr: 5.0000e-06
# Epoch 30: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %%
model = load_model('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 0s 102ms/step
# Accuracy =  0.6875

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 21ms/step
# Accuracy =  0.796875
# 2/2 [==============================] - 0s 19ms/step
# Accuracy =  0.453125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6500

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 17ms/step
# Accuracy: 64.99720982142857
# Angry 956/7178 acc: 60.5
# Disgust 111/7178 acc: 66.7
# Fear 1023/7178 acc: 40.1
# Happy 1772/7178 acc: 81.3
# Neutral 1232/7178 acc: 69.5
# Sad 1245/7178 acc: 49.2
# Surprise 829/7178 acc: 82.9

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 64.99720982142857
# Angry 956/7178 acc: 60.5
# Disgust 111/7178 acc: 66.7
# Fear 1023/7178 acc: 40.1
# Happy 1772/7178 acc: 81.3
# Neutral 1232/7178 acc: 69.5
# Sad 1245/7178 acc: 49.2
# Surprise 829/7178 acc: 82.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.55      0.60      0.57       956
#      Disgust       0.71      0.67      0.69       111
#         Fear       0.53      0.40      0.46      1023
#        Happy       0.90      0.81      0.85      1772
#      Neutral       0.56      0.69      0.62      1232
#          Sad       0.54      0.49      0.51      1245
#     Surprise       0.72      0.83      0.77       829
#
#     accuracy                           0.65      7168
#    macro avg       0.64      0.64      0.64      7168
# weighted avg       0.65      0.65      0.65      7168

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 13ms/step
# Accuracy =  0.703125
# 2/2 [==============================] - 0s 10ms/step
# Accuracy =  0.421875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5396

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# Accuracy: 53.955078125
# Angry 294/2100 acc: 73.5
# Disgust 294/2100 acc: 5.8
# Fear 291/2100 acc: 24.4
# Happy 293/2100 acc: 86.0
# Neutral 293/2100 acc: 66.9
# Sad 292/2100 acc: 49.0
# Surprise 291/2100 acc: 72.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 53.955078125
# Angry 294/2100 acc: 73.5
# Disgust 294/2100 acc: 5.8
# Fear 291/2100 acc: 24.4
# Happy 293/2100 acc: 86.0
# Neutral 293/2100 acc: 66.9
# Sad 292/2100 acc: 49.0
# Surprise 291/2100 acc: 72.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.44      0.73      0.55       294
#      Disgust       1.00      0.06      0.11       294
#         Fear       0.56      0.24      0.34       291
#        Happy       0.74      0.86      0.79       293
#      Neutral       0.48      0.67      0.56       293
#          Sad       0.47      0.49      0.48       292
#     Surprise       0.58      0.72      0.65       291
#
#     accuracy                           0.54      2048
#    macro avg       0.61      0.54      0.50      2048
# weighted avg       0.61      0.54      0.50      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 935ms/step
# Predicted emotion class: sad, probability: 0.6381509900093079
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: surprise, probability: 0.9913589954376221
# 1/1 [==============================] - 0s 37ms/step
# Predicted emotion class: surprise, probability: 0.7494197487831116
# 1/1 [==============================] - 0s 34ms/step
# Predicted emotion class: angry, probability: 0.3593408763408661
# 1/1 [==============================] - 0s 38ms/step
# Predicted emotion class: happy, probability: 0.9994934797286987
# 1/1 [==============================] - 0s 42ms/step
# Predicted emotion class: angry, probability: 0.8243364691734314
# 1/1 [==============================] - 0s 51ms/step
# Predicted emotion class: angry, probability: 0.9098782539367676
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.5012086033821106
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.8153152465820312
