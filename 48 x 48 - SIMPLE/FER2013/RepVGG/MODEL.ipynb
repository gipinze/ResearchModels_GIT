# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
## RAFDB
# train_data_dir = r'W:/RAFDB/RAFDB/train/'
# validation_data_dir = r'W:/RAFDB/RAFDB/val/'

train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT =48
IMG_WIDTH = 48
CHANNELS = 3

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 1.8060075093867334, 1: 16.54816513761468, 2: 1.7610446668293875, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
class RepVGGBlock(layers.Layer):
      def __init__(self, out_channels, strides, kernel_size, name=None, **kwargs):
         super().__init__(name=name, **kwargs)
         self.out_channels = out_channels
         self.strides = strides
         self.kernel_size = kernel_size
         self.conv1 = Conv2D(out_channels, kernel_size, strides=strides, padding='same', use_bias=False)
         self.bn1 = BatchNormalization()
         self.relu = ReLU()
         self.conv2 = Conv2D(out_channels, kernel_size, padding='same', use_bias=False)
         self.bn2 = BatchNormalization()
         if strides == 1:
               self.identity_map = Activation('linear')
         else:
               self.identity_map = Conv2D(out_channels, kernel_size=1, strides=strides, padding='same', use_bias=False)
         
      def call(self, inputs):
         x = self.conv1(inputs)
         x = self.bn1(x)
         x = self.relu(x)
         x = self.conv2(x)
         x = self.bn2(x)
         identity_map = self.identity_map(inputs)
         return x + identity_map
      
      def get_config(self):
         config = super().get_config()
         config.update({
               'out_channels': self.out_channels,
               'strides': self.strides,
               'kernel_size': self.kernel_size,
         })
         return config

class GradientCheckpointing(layers.Layer):
      def __init__(self, checkpointing_depth, **kwargs):
         super().__init__(**kwargs)
         self.checkpointing_depth = checkpointing_depth

      def get_config(self):
         config = super().get_config()
         config.update({
               "checkpointing_depth": self.checkpointing_depth,
         })
         return config

      def call(self, inputs):
         if self.checkpointing_depth == 0:
               return inputs
         else:
               num_chunks = self.checkpointing_depth + 1
               chunk_size = inputs.shape[-1] // num_chunks
               remainder = inputs.shape[-1] % num_chunks
               if remainder != 0:
                  chunk_size += 1
               chunks = []
               for i in range(num_chunks):
                  start = i * chunk_size
                  end = start + chunk_size
                  if i == num_chunks - 1:
                     end = inputs.shape[-1]
                  chunk = inputs[..., start:end]
                  if i == 0:
                     chunk = tf.identity(chunk)
                  else:
                     chunk = tf.stop_gradient(chunk)
                  chunks.append(chunk)
         return tf.concat(chunks, axis=-1)

def create_repvgg_a0(checkpointing_depth=1):
      inputs = Input(shape=IMAGE_SHAPE)
      x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(inputs)
      x = BatchNormalization()(x)
      x = ReLU()(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=64, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)

      x = GlobalAveragePooling2D()(x)
      outputs = Dense(num_classes, activation='softmax')(x)  # number of classes in VGGFace2 dataset

      model = Model(inputs=inputs, outputs=outputs)

      return model

# %%
with strategy.scope():

    
   model = create_repvgg_a0()


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# 448/448 [==============================] - ETA: 0s - loss: 2.4729 - accuracy: 0.4582
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.38.h5
# 448/448 [==============================] - 51s 100ms/step - loss: 2.4729 - accuracy: 0.4582 - val_loss: 1.7338 - val_accuracy: 0.3760 - lr: 1.0000e-04
# Epoch 2/300
# 447/448 [============================>.] - ETA: 0s - loss: 2
300
# 448/448 [==============================] - ETA: 0s - loss: 1.5908 - accuracy: 0.6357
# Epoch 62: saving model to checkpoints_freeze\toy-model_1-epoch-62-val_accuracy-0.59.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5908 - accuracy: 0.6357 - val_loss: 1.1255 - val_accuracy: 0.5907 - lr: 5.0000e-05
# Epoch 63/300
# 447/448 [============================>.] - ETA: 0s - loss: 1.5790 - accuracy: 0.6394
# Epoch 63: saving model to checkpoints_freeze\toy-model_1-epoch-63-val_accuracy-0.58.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5796 - accuracy: 0.6394 - val_loss: 1.1458 - val_accuracy: 0.5845 - lr: 5.0000e-05
# Epoch 64/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5592 - accuracy: 0.6412
# Epoch 64: saving model to checkpoints_freeze\toy-model_1-epoch-64-val_accuracy-0.60.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5592 - accuracy: 0.6412 - val_loss: 1.0954 - val_accuracy: 0.6010 - lr: 5.0000e-05
# Epoch 65/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5748 - accuracy: 0.6388
# Epoch 65: saving model to checkpoints_freeze\toy-model_1-epoch-65-val_accuracy-0.60.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5748 - accuracy: 0.6388 - val_loss: 1.0998 - val_accuracy: 0.6010 - lr: 5.0000e-05
# Epoch 66/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5506 - accuracy: 0.6423
# Epoch 66: saving model to checkpoints_freeze\toy-model_1-epoch-66-val_accuracy-0.62.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5506 - accuracy: 0.6423 - val_loss: 1.0752 - val_accuracy: 0.6165 - lr: 5.0000e-05
# Epoch 67/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5584 - accuracy: 0.6428
# Epoch 67: saving model to checkpoints_freeze\toy-model_1-epoch-67-val_accuracy-0.61.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5584 - accuracy: 0.6428 - val_loss: 1.0643 - val_accuracy: 0.6140 - lr: 5.0000e-05
# Epoch 68/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5414 - accuracy: 0.6458
# Epoch 68: saving model to checkpoints_freeze\toy-model_1-epoch-68-val_accuracy-0.59.h5
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5414 - accuracy: 0.6458 - val_loss: 1.1312 - val_accuracy: 0.5917 - lr: 5.0000e-05
# Epoch 69/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5068 - accuracy: 0.6538
# Epoch 69: saving model to checkpoints_freeze\toy-model_1-epoch-69-val_accuracy-0.62.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5068 - accuracy: 0.6538 - val_loss: 1.0643 - val_accuracy: 0.6154 - lr: 2.5000e-05
# Epoch 70/300
# 447/448 [============================>.] - ETA: 0s - loss: 1.4940 - accuracy: 0.6578
# Epoch 70: saving model to checkpoints_freeze\toy-model_1-epoch-70-val_accuracy-0.61.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4939 - accuracy: 0.6580 - val_loss: 1.1048 - val_accuracy: 0.6098 - lr: 2.5000e-05
# Epoch 71/300
# 447/448 [============================>.] - ETA: 0s - loss: 1.4830 - accuracy: 0.6603
# Epoch 71: saving model to checkpoints_freeze\toy-model_1-epoch-71-val_accuracy-0.63.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4831 - accuracy: 0.6601 - val_loss: 1.0310 - val_accuracy: 0.6300 - lr: 2.5000e-05
# Epoch 72/300
# 447/448 [============================>.] - ETA: 0s - loss: 1.4518 - accuracy: 0.6620
# Epoch 72: saving model to checkpoints_freeze\toy-model_1-epoch-72-val_accuracy-0.62.h5
# 448/448 [==============================] - 26s 57ms/step - loss: 1.4530 - accuracy: 0.6620 - val_loss: 1.0526 - val_accuracy: 0.6179 - lr: 2.5000e-05
# Epoch 73/300
# 447/448 [============================>.] - ETA: 0s - loss: 1.4509 - accuracy: 0.6652
# Epoch 73: saving model to checkpoints_freeze\toy-model_1-epoch-73-val_accuracy-0.63.h5
# 448/448 [==============================] - 26s 59ms/step - loss: 1.4517 - accuracy: 0.6650 - val_loss: 1.0263 - val_accuracy: 0.6304 - lr: 2.5000e-05
# Epoch 74/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4422 - accuracy: 0.6695
# Epoch 74: saving model to checkpoints_freeze\toy-model_1-epoch-74-val_accuracy-0.63.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4422 - accuracy: 0.6695 - val_loss: 1.0235 - val_accuracy: 0.6316 - lr: 2.5000e-05
# Epoch 75/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4617 - accuracy: 0.6636
# Epoch 75: saving model to checkpoints_freeze\toy-model_1-epoch-75-val_accuracy-0.62.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4617 - accuracy: 0.6636 - val_loss: 1.0448 - val_accuracy: 0.6250 - lr: 2.5000e-05
# Epoch 76/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4327 - accuracy: 0.6669
# Epoch 76: saving model to checkpoints_freeze\toy-model_1-epoch-76-val_accuracy-0.62.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4327 - accuracy: 0.6669 - val_loss: 1.0617 - val_accuracy: 0.6223 - lr: 2.5000e-05
# Epoch 77/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4474 - accuracy: 0.6660
# Epoch 77: saving model to checkpoints_freeze\toy-model_1-epoch-77-val_accuracy-0.63.h5
# 448/448 [==============================] - 26s 58ms/step - loss: 1.4474 - accuracy: 0.6660 - val_loss: 1.0428 - val_accuracy: 0.6267 - lr: 2.5000e-05
# Epoch 78/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4351 - accuracy: 0.6700
# Epoch 78: saving model to checkpoints_freeze\toy-model_1-epoch-78-val_accuracy-0.63.h5
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 448/448 [==============================] - 27s 60ms/step - loss: 1.4351 - accuracy: 0.6700 - val_loss: 1.0428 - val_accuracy: 0.6339 - lr: 2.5000e-05
# Epoch 78: early stopping

# %%
save_model = model.save('REPVGG_106e2_FER.h5')

# %%
custom_objects = {
    'RepVGGBlock': RepVGGBlock,
    'GradientCheckpointing': GradientCheckpointing
}

model = load_model("REPVGG_100e_FER.h5", custom_objects=custom_objects)

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 1s 7ms/step
# Accuracy =  0.6875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 22ms/step
# Accuracy =  0.828125
# 2/2 [==============================] - 0s 25ms/step
# Accuracy =  0.5

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6456

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# Accuracy: 64.56473214285714
# Angry 955/7178 acc: 64.4
# Disgust 111/7178 acc: 68.5
# Fear 1022/7178 acc: 44.3
# Happy 1771/7178 acc: 82.0
# Neutral 1232/7178 acc: 65.6
# Sad 1246/7178 acc: 45.1
# Surprise 831/7178 acc: 79.5

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 64.56473214285714
# Angry 955/7178 acc: 64.4
# Disgust 111/7178 acc: 68.5
# Fear 1022/7178 acc: 44.3
# Happy 1771/7178 acc: 82.0
# Neutral 1232/7178 acc: 65.6
# Sad 1246/7178 acc: 45.1
# Surprise 831/7178 acc: 79.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.52      0.64      0.58       955
#      Disgust       0.58      0.68      0.63       111
#         Fear       0.51      0.44      0.47      1022
#        Happy       0.89      0.82      0.85      1771
#      Neutral       0.56      0.66      0.61      1232
#          Sad       0.56      0.45      0.50      1246
#     Surprise       0.72      0.80      0.76       831
#
#     accuracy                           0.65      7168
#    macro avg       0.62      0.64      0.63      7168
# weighted avg       0.65      0.65      0.64      7168

# %% [markdown]
# # Unseen batch

# %%
# custom_objects = {
#     'RepVGGBlock': RepVGGBlock,
#     'GradientCheckpointing': GradientCheckpointing
# }

# model = load_model('REPVGG_100e_FER.h5', custom_objects=custom_objects)

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 24ms/step
# Accuracy =  0.5
# 2/2 [==============================] - 0s 22ms/step
# Accuracy =  0.28125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3789

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 46ms/step
# Accuracy: 37.890625
# Angry 289/2100 acc: 59.2
# Disgust 296/2100 acc: 1.7
# Fear 296/2100 acc: 10.1
# Happy 290/2100 acc: 43.1
# Neutral 295/2100 acc: 82.0
# Sad 294/2100 acc: 38.4
# Surprise 288/2100 acc: 31.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 37.890625
# Angry 289/2100 acc: 59.2
# Disgust 296/2100 acc: 1.7
# Fear 296/2100 acc: 10.1
# Happy 290/2100 acc: 43.1
# Neutral 295/2100 acc: 82.0
# Sad 294/2100 acc: 38.4
# Surprise 288/2100 acc: 31.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.45      0.59      0.51       289
#      Disgust       1.00      0.02      0.03       296
#         Fear       0.70      0.10      0.18       296
#        Happy       0.68      0.43      0.53       290
#      Neutral       0.29      0.82      0.42       295
#          Sad       0.27      0.38      0.32       294
#     Surprise       0.52      0.31      0.39       288
#
#     accuracy                           0.38      2048
#    macro avg       0.56      0.38      0.34      2048
# weighted avg       0.56      0.38      0.34      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces1.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: neutral, probability: 0.5735132098197937
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: fear, probability: 0.8163601756095886
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: happy, probability: 0.9853755235671997
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: disgust, probability: 0.810349702835083
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: surprise, probability: 0.4194989800453186
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: sad, probability: 0.7563184499740601

# %% [markdown]
# # Fine Tunning

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Callbacks

# Checkpoints
filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 7, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 1.8060075093867334, 1: 16.54816513761468, 2: 1.7610446668293875, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
with strategy.scope():

    custom_objects = {
    'RepVGGBlock': RepVGGBlock,
    'GradientCheckpointing': GradientCheckpointing
}

    model = load_model('checkpoints_freeze/toy-model_1-epoch-78-val_accuracy-0.63.h5', custom_objects=custom_objects)
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    # for layer in base_model.layers:
    #     layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 1.4396 - accuracy: 0.6659
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.63.h5
# 448/448 [==============================] - 67s 106ms/step - loss: 1.4396 - accuracy: 0.6659 - val_loss: 1.0266 - val_accuracy: 0.6318 - lr: 1.0000e-05
# Epoch 2/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4192 - accuracy: 0.6714
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.64.h5
# 448/448 [==============================] - 49s 109ms/step - loss: 1.4192 - accuracy: 0.6714 - val_loss: 1.0137 - val_accuracy: 0.6356 - lr: 1.0000e-05
# Epoch 3/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4242 - accuracy: 0.6684
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.63.h5
# 448/448 [==============================] - 59s 131ms/step - loss: 1.4242 - accuracy: 0.6684 - val_loss: 1.0300 - val_accuracy: 0.6318 - lr: 1.0000e-05
# Epoch 4/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4105 - accuracy: 0.6720
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 111ms/step - loss: 1.4105 - accuracy: 0.6720 - val_loss: 1.0144 - val_accuracy: 0.6378 - lr: 1.0000e-05
# Epoch 5/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4062 - accuracy: 0.6753
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.64.h5
# 448/448 [==============================] - 53s 119ms/step - loss: 1.4062 - accuracy: 0.6753 - val_loss: 1.0115 - val_accuracy: 0.6366 - lr: 1.0000e-05
# Epoch 6/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3998 - accuracy: 0.6752
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.64.h5
# 448/448 [==============================] - 63s 141ms/step - loss: 1.3998 - accuracy: 0.6752 - val_loss: 1.0224 - val_accuracy: 0.6352 - lr: 1.0000e-05
# Epoch 7/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3967 - accuracy: 0.6757
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.63.h5
# 448/448 [==============================] - 59s 130ms/step - loss: 1.3967 - accuracy: 0.6757 - val_loss: 1.0347 - val_accuracy: 0.6343 - lr: 1.0000e-05
# Epoch 8/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4062 - accuracy: 0.6737
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4062 - accuracy: 0.6737 - val_loss: 1.0170 - val_accuracy: 0.6384 - lr: 1.0000e-05
# Epoch 9/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3985 - accuracy: 0.6748
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.64.h5
# 448/448 [==============================] - 50s 110ms/step - loss: 1.3985 - accuracy: 0.6748 - val_loss: 1.0266 - val_accuracy: 0.6363 - lr: 1.0000e-05
# Epoch 10/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.6775
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0