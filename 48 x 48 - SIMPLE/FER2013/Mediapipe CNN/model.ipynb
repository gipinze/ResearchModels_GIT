# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import collections
import random
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from keras import Model
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten, Activation, Rescaling
from keras.layers import BatchNormalization, GlobalAveragePooling2D
from keras.losses import categorical_crossentropy
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.initializers import HeNormal

# %%
classes = ["Angry", "Disgust", "Fear", "Happy", "Neutral", "Sad", "Surprise"]


checkpoints_path = 'best_model.h5'

# %%
def load_data(data_file):
    print('Loading data ...')
    with open(data_file, 'rb') as f:
        pickle_data = pickle.load(f)
        return pickle_data[0], pickle_data[1]

# %%
data_file = 'image_dataset.p'
images, labels = load_data(data_file)

n_samples = labels.shape[0]
print('Total samples:', n_samples)
print('images shape:', images.shape)
print('labels shape:', labels.shape)
# Out:
# Loading data ...
# Total samples: 35887
# images shape: (35887, 48, 48)
# labels shape: (35887,)

# %% [markdown]
# # Explore the data

# %%
emotions = {
    0: 'Angry',
    1: 'Disgust',
    2: 'Fear',
    3: 'Happy',
    4: 'Sad',
    5: 'Surprise',
    6: 'Neutral'
}

num_classes = len(emotions)

# %%
def plot_sample_distribution(labels):
    classes, cnts = np.unique(labels, return_counts=True)
    plt.figure(figsize=(12, 5))
    plt.barh(list(emotions.values()), cnts, height=0.6)
    for i, v in enumerate(cnts):
        plt.text(v, i, ' '+str(v), va='center')
    plt.xlabel('Counts')
    plt.title("Distribution of samples")

plot_sample_distribution(labels)

# %%
def show_images(images, labels, col=7):
    n = images.shape[0]
    row = int(np.ceil(n / col))
    fig = plt.figure(figsize=(2*col, 2*row))
    for i in range(n):
        fig.add_subplot(row, col, i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(emotions[labels[i]])
        plt.xticks([]), plt.yticks([])
    plt.show()

# %%
# Id is the emotion number, ex: 1 is Disgust

id = 2

def show_one_emotion(images, labels, id, start=0, num=25):
    image_x = images[labels==id]
    label_x = labels[labels==id]
    show_images(image_x[start:start+num], label_x[start:start+num])

show_one_emotion(images, labels, id=id)

# %%
def show_images(images, labels, col=5):
    n = col * 7
    fig = plt.figure(figsize=(2*col, 10))
    for i, class_name in enumerate(classes):
        class_images = images[labels == i][:5]
        for j in range(col):
            fig.add_subplot(7, col, i*col+j+1)
            if j < len(class_images):
                plt.imshow(class_images[j], cmap='gray')
                plt.title(class_name)
            plt.xticks([]), plt.yticks([])
    plt.show()

show_images(images, labels)

# %% [markdown]
# # Split dataset

# %%
image_train, image_test, label_train, label_test = train_test_split(images, labels, test_size=0.2, random_state=42)
image_train, image_val, label_train, label_val = train_test_split(image_train, label_train, test_size=0.2, random_state=42)

print('Training samples:', label_train.shape[0])
print('Validation samples:', label_val.shape[0])
print('Test samples:', label_test.shape[0])
# Out:
# Training samples: 22967
# Validation samples: 5742
# Test samples: 7178

# %% [markdown]
# # **Upsamling training data**

# %%
def upsampling(x, y, strategy):
    (n, w, h) = x.shape
    sm = SMOTE(sampling_strategy=strategy, random_state=42)
    x_flat = x.reshape((n,-1))
    x_up, y_up = sm.fit_resample(x_flat, y)
    n_up = x_up.shape[0]
    x_up = x_up.reshape((n_up,w,h))

    return x_up, y_up

# %%
collections.Counter(label_train)
# Out:
# Counter({0: 3163, 3: 5806, 2: 3288, 5: 3855, 4: 3926, 6: 2574, 1: 355})

# %%
image_train_up, label_train_up = upsampling(image_train, label_train, 'auto')

# %%
collections.Counter(label_train_up)
# Out:
# Counter({0: 5806, 3: 5806, 2: 5806, 5: 5806, 4: 5806, 6: 5806, 1: 5806})

# %%
def show_one_emotion(images, labels, id, start=0, num=5):
    fig, axes = plt.subplots(nrows=1, ncols=num, figsize=(15, 15))
    axes = axes.flatten()
    for i in range(start, start+num):
        img = images[labels == id][i]
        axes[i-start].imshow(img, cmap="gray")
        axes[i-start].set_xticks(())
        axes[i-start].set_yticks(())
    plt.show()

num_classes = len(np.unique(label_train_up))

for i in range(num_classes):
    if i == 3:
        continue
    show_one_emotion(image_train_up, label_train_up, id=i, start=0, num=5)

# %% [markdown]
# # Utils

# %%
def one_hot_encoding(labels, num_classes):
    return tf.keras.utils.to_categorical(labels, num_classes)

# %%
def reshape_images(images, channel=1, resize=None):
    x = tf.expand_dims(tf.convert_to_tensor(images), axis=3)
    if channel > 1:
        x = tf.repeat(x, channel, axis=3)
    if resize is not None:
        x = tf.image.resize(x, resize)
    return x

# %%
def pre_processing(images, labels, num_classes, channel=1, resize=None, one_hot=True):
    x = reshape_images(images, channel, resize)
    y = one_hot_encoding(labels, num_classes)
    return x, y

# %%
def plot_metrics(history):
    metrics = ['loss', 'accuracy']
    plt.figure(figsize=(15, 6))
    plt.rc('font', size=12)
    for n, metric in enumerate(metrics):
        name = metric.capitalize()
        plt.subplot(1,2,n+1)
        plt.plot(history.epoch, history.history[metric], label='Training', lw=3, color='navy')
        plt.plot(history.epoch, history.history['val_'+metric], lw=3, label='Validation', color='deeppink')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        plt.title('Model '+name)
        plt.legend()
    plt.show()

# %%
def evaluate_class(model, x_test, y_test):
    labels = np.argmax(y_test, axis=1)
    print('{:<15}Accuracy'.format('Emotion'))
    print('-'*23)
    for i in range(num_classes):
        x = x_test[labels==i]
        y = y_test[labels==i]
        loss, acc = model.evaluate(x,  y, verbose=0)
        print('{:<15}{:.1%}'.format(emotions[i], acc))
    print('-'*23)
    loss, acc = model.evaluate(x_test,  y_test, verbose=0)
    print('{:<15}{:.1%}'.format('Overall', acc))

# %% [markdown]
# # Model

# %%
x_train, y_train = pre_processing(image_train_up, label_train_up, num_classes)
x_val, y_val = pre_processing(image_val, label_val, num_classes)
x_test, y_test = pre_processing(image_test, label_test, num_classes)

train_datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True)

val_datagen = ImageDataGenerator()

batch_size = 128
train_generator = train_datagen.flow(x_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(x_val, y_val)

steps_per_epoch = train_generator.n // train_generator.batch_size
input_shape = x_train[0].shape

# %%
epochs = 200

cp = ModelCheckpoint(filepath = checkpoints_path, save_weights_only=False, monitor='val_accuracy',  mode='max', save_best_only=True,  verbose=1)

#Early Stopping
es = EarlyStopping(monitor='val_loss', verbose=1, patience=20)

#Learning rate reduction
lr = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
model = Sequential()

model.add(Rescaling(1./255, input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.5))

model.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
        
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))

model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer=Adam(learning_rate = 1e-3, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 48, 48, 1)         0
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 23, 23, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 23, 23, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 23, 23, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 256)       295168
#
#  batch_normalization_4 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 256)       590080
#
#  batch_normalization_5 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 256)         0
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 512)         1180160
#
#  batch_normalization_6 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 5, 5, 512)         2359808
#
#  batch_normalization_7 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 7,054,279
# Trainable params: 7,050,439
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        validation_data=val_generator,
        callbacks=[lr, es, cp])
# Out:
# Epoch 1/200
# 317/317 [==============================] - ETA: 0s - loss: 2.0126 - accuracy: 0.2003
# Epoch 1: val_accuracy improved from -inf to 0.24887, saving model to best_model.h5
# 317/317 [==============================] - 32s 77ms/step - loss: 2.0126 - accuracy: 0.2003 - val_loss: 1.8282 - val_accuracy: 0.2489 - lr: 0.0010
# Epoch 2/200
# 317/317 [==============================] - ETA: 0s - loss: 1.8348 - accuracy: 0.2425
# Epoch 2: val_accuracy improved from 0.24887 to 0.27760, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.8348 - accuracy: 0.2425 - val_loss: 1.7857 - val_accuracy: 0.2776 - lr: 0.0010
# Epoch 3/200
# 317/317 [==============================] - ETA: 0s - loss: 1.7795 - accuracy: 0.2761
# Epoch 3: val_accuracy improved from 0.27760 to 0.30077, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.7795 - accuracy: 0.2761 - val_loss: 1.6907 - val_accuracy: 0.3008 - lr: 0.0010
# Epoch 4/200
# 317/317 [==============================] - ETA: 0s - loss: 1.6882 - accuracy: 0.3240
# Epoch 4: val_accuracy did not improve from 0.30077
# 317/317 [==============================] - 22s 69ms/step - loss: 1.6882 - accuracy: 0.3240 - val_loss: 2.2853 - val_accuracy: 0.2372 - lr: 0.0010
# Epoch 5/200
# 317/317 [==============================] - ETA: 0s - loss: 1.5801 - accuracy: 0.3804
# Epoch 5: val_accuracy improved from 0.30077 to 0.41815, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.5801 - accuracy: 0.3804 - val_loss: 1.5791 - val_accuracy: 0.4181 - lr: 0.0010
# Epoch 6/200
# 317/317 [==============================] - ETA: 0s - loss: 1.4823 - accuracy: 0.4251
# Epoch 6: val_accuracy improved from 0.41815 to 0.46569, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.4823 - accuracy: 0.4251 - val_loss: 1.4297 - val_accuracy: 0.4657 - lr: 0.0010
# Epoch 7/200
# 317/317 [==============================] - ETA: 0s - loss: 1.4142 - accuracy: 0.4552
# Epoch 7: val_accuracy improved from 0.46569 to 0.49565, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.4142 - accuracy: 0.4552 - val_loss: 1.3276 - val_accuracy: 0.4956 - lr: 0.0010
# Epoch 8/200
# 317/317 [==============================] - ETA: 0s - loss: 1.3649 - accuracy: 0.4753
# Epoch 8: val_accuracy improved from 0.49565 to 0.50731, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.3649 - accuracy: 0.4753 - val_loss: 1.3109 - val_accuracy: 0.5073 - lr: 0.0010
# Epoch 9/200
# 317/317 [==============================] - ETA: 0s - loss: 1.3304 - accuracy: 0.4920
# Epoch 9: val_accuracy did not improve from 0.50731
# 317/317 [==============================] - 22s 69ms/step - loss: 1.3304 - accuracy: 0.4920 - val_loss: 1.3182 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 10/200
# 317/317 [==============================] - ETA: 0s - loss: 1.3054 - accuracy: 0.5017
# Epoch 10: val_accuracy did not improve from 0.50731
# 317/317 [==============================] - 22s 70ms/step - loss: 1.3054 - accuracy: 0.5017 - val_loss: 1.3631 - val_accuracy: 0.4988 - lr: 0.0010
# Epoch 11/200
# 317/317 [==============================] - ETA: 0s - loss: 1.2724 - accuracy: 0.5160
# Epoch 11: val_accuracy improved from 0.50731 to 0.55364, saving model to best_model.h5
# 317/317 [==============================] - 22s 71ms/step - loss: 1.2724 - accuracy: 0.5160 - val_loss: 1.1989 - val_accuracy: 0.5536 - lr: 0.0010
# Epoch 12/200
# 317/317 [==============================] - ETA: 0s - loss: 1.2450 - accuracy: 0.5288
# Epoch 12: val_accuracy did not improve from 0.55364
# 317/317 [==============================] - 22s 70ms/step - loss: 1.2450 - accuracy: 0.5288 - val_loss: 1.3947 - val_accuracy: 0.5103 - lr: 0.0010
# Epoch 13/200
# 317/317 [==============================] - ETA: 0s - loss: 1.2327 - accuracy: 0.5360
# Epoch 13: val_accuracy did not improve from 0.55364
# 317/317 [==============================] - 22s 70ms/step - loss: 1.2327 - accuracy: 0.5360 - val_loss: 1.3112 - val_accuracy: 0.5244 - lr: 0.0010
# Epoch 14/200
# 317/317 [==============================] - ETA: 0s - loss: 1.2132 - accuracy: 0.5451
# Epoch 14: val_accuracy improved from 0.55364 to 0.56653, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.2132 - accuracy: 0.5451 - val_loss: 1.1659 - val_accuracy: 0.5665 - lr: 0.0010
# Epoch 15/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1915 - accuracy: 0.5513
# Epoch 15: val_accuracy improved from 0.56653 to 0.59666, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1915 - accuracy: 0.5513 - val_loss: 1.0952 - val_accuracy: 0.5967 - lr: 0.0010
# Epoch 16/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1792 - accuracy: 0.5540
# Epoch 16: val_accuracy did not improve from 0.59666
# 317/317 [==============================] - 22s 69ms/step - loss: 1.1792 - accuracy: 0.5540 - val_loss: 1.1261 - val_accuracy: 0.5796 - lr: 0.0010
# Epoch 17/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1637 - accuracy: 0.5612
# Epoch 17: val_accuracy improved from 0.59666 to 0.60693, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1637 - accuracy: 0.5612 - val_loss: 1.0423 - val_accuracy: 0.6069 - lr: 0.0010
# Epoch 18/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1478 - accuracy: 0.5691
# Epoch 18: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1478 - accuracy: 0.5691 - val_loss: 1.0953 - val_accuracy: 0.5895 - lr: 0.0010
# Epoch 19/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1419 - accuracy: 0.5700
# Epoch 19: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1419 - accuracy: 0.5700 - val_loss: 1.1285 - val_accuracy: 0.5784 - lr: 0.0010
# Epoch 20/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1248 - accuracy: 0.5779
# Epoch 20: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1248 - accuracy: 0.5779 - val_loss: 1.1189 - val_accuracy: 0.5993 - lr: 0.0010
# Epoch 21/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1149 - accuracy: 0.5816
# Epoch 21: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1149 - accuracy: 0.5816 - val_loss: 1.0567 - val_accuracy: 0.6005 - lr: 0.0010
# Epoch 22/200
# 317/317 [==============================] - ETA: 0s - loss: 1.1041 - accuracy: 0.5842
# Epoch 22: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.1041 - accuracy: 0.5842 - val_loss: 1.0857 - val_accuracy: 0.5935 - lr: 0.0010
# Epoch 23/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.5867
# Epoch 23: val_accuracy did not improve from 0.60693
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0963 - accuracy: 0.5867 - val_loss: 1.0759 - val_accuracy: 0.5935 - lr: 0.0010
# Epoch 24/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0833 - accuracy: 0.5917
# Epoch 24: val_accuracy improved from 0.60693 to 0.61808, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0833 - accuracy: 0.5917 - val_loss: 1.0423 - val_accuracy: 0.6181 - lr: 0.0010
# Epoch 25/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0764 - accuracy: 0.5946
# Epoch 25: val_accuracy did not improve from 0.61808
# 317/317 [==============================] - 22s 69ms/step - loss: 1.0764 - accuracy: 0.5946 - val_loss: 1.0610 - val_accuracy: 0.6106 - lr: 0.0010
# Epoch 26/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0682 - accuracy: 0.5982
# Epoch 26: val_accuracy did not improve from 0.61808
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0682 - accuracy: 0.5982 - val_loss: 1.1179 - val_accuracy: 0.5951 - lr: 0.0010
# Epoch 27/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0602 - accuracy: 0.6011
# Epoch 27: val_accuracy improved from 0.61808 to 0.62487, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0602 - accuracy: 0.6011 - val_loss: 1.0012 - val_accuracy: 0.6249 - lr: 0.0010
# Epoch 28/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0495 - accuracy: 0.6037
# Epoch 28: val_accuracy improved from 0.62487 to 0.62887, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0495 - accuracy: 0.6037 - val_loss: 1.0020 - val_accuracy: 0.6289 - lr: 0.0010
# Epoch 29/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0482 - accuracy: 0.6059
# Epoch 29: val_accuracy did not improve from 0.62887
# 317/317 [==============================] - 22s 69ms/step - loss: 1.0482 - accuracy: 0.6059 - val_loss: 1.0273 - val_accuracy: 0.6254 - lr: 0.0010
# Epoch 30/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0336 - accuracy: 0.6117
# Epoch 30: val_accuracy did not improve from 0.62887
# 317/317 [==============================] - 22s 69ms/step - loss: 1.0336 - accuracy: 0.6117 - val_loss: 1.0250 - val_accuracy: 0.6113 - lr: 0.0010
# Epoch 31/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0306 - accuracy: 0.6104
# Epoch 31: val_accuracy did not improve from 0.62887
# 317/317 [==============================] - 22s 69ms/step - loss: 1.0306 - accuracy: 0.6104 - val_loss: 1.0321 - val_accuracy: 0.6223 - lr: 0.0010
# Epoch 32/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0296 - accuracy: 0.6152
# Epoch 32: val_accuracy did not improve from 0.62887
# 317/317 [==============================] - 22s 69ms/step - loss: 1.0296 - accuracy: 0.6152 - val_loss: 1.0978 - val_accuracy: 0.5998 - lr: 0.0010
# Epoch 33/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0139 - accuracy: 0.6203
# Epoch 33: val_accuracy improved from 0.62887 to 0.63480, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0139 - accuracy: 0.6203 - val_loss: 1.0221 - val_accuracy: 0.6348 - lr: 0.0010
# Epoch 34/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0165 - accuracy: 0.6195
# Epoch 34: val_accuracy did not improve from 0.63480
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0165 - accuracy: 0.6195 - val_loss: 1.0222 - val_accuracy: 0.6237 - lr: 0.0010
# Epoch 35/200
# 317/317 [==============================] - ETA: 0s - loss: 1.0075 - accuracy: 0.6217
# Epoch 35: val_accuracy improved from 0.63480 to 0.63863, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 1.0075 - accuracy: 0.6217 - val_loss: 0.9943 - val_accuracy: 0.6386 - lr: 0.0010
# Epoch 36/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9936 - accuracy: 0.6275
# Epoch 36: val_accuracy improved from 0.63863 to 0.64159, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9936 - accuracy: 0.6275 - val_loss: 0.9866 - val_accuracy: 0.6416 - lr: 0.0010
# Epoch 37/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9942 - accuracy: 0.6261
# Epoch 37: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9942 - accuracy: 0.6261 - val_loss: 1.0334 - val_accuracy: 0.6285 - lr: 0.0010
# Epoch 38/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9865 - accuracy: 0.6320
# Epoch 38: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9865 - accuracy: 0.6320 - val_loss: 1.0137 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 39/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9800 - accuracy: 0.6309
# Epoch 39: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9800 - accuracy: 0.6309 - val_loss: 1.1403 - val_accuracy: 0.5897 - lr: 0.0010
# Epoch 40/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9750 - accuracy: 0.6326
# Epoch 40: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9750 - accuracy: 0.6326 - val_loss: 0.9873 - val_accuracy: 0.6341 - lr: 0.0010
# Epoch 41/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9696 - accuracy: 0.6361
# Epoch 41: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9696 - accuracy: 0.6361 - val_loss: 1.0576 - val_accuracy: 0.6212 - lr: 0.0010
# Epoch 42/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9612 - accuracy: 0.6389
# Epoch 42: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9612 - accuracy: 0.6389 - val_loss: 1.0051 - val_accuracy: 0.6360 - lr: 0.0010
# Epoch 43/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9550 - accuracy: 0.6375
# Epoch 43: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9550 - accuracy: 0.6375 - val_loss: 1.0212 - val_accuracy: 0.6266 - lr: 0.0010
# Epoch 44/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9560 - accuracy: 0.6402
# Epoch 44: val_accuracy did not improve from 0.64159
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9560 - accuracy: 0.6402 - val_loss: 1.0088 - val_accuracy: 0.6339 - lr: 0.0010
# Epoch 45/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9487 - accuracy: 0.6438
# Epoch 45: val_accuracy improved from 0.64159 to 0.64333, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9487 - accuracy: 0.6438 - val_loss: 0.9765 - val_accuracy: 0.6433 - lr: 0.0010
# Epoch 46/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9441 - accuracy: 0.6459
# Epoch 46: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9441 - accuracy: 0.6459 - val_loss: 1.0361 - val_accuracy: 0.6280 - lr: 0.0010
# Epoch 47/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9415 - accuracy: 0.6454
# Epoch 47: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9415 - accuracy: 0.6454 - val_loss: 1.0032 - val_accuracy: 0.6351 - lr: 0.0010
# Epoch 48/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9336 - accuracy: 0.6481
# Epoch 48: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9336 - accuracy: 0.6481 - val_loss: 1.0363 - val_accuracy: 0.6263 - lr: 0.0010
# Epoch 49/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9319 - accuracy: 0.6491
# Epoch 49: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9319 - accuracy: 0.6491 - val_loss: 1.0377 - val_accuracy: 0.6233 - lr: 0.0010
# Epoch 50/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.6537
# Epoch 50: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9260 - accuracy: 0.6537 - val_loss: 1.0250 - val_accuracy: 0.6367 - lr: 0.0010
# Epoch 51/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9267 - accuracy: 0.6547
# Epoch 51: val_accuracy did not improve from 0.64333
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9267 - accuracy: 0.6547 - val_loss: 1.0470 - val_accuracy: 0.6280 - lr: 0.0010
# Epoch 52/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9134 - accuracy: 0.6570
# Epoch 52: val_accuracy improved from 0.64333 to 0.65099, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9134 - accuracy: 0.6570 - val_loss: 0.9831 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 53/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9106 - accuracy: 0.6574
# Epoch 53: val_accuracy improved from 0.65099 to 0.65500, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9106 - accuracy: 0.6574 - val_loss: 0.9870 - val_accuracy: 0.6550 - lr: 0.0010
# Epoch 54/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9047 - accuracy: 0.6585
# Epoch 54: val_accuracy did not improve from 0.65500
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9047 - accuracy: 0.6585 - val_loss: 1.0271 - val_accuracy: 0.6447 - lr: 0.0010
# Epoch 55/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9087 - accuracy: 0.6587
# Epoch 55: val_accuracy did not improve from 0.65500
# 317/317 [==============================] - 22s 70ms/step - loss: 0.9087 - accuracy: 0.6587 - val_loss: 0.9678 - val_accuracy: 0.6526 - lr: 0.0010
# Epoch 56/200
# 317/317 [==============================] - ETA: 0s - loss: 0.9002 - accuracy: 0.6622
# Epoch 56: val_accuracy did not improve from 0.65500
# 317/317 [==============================] - 22s 69ms/step - loss: 0.9002 - accuracy: 0.6622 - val_loss: 0.9698 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 57/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8961 - accuracy: 0.6634
# Epoch 57: val_accuracy did not improve from 0.65500
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8961 - accuracy: 0.6634 - val_loss: 0.9674 - val_accuracy: 0.6499 - lr: 0.0010
# Epoch 58/200
# 316/317 [============================>.] - ETA: 0s - loss: 0.8909 - accuracy: 0.6660
# Epoch 58: val_accuracy improved from 0.65500 to 0.65709, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8906 - accuracy: 0.6661 - val_loss: 0.9543 - val_accuracy: 0.6571 - lr: 0.0010
# Epoch 59/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8835 - accuracy: 0.6673
# Epoch 59: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8835 - accuracy: 0.6673 - val_loss: 0.9987 - val_accuracy: 0.6432 - lr: 0.0010
# Epoch 60/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8833 - accuracy: 0.6668
# Epoch 60: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8833 - accuracy: 0.6668 - val_loss: 0.9866 - val_accuracy: 0.6482 - lr: 0.0010
# Epoch 61/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8755 - accuracy: 0.6713
# Epoch 61: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8755 - accuracy: 0.6713 - val_loss: 1.0119 - val_accuracy: 0.6430 - lr: 0.0010
# Epoch 62/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8757 - accuracy: 0.6680
# Epoch 62: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8757 - accuracy: 0.6680 - val_loss: 1.0216 - val_accuracy: 0.6407 - lr: 0.0010
# Epoch 63/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8792 - accuracy: 0.6687
# Epoch 63: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8792 - accuracy: 0.6687 - val_loss: 1.0169 - val_accuracy: 0.6398 - lr: 0.0010
# Epoch 64/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8703 - accuracy: 0.6770
# Epoch 64: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8703 - accuracy: 0.6770 - val_loss: 1.0009 - val_accuracy: 0.6475 - lr: 0.0010
# Epoch 65/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8691 - accuracy: 0.6734
# Epoch 65: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8691 - accuracy: 0.6734 - val_loss: 0.9893 - val_accuracy: 0.6486 - lr: 0.0010
# Epoch 66/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8561 - accuracy: 0.6793
# Epoch 66: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8561 - accuracy: 0.6793 - val_loss: 0.9838 - val_accuracy: 0.6466 - lr: 0.0010
# Epoch 67/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8592 - accuracy: 0.6788
# Epoch 67: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8592 - accuracy: 0.6788 - val_loss: 1.0091 - val_accuracy: 0.6445 - lr: 0.0010
# Epoch 68/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8538 - accuracy: 0.6797
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 68: val_accuracy did not improve from 0.65709
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8538 - accuracy: 0.6797 - val_loss: 0.9757 - val_accuracy: 0.6566 - lr: 0.0010
# Epoch 69/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.6931
# Epoch 69: val_accuracy improved from 0.65709 to 0.65848, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8214 - accuracy: 0.6931 - val_loss: 0.9807 - val_accuracy: 0.6585 - lr: 5.0000e-04
# Epoch 70/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8139 - accuracy: 0.6949
# Epoch 70: val_accuracy improved from 0.65848 to 0.66301, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8139 - accuracy: 0.6949 - val_loss: 0.9766 - val_accuracy: 0.6630 - lr: 5.0000e-04
# Epoch 71/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8089 - accuracy: 0.6943
# Epoch 71: val_accuracy did not improve from 0.66301
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8089 - accuracy: 0.6943 - val_loss: 1.0036 - val_accuracy: 0.6559 - lr: 5.0000e-04
# Epoch 72/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8084 - accuracy: 0.6957
# Epoch 72: val_accuracy did not improve from 0.66301
# 317/317 [==============================] - 22s 69ms/step - loss: 0.8084 - accuracy: 0.6957 - val_loss: 0.9665 - val_accuracy: 0.6618 - lr: 5.0000e-04
# Epoch 73/200
# 317/317 [==============================] - ETA: 0s - loss: 0.8011 - accuracy: 0.7007
# Epoch 73: val_accuracy did not improve from 0.66301
# 317/317 [==============================] - 22s 70ms/step - loss: 0.8011 - accuracy: 0.7007 - val_loss: 0.9868 - val_accuracy: 0.6607 - lr: 5.0000e-04
# Epoch 74/200
# 317/317 [==============================] - ETA: 0s - loss: 0.7933 - accuracy: 0.7009
# Epoch 74: val_accuracy improved from 0.66301 to 0.66371, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.7933 - accuracy: 0.7009 - val_loss: 0.9872 - val_accuracy: 0.6637 - lr: 5.0000e-04
# Epoch 75/200
# 317/317 [==============================] - ETA: 0s - loss: 0.7892 - accuracy: 0.7033
# Epoch 75: val_accuracy did not improve from 0.66371
# 317/317 [==============================] - 22s 69ms/step - loss: 0.7892 - accuracy: 0.7033 - val_loss: 0.9956 - val_accuracy: 0.6595 - lr: 5.0000e-04
# Epoch 76/200
# 317/317 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.7028
# Epoch 76: val_accuracy improved from 0.66371 to 0.66806, saving model to best_model.h5
# 317/317 [==============================] - 22s 70ms/step - loss: 0.7903 - accuracy: 0.7028 - val_loss: 0.9853 - val_accuracy: 0.6681 - lr: 5.0000e-04
# Epoch 77/200
# 317/317 [==============================] - ETA: 0s - loss: 0.7884 - accuracy: 0.7035
# Epoch 77: val_accuracy did not improve from 0.66806
# 317/317 [==============================] - 22s 70ms/step - loss: 0.7884 - accuracy: 0.7035 - val_loss: 1.0016 - val_accuracy: 0.6498 - lr: 5.0000e-04
# Epoch 78/200
# 317/317 [==============================] - ETA: 0s - loss: 0.7826 - accuracy: 0.7067
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 78: val_accuracy did not improve from 0.66806
# 317/317 [==============================] - 22s 69ms/step - loss: 0.7826 - accuracy: 0.7067 - val_loss: 0.9679 - val_accuracy: 0.6639 - lr: 5.0000e-04
# Epoch 78: early stopping

# %%
plot_metrics(history)

# %%
save_model = model.save("model_FER48.h5")

# %%
# model.load_weights(model.checkpoint_path)
model = load_model("model_FER48.h5")
evaluate_class(model, x_test, y_test)
# Out:
# Emotion        Accuracy
# -----------------------
# Angry          57.6%
# Disgust        65.5%
# Fear           48.1%
# Happy          83.9%
# Sad            68.0%
# Surprise       48.6%
# Neutral        80.4%
# -----------------------
# Overall        65.5%

# %% [markdown]
# # Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix

# Make predictions on test data
y_pred = model.predict(image_test)
y_pred = np.argmax(y_pred, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(label_test, y_pred)
print(cm)
# Out:
# 225/225 [==============================] - 2s 6ms/step
# [[ 578   33  118   35  112   98   29]
#  [  20   74    6    1    2    9    1]
#  [ 126    9  497   21   92  160  129]
#  [  40    2   44 1472  112   36   48]
#  [  73    5   66   67  840  149   35]
#  [ 124   15  195   41  242  607   26]
#  [  24    3   59   43   16   10  634]]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
confusion_mtx = confusion_matrix(label_test, y_pred)

# Print the classification report
class_names = ["Angry", "Disgust", "Fear", "Happy", "Neutral", "Sad", "Surprise"]  # replace with your own class names
print(classification_report(label_test, y_pred, target_names=class_names))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.59      0.58      0.58      1003
#      Disgust       0.52      0.65      0.58       113
#         Fear       0.50      0.48      0.49      1034
#        Happy       0.88      0.84      0.86      1754
#      Neutral       0.59      0.68      0.63      1235
#          Sad       0.57      0.49      0.52      1250
#     Surprise       0.70      0.80      0.75       789
#
#     accuracy                           0.66      7178
#    macro avg       0.62      0.65      0.63      7178
# weighted avg       0.66      0.66      0.65      7178

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Generate the confusion matrix
confusion_mtx = confusion_matrix(label_test, y_pred)

# Calculate overall accuracy
overall_accuracy = (confusion_mtx.diagonal().sum() / confusion_mtx.sum()) * 100
print(f"Overall Accuracy: {overall_accuracy:.2f}%")

# Calculate class accuracy
class_accuracy = {}
for i in range(len(class_names)):
    class_accuracy[class_names[i]] = (confusion_mtx[i,i] / confusion_mtx[i,:].sum()) * 100
    print(f"{class_names[i]} Accuracy: {class_accuracy[class_names[i]]:.2f}%")
# Out:
# Overall Accuracy: 65.51%
# Angry Accuracy: 57.63%
# Disgust Accuracy: 65.49%
# Fear Accuracy: 48.07%
# Happy Accuracy: 83.92%
# Neutral Accuracy: 68.02%
# Sad Accuracy: 48.56%
# Surprise Accuracy: 80.35%

# %% [markdown]
# # Unseen Batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    color_mode='grayscale',
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = classes[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 4/4 [==============================] - 0s 84ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# Accuracy: 55.17578125
# Angry 296/2100 acc: 74.3
# Disgust 287/2100 acc: 36.6
# Fear 292/2100 acc: 36.6
# Happy 294/2100 acc: 76.2
# Neutral 294/2100 acc: 76.5
# Sad 294/2100 acc: 28.9
# Surprise 291/2100 acc: 56.4

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 55.17578125
# Angry 296/2100 acc: 74.3
# Disgust 287/2100 acc: 36.6
# Fear 292/2100 acc: 36.6
# Happy 294/2100 acc: 76.2
# Neutral 294/2100 acc: 76.5
# Sad 294/2100 acc: 28.9
# Surprise 291/2100 acc: 56.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.50      0.74      0.60       296
#      Disgust       0.64      0.37      0.47       287
#         Fear       0.50      0.37      0.42       292
#        Happy       0.76      0.76      0.76       294
#      Neutral       0.44      0.77      0.56       294
#          Sad       0.54      0.29      0.38       294
#     Surprise       0.62      0.56      0.59       291
#
#     accuracy                           0.55      2048
#    macro avg       0.57      0.55      0.54      2048
# weighted avg       0.57      0.55      0.54      2048

# %% [markdown]
# # Test with images

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Define the colors for each emotion
emotions = {
    0: ['Angry', (0,0,255)],
    1: ['Disgust', (0,102,0)],
    2: ['Fear', (255,255,153)],
    3: ['Happy', (153,0,153)],
    4: ['Sad', (255,0,0)],
    5: ['Surprise', (0,255,0)],
    6: ['Neutral', (160,160,160)]
}

# Load the image
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the grayscale image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI from the original image
    face_image = image[y:y+h, x:x+w]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to grayscale
    normalized_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    normalized_image = normalized_image.astype('float32')

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Get the color for the predicted emotion
    color = emotions[predicted_class_index][1]

    # Draw a rectangle around the detected face with the corresponding color
    cv2.rectangle(image, (x, y), (x+w, y+h), color, 2)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

# Resize the image to 1800x1200 pixels
image = cv2.resize(image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.7985390424728394
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: surprise, probability: 0.9998112320899963
# 1/1 [==============================] - 0s 31ms/step
# Predicted emotion class: fear, probability: 0.7220748662948608
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: sad, probability: 0.6166070103645325
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: happy, probability: 0.9918322563171387
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: angry, probability: 0.9947086572647095
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.9716494083404541
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: sad, probability: 0.9391486048698425
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: sad, probability: 0.547863245010376

# %% [markdown]
# # Video

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Define the colors for each emotion
emotions = {
    0: ['Angry', (0,0,255)],
    1: ['Disgust', (0,102,0)],
    2: ['Fear', (255,255,153)],
    3: ['Happy', (153,0,153)],
    4: ['Sad', (255,0,0)],
    5: ['Surprise', (0,255,0)],
    6: ['Neutral', (160,160,160)]
}

# Create a VideoCapture object to capture frames from the webcam
video_capture = cv2.VideoCapture(0)

while True:
    # Capture a frame from the webcam
    ret, frame = video_capture.read()

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale frame
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)

    # Loop through each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI from the original frame
        face_image = frame[y:y+h, x:x+w]

        # Resize the face ROI to 48x48 pixels
        resized_image = cv2.resize(face_image, (48, 48))

        # Convert the resized image to grayscale
        normalized_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
        normalized_image = normalized_image.astype('float32')

        # Make a prediction on the normalized image using the loaded model
        predictions = model.predict(np.expand_dims(normalized_image, axis=0))

        # Get the index of the highest predicted class
        predicted_class_index = np.argmax(predictions)

        # Print the predicted emotion class and its corresponding probability
        predicted_class = emotion_classes[predicted_class_index]
        predicted_probability = predictions[0][predicted_class_index]
        print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

        # Get the color for the predicted emotion
        color = emotions[predicted_class_index][1]

        # Draw a rectangle around the detected face with the corresponding color
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)

        # Display the predicted emotion class and its corresponding probability on the frame
        text = f"{predicted_class} ({predicted_probability:.2f})"
        cv2.putText(frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Display the frame with the detected faces and their predictions
    cv2.imshow("Webcam", frame)

    # Check if the user pressed the 'q' key to quit the program
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object and close all windows
video_capture.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: fear, probability: 0.6552807688713074
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.7833343744277954
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9380834698677063
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9530553221702576
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: fear, probability: 0.8754827976226807
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.8754827976226807
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: fear, probability: 0.6696915030479431
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.8481820821762085
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9169265627861023
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9169265627861023
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: fear, probability: 0.9295916557312012
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: fear, probability: 0.9478655457496643
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9215070605278015
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.8721565008163452
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9335295557975769
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: fear, probability: 0.9335295557975769
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.818850576877594
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: neutral, probability: 0.6428242325782776
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.555526852607727
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: sad, probability: 0.5020215511322021
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: sad, probability: 0.43924766778945923
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: neutral, probability: 0.5676478147506714
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.3429356813430786
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: neutral, probability: 0.4394720494747162
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.5622653961181641
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.6878315806388855
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.7038595676422119
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.36150938272476196
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.4098454713821411
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: disgust, probability: 0.5610839128494263
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.7042909264564514
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9217426180839539
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.5120835900306702
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9645528197288513
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9588775634765625
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: fear, probability: 0.9429471492767334
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.8203414082527161
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9835611581802368
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.5625013113021851
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.6637890934944153
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9852811694145203
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: fear, probability: 0.8598129749298096
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.6413914561271667
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.8506611585617065
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.9323896169662476
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: fear, probability: 0.769286036491394
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: neutral, probability: 0.4409867525100708
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: neutral, probability: 0.4409867525100708
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: neutral, probability: 0.559882402420044
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: disgust, probability: 0.3833446502685547
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.8484346270561218
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.5198760628700256
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.5198760628700256
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: neutral, probability: 0.4797632098197937
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: disgust, probability: 0.47869396209716797
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.3770703077316284
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.28737887740135193
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: fear, probability: 0.9392436146736145
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.978410542011261
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.958101212978363
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9855269193649292
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9547937512397766
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: fear, probability: 0.9547937512397766
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.6768714785575867
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.7580083608627319
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.9455355405807495
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: fear, probability: 0.996220052242279
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: fear, probability: 0.6231661438941956
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: fear, probability: 0.6231661438941956
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: happy, probability: 0.5210902690887451
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.4875258803367615
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: fear, probability: 0.54884272813797
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: happy, probability: 0.8944712281227112
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.8271741271018982
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.7889389991760254
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.8952949047088623
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: happy, probability: 0.9068796038627625
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.9665393829345703
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: happy, probability: 0.864453136920929
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.8866627216339111
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.7631361484527588
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: happy, probability: 0.9130411744117737
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.9130411744117737
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: happy, probability: 0.9259961247444153
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.5456908345222473
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.8297650814056396
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.7420274615287781
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: happy, probability: 0.8321171402931213
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: happy, probability: 0.8843627572059631
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.9868804216384888
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: happy, probability: 0.793242335319519
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: happy, probability: 0.8878927230834961
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: happy, probability: 0.8878927230834961
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.9602646827697754
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: happy, probability: 0.9841915369033813
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: happy, probability: 0.893936276435852
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: neutral, probability: 0.7050684690475464
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: neutral, probability: 0.6551055908203125
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: neutral, probability: 0.8176732659339905
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: neutral, probability: 0.8401620388031006
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: neutral, probability: 0.7762387990951538
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: neutral, probability: 0.7762387990951538
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: neutral, probability: 0.7698552012443542
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: sad, probability: 0.4535121023654938
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.8667519092559814
# 1/1 [==============================] - 0s 22ms/step
# Predicted emotion class: angry, probability: 0.8686662316322327
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.7355910539627075
