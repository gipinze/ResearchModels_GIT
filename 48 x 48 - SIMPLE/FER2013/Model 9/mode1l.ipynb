# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
from tensorflow.python.client import device_lib
devices = device_lib.list_local_devices()

def sizeof_fmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f%s%s" % (num, 'Yi', suffix)

for d in devices:
    t = d.device_type
    name = d.physical_device_desc
    l = [item.split(':',1) for item in name.split(", ")]
    name_attr = dict([x for x in l if len(x)==2])
    dev = name_attr.get('name', 'Unnamed device')
    print(f" {d.name} || {dev} || {t} || {sizeof_fmt(d.memory_limit)}")
# Out:
#  /device:CPU:0 || Unnamed device || CPU || 256.0 MiB
#  /device:GPU:0 ||  NVIDIA GeForce RTX 3060 || GPU || 9.4 GiB
#  /device:GPU:1 ||  NVIDIA GeForce RTX 3060 || GPU || 9.4 GiB

# %%
import tensorflow as tf
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Dense, Flatten, Dropout, Input, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
import keras.backend as K
import random
from keras.models import Model, Sequential, load_model
from keras.optimizers import Adam
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from collections import Counter
import matplotlib.pyplot as plt
from IPython.display import Image, HTML
import pandas as pd
import numpy as np
from keras.metrics import AUC, Precision, Recall, Accuracy
from sklearn.metrics import f1_score
from keras.callbacks import LambdaCallback
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
    print("GPU memory growth has been limited successfully!")
except:
    print("Failed to limit the GPU memory growth.")
# Out:
# GPU memory growth has been limited successfully!

# %%
GPUS = ["GPU:0", "GPU:1"]
strategy = tf.distribute.MirroredStrategy(GPUS,
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %% [markdown]
# # Importing dependencies

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
num_classes = 7
IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)

IMAGE_SHAPE = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))

batch_size=16*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)

class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Data augmentation
# Data augmentation

train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					horizontal_flip=True,
					fill_mode='nearest')

valid_datagen  = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(directory = train_data_dir,
                                                    target_size=IMG_SIZE,
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    class_mode='categorical')

valid_generator = valid_datagen.flow_from_directory(directory = validation_data_dir,
                                                    target_size=IMG_SIZE,
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>angry</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = valid_generator.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

# %%
# # lot distribution of train/test dataste per class

x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='green')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# class_weights = class_weight.compute_class_weight(
#                                         class_weight = "balanced",
#                                         classes = np.unique(train_generator.classes),
#                                         y = train_generator.classes                                                    
#                                     )
# class_weights = dict(zip(np.unique(train_generator.classes), class_weights))
# class_weights

# %%
# from collections import Counter

# counter = Counter(train_generator.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     
# print(class_weights)

# %%
with strategy.scope():
    
        model = tf.keras.Sequential()

                #Input Layers
        model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 3), padding='same'))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2))) 
        model.add(Dropout(0.25)) #test

        model.add(Conv2D(128, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2))) 
        model.add(Conv2D(128, (3, 3), activation='relu'))
        model.add(Dropout(0.25))

        model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2))) 
        model.add(Dropout(0.2))

        model.add(Flatten()) #Flattens our data into a vector

        model.add(Dense(1024, activation = 'relu'))
        model.add(Dropout(0.5))
        model.add(Dense(7, activation = 'softmax'))


        counter = Counter(train_generator.classes)                          
        max_val = float(max(counter.values()))       
        class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     

        filepath="checkpoints_freeze/toy-model_1-epoch-{epoch:02d}-val_accuracy-{val_accuracy:.2f}.h5"
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='auto', period=1)


        # Compile model
        model.compile(optimizer=Adam(learning_rate=0.001),
                        loss='categorical_crossentropy',
                        metrics = ['accuracy'])
        model.summary()

        # Train model
        history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=valid_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, csv_logger],
                verbose=1)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        896
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         590336
#
#  batch_normalization (BatchN  (None, 8, 8, 512)        2048
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 9,230,023
# Trainable params: 9,228,999
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 897/897 [==============================] - ETA: 0s - loss: 2.9562 - accuracy: 0.1576
# Epoch 1: saving model to checkpoints_freeze\toy-model_1-epoch-01-val_accuracy-0.13.h5
# 897/897 [==============================] - 202s 212ms/step - loss: 2.9562 - accuracy: 0.1576 - val_loss: 1.8509 - val_accuracy: 0.1335
# Epoch 2/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9177 - accuracy: 0.1587
# Epoch 2: saving model to checkpoints_freeze\toy-model_1-epoch-02-val_accuracy-0.14.h5
# 897/897 [==============================] - 30s 34ms/step - loss: 2.9176 - accuracy: 0.1587 - val_loss: 1.8471 - val_accuracy: 0.1427
# Epoch 3/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9194 - accuracy: 0.1653
# Epoch 3: saving model to checkpoints_freeze\toy-model_1-epoch-03-val_accuracy-0.14.h5
# 897/897 [==============================] - 30s 33ms/step - loss: 2.9191 - accuracy: 0.1652 - val_loss: 1.8544 - val_accuracy: 0.1427
# Epoch 4/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9176 - accuracy: 0.1599
# Epoch 4: saving model to checkpoints_freeze\toy-model_1-epoch-04-val_accuracy-0.12.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9179 - accuracy: 0.1598 - val_loss: 1.8722 - val_accuracy: 0.1155
# Epoch 5/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9180 - accuracy: 0.1618
# Epoch 5: saving model to checkpoints_freeze\toy-model_1-epoch-05-val_accuracy-0.12.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9180 - accuracy: 0.1618 - val_loss: 1.8529 - val_accuracy: 0.1157
# Epoch 6/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9174 - accuracy: 0.1614
# Epoch 6: saving model to checkpoints_freeze\toy-model_1-epoch-06-val_accuracy-0.17.h5
# 897/897 [==============================] - 29s 33ms/step - loss: 2.9174 - accuracy: 0.1615 - val_loss: 1.8576 - val_accuracy: 0.1716
# Epoch 7/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9172 - accuracy: 0.1617
# Epoch 7: saving model to checkpoints_freeze\toy-model_1-epoch-07-val_accuracy-0.17.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9172 - accuracy: 0.1617 - val_loss: 1.8580 - val_accuracy: 0.1740
# Epoch 8/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9154 - accuracy: 0.1628
# Epoch 8: saving model to checkpoints_freeze\toy-model_1-epoch-08-val_accuracy-0.14.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9154 - accuracy: 0.1628 - val_loss: 1.8539 - val_accuracy: 0.1429
# Epoch 9/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9160 - accuracy: 0.1564
# Epoch 9: saving model to checkpoints_freeze\toy-model_1-epoch-09-val_accuracy-0.13.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9158 - accuracy: 0.1565 - val_loss: 1.8527 - val_accuracy: 0.1335
# Epoch 10/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9134 - accuracy: 0.1631
# Epoch 10: saving model to checkpoints_freeze\toy-model_1-epoch-10-val_accuracy-0.12.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9137 - accuracy: 0.1631 - val_loss: 1.8453 - val_accuracy: 0.1158
# Epoch 11/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9154 - accuracy: 0.1619
# Epoch 11: saving model to checkpoints_freeze\toy-model_1-epoch-11-val_accuracy-0.14.h5
# 897/897 [==============================] - 29s 32ms/step - loss: 2.9150 - accuracy: 0.1619 - val_loss: 1.8551 - val_accuracy: 0.1426
# Epoch 12/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9119 - accuracy: 0.1566
# Epoch 12: saving model to checkpoints_freeze\toy-model_1-epoch-12-val_accuracy-0.25.h5
# 897/897 [==============================] - 29s 33ms/step - loss: 2.9122 - accuracy: 0.1565 - val_loss: 1.8451 - val_accuracy: 0.2473
# Epoch 13/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9115 - accuracy: 0.1818
# Epoch 13: saving model to checkpoints_freeze\toy-model_1-epoch-13-val_accuracy-0.17.h5
# 897/897 [==============================] - 28s 32ms/step - loss: 2.9114 - accuracy: 0.1817 - val_loss: 1.8523 - val_accuracy: 0.1738
# Epoch 14/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9120 - accuracy: 0.1644
# Epoch 14: saving model to checkpoints_freeze\toy-model_1-epoch-14-val_accuracy-0.13.h5
# 897/897 [==============================] - 28s 32ms/step - loss: 2.9117 - accuracy: 0.1644 - val_loss: 1.8522 - val_accuracy: 0.1336
# Epoch 15/50
# 895/897 [============================>.] - ETA: 0s - loss: 2.9097 - accuracy: 0.1855
# Epoch 15: saving model to checkpoints_freeze\toy-model_1-epoch-15-val_accuracy-0.17.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9094 - accuracy: 0.1856 - val_loss: 1.8507 - val_accuracy: 0.1717
# Epoch 16/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9084 - accuracy: 0.1747
# Epoch 16: saving model to checkpoints_freeze\toy-model_1-epoch-16-val_accuracy-0.12.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9084 - accuracy: 0.1747 - val_loss: 1.8516 - val_accuracy: 0.1158
# Epoch 17/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9079 - accuracy: 0.1626
# Epoch 17: saving model to checkpoints_freeze\toy-model_1-epoch-17-val_accuracy-0.14.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9081 - accuracy: 0.1625 - val_loss: 1.8494 - val_accuracy: 0.1427
# Epoch 18/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9082 - accuracy: 0.1472
# Epoch 18: saving model to checkpoints_freeze\toy-model_1-epoch-18-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9080 - accuracy: 0.1472 - val_loss: 1.8486 - val_accuracy: 0.1157
# Epoch 19/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9079 - accuracy: 0.1340
# Epoch 19: saving model to checkpoints_freeze\toy-model_1-epoch-19-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1340 - val_loss: 1.8472 - val_accuracy: 0.1336
# Epoch 20/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9077 - accuracy: 0.1684
# Epoch 20: saving model to checkpoints_freeze\toy-model_1-epoch-20-val_accuracy-0.17.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9076 - accuracy: 0.1686 - val_loss: 1.8486 - val_accuracy: 0.1735
# Epoch 21/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9076 - accuracy: 0.1496
# Epoch 21: saving model to checkpoints_freeze\toy-model_1-epoch-21-val_accuracy-0.13.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9076 - accuracy: 0.1496 - val_loss: 1.8476 - val_accuracy: 0.1335
# Epoch 22/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9080 - accuracy: 0.1686
# Epoch 22: saving model to checkpoints_freeze\toy-model_1-epoch-22-val_accuracy-0.14.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1685 - val_loss: 1.8487 - val_accuracy: 0.1429
# Epoch 23/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9077 - accuracy: 0.1507
# Epoch 23: saving model to checkpoints_freeze\toy-model_1-epoch-23-val_accuracy-0.25.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9078 - accuracy: 0.1510 - val_loss: 1.8465 - val_accuracy: 0.2472
# Epoch 24/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9079 - accuracy: 0.1823
# Epoch 24: saving model to checkpoints_freeze\toy-model_1-epoch-24-val_accuracy-0.14.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1823 - val_loss: 1.8483 - val_accuracy: 0.1424
# Epoch 25/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9077 - accuracy: 0.1448
# Epoch 25: saving model to checkpoints_freeze\toy-model_1-epoch-25-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9078 - accuracy: 0.1447 - val_loss: 1.8485 - val_accuracy: 0.1158
# Epoch 26/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9078 - accuracy: 0.1250
# Epoch 26: saving model to checkpoints_freeze\toy-model_1-epoch-26-val_accuracy-0.14.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9077 - accuracy: 0.1250 - val_loss: 1.8478 - val_accuracy: 0.1427
# Epoch 27/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9078 - accuracy: 0.1572
# Epoch 27: saving model to checkpoints_freeze\toy-model_1-epoch-27-val_accuracy-0.25.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9078 - accuracy: 0.1572 - val_loss: 1.8478 - val_accuracy: 0.2475
# Epoch 28/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9074 - accuracy: 0.1629
# Epoch 28: saving model to checkpoints_freeze\toy-model_1-epoch-28-val_accuracy-0.17.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9074 - accuracy: 0.1629 - val_loss: 1.8473 - val_accuracy: 0.1734
# Epoch 29/50
# 895/897 [============================>.] - ETA: 0s - loss: 2.9077 - accuracy: 0.1536
# Epoch 29: saving model to checkpoints_freeze\toy-model_1-epoch-29-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9077 - accuracy: 0.1537 - val_loss: 1.8493 - val_accuracy: 0.1334
# Epoch 30/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9075 - accuracy: 0.1431
# Epoch 30: saving model to checkpoints_freeze\toy-model_1-epoch-30-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9075 - accuracy: 0.1431 - val_loss: 1.8471 - val_accuracy: 0.1735
# Epoch 31/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9078 - accuracy: 0.1599
# Epoch 31: saving model to checkpoints_freeze\toy-model_1-epoch-31-val_accuracy-0.13.h5
# 897/897 [==============================] - 28s 31ms/step - loss: 2.9074 - accuracy: 0.1597 - val_loss: 1.8485 - val_accuracy: 0.1334
# Epoch 32/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9075 - accuracy: 0.1713
# Epoch 32: saving model to checkpoints_freeze\toy-model_1-epoch-32-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9072 - accuracy: 0.1714 - val_loss: 1.8482 - val_accuracy: 0.1733
# Epoch 33/50
# 895/897 [============================>.] - ETA: 0s - loss: 2.9078 - accuracy: 0.1621
# Epoch 33: saving model to checkpoints_freeze\toy-model_1-epoch-33-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9075 - accuracy: 0.1621 - val_loss: 1.8493 - val_accuracy: 0.1335
# Epoch 34/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9081 - accuracy: 0.1578
# Epoch 34: saving model to checkpoints_freeze\toy-model_1-epoch-34-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9081 - accuracy: 0.1578 - val_loss: 1.8494 - val_accuracy: 0.1159
# Epoch 35/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9073 - accuracy: 0.1348
# Epoch 35: saving model to checkpoints_freeze\toy-model_1-epoch-35-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9073 - accuracy: 0.1348 - val_loss: 1.8478 - val_accuracy: 0.1159
# Epoch 36/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9073 - accuracy: 0.1611
# Epoch 36: saving model to checkpoints_freeze\toy-model_1-epoch-36-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9073 - accuracy: 0.1611 - val_loss: 1.8481 - val_accuracy: 0.1716
# Epoch 37/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9072 - accuracy: 0.1642
# Epoch 37: saving model to checkpoints_freeze\toy-model_1-epoch-37-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9073 - accuracy: 0.1645 - val_loss: 1.8483 - val_accuracy: 0.1717
# Epoch 38/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9079 - accuracy: 0.1502
# Epoch 38: saving model to checkpoints_freeze\toy-model_1-epoch-38-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9077 - accuracy: 0.1502 - val_loss: 1.8491 - val_accuracy: 0.1737
# Epoch 39/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9078 - accuracy: 0.1375
# Epoch 39: saving model to checkpoints_freeze\toy-model_1-epoch-39-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9078 - accuracy: 0.1375 - val_loss: 1.8475 - val_accuracy: 0.1735
# Epoch 40/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9073 - accuracy: 0.1583
# Epoch 40: saving model to checkpoints_freeze\toy-model_1-epoch-40-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9074 - accuracy: 0.1583 - val_loss: 1.8468 - val_accuracy: 0.1738
# Epoch 41/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9079 - accuracy: 0.1665
# Epoch 41: saving model to checkpoints_freeze\toy-model_1-epoch-41-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1665 - val_loss: 1.8461 - val_accuracy: 0.1737
# Epoch 42/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9071 - accuracy: 0.1800
# Epoch 42: saving model to checkpoints_freeze\toy-model_1-epoch-42-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9071 - accuracy: 0.1800 - val_loss: 1.8482 - val_accuracy: 0.1335
# Epoch 43/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9079 - accuracy: 0.1374
# Epoch 43: saving model to checkpoints_freeze\toy-model_1-epoch-43-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1374 - val_loss: 1.8473 - val_accuracy: 0.1332
# Epoch 44/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9077 - accuracy: 0.1664
# Epoch 44: saving model to checkpoints_freeze\toy-model_1-epoch-44-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9077 - accuracy: 0.1664 - val_loss: 1.8474 - val_accuracy: 0.1159
# Epoch 45/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9078 - accuracy: 0.1867
# Epoch 45: saving model to checkpoints_freeze\toy-model_1-epoch-45-val_accuracy-0.13.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9078 - accuracy: 0.1867 - val_loss: 1.8499 - val_accuracy: 0.1334
# Epoch 46/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9079 - accuracy: 0.1365
# Epoch 46: saving model to checkpoints_freeze\toy-model_1-epoch-46-val_accuracy-0.14.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9079 - accuracy: 0.1365 - val_loss: 1.8495 - val_accuracy: 0.1429
# Epoch 47/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9075 - accuracy: 0.1618
# Epoch 47: saving model to checkpoints_freeze\toy-model_1-epoch-47-val_accuracy-0.12.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9075 - accuracy: 0.1618 - val_loss: 1.8489 - val_accuracy: 0.1157
# Epoch 48/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9072 - accuracy: 0.1532
# Epoch 48: saving model to checkpoints_freeze\toy-model_1-epoch-48-val_accuracy-0.17.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9074 - accuracy: 0.1533 - val_loss: 1.8478 - val_accuracy: 0.1738
# Epoch 49/50
# 896/897 [============================>.] - ETA: 0s - loss: 2.9075 - accuracy: 0.1558
# Epoch 49: saving model to checkpoints_freeze\toy-model_1-epoch-49-val_accuracy-0.25.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9075 - accuracy: 0.1558 - val_loss: 1.8465 - val_accuracy: 0.2468
# Epoch 50/50
# 897/897 [==============================] - ETA: 0s - loss: 2.9076 - accuracy: 0.1703
# Epoch 50: saving model to checkpoints_freeze\toy-model_1-epoch-50-val_accuracy-0.25.h5
# 897/897 [==============================] - 27s 30ms/step - loss: 2.9076 - accuracy: 0.1703 - val_loss: 1.8465 - val_accuracy: 0.2473

# %%
save_model = model.save('Model9_50e.h5')

# %% [markdown]
# # Model Evaluation

# %%
model = load_model('Model9_50e.h5')

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(valid_generator)
# Out:
# 898/898 [==============================] - 24s 27ms/step - loss: 1.0335 - accuracy: 0.6111
# 225/225 [==============================] - 3s 14ms/step - loss: 1.0572 - accuracy: 0.6106

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(valid_generator.n // batch_size):
    test_img, test_lbl = valid_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 1/1 [==============================] - 1s 1s/step
# Accuracy =  0.5625
# 1/1 [==============================] - 0s 142ms/step
# Accuracy =  0.0625

# %%
total_acc = 0
num_batches = valid_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = valid_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.2472

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(valid_generator.n // batch_size):
    test_img, test_lbl = valid_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = valid_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{valid_generator.n} acc: {class_acc:.1f}")
# Out:
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 161ms/step
# Accuracy: 24.720982142857142
# angry 954/7178 acc: 0.0
# disgust 110/7178 acc: 0.0
# fear 1024/7178 acc: 0.0
# happy 1772/7178 acc: 100.0
# neutral 1232/7178 acc: 0.0
# sad 1245/7178 acc: 0.0
# surprise 831/7178 acc: 0.0

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = valid_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{valid_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 24.720982142857142
# angry 954/7178 acc: 0.0
# disgust 110/7178 acc: 0.0
# fear 1024/7178 acc: 0.0
# happy 1772/7178 acc: 100.0
# neutral 1232/7178 acc: 0.0
# sad 1245/7178 acc: 0.0
# surprise 831/7178 acc: 0.0

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(valid_generator.n // batch_size):
    test_img, test_lbl = valid_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = valid_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{valid_generator.n} acc: {class_acc:.1f}")

# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# Accuracy: 61.10491071428571
# angry 956/7178 acc: 57.9
# disgust 111/7178 acc: 47.7
# fear 1024/7178 acc: 23.3
# happy 1773/7178 acc: 80.4
# neutral 1229/7178 acc: 57.9
# sad 1244/7178 acc: 56.0
# surprise 831/7178 acc: 84.4
#               precision    recall  f1-score   support
#
#        angry       0.49      0.58      0.53       956
#      disgust       0.57      0.48      0.52       111
#         fear       0.57      0.23      0.33      1024
#        happy       0.85      0.80      0.83      1773
#      neutral       0.57      0.58      0.57      1229
#          sad       0.46      0.56      0.50      1244
#     surprise       0.65      0.84      0.73       831
#
#     accuracy                           0.61      7168
#    macro avg       0.59      0.58      0.57      7168
# weighted avg       0.62      0.61      0.60      7168

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.49      0.58      0.53       956
#      disgust       0.57      0.48      0.52       111
#         fear       0.57      0.23      0.33      1024
#        happy       0.85      0.80      0.83      1773
#      neutral       0.57      0.58      0.57      1229
#          sad       0.46      0.56      0.50      1244
#     surprise       0.65      0.84      0.73       831
#
#     accuracy                           0.61      7168
#    macro avg       0.59      0.58      0.57      7168
# weighted avg       0.62      0.61      0.60      7168

# %%
#Generate a batch of images
test_img, test_lbl = valid_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 1/1 [==============================] - 0s 137ms/step
# Accuracy =  0.5

# %%
from collections import defaultdict

# Initialize a dictionary to keep track of correct and incorrect predictions for each class
class_stats = defaultdict(lambda: {'correct': 0, 'incorrect': 0})

test_img, test_lbl = valid_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

for i in range(len(predictions)):
    class_name = class_labels[test_labels[i]]
    if predictions[i] == test_labels[i]:
        class_stats[class_name]['correct'] += 1
    else:
        class_stats[class_name]['incorrect'] += 1

total_correct = sum([stats['correct'] for stats in class_stats.values()])
total_incorrect = sum([stats['incorrect'] for stats in class_stats.values()])
total_predictions = total_correct + total_incorrect
accuracy_percentage = 100 * total_correct / total_predictions

for class_name, stats in class_stats.items():
    print(f"Class {class_name}:")
    print(f"  Correct predictions: {stats['correct']}")
    print(f"  Incorrect predictions: {stats['incorrect']}")

print(f"/nTotal number of correct predictions: {total_correct}")
print(f"Total number of incorrect predictions: {total_incorrect}")
print(f"Percentage of correct predictions: {accuracy_percentage:.2f}%")
# Out:
# 1/1 [==============================] - 0s 119ms/step
# Class Happy:
#   Correct predictions: 6
#   Incorrect predictions: 2
# Class Neutral:
#   Correct predictions: 6
#   Incorrect predictions: 5
# Class Angry:
#   Correct predictions: 2
#   Incorrect predictions: 1
# Class Sad:
#   Correct predictions: 3
#   Incorrect predictions: 1
# Class Fear:
#   Correct predictions: 1
#   Incorrect predictions: 1
# Class Surprise:
#   Correct predictions: 4
#   Incorrect predictions: 0
#
# Total number of correct predictions: 22
# Total number of incorrect predictions: 10
# Percentage of correct predictions: 68.75%

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Predicted emotion class: neutral, probability: 0.5881974697113037
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: surprise, probability: 0.9420915246009827
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: surprise, probability: 0.6290400624275208
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: neutral, probability: 0.39827385544776917
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: happy, probability: 0.9912444949150085
# 1/1 [==============================] - 0s 21ms/step
# Predicted emotion class: angry, probability: 0.9502969980239868
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: angry, probability: 0.865021288394928
# 1/1 [==============================] - 0s 23ms/step
# Predicted emotion class: fear, probability: 0.2931903302669525
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: sad, probability: 0.4253530502319336
