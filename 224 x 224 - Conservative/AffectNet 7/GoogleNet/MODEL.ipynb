# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Dense, concatenate, AveragePooling2D, Flatten
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/AffectNet/DATASET/AffectNet/train/'
validation_data_dir = r'C:/Users/darks/Desktop/AffectNet/DATASET/AffectNet/test/'

# %%
IMG_HEIGHT = 224
IMG_WIDTH = 224
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 20761 images belonging to 7 classes.
# Found 5160 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2691</td>
#       <td>1969</td>
#       <td>2628</td>
#       <td>3831</td>
#       <td>3906</td>
#       <td>2540</td>
#       <td>3196</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>662</td>
#       <td>494</td>
#       <td>661</td>
#       <td>960</td>
#       <td>972</td>
#       <td>624</td>
#       <td>787</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 20761
# 5160

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # PERFECT CODE

# %%
def inception_module(x, filters):
    tower_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
    tower_1 = Conv2D(filters[1], (3, 3), padding='same', activation='relu')(tower_1)
    
    tower_2 = Conv2D(filters[2], (1, 1), padding='same', activation='relu')(x)
    tower_2 = Conv2D(filters[3], (5, 5), padding='same', activation='relu')(tower_2)
    
    tower_3 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    tower_3 = Conv2D(filters[4], (1, 1), padding='same', activation='relu')(tower_3)
    
    tower_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(x)
    
    output = concatenate([tower_1, tower_2, tower_3, tower_4], axis=3)
    return output

# Define GoogLeNet model
def GoogLeNet(input_shape, num_classes):
    input_img = Input(shape=input_shape)
    
    # Stage 1: Convolution and MaxPooling
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_img)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Stage 2: Convolution and MaxPooling
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Stage 3: Inception modules
    x = inception_module(x, [64, 96, 128, 16, 32, 32])
    x = inception_module(x, [128, 128, 192, 32, 96, 64])
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Stage 4: Inception modules
    x = inception_module(x, [192, 96, 208, 16, 48, 64])
    x = inception_module(x, [160, 112, 224, 24, 64, 64])
    x = inception_module(x, [128, 128, 256, 24, 64, 64])
    x = inception_module(x, [112, 144, 288, 32, 64, 64])
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    # Stage 5: Inception modules
    x = inception_module(x, [256, 160, 320, 32, 128, 128])
    x = inception_module(x, [384, 192, 384, 48, 128, 128])
    
    # Stage 6: Final layers
    x = AveragePooling2D((7, 7), strides=(1, 1), padding='valid')(x)
    x = Flatten()(x)
    x = Dropout(0.4)(x)
    x = Dense(num_classes, activation='softmax')(x)
    
    # Create model
    model = Model(inputs=input_img, outputs=x)
    return model

# %%
# Specify input shape and number of classes
input_shape = (224, 224, 3)
num_classes = 7

# Open the strategy scope
with strategy.scope():
    model = GoogLeNet(input_shape, num_classes)
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 320)  0          ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 320)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 224)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 160)  36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 224)  50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 224)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 112)  161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 24)   134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 64)   14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 264)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 128)  33920       ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 256)  67840       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 264)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 24)   153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 64)   16960       ['max_pooling2d_7[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   16960       ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 280)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 112)  31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 288)  80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 280)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 144)  145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 64)   17984       ['max_pooling2d_8[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 304)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 320)  97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 304)  0          ['concatenate_5[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 160)  368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  39040       ['max_pooling2d_9[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 128)  39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 448)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 256)    114944      ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 320)    143680      ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 448)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_10[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 496)   0           ['concatenate_8[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 496)          0           ['average_pooling2d[0][0]']
#
#  dropout (Dropout)              (None, 496)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,916,999
# Trainable params: 5,916,999
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images, 3) for class_id, num_images in counter.items()} 
print(class_weights)    

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 1.451505016722408, 1: 1.9837480954799391, 2: 1.4863013698630136, 3: 1.0195771339075959, 4: 1.0, 5: 1.5377952755905513, 6: 1.2221526908635796}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 324/324 [==============================] - ETA: 0s - loss: 2.4616 - accuracy: 0.2032
# Epoch 1: val_accuracy improved from -inf to 0.25547, saving model to best_model.h5
# 324/324 [==============================] - 242s 687ms/step - loss: 2.4616 - accuracy: 0.2032 - val_loss: 1.7278 - val_accuracy: 0.2555 - lr: 1.0000e-04
# Epoch 2/400
# 324/324 [==============================] - ETA: 0s - loss: 2.3327 - accuracy: 0.2540
# Epoch 2: val_accuracy improved from 0.25547 to 0.28438, saving model to best_model.h5
# 324/324 [==============================] - 224s 690ms/step - loss: 2.3327 - accuracy: 0.2540 - val_loss: 1.6465 - val_accuracy: 0.2844 - lr: 1.0000e-04
# Epoch 3/400
# 324/324 [==============================] - ETA: 0s - loss: 2.2675 - accuracy: 0.2760
# Epoch 3: val_accuracy did not improve from 0.28438
# 324/324 [==============================] - 224s 691ms/step - loss: 2.2675 - accuracy: 0.2760 - val_loss: 1.6532 - val_accuracy: 0.2791 - lr: 1.0000e-04
# Epoch 4/400
# 324/324 [==============================] - ETA: 0s - loss: 2.1702 - accuracy: 0.3100
# Epoch 4: val_accuracy improved from 0.28438 to 0.32715, saving model to best_model.h5
# 324/324 [==============================] - 223s 688ms/step - loss: 2.1702 - accuracy: 0.3100 - val_loss: 1.5902 - val_accuracy: 0.3271 - lr: 1.0000e-04
# Epoch 5/400
# 324/324 [==============================] - ETA: 0s - loss: 2.0736 - accuracy: 0.3409
# Epoch 5: val_accuracy did not improve from 0.32715
# 324/324 [==============================] - 222s 683ms/step - loss: 2.0736 - accuracy: 0.3409 - val_loss: 1.7497 - val_accuracy: 0.2846 - lr: 1.0000e-04
# Epoch 6/400
# 324/324 [==============================] - ETA: 0s - loss: 2.0058 - accuracy: 0.3602
# Epoch 6: val_accuracy improved from 0.32715 to 0.39590, saving model to best_model.h5
# 324/324 [==============================] - 222s 685ms/step - loss: 2.0058 - accuracy: 0.3602 - val_loss: 1.4197 - val_accuracy: 0.3959 - lr: 1.0000e-04
# Epoch 7/400
# 324/324 [==============================] - ETA: 0s - loss: 1.9411 - accuracy: 0.3960
# Epoch 7: val_accuracy improved from 0.39590 to 0.41934, saving model to best_model.h5
# 324/324 [==============================] - 221s 683ms/step - loss: 1.9411 - accuracy: 0.3960 - val_loss: 1.4064 - val_accuracy: 0.4193 - lr: 1.0000e-04
# Epoch 8/400
# 324/324 [==============================] - ETA: 0s - loss: 1.8661 - accuracy: 0.4314
# Epoch 8: val_accuracy improved from 0.41934 to 0.47422, saving model to best_model.h5
# 324/324 [==============================] - 226s 696ms/step - loss: 1.8661 - accuracy: 0.4314 - val_loss: 1.3019 - val_accuracy: 0.4742 - lr: 1.0000e-04
# Epoch 9/400
# 324/324 [==============================] - ETA: 0s - loss: 1.7756 - accuracy: 0.4803
# Epoch 9: val_accuracy improved from 0.47422 to 0.48613, saving model to best_model.h5
# 324/324 [==============================] - 223s 686ms/step - loss: 1.7756 - accuracy: 0.4803 - val_loss: 1.2628 - val_accuracy: 0.4861 - lr: 1.0000e-04
# Epoch 10/400
# 324/324 [==============================] - ETA: 0s - loss: 1.7132 - accuracy: 0.5009
# Epoch 10: val_accuracy improved from 0.48613 to 0.49590, saving model to best_model.h5
# 324/324 [==============================] - 219s 676ms/step - loss: 1.7132 - accuracy: 0.5009 - val_loss: 1.2259 - val_accuracy: 0.4959 - lr: 1.0000e-04
# Epoch 11/400
# 324/324 [==============================] - ETA: 0s - loss: 1.6455 - accuracy: 0.5265
# Epoch 11: val_accuracy improved from 0.49590 to 0.52461, saving model to best_model.h5
# 324/324 [==============================] - 219s 676ms/step - loss: 1.6455 - accuracy: 0.5265 - val_loss: 1.1609 - val_accuracy: 0.5246 - lr: 1.0000e-04
# Epoch 12/400
# 324/324 [==============================] - ETA: 0s - loss: 1.6129 - accuracy: 0.5385
# Epoch 12: val_accuracy improved from 0.52461 to 0.54648, saving model to best_model.h5
# 324/324 [==============================] - 218s 671ms/step - loss: 1.6129 - accuracy: 0.5385 - val_loss: 1.1554 - val_accuracy: 0.5465 - lr: 1.0000e-04
# Epoch 13/400
# 324/324 [==============================] - ETA: 0s - loss: 1.5806 - accuracy: 0.5508
# Epoch 13: val_accuracy improved from 0.54648 to 0.58594, saving model to best_model.h5
# 324/324 [==============================] - 214s 659ms/step - loss: 1.5806 - accuracy: 0.5508 - val_loss: 1.0355 - val_accuracy: 0.5859 - lr: 1.0000e-04
# Epoch 14/400
# 324/324 [==============================] - ETA: 0s - loss: 1.5423 - accuracy: 0.5604
# Epoch 14: val_accuracy did not improve from 0.58594
# 324/324 [==============================] - 215s 664ms/step - loss: 1.5423 - accuracy: 0.5604 - val_loss: 1.0597 - val_accuracy: 0.5752 - lr: 1.0000e-04
# Epoch 15/400
# 324/324 [==============================] - ETA: 0s - loss: 1.5152 - accuracy: 0.5685
# Epoch 15: val_accuracy improved from 0.58594 to 0.58770, saving model to best_model.h5
# 324/324 [==============================] - 217s 671ms/step - loss: 1.5152 - accuracy: 0.5685 - val_loss: 1.0222 - val_accuracy: 0.5877 - lr: 1.0000e-04
# Epoch 16/400
# 324/324 [==============================] - ETA: 0s - loss: 1.4939 - accuracy: 0.5796
# Epoch 16: val_accuracy did not improve from 0.58770
# 324/324 [==============================] - 218s 674ms/step - loss: 1.4939 - accuracy: 0.5796 - val_loss: 1.0395 - val_accuracy: 0.5852 - lr: 1.0000e-04
# Epoch 17/400
# 324/324 [==============================] - ETA: 0s - loss: 1.4608 - accuracy: 0.5911
# Epoch 17: val_accuracy improved from 0.58770 to 0.59336, saving model to best_model.h5
# 324/324 [==============================] - 217s 669ms/step - loss: 1.4608 - accuracy: 0.5911 - val_loss: 1.0224 - val_accuracy: 0.5934 - lr: 1.0000e-04
# Epoch 18/400
# 324/324 [==============================] - ETA: 0s - loss: 1.4329 - accuracy: 0.5946
# Epoch 18: val_accuracy did not improve from 0.59336
# 324/324 [==============================] - 219s 675ms/step - loss: 1.4329 - accuracy: 0.5946 - val_loss: 1.0439 - val_accuracy: 0.5863 - lr: 1.0000e-04
# Epoch 19/400
# 324/324 [==============================] - ETA: 0s - loss: 1.4135 - accuracy: 0.6035
# Epoch 19: val_accuracy did not improve from 0.59336
# 324/324 [==============================] - 220s 678ms/step - loss: 1.4135 - accuracy: 0.6035 - val_loss: 1.0366 - val_accuracy: 0.5840 - lr: 1.0000e-04
# Epoch 20/400
# 324/324 [==============================] - ETA: 0s - loss: 1.3977 - accuracy: 0.6086
# Epoch 20: val_accuracy did not improve from 0.59336
# 324/324 [==============================] - 216s 667ms/step - loss: 1.3977 - accuracy: 0.6086 - val_loss: 1.0709 - val_accuracy: 0.5744 - lr: 1.0000e-04
# Epoch 21/400
# 324/324 [==============================] - ETA: 0s - loss: 1.3830 - accuracy: 0.6116
# Epoch 21: val_accuracy did not improve from 0.59336
# 324/324 [==============================] - 219s 674ms/step - loss: 1.3830 - accuracy: 0.6116 - val_loss: 1.0740 - val_accuracy: 0.5852 - lr: 1.0000e-04
# Epoch 22/400
# 324/324 [==============================] - ETA: 0s - loss: 1.3285 - accuracy: 0.6272
# Epoch 22: val_accuracy improved from 0.59336 to 0.60020, saving model to best_model.h5
# 324/324 [==============================] - 214s 660ms/step - loss: 1.3285 - accuracy: 0.6272 - val_loss: 1.0405 - val_accuracy: 0.6002 - lr: 1.0000e-04
# Epoch 23/400
# 324/324 [==============================] - ETA: 0s - loss: 1.3259 - accuracy: 0.6280
# Epoch 23: val_accuracy did not improve from 0.60020
# 324/324 [==============================] - 215s 662ms/step - loss: 1.3259 - accuracy: 0.6280 - val_loss: 1.0636 - val_accuracy: 0.5840 - lr: 1.0000e-04
# Epoch 24/400
# 324/324 [==============================] - ETA: 0s - loss: 1.3070 - accuracy: 0.6355
# Epoch 24: val_accuracy did not improve from 0.60020
# 324/324 [==============================] - 212s 652ms/step - loss: 1.3070 - accuracy: 0.6355 - val_loss: 1.0425 - val_accuracy: 0.5957 - lr: 1.0000e-04
# Epoch 25/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2870 - accuracy: 0.6411
# Epoch 25: val_accuracy improved from 0.60020 to 0.62988, saving model to best_model.h5
# 324/324 [==============================] - 210s 648ms/step - loss: 1.2870 - accuracy: 0.6411 - val_loss: 0.9528 - val_accuracy: 0.6299 - lr: 1.0000e-04
# Epoch 26/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2671 - accuracy: 0.6493
# Epoch 26: val_accuracy improved from 0.62988 to 0.63730, saving model to best_model.h5
# 324/324 [==============================] - 210s 648ms/step - loss: 1.2671 - accuracy: 0.6493 - val_loss: 0.8962 - val_accuracy: 0.6373 - lr: 1.0000e-04
# Epoch 27/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2549 - accuracy: 0.6522
# Epoch 27: val_accuracy did not improve from 0.63730
# 324/324 [==============================] - 209s 645ms/step - loss: 1.2549 - accuracy: 0.6522 - val_loss: 0.9769 - val_accuracy: 0.6246 - lr: 1.0000e-04
# Epoch 28/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2355 - accuracy: 0.6548
# Epoch 28: val_accuracy improved from 0.63730 to 0.64316, saving model to best_model.h5
# 324/324 [==============================] - 210s 649ms/step - loss: 1.2355 - accuracy: 0.6548 - val_loss: 0.9004 - val_accuracy: 0.6432 - lr: 1.0000e-04
# Epoch 29/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2207 - accuracy: 0.6593
# Epoch 29: val_accuracy improved from 0.64316 to 0.64590, saving model to best_model.h5
# 324/324 [==============================] - 208s 643ms/step - loss: 1.2207 - accuracy: 0.6593 - val_loss: 0.9420 - val_accuracy: 0.6459 - lr: 1.0000e-04
# Epoch 30/400
# 324/324 [==============================] - ETA: 0s - loss: 1.2125 - accuracy: 0.6579
# Epoch 30: val_accuracy improved from 0.64590 to 0.65898, saving model to best_model.h5
# 324/324 [==============================] - 209s 644ms/step - loss: 1.2125 - accuracy: 0.6579 - val_loss: 0.8781 - val_accuracy: 0.6590 - lr: 1.0000e-04
# Epoch 31/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1892 - accuracy: 0.6684
# Epoch 31: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 204s 629ms/step - loss: 1.1892 - accuracy: 0.6684 - val_loss: 1.0478 - val_accuracy: 0.6043 - lr: 1.0000e-04
# Epoch 32/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1878 - accuracy: 0.6728
# Epoch 32: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 204s 628ms/step - loss: 1.1878 - accuracy: 0.6728 - val_loss: 0.9350 - val_accuracy: 0.6404 - lr: 1.0000e-04
# Epoch 33/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1624 - accuracy: 0.6773
# Epoch 33: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 204s 630ms/step - loss: 1.1624 - accuracy: 0.6773 - val_loss: 0.8737 - val_accuracy: 0.6537 - lr: 1.0000e-04
# Epoch 34/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1576 - accuracy: 0.6800
# Epoch 34: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 204s 629ms/step - loss: 1.1576 - accuracy: 0.6800 - val_loss: 0.9846 - val_accuracy: 0.6416 - lr: 1.0000e-04
# Epoch 35/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1408 - accuracy: 0.6832
# Epoch 35: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 204s 629ms/step - loss: 1.1408 - accuracy: 0.6832 - val_loss: 0.9909 - val_accuracy: 0.6143 - lr: 1.0000e-04
# Epoch 36/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1237 - accuracy: 0.6867
# Epoch 36: val_accuracy did not improve from 0.65898
# 324/324 [==============================] - 207s 637ms/step - loss: 1.1237 - accuracy: 0.6867 - val_loss: 0.9227 - val_accuracy: 0.6484 - lr: 1.0000e-04
# Epoch 37/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1200 - accuracy: 0.6900
# Epoch 37: val_accuracy improved from 0.65898 to 0.67520, saving model to best_model.h5
# 324/324 [==============================] - 210s 647ms/step - loss: 1.1200 - accuracy: 0.6900 - val_loss: 0.8462 - val_accuracy: 0.6752 - lr: 1.0000e-04
# Epoch 38/400
# 324/324 [==============================] - ETA: 0s - loss: 1.1187 - accuracy: 0.6955
# Epoch 38: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 209s 645ms/step - loss: 1.1187 - accuracy: 0.6955 - val_loss: 0.8451 - val_accuracy: 0.6752 - lr: 1.0000e-04
# Epoch 39/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.6938
# Epoch 39: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 208s 643ms/step - loss: 1.0987 - accuracy: 0.6938 - val_loss: 0.8804 - val_accuracy: 0.6619 - lr: 1.0000e-04
# Epoch 40/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0771 - accuracy: 0.7027
# Epoch 40: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 211s 651ms/step - loss: 1.0771 - accuracy: 0.7027 - val_loss: 0.8828 - val_accuracy: 0.6541 - lr: 1.0000e-04
# Epoch 41/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0631 - accuracy: 0.7064
# Epoch 41: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 214s 661ms/step - loss: 1.0631 - accuracy: 0.7064 - val_loss: 0.9278 - val_accuracy: 0.6572 - lr: 1.0000e-04
# Epoch 42/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0576 - accuracy: 0.7112
# Epoch 42: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 213s 656ms/step - loss: 1.0576 - accuracy: 0.7112 - val_loss: 0.8355 - val_accuracy: 0.6709 - lr: 1.0000e-04
# Epoch 43/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0588 - accuracy: 0.7120
# Epoch 43: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 213s 656ms/step - loss: 1.0588 - accuracy: 0.7120 - val_loss: 0.8780 - val_accuracy: 0.6746 - lr: 1.0000e-04
# Epoch 44/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0502 - accuracy: 0.7133
# Epoch 44: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 211s 651ms/step - loss: 1.0502 - accuracy: 0.7133 - val_loss: 0.9489 - val_accuracy: 0.6463 - lr: 1.0000e-04
# Epoch 45/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0283 - accuracy: 0.7158
# Epoch 45: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 214s 660ms/step - loss: 1.0283 - accuracy: 0.7158 - val_loss: 0.9002 - val_accuracy: 0.6727 - lr: 1.0000e-04
# Epoch 46/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0208 - accuracy: 0.7215
# Epoch 46: val_accuracy did not improve from 0.67520
# 324/324 [==============================] - 210s 649ms/step - loss: 1.0208 - accuracy: 0.7215 - val_loss: 0.8800 - val_accuracy: 0.6678 - lr: 1.0000e-04
# Epoch 47/400
# 324/324 [==============================] - ETA: 0s - loss: 1.0075 - accuracy: 0.7231
# Epoch 47: val_accuracy improved from 0.67520 to 0.68770, saving model to best_model.h5
# 324/324 [==============================] - 211s 650ms/step - loss: 1.0075 - accuracy: 0.7231 - val_loss: 0.8528 - val_accuracy: 0.6877 - lr: 1.0000e-04
# Epoch 48/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9928 - accuracy: 0.7263
# Epoch 48: val_accuracy did not improve from 0.68770
# 324/324 [==============================] - 213s 658ms/step - loss: 0.9928 - accuracy: 0.7263 - val_loss: 0.9017 - val_accuracy: 0.6777 - lr: 1.0000e-04
# Epoch 49/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9908 - accuracy: 0.7284
# Epoch 49: val_accuracy did not improve from 0.68770
# 324/324 [==============================] - 208s 641ms/step - loss: 0.9908 - accuracy: 0.7284 - val_loss: 0.9056 - val_accuracy: 0.6816 - lr: 1.0000e-04
# Epoch 50/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9690 - accuracy: 0.7351
# Epoch 50: val_accuracy improved from 0.68770 to 0.68828, saving model to best_model.h5
# 324/324 [==============================] - 207s 640ms/step - loss: 0.9690 - accuracy: 0.7351 - val_loss: 0.8507 - val_accuracy: 0.6883 - lr: 1.0000e-04
# Epoch 51/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9710 - accuracy: 0.7330
# Epoch 51: val_accuracy improved from 0.68828 to 0.69492, saving model to best_model.h5
# 324/324 [==============================] - 207s 638ms/step - loss: 0.9710 - accuracy: 0.7330 - val_loss: 0.7924 - val_accuracy: 0.6949 - lr: 1.0000e-04
# Epoch 52/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9582 - accuracy: 0.7353
# Epoch 52: val_accuracy did not improve from 0.69492
# 324/324 [==============================] - 206s 634ms/step - loss: 0.9582 - accuracy: 0.7353 - val_loss: 0.8544 - val_accuracy: 0.6820 - lr: 1.0000e-04
# Epoch 53/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9546 - accuracy: 0.7394
# Epoch 53: val_accuracy did not improve from 0.69492
# 324/324 [==============================] - 208s 642ms/step - loss: 0.9546 - accuracy: 0.7394 - val_loss: 0.8591 - val_accuracy: 0.6799 - lr: 1.0000e-04
# Epoch 54/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9433 - accuracy: 0.7382
# Epoch 54: val_accuracy did not improve from 0.69492
# 324/324 [==============================] - 215s 662ms/step - loss: 0.9433 - accuracy: 0.7382 - val_loss: 0.8545 - val_accuracy: 0.6936 - lr: 1.0000e-04
# Epoch 55/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9397 - accuracy: 0.7430
# Epoch 55: val_accuracy improved from 0.69492 to 0.69844, saving model to best_model.h5
# 324/324 [==============================] - 210s 649ms/step - loss: 0.9397 - accuracy: 0.7430 - val_loss: 0.8252 - val_accuracy: 0.6984 - lr: 1.0000e-04
# Epoch 56/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9399 - accuracy: 0.7402
# Epoch 56: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 212s 654ms/step - loss: 0.9399 - accuracy: 0.7402 - val_loss: 0.9156 - val_accuracy: 0.6684 - lr: 1.0000e-04
# Epoch 57/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9087 - accuracy: 0.7522
# Epoch 57: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 211s 651ms/step - loss: 0.9087 - accuracy: 0.7522 - val_loss: 0.9181 - val_accuracy: 0.6811 - lr: 1.0000e-04
# Epoch 58/400
# 324/324 [==============================] - ETA: 0s - loss: 0.9016 - accuracy: 0.7543
# Epoch 58: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 210s 647ms/step - loss: 0.9016 - accuracy: 0.7543 - val_loss: 0.8579 - val_accuracy: 0.6830 - lr: 1.0000e-04
# Epoch 59/400
# 324/324 [==============================] - ETA: 0s - loss: 0.8919 - accuracy: 0.7563
# Epoch 59: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 212s 653ms/step - loss: 0.8919 - accuracy: 0.7563 - val_loss: 0.8974 - val_accuracy: 0.6670 - lr: 1.0000e-04
# Epoch 60/400
# 324/324 [==============================] - ETA: 0s - loss: 0.8930 - accuracy: 0.7552
# Epoch 60: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 208s 643ms/step - loss: 0.8930 - accuracy: 0.7552 - val_loss: 0.8665 - val_accuracy: 0.6914 - lr: 1.0000e-04
# Epoch 61/400
# 324/324 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.7594
# Epoch 61: val_accuracy did not improve from 0.69844
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 324/324 [==============================] - 207s 639ms/step - loss: 0.8811 - accuracy: 0.7594 - val_loss: 0.8554 - val_accuracy: 0.6924 - lr: 1.0000e-04
# Epoch 62/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7997 - accuracy: 0.7823
# Epoch 62: val_accuracy did not improve from 0.69844
# 324/324 [==============================] - 205s 634ms/step - loss: 0.7997 - accuracy: 0.7823 - val_loss: 0.8672 - val_accuracy: 0.6980 - lr: 5.0000e-05
# Epoch 63/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7883 - accuracy: 0.7840
# Epoch 63: val_accuracy improved from 0.69844 to 0.70527, saving model to best_model.h5
# 324/324 [==============================] - 205s 633ms/step - loss: 0.7883 - accuracy: 0.7840 - val_loss: 0.8420 - val_accuracy: 0.7053 - lr: 5.0000e-05
# Epoch 64/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.7897
# Epoch 64: val_accuracy improved from 0.70527 to 0.71465, saving model to best_model.h5
# 324/324 [==============================] - 206s 636ms/step - loss: 0.7648 - accuracy: 0.7897 - val_loss: 0.8267 - val_accuracy: 0.7146 - lr: 5.0000e-05
# Epoch 65/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7624 - accuracy: 0.7917
# Epoch 65: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 206s 636ms/step - loss: 0.7624 - accuracy: 0.7917 - val_loss: 0.8719 - val_accuracy: 0.6947 - lr: 5.0000e-05
# Epoch 66/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.7966
# Epoch 66: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 209s 645ms/step - loss: 0.7521 - accuracy: 0.7966 - val_loss: 0.8983 - val_accuracy: 0.6926 - lr: 5.0000e-05
# Epoch 67/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7459 - accuracy: 0.7963
# Epoch 67: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 203s 625ms/step - loss: 0.7459 - accuracy: 0.7963 - val_loss: 0.8842 - val_accuracy: 0.7012 - lr: 5.0000e-05
# Epoch 68/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7404 - accuracy: 0.7985
# Epoch 68: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 204s 629ms/step - loss: 0.7404 - accuracy: 0.7985 - val_loss: 0.9147 - val_accuracy: 0.6949 - lr: 5.0000e-05
# Epoch 69/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7240 - accuracy: 0.8002
# Epoch 69: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 202s 624ms/step - loss: 0.7240 - accuracy: 0.8002 - val_loss: 0.9306 - val_accuracy: 0.6971 - lr: 5.0000e-05
# Epoch 70/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7204 - accuracy: 0.8026
# Epoch 70: val_accuracy did not improve from 0.71465
# 324/324 [==============================] - 201s 620ms/step - loss: 0.7204 - accuracy: 0.8026 - val_loss: 0.9208 - val_accuracy: 0.6918 - lr: 5.0000e-05
# Epoch 71/400
# 324/324 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.8036
# Epoch 71: val_accuracy did not improve from 0.71465
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 324/324 [==============================] - 201s 620ms/step - loss: 0.7191 - accuracy: 0.8036 - val_loss: 0.9280 - val_accuracy: 0.6930 - lr: 5.0000e-05
# Epoch 71: early stopping

# %%
save_model = model.save('GoogLeNet1.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model('GoogLeNet1.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 320)  0          ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 320)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 224)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 160)  36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 224)  50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 224)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 112)  161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 24)   134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 64)   14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 264)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 128)  33920       ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 256)  67840       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 264)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 24)   153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 64)   16960       ['max_pooling2d_7[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   16960       ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 280)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 112)  31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 288)  80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 280)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 144)  145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 64)   17984       ['max_pooling2d_8[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 304)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 320)  97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 304)  0          ['concatenate_5[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 160)  368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  39040       ['max_pooling2d_9[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 128)  39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 448)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 256)    114944      ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 320)    143680      ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 448)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_10[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 496)   0           ['concatenate_8[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 496)          0           ['average_pooling2d[0][0]']
#
#  dropout (Dropout)              (None, 496)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,916,999
# Trainable params: 5,916,999
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 0s 32ms/step
# Accuracy =  0.671875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.828125
# 2/2 [==============================] - 0s 34ms/step
# Accuracy =  0.53125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6932

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 33ms/step
# Accuracy: 69.31640625
# anger 655/5160 acc: 56.0
# disgust 491/5160 acc: 48.7
# fear 655/5160 acc: 64.7
# happy 948/5160 acc: 91.4
# neutral 967/5160 acc: 77.4
# sad 620/5160 acc: 61.9
# surprise 784/5160 acc: 66.5

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 69.31640625
# anger 655/5160 acc: 56.0
# disgust 491/5160 acc: 48.7
# fear 655/5160 acc: 64.7
# happy 948/5160 acc: 91.4
# neutral 967/5160 acc: 77.4
# sad 620/5160 acc: 61.9
# surprise 784/5160 acc: 66.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.61      0.56      0.58       655
#      disgust       0.58      0.49      0.53       491
#         fear       0.55      0.65      0.60       655
#        happy       0.91      0.91      0.91       948
#      neutral       0.91      0.77      0.84       967
#          sad       0.56      0.62      0.59       620
#     surprise       0.59      0.66      0.62       784
#
#     accuracy                           0.69      5120
#    macro avg       0.67      0.67      0.67      5120
# weighted avg       0.70      0.69      0.70      5120

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 325/325 [==============================] - 196s 597ms/step - loss: 0.4828 - accuracy: 0.8155
# 81/81 [==============================] - 9s 109ms/step - loss: 0.9260 - accuracy: 0.6936

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# Top 1 Accuracy: 69.28%
# 2/2 [==============================] - 0s 35ms/step
# Top 2 Accuracy: 37.50%
# 2/2 [==============================] - 0s 34ms/step - loss: 0.9156 - accuracy: 0.7344
# Loss: 0.9156292676925659
# Precision: 0.67
# Recall: 0.67
# F1-Score: 0.67

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'X:/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 35ms/step
# Accuracy =  0.71875
# 2/2 [==============================] - 0s 38ms/step
# Accuracy =  0.46875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6064

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 30ms/step
# Accuracy: 60.64453125
# Angry 289/2100 acc: 58.5
# Disgust 295/2100 acc: 55.9
# Fear 293/2100 acc: 60.4
# Happy 290/2100 acc: 76.9
# Neutral 294/2100 acc: 40.1
# Sad 293/2100 acc: 59.0
# Surprise 294/2100 acc: 73.8

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 60.64453125
# Angry 289/2100 acc: 58.5
# Disgust 295/2100 acc: 55.9
# Fear 293/2100 acc: 60.4
# Happy 290/2100 acc: 76.9
# Neutral 294/2100 acc: 40.1
# Sad 293/2100 acc: 59.0
# Surprise 294/2100 acc: 73.8

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.62      0.58      0.60       289
#      Disgust       0.72      0.56      0.63       295
#         Fear       0.60      0.60      0.60       293
#        Happy       0.81      0.77      0.79       290
#      Neutral       0.46      0.40      0.43       294
#          Sad       0.56      0.59      0.58       293
#     Surprise       0.53      0.74      0.61       294
#
#     accuracy                           0.61      2048
#    macro avg       0.61      0.61      0.61      2048
# weighted avg       0.61      0.61      0.61      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.000001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   55392       ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   51216       ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 176)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  22656       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  33984       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 176)  0          ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   153632      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   16992       ['max_pooling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   11328       ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 320)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 320)  0          ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  61632       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  66768       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 320)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   165984      ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   83216       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   15408       ['max_pooling2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   20544       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 224)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 160)  36000       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 224)  50400       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 224)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 112)  161392      ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 24)   134424      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 64)   14400       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   14400       ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 264)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 128)  33920       ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 256)  67840       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 264)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 24)   153624      ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 64)   16960       ['max_pooling2d_7[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   16960       ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 280)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 112)  31472       ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 288)  80928       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 280)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 144)  145296      ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   230432      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 64)   17984       ['max_pooling2d_8[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   17984       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 304)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  78080       ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 320)  97600       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 304)  0          ['concatenate_5[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 160)  368800      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   256032      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  39040       ['max_pooling2d_9[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 128)  39040       ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 448)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 256)    114944      ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 320)    143680      ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 448)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 160)    368800      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     256032      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_11[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_10[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 448)    0           ['conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    172416      ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 448)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 192)    663744      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 48)     460848      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 128)    57472       ['max_pooling2d_12[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 128)    57472       ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 496)    0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 496)   0           ['concatenate_8[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 496)          0           ['average_pooling2d[0][0]']
#
#  dropout (Dropout)              (None, 496)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 7)            3479        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5,916,999
# Trainable params: 5,916,999
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 116 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 0.9749 - accuracy: 0.7663
# Epoch 1: val_accuracy improved from -inf to 0.67773, saving model to best_model.h5
# 448/448 [==============================] - 271s 583ms/step - loss: 0.9749 - accuracy: 0.7663 - val_loss: 0.9911 - val_accuracy: 0.6777 - lr: 1.0000e-06
# Epoch 2/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9655 - accuracy: 0.7708
# Epoch 2: val_accuracy improved from 0.67773 to 0.67871, saving model to best_model.h5
# 448/448 [==============================] - 264s 589ms/step - loss: 0.9655 - accuracy: 0.7708 - val_loss: 0.9897 - val_accuracy: 0.6787 - lr: 1.0000e-06
# Epoch 3/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9599 - accuracy: 0.7698
# Epoch 3: val_accuracy did not improve from 0.67871
# 448/448 [==============================] - 260s 580ms/step - loss: 0.9599 - accuracy: 0.7698 - val_loss: 0.9925 - val_accuracy: 0.6779 - lr: 1.0000e-06
# Epoch 4/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9571 - accuracy: 0.7696
# Epoch 4: val_accuracy improved from 0.67871 to 0.68011, saving model to best_model.h5
# 448/448 [==============================] - 260s 581ms/step - loss: 0.9571 - accuracy: 0.7696 - val_loss: 0.9930 - val_accuracy: 0.6801 - lr: 1.0000e-06
# Epoch 5/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9595 - accuracy: 0.7708
# Epoch 5: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 259s 578ms/step - loss: 0.9595 - accuracy: 0.7708 - val_loss: 0.9965 - val_accuracy: 0.6768 - lr: 1.0000e-06
# Epoch 6/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9578 - accuracy: 0.7713
# Epoch 6: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 259s 578ms/step - loss: 0.9578 - accuracy: 0.7713 - val_loss: 0.9939 - val_accuracy: 0.6786 - lr: 1.0000e-06
# Epoch 7/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9572 - accuracy: 0.7740
# Epoch 7: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 260s 580ms/step - loss: 0.9572 - accuracy: 0.7740 - val_loss: 0.9943 - val_accuracy: 0.6779 - lr: 1.0000e-06
# Epoch 8/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9613 - accuracy: 0.7700
# Epoch 8: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 264s 588ms/step - loss: 0.9613 - accuracy: 0.7700 - val_loss: 0.9940 - val_accuracy: 0.6769 - lr: 1.0000e-06
# Epoch 9/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9586 - accuracy: 0.7746
# Epoch 9: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 267s 596ms/step - loss: 0.9586 - accuracy: 0.7746 - val_loss: 0.9888 - val_accuracy: 0.6780 - lr: 1.0000e-06
# Epoch 10/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9495 - accuracy: 0.7730
# Epoch 10: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 266s 594ms/step - loss: 0.9495 - accuracy: 0.7730 - val_loss: 0.9965 - val_accuracy: 0.6800 - lr: 1.0000e-06
# Epoch 11/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9621 - accuracy: 0.7711
# Epoch 11: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 263s 587ms/step - loss: 0.9621 - accuracy: 0.7711 - val_loss: 0.9961 - val_accuracy: 0.6763 - lr: 1.0000e-06
# Epoch 12/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.7715
# Epoch 12: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 266s 594ms/step - loss: 0.9483 - accuracy: 0.7715 - val_loss: 1.0018 - val_accuracy: 0.6794 - lr: 1.0000e-06
# Epoch 13/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9527 - accuracy: 0.7726
# Epoch 13: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 272s 606ms/step - loss: 0.9527 - accuracy: 0.7726 - val_loss: 0.9965 - val_accuracy: 0.6795 - lr: 1.0000e-06
# Epoch 14/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9455 - accuracy: 0.7728
# Epoch 14: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 275s 614ms/step - loss: 0.9455 - accuracy: 0.7728 - val_loss: 0.9988 - val_accuracy: 0.6768 - lr: 1.0000e-06
# Epoch 15/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9668 - accuracy: 0.7705
# Epoch 15: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 274s 612ms/step - loss: 0.9668 - accuracy: 0.7705 - val_loss: 0.9955 - val_accuracy: 0.6770 - lr: 1.0000e-06
# Epoch 16/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9503 - accuracy: 0.7736
# Epoch 16: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 272s 606ms/step - loss: 0.9503 - accuracy: 0.7736 - val_loss: 1.0006 - val_accuracy: 0.6762 - lr: 1.0000e-06
# Epoch 17/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9419 - accuracy: 0.7749
# Epoch 17: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 270s 602ms/step - loss: 0.9419 - accuracy: 0.7749 - val_loss: 1.0012 - val_accuracy: 0.6782 - lr: 1.0000e-06
# Epoch 18/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.7745
# Epoch 18: val_accuracy did not improve from 0.68011
# 448/448 [==============================] - 260s 581ms/step - loss: 0.9483 - accuracy: 0.7745 - val_loss: 1.0011 - val_accuracy: 0.6782 - lr: 1.0000e-06
# Epoch 19/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9499 - accuracy: 0.7729
# Epoch 19: val_accuracy improved from 0.68011 to 0.68052, saving model to best_model.h5
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999987376214e-07.
# 448/448 [==============================] - 261s 581ms/step - loss: 0.9499 - accuracy: 0.7729 - val_loss: 0.9994 - val_accuracy: 0.6805 - lr: 1.0000e-06
# Epoch 20/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9486 - accuracy: 0.7738
# Epoch 20: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 269s 601ms/step - loss: 0.9486 - accuracy: 0.7738 - val_loss: 1.0006 - val_accuracy: 0.6783 - lr: 5.0000e-07
# Epoch 21/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9582 - accuracy: 0.7707
# Epoch 21: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 266s 593ms/step - loss: 0.9582 - accuracy: 0.7707 - val_loss: 0.9972 - val_accuracy: 0.6787 - lr: 5.0000e-07
# Epoch 22/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9431 - accuracy: 0.7745
# Epoch 22: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 267s 596ms/step - loss: 0.9431 - accuracy: 0.7745 - val_loss: 0.9971 - val_accuracy: 0.6791 - lr: 5.0000e-07
# Epoch 23/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9545 - accuracy: 0.7732
# Epoch 23: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 262s 584ms/step - loss: 0.9545 - accuracy: 0.7732 - val_loss: 0.9997 - val_accuracy: 0.6789 - lr: 5.0000e-07
# Epoch 24/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.7753
# Epoch 24: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 265s 591ms/step - loss: 0.9359 - accuracy: 0.7753 - val_loss: 1.0003 - val_accuracy: 0.6786 - lr: 5.0000e-07
# Epoch 25/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9469 - accuracy: 0.7742
# Epoch 25: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 267s 596ms/step - loss: 0.9469 - accuracy: 0.7742 - val_loss: 0.9998 - val_accuracy: 0.6790 - lr: 5.0000e-07
# Epoch 26/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9532 - accuracy: 0.7739
# Epoch 26: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 256s 571ms/step - loss: 0.9532 - accuracy: 0.7739 - val_loss: 1.0008 - val_accuracy: 0.6776 - lr: 5.0000e-07
# Epoch 27/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9453 - accuracy: 0.7748
# Epoch 27: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 262s 584ms/step - loss: 0.9453 - accuracy: 0.7748 - val_loss: 1.0011 - val_accuracy: 0.6789 - lr: 5.0000e-07
# Epoch 28/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9494 - accuracy: 0.7705
# Epoch 28: val_accuracy did not improve from 0.68052
# 448/448 [==============================] - 268s 597ms/step - loss: 0.9494 - accuracy: 0.7705 - val_loss: 1.0009 - val_accuracy: 0.6797 - lr: 5.0000e-07
# Epoch 29/200
# 448/448 [==============================] - ETA: 0s - loss: 0.9489 - accuracy: 0.7738
# Epoch 29: val_accuracy did not improve from 0.68052
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999993688107e-07.
# 448/448 [==============================] - 265s 590ms/step - loss: 0.9489 - accuracy: 0.7738 - val_loss: 1.0012 - val_accuracy: 0.6777 - lr: 5.0000e-07
# Epoch 29: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %%
model = load_model('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 3s 21ms/step
# Accuracy =  0.71875

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 38ms/step
# Accuracy =  0.828125
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.546875

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6782

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 67.81529017857143
# Angry 956/7178 acc: 65.9
# Disgust 111/7178 acc: 71.2
# Fear 1023/7178 acc: 45.9
# Happy 1772/7178 acc: 85.4
# Neutral 1231/7178 acc: 67.5
# Sad 1245/7178 acc: 52.4
# Surprise 830/7178 acc: 82.4

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 67.81529017857143
# Angry 956/7178 acc: 65.9
# Disgust 111/7178 acc: 71.2
# Fear 1023/7178 acc: 45.9
# Happy 1772/7178 acc: 85.4
# Neutral 1231/7178 acc: 67.5
# Sad 1245/7178 acc: 52.4
# Surprise 830/7178 acc: 82.4

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.57      0.66      0.61       956
#      Disgust       0.81      0.71      0.76       111
#         Fear       0.52      0.46      0.49      1023
#        Happy       0.89      0.85      0.87      1772
#      Neutral       0.61      0.68      0.64      1231
#          Sad       0.58      0.52      0.55      1245
#     Surprise       0.79      0.82      0.81       830
#
#     accuracy                           0.68      7168
#    macro avg       0.68      0.67      0.67      7168
# weighted avg       0.68      0.68      0.68      7168

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.71875
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.546875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6318

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 1s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 63.18359375
# Angry 297/2100 acc: 80.8
# Disgust 292/2100 acc: 12.3
# Fear 289/2100 acc: 47.1
# Happy 291/2100 acc: 92.4
# Neutral 295/2100 acc: 85.8
# Sad 292/2100 acc: 50.3
# Surprise 292/2100 acc: 72.9

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 63.18359375
# Angry 297/2100 acc: 80.8
# Disgust 292/2100 acc: 12.3
# Fear 289/2100 acc: 47.1
# Happy 291/2100 acc: 92.4
# Neutral 295/2100 acc: 85.8
# Sad 292/2100 acc: 50.3
# Surprise 292/2100 acc: 72.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.53      0.81      0.64       297
#      Disgust       0.97      0.12      0.22       292
#         Fear       0.64      0.47      0.54       289
#        Happy       0.76      0.92      0.83       291
#      Neutral       0.56      0.86      0.68       295
#          Sad       0.61      0.50      0.55       292
#     Surprise       0.73      0.73      0.73       292
#
#     accuracy                           0.63      2048
#    macro avg       0.68      0.63      0.60      2048
# weighted avg       0.68      0.63      0.60      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (224, 224))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 748ms/step
# Predicted emotion class: neutral, probability: 0.7369038462638855
# 1/1 [==============================] - 0s 37ms/step
# Predicted emotion class: fear, probability: 0.568371057510376
# 1/1 [==============================] - 0s 28ms/step
# Predicted emotion class: fear, probability: 0.7439523935317993
# 1/1 [==============================] - 0s 27ms/step
# Predicted emotion class: sad, probability: 0.3771692216396332
# 1/1 [==============================] - 0s 40ms/step
# Predicted emotion class: happy, probability: 0.9942155480384827
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.7172683477401733
# 1/1 [==============================] - 0s 26ms/step
# Predicted emotion class: angry, probability: 0.8721256852149963
# 1/1 [==============================] - 0s 25ms/step
# Predicted emotion class: sad, probability: 0.5261616110801697
# 1/1 [==============================] - 0s 33ms/step
# Predicted emotion class: sad, probability: 0.5279726386070251
