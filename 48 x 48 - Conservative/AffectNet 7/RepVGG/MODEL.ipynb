# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/train 7/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/test 7/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 22221 images belonging to 7 classes.
# Found 5545 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2093</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>520</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 22221
# 5545

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
class RepVGGBlock(layers.Layer):
      def __init__(self, out_channels, strides, kernel_size, name=None, **kwargs):
         super().__init__(name=name, **kwargs)
         self.out_channels = out_channels
         self.strides = strides
         self.kernel_size = kernel_size
         self.conv1 = Conv2D(out_channels, kernel_size, strides=strides, padding='same', use_bias=False)
         self.bn1 = BatchNormalization()
         self.relu = ReLU()
         self.conv2 = Conv2D(out_channels, kernel_size, padding='same', use_bias=False)
         self.bn2 = BatchNormalization()
         if strides == 1:
               self.identity_map = Activation('linear')
         else:
               self.identity_map = Conv2D(out_channels, kernel_size=1, strides=strides, padding='same', use_bias=False)
         
      def call(self, inputs):
         x = self.conv1(inputs)
         x = self.bn1(x)
         x = self.relu(x)
         x = self.conv2(x)
         x = self.bn2(x)
         identity_map = self.identity_map(inputs)
         return x + identity_map
      
      def get_config(self):
         config = super().get_config()
         config.update({
               'out_channels': self.out_channels,
               'strides': self.strides,
               'kernel_size': self.kernel_size,
         })
         return config

class GradientCheckpointing(layers.Layer):
      def __init__(self, checkpointing_depth, **kwargs):
         super().__init__(**kwargs)
         self.checkpointing_depth = checkpointing_depth

      def get_config(self):
         config = super().get_config()
         config.update({
               "checkpointing_depth": self.checkpointing_depth,
         })
         return config

      def call(self, inputs):
         if self.checkpointing_depth == 0:
               return inputs
         else:
               num_chunks = self.checkpointing_depth + 1
               chunk_size = inputs.shape[-1] // num_chunks
               remainder = inputs.shape[-1] % num_chunks
               if remainder != 0:
                  chunk_size += 1
               chunks = []
               for i in range(num_chunks):
                  start = i * chunk_size
                  end = start + chunk_size
                  if i == num_chunks - 1:
                     end = inputs.shape[-1]
                  chunk = inputs[..., start:end]
                  if i == 0:
                     chunk = tf.identity(chunk)
                  else:
                     chunk = tf.stop_gradient(chunk)
                  chunks.append(chunk)
         return tf.concat(chunks, axis=-1)

def create_repvgg_a0(checkpointing_depth=1):
      inputs = Input(shape=IMAGE_SHAPE)
      x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(inputs)
      x = BatchNormalization()(x)
      x = ReLU()(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=64, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)

      x = GlobalAveragePooling2D()(x)
      outputs = Dense(num_classes, activation='softmax')(x)  # number of classes in VGGFace2 dataset

      model = Model(inputs=inputs, outputs=outputs)

      return model

# %%
with strategy.scope():

   model = create_repvgg_a0()


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
# # Compute the class weights
# class_to_idx=validation_generator.class_indices
# idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
# print(idx_to_class)

# (unique, counts) = np.unique(train_generator.classes, return_counts=True)
# cw=1/counts
# cw/=cw.min()
# class_weights = {i:cwi for i,cwi in zip(unique,cw)}
# print(class_weights)

from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     



# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 347/347 [==============================] - ETA: 0s - loss: 2.7590 - accuracy: 0.1994
# Epoch 1: val_accuracy improved from -inf to 0.11355, saving model to best_model.h5
# 347/347 [==============================] - 72s 162ms/step - loss: 2.7590 - accuracy: 0.1994 - val_loss: 2.7202 - val_accuracy: 0.1136 - lr: 1.0000e-04
# Epoch 2/200
# 347/347 [==============================] - ETA: 0s - loss: 2.4701 - accuracy: 0.2378
# Epoch 2: val_accuracy improved from 0.11355 to 0.15334, saving model to best_model.h5
# 347/347 [==============================] - 59s 169ms/step - loss: 2.4701 - accuracy: 0.2378 - val_loss: 2.4407 - val_accuracy: 0.1533 - lr: 1.0000e-04
# Epoch 3/200
# 347/347 [==============================] - ETA: 0s - loss: 2.3592 - accuracy: 0.2691
# Epoch 3: val_accuracy improved from 0.15334 to 0.25709, saving model to best_model.h5
# 347/347 [==============================] - 58s 167ms/step - loss: 2.3592 - accuracy: 0.2691 - val_loss: 1.9598 - val_accuracy: 0.2571 - lr: 1.0000e-04
# Epoch 4/200
# 347/347 [==============================] - ETA: 0s - loss: 2.2566 - accuracy: 0.3038
# Epoch 4: val_accuracy did not improve from 0.25709
# 347/347 [==============================] - 57s 164ms/step - loss: 2.2566 - accuracy: 0.3038 - val_loss: 2.2068 - val_accuracy: 0.2498 - lr: 1.0000e-04
# Epoch 5/200
# 347/347 [==============================] - ETA: 0s - loss: 2.1758 - accuracy: 0.3438
# Epoch 5: val_accuracy improved from 0.25709 to 0.29342, saving model to best_model.h5
# 347/347 [==============================] - 59s 170ms/step - loss: 2.1758 - accuracy: 0.3438 - val_loss: 1.7845 - val_accuracy: 0.2934 - lr: 1.0000e-04
# Epoch 6/200
# 347/347 [==============================] - ETA: 0s - loss: 2.1067 - accuracy: 0.3600
# Epoch 6: val_accuracy improved from 0.29342 to 0.36573, saving model to best_model.h5
# 347/347 [==============================] - 57s 164ms/step - loss: 2.1067 - accuracy: 0.3600 - val_loss: 1.6071 - val_accuracy: 0.3657 - lr: 1.0000e-04
# Epoch 7/200
# 347/347 [==============================] - ETA: 0s - loss: 2.0466 - accuracy: 0.3917
# Epoch 7: val_accuracy did not improve from 0.36573
# 347/347 [==============================] - 57s 163ms/step - loss: 2.0466 - accuracy: 0.3917 - val_loss: 1.7998 - val_accuracy: 0.3327 - lr: 1.0000e-04
# Epoch 8/200
# 347/347 [==============================] - ETA: 0s - loss: 1.9978 - accuracy: 0.4043
# Epoch 8: val_accuracy improved from 0.36573 to 0.39244, saving model to best_model.h5
# 347/347 [==============================] - 57s 163ms/step - loss: 1.9978 - accuracy: 0.4043 - val_loss: 1.5499 - val_accuracy: 0.3924 - lr: 1.0000e-04
# Epoch 9/200
# 347/347 [==============================] - ETA: 0s - loss: 1.9553 - accuracy: 0.4217
# Epoch 9: val_accuracy did not improve from 0.39244
# 347/347 [==============================] - 55s 158ms/step - loss: 1.9553 - accuracy: 0.4217 - val_loss: 1.6290 - val_accuracy: 0.3725 - lr: 1.0000e-04
# Epoch 10/200
# 347/347 [==============================] - ETA: 0s - loss: 1.8970 - accuracy: 0.4383
# Epoch 10: val_accuracy did not improve from 0.39244
# 347/347 [==============================] - 55s 159ms/step - loss: 1.8970 - accuracy: 0.4383 - val_loss: 1.7998 - val_accuracy: 0.3481 - lr: 1.0000e-04
# Epoch 11/200
# 347/347 [==============================] - ETA: 0s - loss: 1.8553 - accuracy: 0.4588
# Epoch 11: val_accuracy improved from 0.39244 to 0.43514, saving model to best_model.h5
# 347/347 [==============================] - 55s 160ms/step - loss: 1.8553 - accuracy: 0.4588 - val_loss: 1.5566 - val_accuracy: 0.4351 - lr: 1.0000e-04
# Epoch 12/200
# 347/347 [==============================] - ETA: 0s - loss: 1.8140 - accuracy: 0.4756
# Epoch 12: val_accuracy did not improve from 0.43514
# 347/347 [==============================] - 55s 158ms/step - loss: 1.8140 - accuracy: 0.4756 - val_loss: 1.6451 - val_accuracy: 0.3904 - lr: 1.0000e-04
# Epoch 13/200
# 347/347 [==============================] - ETA: 0s - loss: 1.7884 - accuracy: 0.4817
# Epoch 13: val_accuracy did not improve from 0.43514
# 347/347 [==============================] - 54s 156ms/step - loss: 1.7884 - accuracy: 0.4817 - val_loss: 1.6940 - val_accuracy: 0.3988 - lr: 1.0000e-04
# Epoch 14/200
# 347/347 [==============================] - ETA: 0s - loss: 1.7647 - accuracy: 0.4890
# Epoch 14: val_accuracy did not improve from 0.43514
# 347/347 [==============================] - 54s 156ms/step - loss: 1.7647 - accuracy: 0.4890 - val_loss: 1.5349 - val_accuracy: 0.4264 - lr: 1.0000e-04
# Epoch 15/200
# 347/347 [==============================] - ETA: 0s - loss: 1.7450 - accuracy: 0.4961
# Epoch 15: val_accuracy improved from 0.43514 to 0.43659, saving model to best_model.h5
# 347/347 [==============================] - 55s 159ms/step - loss: 1.7450 - accuracy: 0.4961 - val_loss: 1.6092 - val_accuracy: 0.4366 - lr: 1.0000e-04
# Epoch 16/200
# 347/347 [==============================] - ETA: 0s - loss: 1.7095 - accuracy: 0.5115
# Epoch 16: val_accuracy improved from 0.43659 to 0.45839, saving model to best_model.h5
# 347/347 [==============================] - 57s 163ms/step - loss: 1.7095 - accuracy: 0.5115 - val_loss: 1.5152 - val_accuracy: 0.4584 - lr: 1.0000e-04
# Epoch 17/200
# 347/347 [==============================] - ETA: 0s - loss: 1.6907 - accuracy: 0.5177
# Epoch 17: val_accuracy did not improve from 0.45839
# 347/347 [==============================] - 56s 160ms/step - loss: 1.6907 - accuracy: 0.5177 - val_loss: 1.5369 - val_accuracy: 0.4415 - lr: 1.0000e-04
# Epoch 18/200
# 347/347 [==============================] - ETA: 0s - loss: 1.6676 - accuracy: 0.5254
# Epoch 18: val_accuracy improved from 0.45839 to 0.49909, saving model to best_model.h5
# 347/347 [==============================] - 57s 165ms/step - loss: 1.6676 - accuracy: 0.5254 - val_loss: 1.3738 - val_accuracy: 0.4991 - lr: 1.0000e-04
# Epoch 19/200
# 347/347 [==============================] - ETA: 0s - loss: 1.6516 - accuracy: 0.5313
# Epoch 19: val_accuracy did not improve from 0.49909
# 347/347 [==============================] - 55s 158ms/step - loss: 1.6516 - accuracy: 0.5313 - val_loss: 1.5025 - val_accuracy: 0.4575 - lr: 1.0000e-04
# Epoch 20/200
# 347/347 [==============================] - ETA: 0s - loss: 1.6287 - accuracy: 0.5351
# Epoch 20: val_accuracy did not improve from 0.49909
# 347/347 [==============================] - 53s 154ms/step - loss: 1.6287 - accuracy: 0.5351 - val_loss: 1.6440 - val_accuracy: 0.3817 - lr: 1.0000e-04
# Epoch 21/200
# 347/347 [==============================] - ETA: 0s - loss: 1.6131 - accuracy: 0.5436
# Epoch 21: val_accuracy did not improve from 0.49909
# 347/347 [==============================] - 54s 156ms/step - loss: 1.6131 - accuracy: 0.5436 - val_loss: 1.4674 - val_accuracy: 0.4680 - lr: 1.0000e-04
# Epoch 22/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5889 - accuracy: 0.5497
# Epoch 22: val_accuracy did not improve from 0.49909
# 347/347 [==============================] - 56s 160ms/step - loss: 1.5889 - accuracy: 0.5497 - val_loss: 1.3864 - val_accuracy: 0.4624 - lr: 1.0000e-04
# Epoch 23/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5760 - accuracy: 0.5514
# Epoch 23: val_accuracy did not improve from 0.49909
# 347/347 [==============================] - 54s 156ms/step - loss: 1.5760 - accuracy: 0.5514 - val_loss: 1.3918 - val_accuracy: 0.4775 - lr: 1.0000e-04
# Epoch 24/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5606 - accuracy: 0.5601
# Epoch 24: val_accuracy improved from 0.49909 to 0.52071, saving model to best_model.h5
# 347/347 [==============================] - 56s 162ms/step - loss: 1.5606 - accuracy: 0.5601 - val_loss: 1.1941 - val_accuracy: 0.5207 - lr: 1.0000e-04
# Epoch 25/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5433 - accuracy: 0.5618
# Epoch 25: val_accuracy did not improve from 0.52071
# 347/347 [==============================] - 57s 163ms/step - loss: 1.5433 - accuracy: 0.5618 - val_loss: 1.8737 - val_accuracy: 0.3937 - lr: 1.0000e-04
# Epoch 26/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5369 - accuracy: 0.5649
# Epoch 26: val_accuracy did not improve from 0.52071
# 347/347 [==============================] - 56s 161ms/step - loss: 1.5369 - accuracy: 0.5649 - val_loss: 1.5861 - val_accuracy: 0.4282 - lr: 1.0000e-04
# Epoch 27/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5220 - accuracy: 0.5691
# Epoch 27: val_accuracy improved from 0.52071 to 0.54924, saving model to best_model.h5
# 347/347 [==============================] - 57s 163ms/step - loss: 1.5220 - accuracy: 0.5691 - val_loss: 1.1492 - val_accuracy: 0.5492 - lr: 1.0000e-04
# Epoch 28/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5105 - accuracy: 0.5732
# Epoch 28: val_accuracy did not improve from 0.54924
# 347/347 [==============================] - 57s 162ms/step - loss: 1.5105 - accuracy: 0.5732 - val_loss: 1.4543 - val_accuracy: 0.5107 - lr: 1.0000e-04
# Epoch 29/200
# 347/347 [==============================] - ETA: 0s - loss: 1.5017 - accuracy: 0.5755
# Epoch 29: val_accuracy did not improve from 0.54924
# 347/347 [==============================] - 56s 160ms/step - loss: 1.5017 - accuracy: 0.5755 - val_loss: 1.2890 - val_accuracy: 0.5305 - lr: 1.0000e-04
# Epoch 30/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4876 - accuracy: 0.5835
# Epoch 30: val_accuracy did not improve from 0.54924
# 347/347 [==============================] - 55s 158ms/step - loss: 1.4876 - accuracy: 0.5835 - val_loss: 1.2784 - val_accuracy: 0.5240 - lr: 1.0000e-04
# Epoch 31/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4722 - accuracy: 0.5878
# Epoch 31: val_accuracy did not improve from 0.54924
# 347/347 [==============================] - 55s 160ms/step - loss: 1.4722 - accuracy: 0.5878 - val_loss: 1.3786 - val_accuracy: 0.4967 - lr: 1.0000e-04
# Epoch 32/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4588 - accuracy: 0.5910
# Epoch 32: val_accuracy did not improve from 0.54924
# 347/347 [==============================] - 56s 162ms/step - loss: 1.4588 - accuracy: 0.5910 - val_loss: 1.1994 - val_accuracy: 0.5343 - lr: 1.0000e-04
# Epoch 33/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4593 - accuracy: 0.5904
# Epoch 33: val_accuracy improved from 0.54924 to 0.58285, saving model to best_model.h5
# 347/347 [==============================] - 57s 163ms/step - loss: 1.4593 - accuracy: 0.5904 - val_loss: 1.1392 - val_accuracy: 0.5828 - lr: 1.0000e-04
# Epoch 34/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4472 - accuracy: 0.5929
# Epoch 34: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 56s 160ms/step - loss: 1.4472 - accuracy: 0.5929 - val_loss: 1.4141 - val_accuracy: 0.4688 - lr: 1.0000e-04
# Epoch 35/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4358 - accuracy: 0.5964
# Epoch 35: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 56s 160ms/step - loss: 1.4358 - accuracy: 0.5964 - val_loss: 1.1889 - val_accuracy: 0.5585 - lr: 1.0000e-04
# Epoch 36/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4287 - accuracy: 0.5985
# Epoch 36: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 54s 157ms/step - loss: 1.4287 - accuracy: 0.5985 - val_loss: 1.4213 - val_accuracy: 0.4955 - lr: 1.0000e-04
# Epoch 37/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4235 - accuracy: 0.6029
# Epoch 37: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 56s 161ms/step - loss: 1.4235 - accuracy: 0.6029 - val_loss: 1.6033 - val_accuracy: 0.4331 - lr: 1.0000e-04
# Epoch 38/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4112 - accuracy: 0.6044
# Epoch 38: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 55s 157ms/step - loss: 1.4112 - accuracy: 0.6044 - val_loss: 1.2194 - val_accuracy: 0.5458 - lr: 1.0000e-04
# Epoch 39/200
# 347/347 [==============================] - ETA: 0s - loss: 1.4048 - accuracy: 0.6050
# Epoch 39: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 55s 157ms/step - loss: 1.4048 - accuracy: 0.6050 - val_loss: 1.5682 - val_accuracy: 0.4544 - lr: 1.0000e-04
# Epoch 40/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3892 - accuracy: 0.6149
# Epoch 40: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 54s 157ms/step - loss: 1.3892 - accuracy: 0.6149 - val_loss: 1.2243 - val_accuracy: 0.5345 - lr: 1.0000e-04
# Epoch 41/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3842 - accuracy: 0.6158
# Epoch 41: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 56s 160ms/step - loss: 1.3842 - accuracy: 0.6158 - val_loss: 1.4029 - val_accuracy: 0.4949 - lr: 1.0000e-04
# Epoch 42/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3817 - accuracy: 0.6153
# Epoch 42: val_accuracy did not improve from 0.58285
# 347/347 [==============================] - 54s 157ms/step - loss: 1.3817 - accuracy: 0.6153 - val_loss: 1.3459 - val_accuracy: 0.5240 - lr: 1.0000e-04
# Epoch 43/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3668 - accuracy: 0.6195
# Epoch 43: val_accuracy improved from 0.58285 to 0.58884, saving model to best_model.h5
# 347/347 [==============================] - 54s 157ms/step - loss: 1.3668 - accuracy: 0.6195 - val_loss: 1.1159 - val_accuracy: 0.5888 - lr: 1.0000e-04
# Epoch 44/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3583 - accuracy: 0.6196
# Epoch 44: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 56s 160ms/step - loss: 1.3583 - accuracy: 0.6196 - val_loss: 1.3735 - val_accuracy: 0.5173 - lr: 1.0000e-04
# Epoch 45/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3569 - accuracy: 0.6192
# Epoch 45: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 57s 163ms/step - loss: 1.3569 - accuracy: 0.6192 - val_loss: 1.1843 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 46/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3452 - accuracy: 0.6254
# Epoch 46: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 55s 157ms/step - loss: 1.3452 - accuracy: 0.6254 - val_loss: 1.2865 - val_accuracy: 0.5425 - lr: 1.0000e-04
# Epoch 47/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3418 - accuracy: 0.6240
# Epoch 47: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 59s 169ms/step - loss: 1.3418 - accuracy: 0.6240 - val_loss: 1.3299 - val_accuracy: 0.5203 - lr: 1.0000e-04
# Epoch 48/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3251 - accuracy: 0.6298
# Epoch 48: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 54s 155ms/step - loss: 1.3251 - accuracy: 0.6298 - val_loss: 1.6233 - val_accuracy: 0.4471 - lr: 1.0000e-04
# Epoch 49/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3293 - accuracy: 0.6312
# Epoch 49: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 54s 156ms/step - loss: 1.3293 - accuracy: 0.6312 - val_loss: 1.3403 - val_accuracy: 0.5298 - lr: 1.0000e-04
# Epoch 50/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3221 - accuracy: 0.6293
# Epoch 50: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 54s 156ms/step - loss: 1.3221 - accuracy: 0.6293 - val_loss: 1.7149 - val_accuracy: 0.4353 - lr: 1.0000e-04
# Epoch 51/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3161 - accuracy: 0.6291
# Epoch 51: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 55s 160ms/step - loss: 1.3161 - accuracy: 0.6291 - val_loss: 1.4962 - val_accuracy: 0.4777 - lr: 1.0000e-04
# Epoch 52/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3125 - accuracy: 0.6314
# Epoch 52: val_accuracy did not improve from 0.58884
# 347/347 [==============================] - 71s 205ms/step - loss: 1.3125 - accuracy: 0.6314 - val_loss: 1.3527 - val_accuracy: 0.5194 - lr: 1.0000e-04
# Epoch 53/200
# 347/347 [==============================] - ETA: 0s - loss: 1.3001 - accuracy: 0.6375
# Epoch 53: val_accuracy did not improve from 0.58884
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 347/347 [==============================] - 55s 157ms/step - loss: 1.3001 - accuracy: 0.6375 - val_loss: 1.1773 - val_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 54/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2495 - accuracy: 0.6520
# Epoch 54: val_accuracy improved from 0.58884 to 0.59847, saving model to best_model.h5
# 347/347 [==============================] - 56s 161ms/step - loss: 1.2495 - accuracy: 0.6520 - val_loss: 1.0630 - val_accuracy: 0.5985 - lr: 5.0000e-05
# Epoch 55/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.6574
# Epoch 55: val_accuracy improved from 0.59847 to 0.61283, saving model to best_model.h5
# 347/347 [==============================] - 67s 192ms/step - loss: 1.2351 - accuracy: 0.6574 - val_loss: 1.0172 - val_accuracy: 0.6128 - lr: 5.0000e-05
# Epoch 56/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2286 - accuracy: 0.6581
# Epoch 56: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 156ms/step - loss: 1.2286 - accuracy: 0.6581 - val_loss: 1.1790 - val_accuracy: 0.5638 - lr: 5.0000e-05
# Epoch 57/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2183 - accuracy: 0.6588
# Epoch 57: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 55s 159ms/step - loss: 1.2183 - accuracy: 0.6588 - val_loss: 1.1315 - val_accuracy: 0.5752 - lr: 5.0000e-05
# Epoch 58/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2104 - accuracy: 0.6624
# Epoch 58: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 156ms/step - loss: 1.2104 - accuracy: 0.6624 - val_loss: 1.2151 - val_accuracy: 0.5616 - lr: 5.0000e-05
# Epoch 59/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2150 - accuracy: 0.6602
# Epoch 59: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 155ms/step - loss: 1.2150 - accuracy: 0.6602 - val_loss: 1.0917 - val_accuracy: 0.5836 - lr: 5.0000e-05
# Epoch 60/200
# 347/347 [==============================] - ETA: 0s - loss: 1.2041 - accuracy: 0.6676
# Epoch 60: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 155ms/step - loss: 1.2041 - accuracy: 0.6676 - val_loss: 1.2094 - val_accuracy: 0.5554 - lr: 5.0000e-05
# Epoch 61/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1937 - accuracy: 0.6663
# Epoch 61: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 156ms/step - loss: 1.1937 - accuracy: 0.6663 - val_loss: 1.0844 - val_accuracy: 0.6008 - lr: 5.0000e-05
# Epoch 62/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1953 - accuracy: 0.6663
# Epoch 62: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 56s 161ms/step - loss: 1.1953 - accuracy: 0.6663 - val_loss: 1.1463 - val_accuracy: 0.5759 - lr: 5.0000e-05
# Epoch 63/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1888 - accuracy: 0.6701
# Epoch 63: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 76s 218ms/step - loss: 1.1888 - accuracy: 0.6701 - val_loss: 1.2173 - val_accuracy: 0.5603 - lr: 5.0000e-05
# Epoch 64/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1833 - accuracy: 0.6730
# Epoch 64: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 154ms/step - loss: 1.1833 - accuracy: 0.6730 - val_loss: 1.0975 - val_accuracy: 0.5878 - lr: 5.0000e-05
# Epoch 65/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1818 - accuracy: 0.6717
# Epoch 65: val_accuracy did not improve from 0.61283
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 347/347 [==============================] - 53s 153ms/step - loss: 1.1818 - accuracy: 0.6717 - val_loss: 1.0677 - val_accuracy: 0.5941 - lr: 5.0000e-05
# Epoch 66/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1570 - accuracy: 0.6775
# Epoch 66: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 153ms/step - loss: 1.1570 - accuracy: 0.6775 - val_loss: 1.0782 - val_accuracy: 0.6032 - lr: 2.5000e-05
# Epoch 67/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1454 - accuracy: 0.6828
# Epoch 67: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 54s 154ms/step - loss: 1.1454 - accuracy: 0.6828 - val_loss: 1.1121 - val_accuracy: 0.5919 - lr: 2.5000e-05
# Epoch 68/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1346 - accuracy: 0.6861
# Epoch 68: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 154ms/step - loss: 1.1346 - accuracy: 0.6861 - val_loss: 1.1683 - val_accuracy: 0.5803 - lr: 2.5000e-05
# Epoch 69/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1309 - accuracy: 0.6861
# Epoch 69: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 153ms/step - loss: 1.1309 - accuracy: 0.6861 - val_loss: 1.0625 - val_accuracy: 0.6028 - lr: 2.5000e-05
# Epoch 70/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1307 - accuracy: 0.6848
# Epoch 70: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 154ms/step - loss: 1.1307 - accuracy: 0.6848 - val_loss: 1.1649 - val_accuracy: 0.5765 - lr: 2.5000e-05
# Epoch 71/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1268 - accuracy: 0.6873
# Epoch 71: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 152ms/step - loss: 1.1268 - accuracy: 0.6873 - val_loss: 1.1064 - val_accuracy: 0.5965 - lr: 2.5000e-05
# Epoch 72/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1271 - accuracy: 0.6874
# Epoch 72: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 152ms/step - loss: 1.1271 - accuracy: 0.6874 - val_loss: 1.2145 - val_accuracy: 0.5601 - lr: 2.5000e-05
# Epoch 73/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1168 - accuracy: 0.6861
# Epoch 73: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 53s 153ms/step - loss: 1.1168 - accuracy: 0.6861 - val_loss: 1.0580 - val_accuracy: 0.6085 - lr: 2.5000e-05
# Epoch 74/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1240 - accuracy: 0.6894
# Epoch 74: val_accuracy did not improve from 0.61283
# 347/347 [==============================] - 55s 157ms/step - loss: 1.1240 - accuracy: 0.6894 - val_loss: 1.1656 - val_accuracy: 0.5801 - lr: 2.5000e-05
# Epoch 75/200
# 347/347 [==============================] - ETA: 0s - loss: 1.1287 - accuracy: 0.6903
# Epoch 75: val_accuracy did not improve from 0.61283
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 347/347 [==============================] - 56s 160ms/step - loss: 1.1287 - accuracy: 0.6903 - val_loss: 1.1694 - val_accuracy: 0.5778 - lr: 2.5000e-05
# Epoch 75: early stopping

# %%
save_model = model.save('RepVGG_100e_AffectNet_BetterBalance_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 16ms/step
# Accuracy =  0.546875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.703125
# 2/2 [==============================] - 0s 41ms/step
# Accuracy =  0.453125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5790

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# Accuracy: 57.903343023255815
# anger 715/5545 acc: 68.0
# disgust 514/5545 acc: 38.7
# fear 717/5545 acc: 54.0
# happy 1003/5545 acc: 77.2
# neutral 1020/5545 acc: 59.2
# sad 680/5545 acc: 52.4
# surprise 855/5545 acc: 44.6

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 57.903343023255815
# anger 715/5545 acc: 68.0
# disgust 514/5545 acc: 38.7
# fear 717/5545 acc: 54.0
# happy 1003/5545 acc: 77.2
# neutral 1020/5545 acc: 59.2
# sad 680/5545 acc: 52.4
# surprise 855/5545 acc: 44.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.42      0.68      0.52       715
#      disgust       0.48      0.39      0.43       514
#         fear       0.45      0.54      0.49       717
#        happy       0.91      0.77      0.83      1003
#      neutral       0.86      0.59      0.70      1020
#          sad       0.43      0.52      0.47       680
#     surprise       0.56      0.45      0.49       855
#
#     accuracy                           0.58      5504
#    macro avg       0.59      0.56      0.56      5504
# weighted avg       0.62      0.58      0.59      5504

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 348/348 [==============================] - 42s 119ms/step - loss: 0.8017 - accuracy: 0.6965
# 87/87 [==============================] - 8s 84ms/step - loss: 1.1659 - accuracy: 0.5789

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 77ms/step
# Accuracy =  0.546875
# 2/2 [==============================] - 0s 37ms/step
# Accuracy =  0.328125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4233

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 42.333984375
# Angry 293/2100 acc: 78.2
# Disgust 289/2100 acc: 52.9
# Fear 291/2100 acc: 66.3
# Happy 290/2100 acc: 6.6
# Neutral 294/2100 acc: 0.0
# Sad 297/2100 acc: 59.6
# Surprise 294/2100 acc: 32.7

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 42.333984375
# Angry 293/2100 acc: 78.2
# Disgust 289/2100 acc: 52.9
# Fear 291/2100 acc: 66.3
# Happy 290/2100 acc: 6.6
# Neutral 294/2100 acc: 0.0
# Sad 297/2100 acc: 59.6
# Surprise 294/2100 acc: 32.7

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.46      0.78      0.58       293
#      Disgust       0.60      0.53      0.56       289
#         Fear       0.39      0.66      0.49       291
#        Happy       0.73      0.07      0.12       290
#      Neutral       0.00      0.00      0.00       294
#          Sad       0.37      0.60      0.46       297
#     Surprise       0.34      0.33      0.33       294
#
#     accuracy                           0.42      2048
#    macro avg       0.41      0.42      0.36      2048
# weighted avg       0.41      0.42      0.36      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
