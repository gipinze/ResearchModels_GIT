# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization,MaxPooling2D, Flatten, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/train 7/'
validation_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/AffectNet Resize/test 7/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 22221 images belonging to 7 classes.
# Found 5545 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2093</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>520</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 22221
# 5545

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
with strategy.scope():

   # Define input shape
   input_shape = (48, 48, 3)

    # Define input tensor
   input_tensor = tf.keras.Input(shape=input_shape)

    # Define shared convolutional layers
   conv1 = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
   conv2 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv1)
   conv3 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv2)

    # Define branch for face detection
   face_detection_branch = MaxPooling2D(pool_size=(2, 2))(conv3)
   face_detection_branch = Conv2D(128, (3, 3), padding='same', activation='relu')(face_detection_branch)
   face_detection_branch = Flatten()(face_detection_branch)
   face_detection_branch = Dense(64, activation='relu')(face_detection_branch)

    # Define branch for emotion recognition with attention mechanism
   emotion_recognition_branch = Conv2D(128, (3, 3), padding='same', activation='relu')(conv3)
   emotion_recognition_branch = MaxPooling2D(pool_size=(2, 2))(emotion_recognition_branch)
   emotion_recognition_branch = Conv2D(256, (3, 3), padding='same', activation='relu')(emotion_recognition_branch)
   emotion_recognition_branch = MaxPooling2D(pool_size=(2, 2))(emotion_recognition_branch)
   attention_size = 32
   num_heads = 4
   attention_layer = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=attention_size)(emotion_recognition_branch, emotion_recognition_branch)
   attention_layer = tf.keras.layers.LayerNormalization()(attention_layer)
   emotion_recognition_branch = Dense(128, activation='relu')(attention_layer)
   emotion_recognition_branch = Dropout(0.5)(emotion_recognition_branch)
    # Flatten the output of the emotion recognition branch
   emotion_recognition_branch = Flatten()(emotion_recognition_branch)

    # Merge the two branches
   merged = tf.keras.layers.concatenate([face_detection_branch, emotion_recognition_branch])

    # Define output layer
   output = Dense(7, activation='softmax')(merged)

    # Create the model
   model = Model(inputs=input_tensor, outputs=output)


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 48, 48, 64)   18496       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 64)   36928       ['conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 48, 48, 128)  73856       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 128)  0          ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 24, 24, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 256)  0          ['conv2d_5[0][0]']
#
#  multi_head_attention (MultiHea  (None, 12, 12, 256)  131712     ['max_pooling2d_2[0][0]',
#  dAttention)                                                      'max_pooling2d_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['conv2d_2[0][0]']
#
#  layer_normalization (LayerNorm  (None, 12, 12, 256)  512        ['multi_head_attention[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 128)  73856       ['max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 12, 12, 128)  32896       ['layer_normalization[0][0]']
#
#  flatten (Flatten)              (None, 73728)        0           ['conv2d_3[0][0]']
#
#  dropout (Dropout)              (None, 12, 12, 128)  0           ['dense_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4718656     ['flatten[0][0]']
#
#  flatten_1 (Flatten)            (None, 18432)        0           ['dropout[0][0]']
#
#  concatenate (Concatenate)      (None, 18496)        0           ['dense[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 7)            129479      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 5,512,455
# Trainable params: 5,512,455
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# # Compute the class weights
# class_to_idx=validation_generator.class_indices
# idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
# print(idx_to_class)

# (unique, counts) = np.unique(train_generator.classes, return_counts=True)
# cw=1/counts
# cw/=cw.min()
# class_weights = {i:cwi for i,cwi in zip(unique,cw)}
# print(class_weights)

from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     



# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 28 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 167/167 [==============================] - ETA: 0s - loss: 3.4545 - accuracy: 0.2921
# Epoch 1: val_accuracy improved from -inf to 0.36334, saving model to best_model.h5
# 167/167 [==============================] - 30s 103ms/step - loss: 3.4545 - accuracy: 0.2921 - val_loss: 1.6909 - val_accuracy: 0.3633 - lr: 1.0000e-04
# Epoch 2/200
# 167/167 [==============================] - ETA: 0s - loss: 3.
- lr: 1.0000e-04
# Epoch 19/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9654 - accuracy: 0.4485
# Epoch 19: val_accuracy did not improve from 0.48019
# 167/167 [==============================] - 14s 82ms/step - loss: 2.9654 - accuracy: 0.4485 - val_loss: 1.5566 - val_accuracy: 0.4338 - lr: 1.0000e-04
# Epoch 20/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9437 - accuracy: 0.4507
# Epoch 20: val_accuracy improved from 0.48019 to 0.51651, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 2.9437 - accuracy: 0.4507 - val_loss: 1.3286 - val_accuracy: 0.5165 - lr: 1.0000e-04
# Epoch 21/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9055 - accuracy: 0.4570
# Epoch 21: val_accuracy did not improve from 0.51651
# 167/167 [==============================] - 13s 80ms/step - loss: 2.9055 - accuracy: 0.4570 - val_loss: 1.4411 - val_accuracy: 0.4820 - lr: 1.0000e-04
# Epoch 22/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8758 - accuracy: 0.4616
# Epoch 22: val_accuracy did not improve from 0.51651
# 167/167 [==============================] - 13s 80ms/step - loss: 2.8758 - accuracy: 0.4616 - val_loss: 1.3020 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 23/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8243 - accuracy: 0.4750
# Epoch 23: val_accuracy did not improve from 0.51651
# 167/167 [==============================] - 13s 79ms/step - loss: 2.8243 - accuracy: 0.4750 - val_loss: 1.3661 - val_accuracy: 0.5084 - lr: 1.0000e-04
# Epoch 24/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7891 - accuracy: 0.4863
# Epoch 24: val_accuracy did not improve from 0.51651
# 167/167 [==============================] - 13s 80ms/step - loss: 2.7891 - accuracy: 0.4863 - val_loss: 1.3408 - val_accuracy: 0.5130 - lr: 1.0000e-04
# Epoch 25/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7588 - accuracy: 0.4943
# Epoch 25: val_accuracy improved from 0.51651 to 0.52949, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 2.7588 - accuracy: 0.4943 - val_loss: 1.2802 - val_accuracy: 0.5295 - lr: 1.0000e-04
# Epoch 26/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7517 - accuracy: 0.4962
# Epoch 26: val_accuracy improved from 0.52949 to 0.53631, saving model to best_model.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 2.7517 - accuracy: 0.4962 - val_loss: 1.2791 - val_accuracy: 0.5363 - lr: 1.0000e-04
# Epoch 27/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7131 - accuracy: 0.5004
# Epoch 27: val_accuracy did not improve from 0.53631
# 167/167 [==============================] - 13s 80ms/step - loss: 2.7131 - accuracy: 0.5004 - val_loss: 1.3186 - val_accuracy: 0.5070 - lr: 1.0000e-04
# Epoch 28/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6849 - accuracy: 0.5040
# Epoch 28: val_accuracy improved from 0.53631 to 0.54665, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 2.6849 - accuracy: 0.5040 - val_loss: 1.2377 - val_accuracy: 0.5467 - lr: 1.0000e-04
# Epoch 29/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6602 - accuracy: 0.5025
# Epoch 29: val_accuracy improved from 0.54665 to 0.56932, saving model to best_model.h5
# 167/167 [==============================] - 14s 81ms/step - loss: 2.6602 - accuracy: 0.5025 - val_loss: 1.2029 - val_accuracy: 0.5693 - lr: 1.0000e-04
# Epoch 30/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6495 - accuracy: 0.5112
# Epoch 30: val_accuracy did not improve from 0.56932
# 167/167 [==============================] - 13s 80ms/step - loss: 2.6495 - accuracy: 0.5112 - val_loss: 1.2320 - val_accuracy: 0.5541 - lr: 1.0000e-04
# Epoch 31/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6126 - accuracy: 0.5146
# Epoch 31: val_accuracy did not improve from 0.56932
# 167/167 [==============================] - 13s 79ms/step - loss: 2.6126 - accuracy: 0.5146 - val_loss: 1.3912 - val_accuracy: 0.4978 - lr: 1.0000e-04
# Epoch 32/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5904 - accuracy: 0.5224
# Epoch 32: val_accuracy did not improve from 0.56932
# 167/167 [==============================] - 14s 81ms/step - loss: 2.5904 - accuracy: 0.5224 - val_loss: 1.3365 - val_accuracy: 0.5106 - lr: 1.0000e-04
# Epoch 33/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5999 - accuracy: 0.5234
# Epoch 33: val_accuracy did not improve from 0.56932
# 167/167 [==============================] - 13s 78ms/step - loss: 2.5999 - accuracy: 0.5234 - val_loss: 1.2939 - val_accuracy: 0.5295 - lr: 1.0000e-04
# Epoch 34/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5901 - accuracy: 0.5225
# Epoch 34: val_accuracy improved from 0.56932 to 0.57262, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 2.5901 - accuracy: 0.5225 - val_loss: 1.1931 - val_accuracy: 0.5726 - lr: 1.0000e-04
# Epoch 35/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5599 - accuracy: 0.5271
# Epoch 35: val_accuracy improved from 0.57262 to 0.57636, saving model to best_model.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 2.5599 - accuracy: 0.5271 - val_loss: 1.1909 - val_accuracy: 0.5764 - lr: 1.0000e-04
# Epoch 36/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5130 - accuracy: 0.5385
# Epoch 36: val_accuracy did not improve from 0.57636
# 167/167 [==============================] - 14s 81ms/step - loss: 2.5130 - accuracy: 0.5385 - val_loss: 1.3687 - val_accuracy: 0.5037 - lr: 1.0000e-04
# Epoch 37/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4991 - accuracy: 0.5434
# Epoch 37: val_accuracy improved from 0.57636 to 0.58011, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 2.4991 - accuracy: 0.5434 - val_loss: 1.1569 - val_accuracy: 0.5801 - lr: 1.0000e-04
# Epoch 38/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4820 - accuracy: 0.5556
# Epoch 38: val_accuracy improved from 0.58011 to 0.58957, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 2.4820 - accuracy: 0.5556 - val_loss: 1.1288 - val_accuracy: 0.5896 - lr: 1.0000e-04
# Epoch 39/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4667 - accuracy: 0.5478
# Epoch 39: val_accuracy did not improve from 0.58957
# 167/167 [==============================] - 13s 79ms/step - loss: 2.4667 - accuracy: 0.5478 - val_loss: 1.1777 - val_accuracy: 0.5803 - lr: 1.0000e-04
# Epoch 40/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4430 - accuracy: 0.5483
# Epoch 40: val_accuracy improved from 0.58957 to 0.60695, saving model to best_model.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 2.4430 - accuracy: 0.5483 - val_loss: 1.1111 - val_accuracy: 0.6070 - lr: 1.0000e-04
# Epoch 41/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4149 - accuracy: 0.5591
# Epoch 41: val_accuracy did not improve from 0.60695
# 167/167 [==============================] - 13s 77ms/step - loss: 2.4149 - accuracy: 0.5591 - val_loss: 1.1499 - val_accuracy: 0.5812 - lr: 1.0000e-04
# Epoch 42/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3948 - accuracy: 0.5677
# Epoch 42: val_accuracy did not improve from 0.60695
# 167/167 [==============================] - 13s 78ms/step - loss: 2.3948 - accuracy: 0.5677 - val_loss: 1.2011 - val_accuracy: 0.5770 - lr: 1.0000e-04
# Epoch 43/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3885 - accuracy: 0.5645
# Epoch 43: val_accuracy did not improve from 0.60695
# 167/167 [==============================] - 13s 79ms/step - loss: 2.3885 - accuracy: 0.5645 - val_loss: 1.1193 - val_accuracy: 0.6004 - lr: 1.0000e-04
# Epoch 44/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3751 - accuracy: 0.5627
# Epoch 44: val_accuracy did not improve from 0.60695
# 167/167 [==============================] - 13s 79ms/step - loss: 2.3751 - accuracy: 0.5627 - val_loss: 1.1272 - val_accuracy: 0.5973 - lr: 1.0000e-04
# Epoch 45/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3320 - accuracy: 0.5734
# Epoch 45: val_accuracy improved from 0.60695 to 0.60783, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 2.3320 - accuracy: 0.5734 - val_loss: 1.1033 - val_accuracy: 0.6078 - lr: 1.0000e-04
# Epoch 46/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3099 - accuracy: 0.5805
# Epoch 46: val_accuracy did not improve from 0.60783
# 167/167 [==============================] - 13s 79ms/step - loss: 2.3099 - accuracy: 0.5805 - val_loss: 1.1594 - val_accuracy: 0.5909 - lr: 1.0000e-04
# Epoch 47/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3120 - accuracy: 0.5869
# Epoch 47: val_accuracy improved from 0.60783 to 0.61642, saving model to best_model.h5
# 167/167 [==============================] - 14s 82ms/step - loss: 2.3120 - accuracy: 0.5869 - val_loss: 1.0668 - val_accuracy: 0.6164 - lr: 1.0000e-04
# Epoch 48/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2874 - accuracy: 0.5844
# Epoch 48: val_accuracy improved from 0.61642 to 0.62588, saving model to best_model.h5
# 167/167 [==============================] - 13s 78ms/step - loss: 2.2874 - accuracy: 0.5844 - val_loss: 1.0527 - val_accuracy: 0.6259 - lr: 1.0000e-04
# Epoch 49/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2593 - accuracy: 0.5902
# Epoch 49: val_accuracy did not improve from 0.62588
# 167/167 [==============================] - 13s 79ms/step - loss: 2.2593 - accuracy: 0.5902 - val_loss: 1.1423 - val_accuracy: 0.5922 - lr: 1.0000e-04
# Epoch 50/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2747 - accuracy: 0.5863
# Epoch 50: val_accuracy improved from 0.62588 to 0.63842, saving model to best_model.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 2.2747 - accuracy: 0.5863 - val_loss: 1.0222 - val_accuracy: 0.6384 - lr: 1.0000e-04
# Epoch 51/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1940 - accuracy: 0.6024
# Epoch 51: val_accuracy did not improve from 0.63842
# 167/167 [==============================] - 13s 78ms/step - loss: 2.1940 - accuracy: 0.6024 - val_loss: 1.0729 - val_accuracy: 0.6204 - lr: 1.0000e-04
# Epoch 52/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2328 - accuracy: 0.5977
# Epoch 52: val_accuracy did not improve from 0.63842
# 167/167 [==============================] - 13s 78ms/step - loss: 2.2328 - accuracy: 0.5977 - val_loss: 1.1338 - val_accuracy: 0.5907 - lr: 1.0000e-04
# Epoch 53/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1951 - accuracy: 0.5983
# Epoch 53: val_accuracy improved from 0.63842 to 0.64855, saving model to best_model.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 2.1951 - accuracy: 0.5983 - val_loss: 0.9964 - val_accuracy: 0.6485 - lr: 1.0000e-04
# Epoch 54/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2074 - accuracy: 0.6036
# Epoch 54: val_accuracy did not improve from 0.64855
# 167/167 [==============================] - 13s 78ms/step - loss: 2.2074 - accuracy: 0.6036 - val_loss: 1.0402 - val_accuracy: 0.6364 - lr: 1.0000e-04
# Epoch 55/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1894 - accuracy: 0.6055
# Epoch 55: val_accuracy did not improve from 0.64855
# 167/167 [==============================] - 13s 78ms/step - loss: 2.1894 - accuracy: 0.6055 - val_loss: 1.0433 - val_accuracy: 0.6356 - lr: 1.0000e-04
# Epoch 56/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1503 - accuracy: 0.6140
# Epoch 56: val_accuracy did not improve from 0.64855
# 167/167 [==============================] - 13s 77ms/step - loss: 2.1503 - accuracy: 0.6140 - val_loss: 1.1111 - val_accuracy: 0.6045 - lr: 1.0000e-04
# Epoch 57/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1525 - accuracy: 0.6108
# Epoch 57: val_accuracy improved from 0.64855 to 0.65163, saving model to best_model.h5
# 167/167 [==============================] - 13s 80ms/step - loss: 2.1525 - accuracy: 0.6108 - val_loss: 0.9792 - val_accuracy: 0.6516 - lr: 1.0000e-04
# Epoch 58/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1062 - accuracy: 0.6159
# Epoch 58: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 77ms/step - loss: 2.1062 - accuracy: 0.6159 - val_loss: 1.0436 - val_accuracy: 0.6325 - lr: 1.0000e-04
# Epoch 59/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0826 - accuracy: 0.6259
# Epoch 59: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 76ms/step - loss: 2.0826 - accuracy: 0.6259 - val_loss: 0.9723 - val_accuracy: 0.6505 - lr: 1.0000e-04
# Epoch 60/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1100 - accuracy: 0.6205
# Epoch 60: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 77ms/step - loss: 2.1100 - accuracy: 0.6205 - val_loss: 1.1000 - val_accuracy: 0.6171 - lr: 1.0000e-04
# Epoch 61/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0738 - accuracy: 0.6310
# Epoch 61: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 77ms/step - loss: 2.0738 - accuracy: 0.6310 - val_loss: 1.0964 - val_accuracy: 0.6210 - lr: 1.0000e-04
# Epoch 62/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0360 - accuracy: 0.6331
# Epoch 62: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 77ms/step - loss: 2.0360 - accuracy: 0.6331 - val_loss: 1.0412 - val_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 63/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0380 - accuracy: 0.6330
# Epoch 63: val_accuracy did not improve from 0.65163
# 167/167 [==============================] - 13s 78ms/step - loss: 2.0380 - accuracy: 0.6330 - val_loss: 1.1901 - val_accuracy: 0.5801 - lr: 1.0000e-04
# Epoch 64/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0295 - accuracy: 0.6409
# Epoch 64: val_accuracy improved from 0.65163 to 0.67430, saving model to best_model.h5
# 167/167 [==============================] - 13s 79ms/step - loss: 2.0295 - accuracy: 0.6409 - val_loss: 0.9254 - val_accuracy: 0.6743 - lr: 1.0000e-04
# Epoch 65/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9960 - accuracy: 0.6417
# Epoch 65: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 78ms/step - loss: 1.9960 - accuracy: 0.6417 - val_loss: 1.1462 - val_accuracy: 0.6015 - lr: 1.0000e-04
# Epoch 66/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9820 - accuracy: 0.6461
# Epoch 66: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 79ms/step - loss: 1.9820 - accuracy: 0.6461 - val_loss: 1.0135 - val_accuracy: 0.6488 - lr: 1.0000e-04
# Epoch 67/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9330 - accuracy: 0.6552
# Epoch 67: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 77ms/step - loss: 1.9330 - accuracy: 0.6552 - val_loss: 1.1287 - val_accuracy: 0.6111 - lr: 1.0000e-04
# Epoch 68/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9367 - accuracy: 0.6558
# Epoch 68: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 78ms/step - loss: 1.9367 - accuracy: 0.6558 - val_loss: 1.0925 - val_accuracy: 0.6219 - lr: 1.0000e-04
# Epoch 69/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9154 - accuracy: 0.6596
# Epoch 69: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 78ms/step - loss: 1.9154 - accuracy: 0.6596 - val_loss: 0.9854 - val_accuracy: 0.6545 - lr: 1.0000e-04
# Epoch 70/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9095 - accuracy: 0.6634
# Epoch 70: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 79ms/step - loss: 1.9095 - accuracy: 0.6634 - val_loss: 0.9755 - val_accuracy: 0.6474 - lr: 1.0000e-04
# Epoch 71/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8871 - accuracy: 0.6648
# Epoch 71: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 78ms/step - loss: 1.8871 - accuracy: 0.6648 - val_loss: 0.9445 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 72/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8716 - accuracy: 0.6579
# Epoch 72: val_accuracy did not improve from 0.67430
# 167/167 [==============================] - 13s 77ms/step - loss: 1.
val_accuracy did not improve from 0.70290
# 167/167 [==============================] - 14s 83ms/step - loss: 1.4112 - accuracy: 0.7431 - val_loss: 0.8782 - val_accuracy: 0.6996 - lr: 2.5000e-05
# Epoch 112/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4071 - accuracy: 0.7501
# Epoch 112: val_accuracy did not improve from 0.70290
# 167/167 [==============================] - 14s 82ms/step - loss: 1.4071 - accuracy: 0.7501 - val_loss: 0.9464 - val_accuracy: 0.6758 - lr: 2.5000e-05
# Epoch 113/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3961 - accuracy: 0.7451
# Epoch 113: val_accuracy did not improve from 0.70290
# 167/167 [==============================] - 14s 82ms/step - loss: 1.3961 - accuracy: 0.7451 - val_loss: 0.9123 - val_accuracy: 0.6873 - lr: 2.5000e-05
# Epoch 114/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3970 - accuracy: 0.7517
# Epoch 114: val_accuracy did not improve from 0.70290
#
# Epoch 114: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 14s 83ms/step - loss: 1.3970 - accuracy: 0.7517 - val_loss: 0.9068 - val_accuracy: 0.6919 - lr: 2.5000e-05
# Epoch 114: early stopping

# %%
save_model = model.save('SMMB_100e_RAFDB_BetterBalance_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model("SMMB_BetterWeights_AffectNet_100e.h5")

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 5s 4ms/step
# Accuracy =  0.453125

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 31ms/step
# Accuracy =  0.59375
# 2/2 [==============================] - 0s 33ms/step
# Accuracy =  0.328125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4624

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# Accuracy: 46.239098837209305
# anger 717/5545 acc: 53.4
# disgust 515/5545 acc: 38.4
# fear 716/5545 acc: 61.5
# happy 996/5545 acc: 65.3
# neutral 1022/5545 acc: 51.6
# sad 684/5545 acc: 27.5
# surprise 854/5545 acc: 18.6

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 46.239098837209305
# anger 717/5545 acc: 53.4
# disgust 515/5545 acc: 38.4
# fear 716/5545 acc: 61.5
# happy 996/5545 acc: 65.3
# neutral 1022/5545 acc: 51.6
# sad 684/5545 acc: 27.5
# surprise 854/5545 acc: 18.6

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.39      0.53      0.45       717
#      disgust       0.28      0.38      0.33       515
#         fear       0.32      0.61      0.42       716
#        happy       0.89      0.65      0.75       996
#      neutral       0.73      0.52      0.60      1022
#          sad       0.30      0.27      0.29       684
#     surprise       0.43      0.19      0.26       854
#
#     accuracy                           0.46      5504
#    macro avg       0.48      0.45      0.44      5504
# weighted avg       0.52      0.46      0.47      5504

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 348/348 [==============================] - 42s 118ms/step - loss: 1.2299 - accuracy: 0.5190
# 87/87 [==============================] - 7s 85ms/step - loss: 1.4479 - accuracy: 0.4628

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# 2/2 [==============================] - 0s 16ms/step
# Accuracy =  0.46875
# 2/2 [==============================] - 0s 16ms/step
# Accuracy =  0.234375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3394

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# Accuracy: 33.935546875
# Angry 295/2100 acc: 48.8
# Disgust 294/2100 acc: 46.9
# Fear 294/2100 acc: 69.4
# Happy 286/2100 acc: 16.8
# Neutral 289/2100 acc: 2.1
# Sad 298/2100 acc: 41.9
# Surprise 292/2100 acc: 10.3

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 33.935546875
# Angry 295/2100 acc: 48.8
# Disgust 294/2100 acc: 46.9
# Fear 294/2100 acc: 69.4
# Happy 286/2100 acc: 16.8
# Neutral 289/2100 acc: 2.1
# Sad 298/2100 acc: 41.9
# Surprise 292/2100 acc: 10.3

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.38      0.49      0.42       295
#      Disgust       0.32      0.47      0.38       294
#         Fear       0.31      0.69      0.43       294
#        Happy       0.77      0.17      0.28       286
#      Neutral       0.19      0.02      0.04       289
#          Sad       0.32      0.42      0.36       298
#     Surprise       0.31      0.10      0.15       292
#
#     accuracy                           0.34      2048
#    macro avg       0.37      0.34      0.30      2048
# weighted avg       0.37      0.34      0.30      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
