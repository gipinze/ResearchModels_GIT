# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.nasnet import NASNetMobile, preprocess_input

from keras.applications import VGG19
from keras.layers import Dense, Dropout, Flatten, Activation, Input, GlobalAveragePooling2D
from keras import regularizers
from keras.models import Model, load_model

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,
        preprocessing_function=preprocess_input)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
with strategy.scope():

   # Load the VGG19 model
    base_model = NASNetMobile( 
        weights='imagenet',
        include_top=False, 
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = False
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    x = base_model(inputs)
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu')(x) 
    predictions = Dense(7, activation='softmax')(x)

    # Compile the model
    model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  NASNet (Functional)         (None, 2, 2, 1056)        4269716
#
#  global_average_pooling2d (G  (None, 1056)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               270592
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 4,574,107
# Trainable params: 304,391
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
from collections import Counter


# Callbacks
counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
import matplotlib.pyplot as plt

# Extract class names and counts for train and test datasets
class_names = list(test_count.columns)
train_counts = train_count.iloc[0].tolist()
test_counts = test_count.iloc[0].tolist()

# Create horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 8))
bar_width = 0.4
bar_spacing = 0.1
index_train = range(len(class_names))
index_test = [i + bar_width + bar_spacing for i in index_train]
train_bars = ax.barh(index_train, train_counts, bar_width, color='blue', label='Train')
test_bars = ax.barh(index_test, test_counts, bar_width, color='green', label='Test')

# Add labels, legend, and title
adjusted_index_train = [i + bar_width / 2 for i in index_train]
ax.set_xlabel('Number of samples')
ax.set_ylabel('Emotions')
ax.set_yticks(adjusted_index_train)
ax.set_yticklabels(class_names)
ax.legend(loc='lower right')
ax.set_title('RAFDB Dataset')

# Display chart
plt.tight_layout()
plt.savefig('distribution.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# Compute class weights
counter = Counter(train_generator.classes)
max_val = float(max(counter.values()))
class_weights = {class_id: np.minimum(max_val / num_images, 3) for class_id, num_images in counter.items()}

# Get the class names and their counts in train and test sets
class_names = list(train_count.columns)
train_counts = train_count.iloc[0].tolist()
test_counts = test_count.iloc[0].tolist()

# Apply the class weights to the train counts
train_counts_weighted = [count * class_weights[i] for i, count in enumerate(train_counts)]

# Define the size of the bars
bar_width = 0.35
bar_spacing = 0.05

# Define the figure and axes objects
fig, ax = plt.subplots(figsize=(12, 7))

# Create the horizontal bars for train and test counts
index = np.arange(len(class_names))
train_bars = ax.barh(index, train_counts_weighted, bar_width, color='blue', label='Train')
test_bars = ax.barh(index + bar_width + bar_spacing, test_counts, bar_width, color='green', label='Test')

# Add labels, legend, and title
ax.set_xlabel('Number of samples')
ax.set_ylabel('Emotions')
ax.set_yticks(index + bar_width / 2)
ax.set_yticklabels(class_names)
ax.legend(loc='lower right')
ax.set_title('RAFDB - Class distribution with weighted training counts')

# Show the plot
plt.show()

# %%
# Compute the class weights
class_to_idx=validation_generator.class_indices
idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
print(idx_to_class)

(unique, counts) = np.unique(train_generator.classes, return_counts=True)
cw=1/counts
cw/=cw.min()
class_weights = {i:cwi for i,cwi in zip(unique,cw)}
print(class_weights)

# Get the class names and their counts in train and test sets
class_names = list(train_count.columns)
train_counts = train_count.iloc[0].tolist()
test_counts = test_count.iloc[0].tolist()

# Apply the class weights to the train counts
train_counts_weighted = [count * class_weights[i] for i, count in enumerate(train_counts)]

# Define the size of the bars
bar_width = 0.35
bar_spacing = 0.05

# Define the figure and axes objects
fig, ax = plt.subplots(figsize=(12, 7))

# Create the horizontal bars for train and test counts
index = np.arange(len(class_names))
train_bars = ax.barh(index, train_counts_weighted, bar_width, color='blue', label='Train')
test_bars = ax.barh(index + bar_width + bar_spacing, test_counts, bar_width, color='green', label='Test')

# Add labels, legend, and title
ax.set_xlabel('Number of samples')
ax.set_ylabel('Emotions')
ax.set_yticks(index + bar_width / 2)
ax.set_yticklabels(class_names)
ax.legend(loc='lower right')
ax.set_title('RAFDB - Class distribution with weighted training counts')

# Show the plot
plt.show()
# Out:
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
# {0: 1.8060075093867334, 1: 16.54816513761468, 2: 1.7610446668293875, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=30,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/30
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 3.0433 - accuracy: 0.2184
# Epoch 1: val_accuracy improved from -inf to 0.30385, saving model to best_model.h5
# 448/448 [==============================] - 86s 124ms/step - loss: 3.0433 - accuracy: 0.2184 - val_loss: 1.7517 - val_accuracy: 0.3039 - lr: 1.0000e-04
# Epoch 2/30
# 448/448 [==============================] - ETA: 0s - loss: 2.8250 - accuracy: 0.2631
# Epoch 2: val_accuracy improved from 0.30385 to 0.31403, saving model to best_model.h5
# 448/448 [==============================] - 47s 104ms/step - loss: 2.8250 - accuracy: 0.2631 - val_loss: 1.7063 - val_accuracy: 0.3140 - lr: 1.0000e-04
# Epoch 3/30
# 448/448 [==============================] - ETA: 0s - loss: 2.7712 - accuracy: 0.2808
# Epoch 3: val_accuracy improved from 0.31403 to 0.32101, saving model to best_model.h5
# 448/448 [==============================] - 46s 103ms/step - loss: 2.7712 - accuracy: 0.2808 - val_loss: 1.6997 - val_accuracy: 0.3210 - lr: 1.0000e-04
# Epoch 4/30
# 448/448 [==============================] - ETA: 0s - loss: 2.7435 - accuracy: 0.2897
# Epoch 4: val_accuracy improved from 0.32101 to 0.34556, saving model to best_model.h5
# 448/448 [==============================] - 46s 102ms/step - loss: 2.7435 - accuracy: 0.2897 - val_loss: 1.6667 - val_accuracy: 0.3456 - lr: 1.0000e-04
# Epoch 5/30
# 448/448 [==============================] - ETA: 0s - loss: 2.7223 - accuracy: 0.3010
# Epoch 5: val_accuracy improved from 0.34556 to 0.34612, saving model to best_model.h5
# 448/448 [==============================] - 47s 105ms/step - loss: 2.7223 - accuracy: 0.3010 - val_loss: 1.6565 - val_accuracy: 0.3461 - lr: 1.0000e-04
# Epoch 6/30
# 448/448 [==============================] - ETA: 0s - loss: 2.7010 - accuracy: 0.3062
# Epoch 6: val_accuracy did not improve from 0.34612
# 448/448 [==============================] - 44s 98ms/step - loss: 2.7010 - accuracy: 0.3062 - val_loss: 1.6566 - val_accuracy: 0.3444 - lr: 1.0000e-04
# Epoch 7/30
# 448/448 [==============================] - ETA: 0s - loss: 2.7031 - accuracy: 0.3054
# Epoch 7: val_accuracy improved from 0.34612 to 0.34654, saving model to best_model.h5
# 448/448 [==============================] - 45s 101ms/step - loss: 2.7031 - accuracy: 0.3054 - val_loss: 1.6554 - val_accuracy: 0.3465 - lr: 1.0000e-04
# Epoch 8/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6774 - accuracy: 0.3115
# Epoch 8: val_accuracy improved from 0.34654 to 0.35393, saving model to best_model.h5
# 448/448 [==============================] - 45s 100ms/step - loss: 2.6774 - accuracy: 0.3115 - val_loss: 1.6317 - val_accuracy: 0.3539 - lr: 1.0000e-04
# Epoch 9/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6736 - accuracy: 0.3144
# Epoch 9: val_accuracy did not improve from 0.35393
# 448/448 [==============================] - 44s 98ms/step - loss: 2.6736 - accuracy: 0.3144 - val_loss: 1.6575 - val_accuracy: 0.3461 - lr: 1.0000e-04
# Epoch 10/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6675 - accuracy: 0.3208
# Epoch 10: val_accuracy did not improve from 0.35393
# 448/448 [==============================] - 42s 94ms/step - loss: 2.6675 - accuracy: 0.3208 - val_loss: 1.6470 - val_accuracy: 0.3502 - lr: 1.0000e-04
# Epoch 11/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6577 - accuracy: 0.3200
# Epoch 11: val_accuracy improved from 0.35393 to 0.35421, saving model to best_model.h5
# 448/448 [==============================] - 47s 105ms/step - loss: 2.6577 - accuracy: 0.3200 - val_loss: 1.6450 - val_accuracy: 0.3542 - lr: 1.0000e-04
# Epoch 12/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6494 - accuracy: 0.3240
# Epoch 12: val_accuracy did not improve from 0.35421
# 448/448 [==============================] - 45s 100ms/step - loss: 2.6494 - accuracy: 0.3240 - val_loss: 1.6383 - val_accuracy: 0.3538 - lr: 1.0000e-04
# Epoch 13/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6401 - accuracy: 0.3268
# Epoch 13: val_accuracy did not improve from 0.35421
# 448/448 [==============================] - 41s 91ms/step - loss: 2.6401 - accuracy: 0.3268 - val_loss: 1.6436 - val_accuracy: 0.3489 - lr: 1.0000e-04
# Epoch 14/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6381 - accuracy: 0.3240
# Epoch 14: val_accuracy did not improve from 0.35421
# 448/448 [==============================] - 40s 90ms/step - loss: 2.6381 - accuracy: 0.3240 - val_loss: 1.6219 - val_accuracy: 0.3534 - lr: 1.0000e-04
# Epoch 15/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6248 - accuracy: 0.3308
# Epoch 15: val_accuracy improved from 0.35421 to 0.36189, saving model to best_model.h5
# 448/448 [==============================] - 490s 1s/step - loss: 2.6248 - accuracy: 0.3308 - val_loss: 1.6290 - val_accuracy: 0.3619 - lr: 1.0000e-04
# Epoch 16/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6238 - accuracy: 0.3319
# Epoch 16: val_accuracy improved from 0.36189 to 0.36914, saving model to best_model.h5
# 448/448 [==============================] - 472s 1s/step - loss: 2.6238 - accuracy: 0.3319 - val_loss: 1.6120 - val_accuracy: 0.3691 - lr: 1.0000e-04
# Epoch 17/30
# 448/448 [==============================] - ETA: 0s - loss: 2.6287 - accuracy: 0.3286
# Epoch 17: val_accuracy improved from 0.36914 to 0.37277, saving model to best_model.h5
# 448/448 [==============================] - 41s 91ms/step - loss: 2.6287 - accuracy: 0.3286 - val_loss: 1.6049 - val_accuracy: 0.3728 - lr: 1.0000e-04
# Epoch 18/30
# 448/448 [==============================] - ETA: 0s - loss: 2.
1

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.27      0.16      0.20       955
#      Disgust       0.33      0.01      0.02       111
#         Fear       0.26      0.20      0.22      1023
#        Happy       0.49      0.52      0.51      1774
#      Neutral       0.32      0.46      0.38      1231
#          Sad       0.37      0.26      0.30      1243
#     Surprise       0.41      0.64      0.50       831
#
#     accuracy                           0.38      7168
#    macro avg       0.35      0.32      0.30      7168
# weighted avg       0.37      0.38      0.36      7168

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 449/449 [==============================] - 32s 70ms/step - loss: 1.6224 - accuracy: 0.3541
# 113/113 [==============================] - 5s 44ms/step - loss: 1.5886 - accuracy: 0.3757

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 45ms/step
# Accuracy =  0.328125
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.171875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.2520

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 64ms/step
# Accuracy: 25.1953125
# Angry 294/2100 acc: 14.6
# Disgust 292/2100 acc: 0.0
# Fear 293/2100 acc: 10.6
# Happy 294/2100 acc: 52.0
# Neutral 294/2100 acc: 62.9
# Sad 293/2100 acc: 6.8
# Surprise 288/2100 acc: 29.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 25.1953125
# Angry 294/2100 acc: 14.6
# Disgust 292/2100 acc: 0.0
# Fear 293/2100 acc: 10.6
# Happy 294/2100 acc: 52.0
# Neutral 294/2100 acc: 62.9
# Sad 293/2100 acc: 6.8
# Surprise 288/2100 acc: 29.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.28      0.13      0.17       292
#      Disgust       0.00      0.00      0.00       290
#         Fear       0.43      0.09      0.15       291
#        Happy       0.25      0.27      0.26       294
#      Neutral       0.26      0.30      0.28       294
#          Sad       0.15      0.30      0.20       292
#     Surprise       0.26      0.53      0.35       295
#
#     accuracy                           0.23      2048
#    macro avg       0.23      0.23      0.20      2048
# weighted avg       0.23      0.23      0.20      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  NASNet (Functional)         (None, 2, 2, 1056)        4269716
#
#  global_average_pooling2d (G  (None, 1056)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               270592
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 4,574,107
# Trainable params: 4,537,369
# Non-trainable params: 36,738
# _________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 746 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 746 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 2.7595 - accuracy: 0.2723
# Epoch 1: val_accuracy did not improve from 0.37598
# 448/448 [==============================] - 182s 235ms/step - loss: 2.7595 - accuracy: 0.2723 - val_loss: 1.7067 - val_accuracy: 0.3619 - lr: 1.0000e-04
# Epoch 2/300
# 448/448 [==============================] - ETA: 0s - loss: 2.5855 - accuracy: 0.3459
# Epoch 2: val_accuracy did not improve from 0.37598
# 448/448 [==============================] - 96s 215ms/step - loss: 2.5855 - accuracy: 0.3459 - val_loss: 1.7407 - val_accuracy: 0.3622 - lr: 1.0000e-04
# Epoch 3/300
# 448/448 [==============================] - ETA: 0s - loss: 2.4896 - accuracy: 0.3809
# Epoch 3: val_accuracy improved from 0.37598 to 0.38825, saving model to best_model.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 2.4896 - accuracy: 0.3809 - val_loss: 1.6766 - val_accuracy: 0.3883 - lr: 1.0000e-04
# Epoch 4/300
# 448/448 [==============================] - ETA: 0s - loss: 2.3897 - accuracy: 0.4126
# Epoch 4: val_accuracy improved from 0.38825 to 0.40081, saving model to best_model.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 2.3897 - accuracy: 0.4126 - val_loss: 1.6470 - val_accuracy: 0.4008 - lr: 1.0000e-04
# Epoch 5/300
# 448/448 [==============================] - ETA: 0s - loss: 2.3185 - accuracy: 0.4376
# Epoch 5: val_accuracy improved from 0.40081 to 0.41713, saving model to best_model.h5
# 448/448 [==============================] - 103s 229ms/step - loss: 2.3185 - accuracy: 0.4376 - val_loss: 1.5942 - val_accuracy: 0.4171 - lr: 1.0000e-04
# Epoch 6/300
# 448/448 [==============================] - ETA: 0s - loss: 2.2346 - accuracy: 0.4622
# Epoch 6: val_accuracy improved from 0.41713 to 0.42048, saving model to best_model.h5
# 448/448 [==============================] - 110s 244ms/step - loss: 2.2346 - accuracy: 0.4622 - val_loss: 1.5387 - val_accuracy: 0.4205 - lr: 1.0000e-04
# Epoch 7/300
# 448/448 [==============================] - ETA: 0s - loss: 2.1771 - accuracy: 0.4762
# Epoch 7: val_accuracy improved from 0.42048 to 0.45103, saving model to best_model.h5
# 448/448 [==============================] - 114s 254ms/step - loss: 2.1771 - accuracy: 0.4762 - val_loss: 1.4711 - val_accuracy: 0.4510 - lr: 1.0000e-04
# Epoch 8/300
# 448/448 [==============================] - ETA: 0s - loss: 2.1312 - accuracy: 0.4865
# Epoch 8: val_accuracy improved from 0.45103 to 0.47084, saving model to best_model.h5
# 448/448 [==============================] - 133s 297ms/step - loss: 2.1312 - accuracy: 0.4865 - val_loss: 1.3741 - val_accuracy: 0.4708 - lr: 1.0000e-04
# Epoch 9/300
# 448/448 [==============================] - ETA: 0s - loss: 2.0699 - accuracy: 0.5033
# Epoch 9: val_accuracy improved from 0.47084 to 0.47712, saving model to best_model.h5
# 448/448 [==============================] - 135s 299ms/step - loss: 2.0699 - accuracy: 0.5033 - val_loss: 1.3593 - val_accuracy: 0.4771 - lr: 1.0000e-04
# Epoch 10/300
# 448/448 [==============================] - ETA: 0s - loss: 2.0462 - accuracy: 0.5090
# Epoch 10: val_accuracy did not improve from 0.47712
# 448/448 [==============================] - 122s 271ms/step - loss: 2.0462 - accuracy: 0.5090 - val_loss: 1.3742 - val_accuracy: 0.4753 - lr: 1.0000e-04
# Epoch 11/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9908 - accuracy: 0.5219
# Epoch 11: val_accuracy improved from 0.47712 to 0.48605, saving model to best_model.h5
# 448/448 [==============================] - 129s 287ms/step - loss: 1.9908 - accuracy: 0.5219 - val_loss: 1.3446 - val_accuracy: 0.4860 - lr: 1.0000e-04
# Epoch 12/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9594 - accuracy: 0.5337
# Epoch 12: val_accuracy improved from 0.48605 to 0.50167, saving model to best_model.h5
# 448/448 [==============================] - 120s 269ms/step - loss: 1.9594 - accuracy: 0.5337 - val_loss: 1.3683 - val_accuracy: 0.5017 - lr: 1.0000e-04
# Epoch 13/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9190 - accuracy: 0.5422
# Epoch 13: val_accuracy improved from 0.50167 to 0.51939, saving model to best_model.h5
# 448/448 [==============================] - 124s 277ms/step - loss: 1.9190 - accuracy: 0.5422 - val_loss: 1.2791 - val_accuracy: 0.5194 - lr: 1.0000e-04
# Epoch 14/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9056 - accuracy: 0.5451
# Epoch 14: val_accuracy improved from 0.51939 to 0.53446, saving model to best_model.h5
# 448/448 [==============================] - 133s 294ms/step - loss: 1.9056 - accuracy: 0.5451 - val_loss: 1.2231 - val_accuracy: 0.5345 - lr: 1.0000e-04
# Epoch 15/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8579 - accuracy: 0.5573
# Epoch 15: val_accuracy improved from 0.53446 to 0.53697, saving model to best_model.h5
# 448/448 [==============================] - 131s 291ms/step - loss: 1.8579 - accuracy: 0.5573 - val_loss: 1.2256 - val_accuracy: 0.5370 - lr: 1.0000e-04
# Epoch 16/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8328 - accuracy: 0.5627
# Epoch 16: val_accuracy did not improve from 0.53697
# 448/448 [==============================] - 145s 324ms/step - loss: 1.8328 - accuracy: 0.5627 - val_loss: 1.2404 - val_accuracy: 0.5324 - lr: 1.0000e-04
# Epoch 17/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8079 - accuracy: 0.5679
# Epoch 17: val_accuracy did not improve from 0.53697
# 448/448 [==============================] - 127s 283ms/step - loss: 1.8079 - accuracy: 0.5679 - val_loss: 1.2622 - val_accuracy: 0.5317 - lr: 1.0000e-04
# Epoch 18/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7759 - accuracy: 0.5781
# Epoch 18: val_accuracy did not improve from 0.53697
# 448/448 [==============================] - 121s 269ms/step - loss: 1.7759 - accuracy: 0.5781 - val_loss: 1.2297 - val_accuracy: 0.5370 - lr: 1.0000e-04
# Epoch 19/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7566 - accuracy: 0.5828
# Epoch 19: val_accuracy improved from 0.53697 to 0.55539, saving model to best_model.h5
# 448/448 [==============================] - 127s 283ms/step - loss: 1.7566 - accuracy: 0.5828 - val_loss: 1.2020 - val_accuracy: 0.5554 - lr: 1.0000e-04
# Epoch 20/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7335 - accuracy: 0.5857
# Epoch 20: val_accuracy improved from 0.55539 to 0.57003, saving model to best_model.h5
# 448/448 [==============================] - 134s 300ms/step - loss: 1.7335 - accuracy: 0.5857 - val_loss: 1.1612 - val_accuracy: 0.5700 - lr: 1.0000e-04
# Epoch 21/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7138 - accuracy: 0.5906
# Epoch 21: val_accuracy did not improve from 0.57003
# 448/448 [==============================] - 129s 287ms/step - loss: 1.7138 - accuracy: 0.5906 - val_loss: 1.1797 - val_accuracy: 0.5639 - lr: 1.0000e-04
# Epoch 22/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6990 - accuracy: 0.5927
# Epoch 22: val_accuracy improved from 0.57003 to 0.57101, saving model to best_model.h5
# 448/448 [==============================] - 121s 269ms/step - loss: 1.6990 - accuracy: 0.5927 - val_loss: 1.1631 - val_accuracy: 0.5710 - lr: 1.0000e-04
# Epoch 23/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6663 - accuracy: 0.6047
# Epoch 23: val_accuracy improved from 0.57101 to 0.58259, saving model to best_model.h5
# 448/448 [==============================] - 126s 280ms/step - loss: 1.6663 - accuracy: 0.6047 - val_loss: 1.1171 - val_accuracy: 0.5826 - lr: 1.0000e-04
# Epoch 24/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6524 - accuracy: 0.6068
# Epoch 24: val_accuracy did not improve from 0.58259
# 448/448 [==============================] - 122s 273ms/step - loss: 1.6524 - accuracy: 0.6068 - val_loss: 1.1317 - val_accuracy: 0.5812 - lr: 1.0000e-04
# Epoch 25/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6284 - accuracy: 0.6111
# Epoch 25: val_accuracy improved from 0.58259 to 0.58538, saving model to best_model.h5
# 448/448 [==============================] - 112s 250ms/step - loss: 1.6284 - accuracy: 0.6111 - val_loss: 1.1248 - val_accuracy: 0.5854 - lr: 1.0000e-04
# Epoch 26/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6011 - accuracy: 0.6178
# Epoch 26: val_accuracy did not improve from 0.58538
# 448/448 [==============================] - 123s 274ms/step - loss: 1.6011 - accuracy: 0.6178 - val_loss: 1.1382 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 27/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5747 - accuracy: 0.6243
# Epoch 27: val_accuracy did not improve from 0.58538
# 448/448 [==============================] - 118s 264ms/step - loss: 1.5747 - accuracy: 0.6243 - val_loss: 1.1267 - val_accuracy: 0.5819 - lr: 1.0000e-04
# Epoch 28/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5695 - accuracy: 0.6244
# Epoch 28: val_accuracy did not improve from 0.58538
# 448/448 [==============================] - 122s 273ms/step - loss: 1.5695 - accuracy: 0.6244 - val_loss: 1.1611 - val_accuracy: 0.5845 - lr: 1.0000e-04
# Epoch 29/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5400 - accuracy: 0.6317
# Epoch 29: val_accuracy improved from 0.58538 to 0.59235, saving model to best_model.h5
# 448/448 [==============================] - 126s 282ms/step - loss: 1.5400 - accuracy: 0.6317 - val_loss: 1.1299 - val_accuracy: 0.5924 - lr: 1.0000e-04
# Epoch 30/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5212 - accuracy: 0.6381
# Epoch 30: val_accuracy did not improve from 0.59235
# 448/448 [==============================] - 116s 259ms/step - loss: 1.5212 - accuracy: 0.6381 - val_loss: 1.2600 - val_accuracy: 0.5774 - lr: 1.0000e-04
# Epoch 31/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5240 - accuracy: 0.6334
# Epoch 31: val_accuracy did not improve from 0.59235
# 448/448 [==============================] - 116s 259ms/step - loss: 1.5240 - accuracy: 0.6334 - val_loss: 1.1976 - val_accuracy: 0.5811 - lr: 1.0000e-04
# Epoch 32/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4797 - accuracy: 0.6439
# Epoch 32: val_accuracy improved from 0.59235 to 0.59249, saving model to best_model.h5
# 448/448 [==============================] - 109s 243ms/step - loss: 1.4797 - accuracy: 0.6439 - val_loss: 1.1447 - val_accuracy: 0.5925 - lr: 1.0000e-04
# Epoch 33/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4680 - accuracy: 0.6478
# Epoch 33: val_accuracy improved from 0.59249 to 0.59849, saving model to best_model.h5
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 448/448 [==============================] - 102s 228ms/step - loss: 1.4680 - accuracy: 0.6478 - val_loss: 1.1383 - val_accuracy: 0.5985 - lr: 1.0000e-04
# Epoch 34/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4173 - accuracy: 0.6603
# Epoch 34: val_accuracy improved from 0.59849 to 0.60631, saving model to best_model.h5
# 448/448 [==============================] - 95s 212ms/step - loss: 1.4173 - accuracy: 0.6603 - val_loss: 1.1324 - val_accuracy: 0.6063 - lr: 5.0000e-05
# Epoch 35/300
# 448/448 [==============================] - ETA: 0s - loss: 1.3953 - accuracy: 0.6639
# Epoch 35: val_accuracy improved from 0.60631 to 0.61635, saving model to best_model.h5
# 448/448 [==============================] - 105s 235ms/step - loss: 1.3953 - accuracy: 0.6639 - val_loss: 1.1167 - val_accuracy: 0.6164 - lr: 5.0000e-05
# Epoch 36/300
# 448/448 [==============================] - ETA: 0s - loss: 1.
300
# 448/448 [==============================] - ETA: 0s - loss: 1.1581 - accuracy: 0.7189
# Epoch 51: val_accuracy did not improve from 0.61942
# 448/448 [==============================] - 97s 216ms/step - loss: 1.1581 - accuracy: 0.7189 - val_loss: 1.2051 - val_accuracy: 0.6143 - lr: 2.5000e-05
# Epoch 52/300
# 448/448 [==============================] - ETA: 0s - loss: 1.1598 - accuracy: 0.7179
# Epoch 52: val_accuracy did not improve from 0.61942
# 448/448 [==============================] - 98s 218ms/step - loss: 1.1598 - accuracy: 0.7179 - val_loss: 1.2067 - val_accuracy: 0.6159 - lr: 2.5000e-05
# Epoch 53/300
# 448/448 [==============================] - ETA: 0s - loss: 1.1533 - accuracy: 0.7240
# Epoch 53: val_accuracy did not improve from 0.61942
# 448/448 [==============================] - 96s 215ms/step - loss: 1.1533 - accuracy: 0.7240 - val_loss: 1.2288 - val_accuracy: 0.6122 - lr: 2.5000e-05
# Epoch 54/300
# 448/448 [==============================] - ETA: 0s - loss: 1.1548 - accuracy: 0.7209
# Epoch 54: val_accuracy improved from 0.61942 to 0.61956, saving model to best_model.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 1.1548 - accuracy: 0.7209 - val_loss: 1.2230 - val_accuracy: 0.6196 - lr: 2.5000e-05
# Epoch 55/300
# 448/448 [==============================] - ETA: 0s - loss: 1.1361 - accuracy: 0.7276
# Epoch 55: val_accuracy did not improve from 0.61956
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 448/448 [==============================] - 92s 205ms/step - loss: 1.1361 - accuracy: 0.7276 - val_loss: 1.2273 - val_accuracy: 0.6158 - lr: 2.5000e-05
# Epoch 55: early stopping

# %%
save_model = model.save('NasNet_100e_RAFDB_BetterWeights.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.59375

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 72ms/step
# Accuracy =  0.8125
# 2/2 [==============================] - 0s 47ms/step
# Accuracy =  0.484375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6162

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# Accuracy: 61.62109375
# Angry 956/7178 acc: 56.3
# Disgust 111/7178 acc: 65.8
# Fear 1022/7178 acc: 42.0
# Happy 1773/7178 acc: 78.8
# Neutral 1232/7178 acc: 57.8
# Sad 1246/7178 acc: 47.8
# Surprise 828/7178 acc: 81.3

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 61.62109375
# Angry 956/7178 acc: 56.3
# Disgust 111/7178 acc: 65.8
# Fear 1022/7178 acc: 42.0
# Happy 1773/7178 acc: 78.8
# Neutral 1232/7178 acc: 57.8
# Sad 1246/7178 acc: 47.8
# Surprise 828/7178 acc: 81.3

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.50      0.56      0.53       956
#      Disgust       0.56      0.66      0.61       111
#         Fear       0.48      0.42      0.45      1022
#        Happy       0.85      0.79      0.82      1773
#      Neutral       0.55      0.58      0.56      1232
#          Sad       0.52      0.48      0.50      1246
#     Surprise       0.69      0.81      0.75       828
#
#     accuracy                           0.62      7168
#    macro avg       0.59      0.61      0.60      7168
# weighted avg       0.62      0.62      0.62      7168

# %% [markdown]
# # Unseen batch

# %%
# model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 56ms/step
# Accuracy =  0.40625
# 2/2 [==============================] - 0s 59ms/step
# Accuracy =  0.171875

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.2944

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# Accuracy: 29.443359375
# Angry 292/2100 acc: 21.2
# Disgust 294/2100 acc: 1.4
# Fear 295/2100 acc: 26.8
# Happy 287/2100 acc: 71.1
# Neutral 292/2100 acc: 51.7
# Sad 296/2100 acc: 12.8
# Surprise 292/2100 acc: 22.3

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 29.443359375
# Angry 292/2100 acc: 21.2
# Disgust 294/2100 acc: 1.4
# Fear 295/2100 acc: 26.8
# Happy 287/2100 acc: 71.1
# Neutral 292/2100 acc: 51.7
# Sad 296/2100 acc: 12.8
# Surprise 292/2100 acc: 22.3

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.34      0.21      0.26       292
#      Disgust       0.44      0.01      0.03       294
#         Fear       0.24      0.27      0.25       295
#        Happy       0.30      0.71      0.42       287
#      Neutral       0.27      0.52      0.36       292
#          Sad       0.49      0.13      0.20       296
#     Surprise       0.30      0.22      0.25       292
#
#     accuracy                           0.29      2048
#    macro avg       0.34      0.30      0.25      2048
# weighted avg       0.34      0.29      0.25      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 127.5

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
