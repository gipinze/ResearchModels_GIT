# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten
from keras import regularizers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
import math

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
def ZF_Net():
    inputs = Input(shape=(48, 48, 3))

    x = Conv2D(96, (7, 7), strides=(2, 2), padding='valid', activation='relu', kernel_initializer='uniform')(inputs)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)  # Adjusted pooling parameters
    x = Conv2D(256, (5, 5), strides=(2, 2), padding='same', activation='relu', kernel_initializer='uniform')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)  # Adjusted pooling parameters
    x = Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform')(x)
    x = Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform')(x)
    x = Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)  # Adjusted pooling parameters
    x = Flatten()(x)
    x = Dense(4096, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(4096, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(7, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Open the strategy scope
with strategy.scope():
    # Compile the model
    model = ZF_Net()
    # Compile the model
    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer=Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Save the model architecture diagram as a PNG file
# plot_model(model, to_file='resnet18_architecture.png', show_shapes=True)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 21, 21, 96)        14208
#
#  max_pooling2d (MaxPooling2D  (None, 10, 10, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 256)         614656
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 7)                 28679
#
# =================================================================
# Total params: 21,589,127
# Trainable params: 21,589,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,100) for class_id, num_images in counter.items()}
print(class_weights)     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)
# Out:
# {0: 1.8060075093867334, 1: 16.548165137614678, 2: 1.7610446668293873, 3: 1.0, 4: 1.4531722054380665, 5: 1.4937888198757765, 6: 2.275307473982971}

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=400,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 448/448 [==============================] - ETA: 0s - loss: 3.4235 - accuracy: 0.1279
# Epoch 1: val_accuracy improved from -inf to 0.17787, saving model to best_model.h5
# 448/448 [==============================] - 270s 556ms/step - loss: 3.4235 - accuracy: 0.1279 - val_loss: 1.9356 - val_accuracy: 0.1779 - lr: 1.0000e-04
# Epoch 2/400
# 448/448 [==============================] - ETA: 0s - loss: 3.3767 - accuracy: 0.1769
# Epoch 2: val_accuracy did not improve from 0.17787
# 448/448 [==============================] - 31s 69ms/step - loss: 3.3767 - accuracy: 0.1769 - val_loss: 1.9184 - val_accuracy: 0.1394 - lr: 1.0000e-04
# Epoch 3/400
# 448/448 [==============================] - ETA: 0s - loss: 3.3107 - accuracy: 0.1930
# Epoch 3: val_accuracy improved from 0.17787 to 0.24051, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 3.3107 - accuracy: 0.1930 - val_loss: 1.8394 - val_accuracy: 0.2405 - lr: 1.0000e-04
# Epoch 4/400
# 448/448 [==============================] - ETA: 0s - loss: 3.2806 - accuracy: 0.1966
# Epoch 4: val_accuracy did not improve from 0.24051
# 448/448 [==============================] - 30s 68ms/step - loss: 3.2806 - accuracy: 0.1966 - val_loss: 1.8570 - val_accuracy: 0.2306 - lr: 1.0000e-04
# Epoch 5/400
# 448/448 [==============================] - ETA: 0s - loss: 3.2541 - accuracy: 0.2190
# Epoch 5: val_accuracy did not improve from 0.24051
# 448/448 [==============================] - 31s 68ms/step - loss: 3.2541 - accuracy: 0.2190 - val_loss: 1.8822 - val_accuracy: 0.1921 - lr: 1.0000e-04
# Epoch 6/400
# 448/448 [==============================] - ETA: 0s - loss: 3.2368 - accuracy: 0.2234
# Epoch 6: val_accuracy improved from 0.24051 to 0.28725, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 3.2368 - accuracy: 0.2234 - val_loss: 1.7672 - val_accuracy: 0.2872 - lr: 1.0000e-04
# Epoch 7/400
# 448/448 [==============================] - ETA: 0s - loss: 3.2106 - accuracy: 0.2299
# Epoch 7: val_accuracy improved from 0.28725 to 0.29157, saving model to best_model.h5
# 448/448 [==============================] - 31s 70ms/step - loss: 3.2106 - accuracy: 0.2299 - val_loss: 1.7342 - val_accuracy: 0.2916 - lr: 1.0000e-04
# Epoch 8/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1901 - accuracy: 0.2402
# Epoch 8: val_accuracy did not improve from 0.29157
# 448/448 [==============================] - 31s 68ms/step - loss: 3.1901 - accuracy: 0.2402 - val_loss: 1.8654 - val_accuracy: 0.2232 - lr: 1.0000e-04
# Epoch 9/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1677 - accuracy: 0.2575
# Epoch 9: val_accuracy improved from 0.29157 to 0.31069, saving model to best_model.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 3.1677 - accuracy: 0.2575 - val_loss: 1.7208 - val_accuracy: 0.3107 - lr: 1.0000e-04
# Epoch 10/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1329 - accuracy: 0.2703
# Epoch 10: val_accuracy improved from 0.31069 to 0.32812, saving model to best_model.h5
# 448/448 [==============================] - 31s 68ms/step - loss: 3.1329 - accuracy: 0.2703 - val_loss: 1.6959 - val_accuracy: 0.3281 - lr: 1.0000e-04
# Epoch 11/400
# 448/448 [==============================] - ETA: 0s - loss: 3.1153 - accuracy: 0.2846
# Epoch 11: val_accuracy did not improve from 0.32812
# 448/448 [==============================] - 30s 67ms/step - loss: 3.1153 - accuracy: 0.2846 - val_loss: 1.7942 - val_accuracy: 0.2793 - lr: 1.0000e-04
# Epoch 12/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0935 - accuracy: 0.2937
# Epoch 12: val_accuracy improved from 0.32812 to 0.33594, saving model to best_model.h5
# 448/448 [==============================] - 31s 68ms/step - loss: 3.0935 - accuracy: 0.2937 - val_loss: 1.6886 - val_accuracy: 0.3359 - lr: 1.0000e-04
# Epoch 13/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0500 - accuracy: 0.2991
# Epoch 13: val_accuracy improved from 0.33594 to 0.34724, saving model to best_model.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 3.0500 - accuracy: 0.2991 - val_loss: 1.6787 - val_accuracy: 0.3472 - lr: 1.0000e-04
# Epoch 14/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0390 - accuracy: 0.3006
# Epoch 14: val_accuracy did not improve from 0.34724
# 448/448 [==============================] - 29s 66ms/step - loss: 3.0390 - accuracy: 0.3006 - val_loss: 1.6863 - val_accuracy: 0.3326 - lr: 1.0000e-04
# Epoch 15/400
# 448/448 [==============================] - ETA: 0s - loss: 3.0187 - accuracy: 0.3134
# Epoch 15: val_accuracy improved from 0.34724 to 0.35477, saving model to best_model.h5
# 448/448 [==============================] - 30s 66ms/step - loss: 3.0187 - accuracy: 0.3134 - val_loss: 1.6457 - val_accuracy: 0.3548 - lr: 1.0000e-04
# Epoch 16/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9891 - accuracy: 0.3222
# Epoch 16: val_accuracy improved from 0.35477 to 0.37095, saving model to best_model.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 2.9891 - accuracy: 0.3222 - val_loss: 1.6111 - val_accuracy: 0.3710 - lr: 1.0000e-04
# Epoch 17/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9665 - accuracy: 0.3252
# Epoch 17: val_accuracy improved from 0.37095 to 0.37681, saving model to best_model.h5
# 448/448 [==============================] - 30s 66ms/step - loss: 2.9665 - accuracy: 0.3252 - val_loss: 1.6006 - val_accuracy: 0.3768 - lr: 1.0000e-04
# Epoch 18/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9659 - accuracy: 0.3284
# Epoch 18: val_accuracy did not improve from 0.37681
# 448/448 [==============================] - 29s 65ms/step - loss: 2.9659 - accuracy: 0.3284 - val_loss: 1.6059 - val_accuracy: 0.3686 - lr: 1.0000e-04
# Epoch 19/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9248 - accuracy: 0.3420
# Epoch 19: val_accuracy improved from 0.37681 to 0.38574, saving model to best_model.h5
# 448/448 [==============================] - 30s 66ms/step - loss: 2.9248 - accuracy: 0.3420 - val_loss: 1.5751 - val_accuracy: 0.3857 - lr: 1.0000e-04
# Epoch 20/400
# 448/448 [==============================] - ETA: 0s - loss: 2.9128 - accuracy: 0.3435
# Epoch 20: val_accuracy did not improve from 0.38574
# 448/448 [==============================] - 29s 65ms/step - loss: 2.9128 - accuracy: 0.3435 - val_loss: 1.6374 - val_accuracy: 0.3528 - lr: 1.0000e-04
# Epoch 21/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8928 - accuracy: 0.3471
# Epoch 21: val_accuracy improved from 0.38574 to 0.40597, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.8928 - accuracy: 0.3471 - val_loss: 1.5458 - val_accuracy: 0.4060 - lr: 1.0000e-04
# Epoch 22/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8848 - accuracy: 0.3475
# Epoch 22: val_accuracy improved from 0.40597 to 0.44057, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.8848 - accuracy: 0.3475 - val_loss: 1.4759 - val_accuracy: 0.4406 - lr: 1.0000e-04
# Epoch 23/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8672 - accuracy: 0.3614
# Epoch 23: val_accuracy did not improve from 0.44057
# 448/448 [==============================] - 29s 64ms/step - loss: 2.8672 - accuracy: 0.3614 - val_loss: 1.5582 - val_accuracy: 0.3969 - lr: 1.0000e-04
# Epoch 24/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8457 - accuracy: 0.3527
# Epoch 24: val_accuracy did not improve from 0.44057
# 448/448 [==============================] - 29s 64ms/step - loss: 2.8457 - accuracy: 0.3527 - val_loss: 1.4877 - val_accuracy: 0.4280 - lr: 1.0000e-04
# Epoch 25/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8477 - accuracy: 0.3617
# Epoch 25: val_accuracy did not improve from 0.44057
# 448/448 [==============================] - 29s 64ms/step - loss: 2.8477 - accuracy: 0.3617 - val_loss: 1.5015 - val_accuracy: 0.4235 - lr: 1.0000e-04
# Epoch 26/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8190 - accuracy: 0.3672
# Epoch 26: val_accuracy did not improve from 0.44057
# 448/448 [==============================] - 29s 64ms/step - loss: 2.8190 - accuracy: 0.3672 - val_loss: 1.5203 - val_accuracy: 0.4062 - lr: 1.0000e-04
# Epoch 27/400
# 448/448 [==============================] - ETA: 0s - loss: 2.8111 - accuracy: 0.3677
# Epoch 27: val_accuracy improved from 0.44057 to 0.44392, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.8111 - accuracy: 0.3677 - val_loss: 1.4531 - val_accuracy: 0.4439 - lr: 1.0000e-04
# Epoch 28/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7876 - accuracy: 0.3757
# Epoch 28: val_accuracy did not improve from 0.44392
# 448/448 [==============================] - 30s 68ms/step - loss: 2.7876 - accuracy: 0.3757 - val_loss: 1.5150 - val_accuracy: 0.4086 - lr: 1.0000e-04
# Epoch 29/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7673 - accuracy: 0.3777
# Epoch 29: val_accuracy did not improve from 0.44392
# 448/448 [==============================] - 30s 66ms/step - loss: 2.7673 - accuracy: 0.3777 - val_loss: 1.4626 - val_accuracy: 0.4399 - lr: 1.0000e-04
# Epoch 30/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7679 - accuracy: 0.3720
# Epoch 30: val_accuracy did not improve from 0.44392
# 448/448 [==============================] - 29s 65ms/step - loss: 2.7679 - accuracy: 0.3720 - val_loss: 1.4858 - val_accuracy: 0.4307 - lr: 1.0000e-04
# Epoch 31/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7483 - accuracy: 0.3801
# Epoch 31: val_accuracy did not improve from 0.44392
# 448/448 [==============================] - 29s 65ms/step - loss: 2.7483 - accuracy: 0.3801 - val_loss: 1.5299 - val_accuracy: 0.4085 - lr: 1.0000e-04
# Epoch 32/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7394 - accuracy: 0.3833
# Epoch 32: val_accuracy did not improve from 0.44392
# 448/448 [==============================] - 30s 66ms/step - loss: 2.7394 - accuracy: 0.3833 - val_loss: 1.4674 - val_accuracy: 0.4305 - lr: 1.0000e-04
# Epoch 33/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7274 - accuracy: 0.3892
# Epoch 33: val_accuracy improved from 0.44392 to 0.44727, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.7274 - accuracy: 0.3892 - val_loss: 1.4431 - val_accuracy: 0.4473 - lr: 1.0000e-04
# Epoch 34/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7298 - accuracy: 0.3922
# Epoch 34: val_accuracy improved from 0.44727 to 0.45564, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.7298 - accuracy: 0.3922 - val_loss: 1.4317 - val_accuracy: 0.4556 - lr: 1.0000e-04
# Epoch 35/400
# 448/448 [==============================] - ETA: 0s - loss: 2.7148 - accuracy: 0.3930
# Epoch 35: val_accuracy did not improve from 0.45564
# 448/448 [==============================] - 29s 64ms/step - loss: 2.7148 - accuracy: 0.3930 - val_loss: 1.4326 - val_accuracy: 0.4531 - lr: 1.0000e-04
# Epoch 36/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6758 - accuracy: 0.4010
# Epoch 36: val_accuracy improved from 0.45564 to 0.46735, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.6758 - accuracy: 0.4010 - val_loss: 1.3944 - val_accuracy: 0.4674 - lr: 1.0000e-04
# Epoch 37/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6693 - accuracy: 0.4017
# Epoch 37: val_accuracy did not improve from 0.46735
# 448/448 [==============================] - 30s 66ms/step - loss: 2.6693 - accuracy: 0.4017 - val_loss: 1.4388 - val_accuracy: 0.4450 - lr: 1.0000e-04
# Epoch 38/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6572 - accuracy: 0.4029
# Epoch 38: val_accuracy improved from 0.46735 to 0.47921, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.6572 - accuracy: 0.4029 - val_loss: 1.3596 - val_accuracy: 0.4792 - lr: 1.0000e-04
# Epoch 39/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6461 - accuracy: 0.4061
# Epoch 39: val_accuracy did not improve from 0.47921
# 448/448 [==============================] - 29s 65ms/step - loss: 2.6461 - accuracy: 0.4061 - val_loss: 1.4389 - val_accuracy: 0.4496 - lr: 1.0000e-04
# Epoch 40/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6268 - accuracy: 0.4131
# Epoch 40: val_accuracy did not improve from 0.47921
# 448/448 [==============================] - 29s 64ms/step - loss: 2.6268 - accuracy: 0.4131 - val_loss: 1.3738 - val_accuracy: 0.4741 - lr: 1.0000e-04
# Epoch 41/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6297 - accuracy: 0.4080
# Epoch 41: val_accuracy did not improve from 0.47921
# 448/448 [==============================] - 29s 64ms/step - loss: 2.6297 - accuracy: 0.4080 - val_loss: 1.4378 - val_accuracy: 0.4480 - lr: 1.0000e-04
# Epoch 42/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6241 - accuracy: 0.4112
# Epoch 42: val_accuracy improved from 0.47921 to 0.49512, saving model to best_model.h5
# 448/448 [==============================] - 29s 64ms/step - loss: 2.6241 - accuracy: 0.4112 - val_loss: 1.3310 - val_accuracy: 0.4951 - lr: 1.0000e-04
# Epoch 43/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6244 - accuracy: 0.4088
# Epoch 43: val_accuracy did not improve from 0.49512
# 448/448 [==============================] - 28s 63ms/step - loss: 2.6244 - accuracy: 0.4088 - val_loss: 1.3553 - val_accuracy: 0.4810 - lr: 1.0000e-04
# Epoch 44/400
# 448/448 [==============================] - ETA: 0s - loss: 2.6166 - accuracy: 0.4160
# Epoch 44: val_accuracy did not improve from 0.49512
# 448/448 [==============================] - 29s 64ms/step - loss: 2.6166 - accuracy: 0.4160 - val_loss: 1.3294 - val_accuracy: 0.4909 - lr: 1.0000e-04
# Epoch 45/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.6027 - accuracy: 0.4202
# Epoch 45: val_accuracy did not improve from 0.49512
# 448/448 [==============================] - 29s 64ms/step - loss: 2.6038 - accuracy: 0.4200 - val_loss: 1.3821 - val_accuracy: 0.4741 - lr: 1.0000e-04
# Epoch 46/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5805 - accuracy: 0.4172
# Epoch 46: val_accuracy did not improve from 0.49512
# 448/448 [==============================] - 29s 64ms/step - loss: 2.5805 - accuracy: 0.4172 - val_loss: 1.3570 - val_accuracy: 0.4849 - lr: 1.0000e-04
# Epoch 47/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5709 - accuracy: 0.4211
# Epoch 47: val_accuracy improved from 0.49512 to 0.50195, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.5709 - accuracy: 0.4211 - val_loss: 1.3128 - val_accuracy: 0.5020 - lr: 1.0000e-04
# Epoch 48/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5472 - accuracy: 0.4258
# Epoch 48: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.5472 - accuracy: 0.4258 - val_loss: 1.3804 - val_accuracy: 0.4704 - lr: 1.0000e-04
# Epoch 49/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5481 - accuracy: 0.4258
# Epoch 49: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 65ms/step - loss: 2.5481 - accuracy: 0.4258 - val_loss: 1.4944 - val_accuracy: 0.4259 - lr: 1.0000e-04
# Epoch 50/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5416 - accuracy: 0.4242
# Epoch 50: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 65ms/step - loss: 2.5416 - accuracy: 0.4242 - val_loss: 1.3827 - val_accuracy: 0.4724 - lr: 1.0000e-04
# Epoch 51/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5483 - accuracy: 0.4263
# Epoch 51: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 30s 67ms/step - loss: 2.5483 - accuracy: 0.4263 - val_loss: 1.3573 - val_accuracy: 0.4805 - lr: 1.0000e-04
# Epoch 52/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5193 - accuracy: 0.4318
# Epoch 52: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 30s 67ms/step - loss: 2.5193 - accuracy: 0.4318 - val_loss: 1.3916 - val_accuracy: 0.4713 - lr: 1.0000e-04
# Epoch 53/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5433 - accuracy: 0.4293
# Epoch 53: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.5433 - accuracy: 0.4293 - val_loss: 1.3380 - val_accuracy: 0.4887 - lr: 1.0000e-04
# Epoch 54/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5086 - accuracy: 0.4382
# Epoch 54: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.5086 - accuracy: 0.4382 - val_loss: 1.3365 - val_accuracy: 0.4860 - lr: 1.0000e-04
# Epoch 55/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4901 - accuracy: 0.4379
# Epoch 55: val_accuracy did not improve from 0.50195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4901 - accuracy: 0.4379 - val_loss: 1.3282 - val_accuracy: 0.4876 - lr: 1.0000e-04
# Epoch 56/400
# 448/448 [==============================] - ETA: 0s - loss: 2.5106 - accuracy: 0.4352
# Epoch 56: val_accuracy improved from 0.50195 to 0.51130, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.5106 - accuracy: 0.4352 - val_loss: 1.2823 - val_accuracy: 0.5113 - lr: 1.0000e-04
# Epoch 57/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4896 - accuracy: 0.4415
# Epoch 57: val_accuracy did not improve from 0.51130
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4896 - accuracy: 0.4415 - val_loss: 1.3478 - val_accuracy: 0.4869 - lr: 1.0000e-04
# Epoch 58/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4665 - accuracy: 0.4436
# Epoch 58: val_accuracy did not improve from 0.51130
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4665 - accuracy: 0.4436 - val_loss: 1.3396 - val_accuracy: 0.4880 - lr: 1.0000e-04
# Epoch 59/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4642 - accuracy: 0.4476
# Epoch 59: val_accuracy did not improve from 0.51130
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4642 - accuracy: 0.4476 - val_loss: 1.3766 - val_accuracy: 0.4679 - lr: 1.0000e-04
# Epoch 60/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4382 - accuracy: 0.4446
# Epoch 60: val_accuracy did not improve from 0.51130
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4382 - accuracy: 0.4446 - val_loss: 1.2815 - val_accuracy: 0.5081 - lr: 1.0000e-04
# Epoch 61/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4636 - accuracy: 0.4435
# Epoch 61: val_accuracy did not improve from 0.51130
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4636 - accuracy: 0.4435 - val_loss: 1.3284 - val_accuracy: 0.4979 - lr: 1.0000e-04
# Epoch 62/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4323 - accuracy: 0.4530
# Epoch 62: val_accuracy improved from 0.51130 to 0.51283, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4323 - accuracy: 0.4530 - val_loss: 1.2872 - val_accuracy: 0.5128 - lr: 1.0000e-04
# Epoch 63/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4175 - accuracy: 0.4574
# Epoch 63: val_accuracy improved from 0.51283 to 0.53195, saving model to best_model.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4175 - accuracy: 0.4574 - val_loss: 1.2299 - val_accuracy: 0.5319 - lr: 1.0000e-04
# Epoch 64/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4359 - accuracy: 0.4525
# Epoch 64: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 65ms/step - loss: 2.4359 - accuracy: 0.4525 - val_loss: 1.3230 - val_accuracy: 0.4992 - lr: 1.0000e-04
# Epoch 65/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4316 - accuracy: 0.4552
# Epoch 65: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4316 - accuracy: 0.4552 - val_loss: 1.2931 - val_accuracy: 0.5085 - lr: 1.0000e-04
# Epoch 66/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3991 - accuracy: 0.4591
# Epoch 66: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3991 - accuracy: 0.4591 - val_loss: 1.3964 - val_accuracy: 0.4717 - lr: 1.0000e-04
# Epoch 67/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4130 - accuracy: 0.4542
# Epoch 67: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4130 - accuracy: 0.4542 - val_loss: 1.3596 - val_accuracy: 0.4813 - lr: 1.0000e-04
# Epoch 68/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3875 - accuracy: 0.4634
# Epoch 68: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3875 - accuracy: 0.4634 - val_loss: 1.3440 - val_accuracy: 0.4883 - lr: 1.0000e-04
# Epoch 69/400
# 448/448 [==============================] - ETA: 0s - loss: 2.4024 - accuracy: 0.4580
# Epoch 69: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.4024 - accuracy: 0.4580 - val_loss: 1.3329 - val_accuracy: 0.4915 - lr: 1.0000e-04
# Epoch 70/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3995 - accuracy: 0.4642
# Epoch 70: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3995 - accuracy: 0.4642 - val_loss: 1.2712 - val_accuracy: 0.5124 - lr: 1.0000e-04
# Epoch 71/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3578 - accuracy: 0.4694
# Epoch 71: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 65ms/step - loss: 2.3578 - accuracy: 0.4694 - val_loss: 1.2861 - val_accuracy: 0.5126 - lr: 1.0000e-04
# Epoch 72/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3612 - accuracy: 0.4641
# Epoch 72: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3612 - accuracy: 0.4641 - val_loss: 1.2248 - val_accuracy: 0.5319 - lr: 1.0000e-04
# Epoch 73/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3610 - accuracy: 0.4639
# Epoch 73: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3610 - accuracy: 0.4639 - val_loss: 1.2730 - val_accuracy: 0.5237 - lr: 1.0000e-04
# Epoch 74/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3796 - accuracy: 0.4663
# Epoch 74: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3796 - accuracy: 0.4663 - val_loss: 1.2991 - val_accuracy: 0.5059 - lr: 1.0000e-04
# Epoch 75/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3334 - accuracy: 0.4715
# Epoch 75: val_accuracy did not improve from 0.53195
# 448/448 [==============================] - 29s 64ms/step - loss: 2.3334 - accuracy: 0.4715 - val_loss: 1.2570 - val_accuracy: 0.5257 - lr: 1.0000e-04
# Epoch 76/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3168 - accuracy: 0.4727
# Epoch 76: val_accuracy improved from 0.53195 to 0.53557, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3168 - accuracy: 0.4727 - val_loss: 1.2253 - val_accuracy: 0.5356 - lr: 1.0000e-04
# Epoch 77/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3374 - accuracy: 0.4710
# Epoch 77: val_accuracy did not improve from 0.53557
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3374 - accuracy: 0.4710 - val_loss: 1.2232 - val_accuracy: 0.5338 - lr: 1.0000e-04
# Epoch 78/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3319 - accuracy: 0.4742
# Epoch 78: val_accuracy improved from 0.53557 to 0.53599, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3319 - accuracy: 0.4742 - val_loss: 1.2194 - val_accuracy: 0.5360 - lr: 1.0000e-04
# Epoch 79/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3089 - accuracy: 0.4762
# Epoch 79: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 62ms/step - loss: 2.3089 - accuracy: 0.4762 - val_loss: 1.2785 - val_accuracy: 0.5170 - lr: 1.0000e-04
# Epoch 80/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3245 - accuracy: 0.4765
# Epoch 80: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3245 - accuracy: 0.4765 - val_loss: 1.2415 - val_accuracy: 0.5346 - lr: 1.0000e-04
# Epoch 81/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3092 - accuracy: 0.4755
# Epoch 81: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3092 - accuracy: 0.4755 - val_loss: 1.2577 - val_accuracy: 0.5239 - lr: 1.0000e-04
# Epoch 82/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3179 - accuracy: 0.4738
# Epoch 82: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.3179 - accuracy: 0.4738 - val_loss: 1.2311 - val_accuracy: 0.5283 - lr: 1.0000e-04
# Epoch 83/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2857 - accuracy: 0.4836
# Epoch 83: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2857 - accuracy: 0.4836 - val_loss: 1.2494 - val_accuracy: 0.5286 - lr: 1.0000e-04
# Epoch 84/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.2882 - accuracy: 0.4793
# Epoch 84: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2876 - accuracy: 0.4794 - val_loss: 1.2449 - val_accuracy: 0.5251 - lr: 1.0000e-04
# Epoch 85/400
# 448/448 [==============================] - ETA: 0s - loss: 2.3215 - accuracy: 0.4777
# Epoch 85: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 62ms/step - loss: 2.3215 - accuracy: 0.4777 - val_loss: 1.2582 - val_accuracy: 0.5223 - lr: 1.0000e-04
# Epoch 86/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2598 - accuracy: 0.4879
# Epoch 86: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2598 - accuracy: 0.4879 - val_loss: 1.2519 - val_accuracy: 0.5266 - lr: 1.0000e-04
# Epoch 87/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2792 - accuracy: 0.4820
# Epoch 87: val_accuracy did not improve from 0.53599
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2792 - accuracy: 0.4820 - val_loss: 1.2586 - val_accuracy: 0.5225 - lr: 1.0000e-04
# Epoch 88/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2842 - accuracy: 0.4780
# Epoch 88: val_accuracy did not improve from 0.53599
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2842 - accuracy: 0.4780 - val_loss: 1.2362 - val_accuracy: 0.5314 - lr: 1.0000e-04
# Epoch 89/400
# 448/448 [==============================] - ETA: 0s - loss: 2.2017 - accuracy: 0.4970
# Epoch 89: val_accuracy improved from 0.53599 to 0.54088, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 2.2017 - accuracy: 0.4970 - val_loss: 1.2112 - val_accuracy: 0.5409 - lr: 5.0000e-05
# Epoch 90/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1792 - accuracy: 0.4994
# Epoch 90: val_accuracy did not improve from 0.54088
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1792 - accuracy: 0.4994 - val_loss: 1.2265 - val_accuracy: 0.5346 - lr: 5.0000e-05
# Epoch 91/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1693 - accuracy: 0.5034
# Epoch 91: val_accuracy did not improve from 0.54088
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1693 - accuracy: 0.5034 - val_loss: 1.2349 - val_accuracy: 0.5363 - lr: 5.0000e-05
# Epoch 92/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1637 - accuracy: 0.5041
# Epoch 92: val_accuracy did not improve from 0.54088
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1637 - accuracy: 0.5041 - val_loss: 1.2309 - val_accuracy: 0.5339 - lr: 5.0000e-05
# Epoch 93/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1461 - accuracy: 0.5080
# Epoch 93: val_accuracy did not improve from 0.54088
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1461 - accuracy: 0.5080 - val_loss: 1.2471 - val_accuracy: 0.5312 - lr: 5.0000e-05
# Epoch 94/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1428 - accuracy: 0.5077
# Epoch 94: val_accuracy improved from 0.54088 to 0.54492, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1428 - accuracy: 0.5077 - val_loss: 1.2071 - val_accuracy: 0.5449 - lr: 5.0000e-05
# Epoch 95/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1583 - accuracy: 0.5094
# Epoch 95: val_accuracy did not improve from 0.54492
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1583 - accuracy: 0.5094 - val_loss: 1.2481 - val_accuracy: 0.5371 - lr: 5.0000e-05
# Epoch 96/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1375 - accuracy: 0.5050
# Epoch 96: val_accuracy did not improve from 0.54492
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1375 - accuracy: 0.5050 - val_loss: 1.2222 - val_accuracy: 0.5431 - lr: 5.0000e-05
# Epoch 97/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1453 - accuracy: 0.5113
# Epoch 97: val_accuracy did not improve from 0.54492
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1453 - accuracy: 0.5113 - val_loss: 1.2217 - val_accuracy: 0.5449 - lr: 5.0000e-05
# Epoch 98/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1553 - accuracy: 0.5099
# Epoch 98: val_accuracy improved from 0.54492 to 0.54534, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1553 - accuracy: 0.5099 - val_loss: 1.1916 - val_accuracy: 0.5453 - lr: 5.0000e-05
# Epoch 99/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1149 - accuracy: 0.5139
# Epoch 99: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1149 - accuracy: 0.5139 - val_loss: 1.2231 - val_accuracy: 0.5414 - lr: 5.0000e-05
# Epoch 100/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1208 - accuracy: 0.5121
# Epoch 100: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 28s 63ms/step - loss: 2.1208 - accuracy: 0.5121 - val_loss: 1.2130 - val_accuracy: 0.5423 - lr: 5.0000e-05
# Epoch 101/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1214 - accuracy: 0.5138
# Epoch 101: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1214 - accuracy: 0.5138 - val_loss: 1.2107 - val_accuracy: 0.5428 - lr: 5.0000e-05
# Epoch 102/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1058 - accuracy: 0.5151
# Epoch 102: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 28s 62ms/step - loss: 2.1058 - accuracy: 0.5151 - val_loss: 1.2408 - val_accuracy: 0.5223 - lr: 5.0000e-05
# Epoch 103/400
# 447/448 [============================>.] - ETA: 0s - loss: 2.1034 - accuracy: 0.5112
# Epoch 103: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 27s 61ms/step - loss: 2.1030 - accuracy: 0.5113 - val_loss: 1.2309 - val_accuracy: 0.5359 - lr: 5.0000e-05
# Epoch 104/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1167 - accuracy: 0.5126
# Epoch 104: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 27s 61ms/step - loss: 2.1167 - accuracy: 0.5126 - val_loss: 1.2250 - val_accuracy: 0.5396 - lr: 5.0000e-05
# Epoch 105/400
# 448/448 [==============================] - ETA: 0s - loss: 2.1048 - accuracy: 0.5169
# Epoch 105: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 27s 61ms/step - loss: 2.1048 - accuracy: 0.5169 - val_loss: 1.2149 - val_accuracy: 0.5382 - lr: 5.0000e-05
# Epoch 106/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0845 - accuracy: 0.5177
# Epoch 106: val_accuracy did not improve from 0.54534
# 448/448 [==============================] - 28s 61ms/step - loss: 2.0845 - accuracy: 0.5177 - val_loss: 1.2440 - val_accuracy: 0.5343 - lr: 5.0000e-05
# Epoch 107/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0786 - accuracy: 0.5176
# Epoch 107: val_accuracy improved from 0.54534 to 0.54743, saving model to best_model.h5
# 448/448 [==============================] - 28s 62ms/step - loss: 2.0786 - accuracy: 0.5176 - val_loss: 1.2029 - val_accuracy: 0.5474 - lr: 5.0000e-05
# Epoch 108/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0816 - accuracy: 0.5197
# Epoch 108: val_accuracy improved from 0.54743 to 0.54799, saving model to best_model.h5
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 448/448 [==============================] - 28s 62ms/step - loss: 2.0816 - accuracy: 0.5197 - val_loss: 1.2039 - val_accuracy: 0.5480 - lr: 5.0000e-05
# Epoch 109/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0390 - accuracy: 0.5281
# Epoch 109: val_accuracy did not improve from 0.54799
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0390 - accuracy: 0.5281 - val_loss: 1.2203 - val_accuracy: 0.5399 - lr: 2.5000e-05
# Epoch 110/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0417 - accuracy: 0.5296
# Epoch 110: val_accuracy did not improve from 0.54799
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0417 - accuracy: 0.5296 - val_loss: 1.2123 - val_accuracy: 0.5392 - lr: 2.5000e-05
# Epoch 111/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0457 - accuracy: 0.5301
# Epoch 111: val_accuracy did not improve from 0.54799
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0457 - accuracy: 0.5301 - val_loss: 1.1980 - val_accuracy: 0.5477 - lr: 2.5000e-05
# Epoch 112/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0290 - accuracy: 0.5327
# Epoch 112: val_accuracy improved from 0.54799 to 0.55678, saving model to best_model.h5
# 448/448 [==============================] - 28s 62ms/step - loss: 2.0290 - accuracy: 0.5327 - val_loss: 1.1875 - val_accuracy: 0.5568 - lr: 2.5000e-05
# Epoch 113/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0294 - accuracy: 0.5317
# Epoch 113: val_accuracy did not improve from 0.55678
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0294 - accuracy: 0.5317 - val_loss: 1.1734 - val_accuracy: 0.5541 - lr: 2.5000e-05
# Epoch 114/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0294 - accuracy: 0.5320
# Epoch 114: val_accuracy did not improve from 0.55678
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0294 - accuracy: 0.5320 - val_loss: 1.1792 - val_accuracy: 0.5516 - lr: 2.5000e-05
# Epoch 115/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0187 - accuracy: 0.5282
# Epoch 115: val_accuracy did not improve from 0.55678
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0187 - accuracy: 0.5282 - val_loss: 1.1946 - val_accuracy: 0.5501 - lr: 2.5000e-05
# Epoch 116/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0284 - accuracy: 0.5311
# Epoch 116: val_accuracy did not improve from 0.55678
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0284 - accuracy: 0.5311 - val_loss: 1.2045 - val_accuracy: 0.5490 - lr: 2.5000e-05
# Epoch 117/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9972 - accuracy: 0.5393
# Epoch 117: val_accuracy did not improve from 0.55678
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9972 - accuracy: 0.5393 - val_loss: 1.1915 - val_accuracy: 0.5551 - lr: 2.5000e-05
# Epoch 118/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.9930 - accuracy: 0.5376
# Epoch 118: val_accuracy improved from 0.55678 to 0.56097, saving model to best_model.h5
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9928 - accuracy: 0.5377 - val_loss: 1.1827 - val_accuracy: 0.5610 - lr: 2.5000e-05
# Epoch 119/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9975 - accuracy: 0.5367
# Epoch 119: val_accuracy did not improve from 0.56097
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9975 - accuracy: 0.5367 - val_loss: 1.1909 - val_accuracy: 0.5541 - lr: 2.5000e-05
# Epoch 120/400
# 448/448 [==============================] - ETA: 0s - loss: 2.0005 - accuracy: 0.5358
# Epoch 120: val_accuracy did not improve from 0.56097
# 448/448 [==============================] - 27s 61ms/step - loss: 2.0005 - accuracy: 0.5358 - val_loss: 1.1933 - val_accuracy: 0.5467 - lr: 2.5000e-05
# Epoch 121/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9997 - accuracy: 0.5376
# Epoch 121: val_accuracy did not improve from 0.56097
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9997 - accuracy: 0.5376 - val_loss: 1.2194 - val_accuracy: 0.5432 - lr: 2.5000e-05
# Epoch 122/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9805 - accuracy: 0.5358
# Epoch 122: val_accuracy did not improve from 0.56097
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9805 - accuracy: 0.5358 - val_loss: 1.1795 - val_accuracy: 0.5582 - lr: 2.5000e-05
# Epoch 123/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9888 - accuracy: 0.5387
# Epoch 123: val_accuracy improved from 0.56097 to 0.56250, saving model to best_model.h5
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9888 - accuracy: 0.5387 - val_loss: 1.1744 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 124/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9891 - accuracy: 0.5372
# Epoch 124: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9891 - accuracy: 0.5372 - val_loss: 1.1905 - val_accuracy: 0.5533 - lr: 1.2500e-05
# Epoch 125/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9546 - accuracy: 0.5393
# Epoch 125: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9546 - accuracy: 0.5393 - val_loss: 1.1825 - val_accuracy: 0.5587 - lr: 1.2500e-05
# Epoch 126/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9700 - accuracy: 0.5410
# Epoch 126: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 29s 65ms/step - loss: 1.9700 - accuracy: 0.5410 - val_loss: 1.1796 - val_accuracy: 0.5587 - lr: 1.2500e-05
# Epoch 127/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9626 - accuracy: 0.5431
# Epoch 127: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9626 - accuracy: 0.5431 - val_loss: 1.1806 - val_accuracy: 0.5571 - lr: 1.2500e-05
# Epoch 128/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9479 - accuracy: 0.5452
# Epoch 128: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9479 - accuracy: 0.5452 - val_loss: 1.1793 - val_accuracy: 0.5619 - lr: 1.2500e-05
# Epoch 129/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9536 - accuracy: 0.5442
# Epoch 129: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 63ms/step - loss: 1.9536 - accuracy: 0.5442 - val_loss: 1.1885 - val_accuracy: 0.5576 - lr: 1.2500e-05
# Epoch 130/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9421 - accuracy: 0.5446
# Epoch 130: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9421 - accuracy: 0.5446 - val_loss: 1.1833 - val_accuracy: 0.5555 - lr: 1.2500e-05
# Epoch 131/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9450 - accuracy: 0.5482
# Epoch 131: val_accuracy did not improve from 0.56250
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9450 - accuracy: 0.5482 - val_loss: 1.1736 - val_accuracy: 0.5625 - lr: 1.2500e-05
# Epoch 132/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9446 - accuracy: 0.5465
# Epoch 132: val_accuracy improved from 0.56250 to 0.56376, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 1.9446 - accuracy: 0.5465 - val_loss: 1.1775 - val_accuracy: 0.5638 - lr: 1.2500e-05
# Epoch 133/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9485 - accuracy: 0.5504
# Epoch 133: val_accuracy improved from 0.56376 to 0.56515, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 1.9485 - accuracy: 0.5504 - val_loss: 1.1723 - val_accuracy: 0.5652 - lr: 1.2500e-05
# Epoch 134/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.9344 - accuracy: 0.5481
# Epoch 134: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9348 - accuracy: 0.5479 - val_loss: 1.1894 - val_accuracy: 0.5523 - lr: 1.2500e-05
# Epoch 135/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9230 - accuracy: 0.5512
# Epoch 135: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9230 - accuracy: 0.5512 - val_loss: 1.1810 - val_accuracy: 0.5576 - lr: 1.2500e-05
# Epoch 136/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9765 - accuracy: 0.5424
# Epoch 136: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9765 - accuracy: 0.5424 - val_loss: 1.1749 - val_accuracy: 0.5592 - lr: 1.2500e-05
# Epoch 137/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9329 - accuracy: 0.5493
# Epoch 137: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9329 - accuracy: 0.5493 - val_loss: 1.1798 - val_accuracy: 0.5603 - lr: 1.2500e-05
# Epoch 138/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9274 - accuracy: 0.5495
# Epoch 138: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9274 - accuracy: 0.5495 - val_loss: 1.1748 - val_accuracy: 0.5603 - lr: 1.2500e-05
# Epoch 139/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9329 - accuracy: 0.5483
# Epoch 139: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9329 - accuracy: 0.5483 - val_loss: 1.1862 - val_accuracy: 0.5550 - lr: 1.2500e-05
# Epoch 140/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9359 - accuracy: 0.5471
# Epoch 140: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9359 - accuracy: 0.5471 - val_loss: 1.1822 - val_accuracy: 0.5557 - lr: 1.2500e-05
# Epoch 141/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9188 - accuracy: 0.5501
# Epoch 141: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9188 - accuracy: 0.5501 - val_loss: 1.1816 - val_accuracy: 0.5550 - lr: 1.2500e-05
# Epoch 142/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.9189 - accuracy: 0.5522
# Epoch 142: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9179 - accuracy: 0.5523 - val_loss: 1.1837 - val_accuracy: 0.5607 - lr: 1.2500e-05
# Epoch 143/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9339 - accuracy: 0.5510
# Epoch 143: val_accuracy did not improve from 0.56515
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9339 - accuracy: 0.5510 - val_loss: 1.1777 - val_accuracy: 0.5572 - lr: 1.2500e-05
# Epoch 144/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9226 - accuracy: 0.5533
# Epoch 144: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9226 - accuracy: 0.5533 - val_loss: 1.1811 - val_accuracy: 0.5569 - lr: 6.2500e-06
# Epoch 145/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9259 - accuracy: 0.5508
# Epoch 145: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9259 - accuracy: 0.5508 - val_loss: 1.1784 - val_accuracy: 0.5598 - lr: 6.2500e-06
# Epoch 146/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9344 - accuracy: 0.5483
# Epoch 146: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9344 - accuracy: 0.5483 - val_loss: 1.1874 - val_accuracy: 0.5545 - lr: 6.2500e-06
# Epoch 147/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9171 - accuracy: 0.5504
# Epoch 147: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9171 - accuracy: 0.5504 - val_loss: 1.1849 - val_accuracy: 0.5579 - lr: 6.2500e-06
# Epoch 148/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9156 - accuracy: 0.5546
# Epoch 148: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9156 - accuracy: 0.5546 - val_loss: 1.1802 - val_accuracy: 0.5586 - lr: 6.2500e-06
# Epoch 149/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9108 - accuracy: 0.5528
# Epoch 149: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9108 - accuracy: 0.5528 - val_loss: 1.1652 - val_accuracy: 0.5632 - lr: 6.2500e-06
# Epoch 150/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9055 - accuracy: 0.5572
# Epoch 150: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9055 - accuracy: 0.5572 - val_loss: 1.1775 - val_accuracy: 0.5589 - lr: 6.2500e-06
# Epoch 151/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8977 - accuracy: 0.5571
# Epoch 151: val_accuracy did not improve from 0.56515
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8977 - accuracy: 0.5571 - val_loss: 1.1777 - val_accuracy: 0.5586 - lr: 6.2500e-06
# Epoch 152/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9014 - accuracy: 0.5524
# Epoch 152: val_accuracy improved from 0.56515 to 0.56585, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 1.9014 - accuracy: 0.5524 - val_loss: 1.1732 - val_accuracy: 0.5658 - lr: 6.2500e-06
# Epoch 153/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9096 - accuracy: 0.5540
# Epoch 153: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9096 - accuracy: 0.5540 - val_loss: 1.1756 - val_accuracy: 0.5607 - lr: 6.2500e-06
# Epoch 154/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9008 - accuracy: 0.5538
# Epoch 154: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9008 - accuracy: 0.5538 - val_loss: 1.1809 - val_accuracy: 0.5598 - lr: 6.2500e-06
# Epoch 155/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8922 - accuracy: 0.5557
# Epoch 155: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8922 - accuracy: 0.5557 - val_loss: 1.1730 - val_accuracy: 0.5597 - lr: 6.2500e-06
# Epoch 156/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8887 - accuracy: 0.5554
# Epoch 156: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 62ms/step - loss: 1.8887 - accuracy: 0.5554 - val_loss: 1.1776 - val_accuracy: 0.5592 - lr: 6.2500e-06
# Epoch 157/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.9131 - accuracy: 0.5518
# Epoch 157: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9129 - accuracy: 0.5520 - val_loss: 1.1702 - val_accuracy: 0.5624 - lr: 6.2500e-06
# Epoch 158/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9004 - accuracy: 0.5556
# Epoch 158: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9004 - accuracy: 0.5556 - val_loss: 1.1752 - val_accuracy: 0.5589 - lr: 6.2500e-06
# Epoch 159/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9065 - accuracy: 0.5552
# Epoch 159: val_accuracy did not improve from 0.56585
#
# Epoch 159: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9065 - accuracy: 0.5552 - val_loss: 1.1790 - val_accuracy: 0.5585 - lr: 6.2500e-06
# Epoch 160/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8986 - accuracy: 0.5573
# Epoch 160: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 62ms/step - loss: 1.8986 - accuracy: 0.5573 - val_loss: 1.1785 - val_accuracy: 0.5590 - lr: 3.1250e-06
# Epoch 161/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9281 - accuracy: 0.5511
# Epoch 161: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 62ms/step - loss: 1.9281 - accuracy: 0.5511 - val_loss: 1.1793 - val_accuracy: 0.5585 - lr: 3.1250e-06
# Epoch 162/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8804 - accuracy: 0.5575
# Epoch 162: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8804 - accuracy: 0.5575 - val_loss: 1.1745 - val_accuracy: 0.5619 - lr: 3.1250e-06
# Epoch 163/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9058 - accuracy: 0.5548
# Epoch 163: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 61ms/step - loss: 1.9058 - accuracy: 0.5548 - val_loss: 1.1750 - val_accuracy: 0.5580 - lr: 3.1250e-06
# Epoch 164/400
# 448/448 [==============================] - ETA: 0s - loss: 1.9026 - accuracy: 0.5565
# Epoch 164: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.9026 - accuracy: 0.5565 - val_loss: 1.1738 - val_accuracy: 0.5617 - lr: 3.1250e-06
# Epoch 165/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8943 - accuracy: 0.5552
# Epoch 165: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8943 - accuracy: 0.5552 - val_loss: 1.1673 - val_accuracy: 0.5625 - lr: 3.1250e-06
# Epoch 166/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8760 - accuracy: 0.5555
# Epoch 166: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 28s 61ms/step - loss: 1.8760 - accuracy: 0.5555 - val_loss: 1.1739 - val_accuracy: 0.5607 - lr: 3.1250e-06
# Epoch 167/400
# 447/448 [============================>.] - ETA: 0s - loss: 1.8950 - accuracy: 0.5591
# Epoch 167: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8952 - accuracy: 0.5592 - val_loss: 1.1757 - val_accuracy: 0.5596 - lr: 3.1250e-06
# Epoch 168/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8992 - accuracy: 0.5534
# Epoch 168: val_accuracy did not improve from 0.56585
# 448/448 [==============================] - 27s 61ms/step - loss: 1.8992 - accuracy: 0.5534 - val_loss: 1.1728 - val_accuracy: 0.5594 - lr: 3.1250e-06
# Epoch 169/400
# 448/448 [==============================] - ETA: 0s - loss: 1.8931 - accuracy: 0.5577
# Epoch 169: val_accuracy did not improve from 0.56585
#
# Epoch 169: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 448/448 [==============================] - 28s 62ms/step - loss: 1.8931 - accuracy: 0.5577 - val_loss: 1.1717 - val_accuracy: 0.5612 - lr: 3.1250e-06
# Epoch 169: early stopping

# %%
save_model = model.save('ZFNET.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model('RESNET18_Ultimate8.h5')
model.summary()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 8ms/step
# Accuracy =  0.703125

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.71875
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.40625

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5615

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 56.15234375
# Angry 957/7178 acc: 46.5
# Disgust 111/7178 acc: 67.6
# Fear 1022/7178 acc: 34.6
# Happy 1771/7178 acc: 73.4
# Neutral 1230/7178 acc: 58.9
# Sad 1246/7178 acc: 37.1
# Surprise 831/7178 acc: 80.0

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 56.15234375
# Angry 957/7178 acc: 46.5
# Disgust 111/7178 acc: 67.6
# Fear 1022/7178 acc: 34.6
# Happy 1771/7178 acc: 73.4
# Neutral 1230/7178 acc: 58.9
# Sad 1246/7178 acc: 37.1
# Surprise 831/7178 acc: 80.0

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.47      0.46      0.47       957
#      Disgust       0.33      0.68      0.45       111
#         Fear       0.41      0.35      0.37      1022
#        Happy       0.83      0.73      0.78      1771
#      Neutral       0.49      0.59      0.54      1230
#          Sad       0.46      0.37      0.41      1246
#     Surprise       0.61      0.80      0.70       831
#
#     accuracy                           0.56      7168
#    macro avg       0.51      0.57      0.53      7168
# weighted avg       0.57      0.56      0.56      7168

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 449/449 [==============================] - 28s 60ms/step - loss: 1.1510 - accuracy: 0.5606
# 113/113 [==============================] - 3s 22ms/step - loss: 1.1715 - accuracy: 0.5614

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Generate predictions for all validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate top 1 accuracy
top1_accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Top 1 Accuracy: {top1_accuracy:.2f}%")

# Calculate top 2 accuracy
top2_predictions = np.argsort(model.predict(test_img), axis=1)[:, -2:]
top2_accuracy = np.mean([1 if true_label in pred_labels else 0 for true_label, pred_labels in zip(y_true, top2_predictions)]) * 100
print(f"Top 2 Accuracy: {top2_accuracy:.2f}%")

# Calculate loss
loss = model.evaluate(test_img, test_lbl)[0]
print(f"Loss: {loss}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='macro')
print(f"Precision: {precision:.2f}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='macro')
print(f"Recall: {recall:.2f}")

# Calculate F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print(f"F1-Score: {f1:.2f}")
# Out:
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# Top 1 Accuracy: 56.18%
# 2/2 [==============================] - 0s 44ms/step
# Top 2 Accuracy: 37.50%
# 2/2 [==============================] - 0s 53ms/step - loss: 1.2997 - accuracy: 0.4844
# Loss: 1.2996506690979004
# Precision: 0.52
# Recall: 0.57
# F1-Score: 0.53

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.625
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.4375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5137

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 55ms/step
# Accuracy: 51.3671875
# Angry 293/2100 acc: 58.7
# Disgust 288/2100 acc: 18.4
# Fear 291/2100 acc: 22.3
# Happy 296/2100 acc: 84.1
# Neutral 293/2100 acc: 69.3
# Sad 292/2100 acc: 31.2
# Surprise 295/2100 acc: 74.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 51.3671875
# Angry 293/2100 acc: 58.7
# Disgust 288/2100 acc: 18.4
# Fear 291/2100 acc: 22.3
# Happy 296/2100 acc: 84.1
# Neutral 293/2100 acc: 69.3
# Sad 292/2100 acc: 31.2
# Surprise 295/2100 acc: 74.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.49      0.59      0.53       293
#      Disgust       0.62      0.18      0.28       288
#         Fear       0.46      0.22      0.30       291
#        Happy       0.61      0.84      0.71       296
#      Neutral       0.42      0.69      0.52       293
#          Sad       0.52      0.31      0.39       292
#     Surprise       0.55      0.74      0.63       295
#
#     accuracy                           0.51      2048
#    macro avg       0.52      0.51      0.48      2048
# weighted avg       0.52      0.51      0.48      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('RESNET18_Real_12.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted emotion class: neutral, probability: 0.49108707904815674
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: fear, probability: 0.8479089140892029
# 1/1 [==============================] - 0s 104ms/step
# Predicted emotion class: fear, probability: 0.5013405084609985
# 1/1 [==============================] - 0s 95ms/step
# Predicted emotion class: neutral, probability: 0.8790304660797119
# 1/1 [==============================] - 0s 100ms/step
# Predicted emotion class: happy, probability: 1.0
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: angry, probability: 0.9999905824661255
# 1/1 [==============================] - 0s 95ms/step
# Predicted emotion class: angry, probability: 0.9884737133979797
# 1/1 [==============================] - 0s 99ms/step
# Predicted emotion class: happy, probability: 0.9093870520591736
# 1/1 [==============================] - 0s 94ms/step
# Predicted emotion class: angry, probability: 0.5784042477607727

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.000001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 21, 21, 96)        14208
#
#  max_pooling2d (MaxPooling2D  (None, 10, 10, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 256)         614656
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         884992
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 7)                 28679
#
# =================================================================
# Total params: 21,589,127
# Trainable params: 21,589,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 16 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 1.7937 - accuracy: 0.5569
# Epoch 1: val_accuracy improved from -inf to 0.56696, saving model to best_model.h5
# 448/448 [==============================] - 35s 69ms/step - loss: 1.7937 - accuracy: 0.5569 - val_loss: 1.1646 - val_accuracy: 0.5670 - lr: 1.0000e-06
# Epoch 2/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7745 - accuracy: 0.5623
# Epoch 2: val_accuracy did not improve from 0.56696
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7745 - accuracy: 0.5623 - val_loss: 1.1673 - val_accuracy: 0.5645 - lr: 1.0000e-06
# Epoch 3/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7691 - accuracy: 0.5645
# Epoch 3: val_accuracy did not improve from 0.56696
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7691 - accuracy: 0.5645 - val_loss: 1.1652 - val_accuracy: 0.5638 - lr: 1.0000e-06
# Epoch 4/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.7778 - accuracy: 0.5605
# Epoch 4: val_accuracy improved from 0.56696 to 0.56724, saving model to best_model.h5
# 448/448 [==============================] - 28s 63ms/step - loss: 1.7773 - accuracy: 0.5606 - val_loss: 1.1621 - val_accuracy: 0.5672 - lr: 1.0000e-06
# Epoch 5/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7802 - accuracy: 0.5610
# Epoch 5: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 28s 61ms/step - loss: 1.7802 - accuracy: 0.5610 - val_loss: 1.1638 - val_accuracy: 0.5638 - lr: 1.0000e-06
# Epoch 6/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7615 - accuracy: 0.5681
# Epoch 6: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7615 - accuracy: 0.5681 - val_loss: 1.1608 - val_accuracy: 0.5657 - lr: 1.0000e-06
# Epoch 7/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7745 - accuracy: 0.5622
# Epoch 7: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7745 - accuracy: 0.5622 - val_loss: 1.1629 - val_accuracy: 0.5633 - lr: 1.0000e-06
# Epoch 8/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7635 - accuracy: 0.5652
# Epoch 8: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7635 - accuracy: 0.5652 - val_loss: 1.1600 - val_accuracy: 0.5668 - lr: 1.0000e-06
# Epoch 9/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7702 - accuracy: 0.5654
# Epoch 9: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7702 - accuracy: 0.5654 - val_loss: 1.1649 - val_accuracy: 0.5639 - lr: 1.0000e-06
# Epoch 10/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7690 - accuracy: 0.5653
# Epoch 10: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7690 - accuracy: 0.5653 - val_loss: 1.1643 - val_accuracy: 0.5633 - lr: 1.0000e-06
# Epoch 11/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7774 - accuracy: 0.5627
# Epoch 11: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7774 - accuracy: 0.5627 - val_loss: 1.1610 - val_accuracy: 0.5646 - lr: 1.0000e-06
# Epoch 12/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7733 - accuracy: 0.5661
# Epoch 12: val_accuracy did not improve from 0.56724
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7733 - accuracy: 0.5661 - val_loss: 1.1637 - val_accuracy: 0.5654 - lr: 1.0000e-06
# Epoch 13/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7691 - accuracy: 0.5648
# Epoch 13: val_accuracy improved from 0.56724 to 0.56780, saving model to best_model.h5
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7691 - accuracy: 0.5648 - val_loss: 1.1573 - val_accuracy: 0.5678 - lr: 1.0000e-06
# Epoch 14/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7751 - accuracy: 0.5625
# Epoch 14: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7751 - accuracy: 0.5625 - val_loss: 1.1602 - val_accuracy: 0.5661 - lr: 1.0000e-06
# Epoch 15/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7674 - accuracy: 0.5653
# Epoch 15: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7674 - accuracy: 0.5653 - val_loss: 1.1629 - val_accuracy: 0.5638 - lr: 1.0000e-06
# Epoch 16/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7782 - accuracy: 0.5632
# Epoch 16: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7782 - accuracy: 0.5632 - val_loss: 1.1600 - val_accuracy: 0.5661 - lr: 1.0000e-06
# Epoch 17/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7688 - accuracy: 0.5684
# Epoch 17: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7688 - accuracy: 0.5684 - val_loss: 1.1600 - val_accuracy: 0.5650 - lr: 1.0000e-06
# Epoch 18/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7736 - accuracy: 0.5623
# Epoch 18: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7736 - accuracy: 0.5623 - val_loss: 1.1587 - val_accuracy: 0.5672 - lr: 1.0000e-06
# Epoch 19/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7641 - accuracy: 0.5673
# Epoch 19: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7641 - accuracy: 0.5673 - val_loss: 1.1616 - val_accuracy: 0.5652 - lr: 1.0000e-06
# Epoch 20/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7633 - accuracy: 0.5663
# Epoch 20: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 60ms/step - loss: 1.7633 - accuracy: 0.5663 - val_loss: 1.1592 - val_accuracy: 0.5658 - lr: 1.0000e-06
# Epoch 21/200
# 447/448 [============================>.] - ETA: 0s - loss: 1.7608 - accuracy: 0.5649
# Epoch 21: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7607 - accuracy: 0.5647 - val_loss: 1.1604 - val_accuracy: 0.5658 - lr: 1.0000e-06
# Epoch 22/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7653 - accuracy: 0.5652
# Epoch 22: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 63ms/step - loss: 1.7653 - accuracy: 0.5652 - val_loss: 1.1605 - val_accuracy: 0.5658 - lr: 1.0000e-06
# Epoch 23/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7620 - accuracy: 0.5664
# Epoch 23: val_accuracy did not improve from 0.56780
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999987376214e-07.
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7620 - accuracy: 0.5664 - val_loss: 1.1627 - val_accuracy: 0.5646 - lr: 1.0000e-06
# Epoch 24/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7668 - accuracy: 0.5649
# Epoch 24: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7668 - accuracy: 0.5649 - val_loss: 1.1616 - val_accuracy: 0.5670 - lr: 5.0000e-07
# Epoch 25/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7556 - accuracy: 0.5688
# Epoch 25: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7556 - accuracy: 0.5688 - val_loss: 1.1615 - val_accuracy: 0.5658 - lr: 5.0000e-07
# Epoch 26/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7680 - accuracy: 0.5655
# Epoch 26: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7680 - accuracy: 0.5655 - val_loss: 1.1608 - val_accuracy: 0.5652 - lr: 5.0000e-07
# Epoch 27/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7613 - accuracy: 0.5684
# Epoch 27: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 27s 61ms/step - loss: 1.7613 - accuracy: 0.5684 - val_loss: 1.1594 - val_accuracy: 0.5653 - lr: 5.0000e-07
# Epoch 28/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7705 - accuracy: 0.5676
# Epoch 28: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 61ms/step - loss: 1.7705 - accuracy: 0.5676 - val_loss: 1.1596 - val_accuracy: 0.5665 - lr: 5.0000e-07
# Epoch 29/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7483 - accuracy: 0.5683
# Epoch 29: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7483 - accuracy: 0.5683 - val_loss: 1.1603 - val_accuracy: 0.5660 - lr: 5.0000e-07
# Epoch 30/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7664 - accuracy: 0.5689
# Epoch 30: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7664 - accuracy: 0.5689 - val_loss: 1.1615 - val_accuracy: 0.5650 - lr: 5.0000e-07
# Epoch 31/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7590 - accuracy: 0.5675
# Epoch 31: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 61ms/step - loss: 1.7590 - accuracy: 0.5675 - val_loss: 1.1639 - val_accuracy: 0.5639 - lr: 5.0000e-07
# Epoch 32/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7680 - accuracy: 0.5644
# Epoch 32: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 28s 62ms/step - loss: 1.7680 - accuracy: 0.5644 - val_loss: 1.1613 - val_accuracy: 0.5652 - lr: 5.0000e-07
# Epoch 33/200
# 448/448 [==============================] - ETA: 0s - loss: 1.7621 - accuracy: 0.5626
# Epoch 33: val_accuracy did not improve from 0.56780
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.499999993688107e-07.
# 448/448 [==============================] - 28s 63ms/step - loss: 1.7621 - accuracy: 0.5626 - val_loss: 1.1607 - val_accuracy: 0.5656 - lr: 5.0000e-07
# Epoch 33: early stopping

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 1s 45ms/step
# Accuracy =  0.46875

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.703125
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.359375

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5650

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 56.50111607142857
# Angry 957/7178 acc: 49.4
# Disgust 111/7178 acc: 52.3
# Fear 1023/7178 acc: 36.0
# Happy 1772/7178 acc: 73.0
# Neutral 1232/7178 acc: 59.3
# Sad 1242/7178 acc: 37.2
# Surprise 831/7178 acc: 79.9

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 56.50111607142857
# Angry 957/7178 acc: 49.4
# Disgust 111/7178 acc: 52.3
# Fear 1023/7178 acc: 36.0
# Happy 1772/7178 acc: 73.0
# Neutral 1232/7178 acc: 59.3
# Sad 1242/7178 acc: 37.2
# Surprise 831/7178 acc: 79.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.47      0.49      0.48       957
#      Disgust       0.59      0.52      0.55       111
#         Fear       0.40      0.36      0.38      1023
#        Happy       0.83      0.73      0.78      1772
#      Neutral       0.50      0.59      0.54      1232
#          Sad       0.45      0.37      0.41      1242
#     Surprise       0.61      0.80      0.69       831
#
#     accuracy                           0.57      7168
#    macro avg       0.55      0.55      0.55      7168
# weighted avg       0.57      0.57      0.56      7168

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.609375
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.375

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.5020

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 50.1953125
# Angry 293/2100 acc: 62.5
# Disgust 288/2100 acc: 6.2
# Fear 295/2100 acc: 24.4
# Happy 295/2100 acc: 82.7
# Neutral 289/2100 acc: 69.2
# Sad 294/2100 acc: 31.3
# Surprise 294/2100 acc: 74.5

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 50.1953125
# Angry 293/2100 acc: 62.5
# Disgust 288/2100 acc: 6.2
# Fear 295/2100 acc: 24.4
# Happy 295/2100 acc: 82.7
# Neutral 289/2100 acc: 69.2
# Sad 294/2100 acc: 31.3
# Surprise 294/2100 acc: 74.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.45      0.62      0.52       293
#      Disgust       0.78      0.06      0.12       288
#         Fear       0.45      0.24      0.32       295
#        Happy       0.62      0.83      0.71       295
#      Neutral       0.41      0.69      0.52       289
#          Sad       0.51      0.31      0.39       294
#     Surprise       0.54      0.74      0.63       294
#
#     accuracy                           0.50      2048
#    macro avg       0.54      0.50      0.46      2048
# weighted avg       0.54      0.50      0.46      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
model = load_model('best_model.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 108ms/step
# Predicted emotion class: neutral, probability: 0.7336022853851318
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: surprise, probability: 0.9353578090667725
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: surprise, probability: 0.7832949757575989
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: sad, probability: 0.6617605090141296
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: happy, probability: 0.9999998807907104
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: angry, probability: 0.9999134540557861
# 1/1 [==============================] - 0s 20ms/step
# Predicted emotion class: angry, probability: 0.9850082397460938
# 1/1 [==============================] - 0s 24ms/step
# Predicted emotion class: happy, probability: 0.8772042989730835
# 1/1 [==============================] - 0s 19ms/step
# Predicted emotion class: angry, probability: 0.554789662361145
