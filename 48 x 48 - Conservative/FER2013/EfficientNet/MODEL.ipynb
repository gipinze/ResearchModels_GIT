# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.efficientnet import EfficientNetB0

from keras.layers import Dense, Dropout, Flatten, Activation, Input, GlobalAveragePooling2D
from keras import regularizers
from keras.models import Model, load_model

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
with strategy.scope():

   # Load the VGG19 model
    base_model =  tf.keras.applications.efficientnet.EfficientNetB0( 
        weights='imagenet',
        include_top=False, 
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = False
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    x = base_model(inputs)
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(128, activation='relu')(x) 
    predictions = Dense(7, activation='softmax')(x)

    # Compile the model
    model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  efficientnetb0 (Functional)  (None, 2, 2, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 4,411,306
# Trainable params: 361,735
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
from collections import Counter


# Callbacks
counter = Counter(train_generator.classes)
max_val = float(max(counter.values()))
class_weights = {class_id: round(float(np.minimum(max_val / num_images, 3)), 2) for class_id, num_images in counter.items()}
class_weights = {class_id: float(weight) for class_id, weight in class_weights.items()}

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=20,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 2.9196 - accuracy: 0.1628
# Epoch 1: val_accuracy improved from -inf to 0.24693, saving model to best_model.h5
# 448/448 [==============================] - 293s 577ms/step - loss: 2.9196 - accuracy: 0.1628 - val_loss: 1.8451 - val_accuracy: 0.2469 - lr: 1.0000e-04
# Epoch 2/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9139 - accuracy: 0.1616
# Epoch 2: val_accuracy did not improve from 0.24693
# 448/448 [==============================] - 39s 88ms/step - loss: 2.9139 - accuracy: 0.1616 - val_loss: 1.8440 - val_accuracy: 0.1335 - lr: 1.0000e-04
# Epoch 3/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9142 - accuracy: 0.1624
# Epoch 3: val_accuracy improved from 0.24693 to 0.24707, saving model to best_model.h5
# 448/448 [==============================] - 38s 85ms/step - loss: 2.9142 - accuracy: 0.1624 - val_loss: 1.8428 - val_accuracy: 0.2471 - lr: 1.0000e-04
# Epoch 4/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9124 - accuracy: 0.1699
# Epoch 4: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 38s 84ms/step - loss: 2.9124 - accuracy: 0.1699 - val_loss: 1.8552 - val_accuracy: 0.1735 - lr: 1.0000e-04
# Epoch 5/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9118 - accuracy: 0.1548
# Epoch 5: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 37s 83ms/step - loss: 2.9118 - accuracy: 0.1548 - val_loss: 1.8483 - val_accuracy: 0.1427 - lr: 1.0000e-04
# Epoch 6/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9118 - accuracy: 0.1616
# Epoch 6: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 37s 83ms/step - loss: 2.9118 - accuracy: 0.1616 - val_loss: 1.8570 - val_accuracy: 0.1157 - lr: 1.0000e-04
# Epoch 7/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9094 - accuracy: 0.1638
# Epoch 7: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 37s 83ms/step - loss: 2.9094 - accuracy: 0.1638 - val_loss: 1.8527 - val_accuracy: 0.1158 - lr: 1.0000e-04
# Epoch 8/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9116 - accuracy: 0.1644
# Epoch 8: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 37s 82ms/step - loss: 2.9116 - accuracy: 0.1644 - val_loss: 1.8539 - val_accuracy: 0.1332 - lr: 1.0000e-04
# Epoch 9/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9110 - accuracy: 0.1578
# Epoch 9: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 37s 82ms/step - loss: 2.9110 - accuracy: 0.1578 - val_loss: 1.8515 - val_accuracy: 0.1155 - lr: 1.0000e-04
# Epoch 10/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9102 - accuracy: 0.1537
# Epoch 10: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 81ms/step - loss: 2.9102 - accuracy: 0.1537 - val_loss: 1.8415 - val_accuracy: 0.1738 - lr: 1.0000e-04
# Epoch 11/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9095 - accuracy: 0.1617
# Epoch 11: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 81ms/step - loss: 2.9095 - accuracy: 0.1617 - val_loss: 1.8460 - val_accuracy: 0.1738 - lr: 1.0000e-04
# Epoch 12/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9101 - accuracy: 0.1522
# Epoch 12: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 80ms/step - loss: 2.9101 - accuracy: 0.1522 - val_loss: 1.8484 - val_accuracy: 0.1426 - lr: 1.0000e-04
# Epoch 13/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9104 - accuracy: 0.1565
# Epoch 13: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 80ms/step - loss: 2.9104 - accuracy: 0.1565 - val_loss: 1.8495 - val_accuracy: 0.1737 - lr: 1.0000e-04
# Epoch 14/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9099 - accuracy: 0.1540
# Epoch 14: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 79ms/step - loss: 2.9099 - accuracy: 0.1540 - val_loss: 1.8479 - val_accuracy: 0.1331 - lr: 1.0000e-04
# Epoch 15/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9113 - accuracy: 0.1618
# Epoch 15: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 35s 79ms/step - loss: 2.9113 - accuracy: 0.1618 - val_loss: 1.8515 - val_accuracy: 0.1424 - lr: 1.0000e-04
# Epoch 16/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9084 - accuracy: 0.1639
# Epoch 16: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 35s 79ms/step - loss: 2.9084 - accuracy: 0.1639 - val_loss: 1.8470 - val_accuracy: 0.1426 - lr: 1.0000e-04
# Epoch 17/20
# 448/448 [==============================] - ETA: 0s - loss: 2.9099 - accuracy: 0.1607
# Epoch 17: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 36s 81ms/step - loss: 2.9099 - accuracy: 0.1607 - val_loss: 1.8472 - val_accuracy: 0.2167 - lr: 1.0000e-04
# Epoch 18/20
#  48/448 [==>...........................] - ETA: 29s - loss: 2.8993 - accuracy: 0.1657
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Train the model
# ----> 2 history = model.fit(
#       3                 train_generator,
#       4                 steps_per_epoch = num_train_imgs//batch_size,
#       5                 epochs=20,
#       6                 validation_data=validation_generator,
#       7                 validation_steps = num_test_imgs//batch_size,
#       8                 class_weight=class_weights,
#       9                 callbacks=[checkpoint, Early, lrd, csv_logger],
#      10                 verbose=1)
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\keras\engine\training.py:1401, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1399 with data_handler.catch_stop_iteration():
#    1400   data_handler._initial_step = self._maybe_load_initial_step_from_ckpt()  # pylint: disable=protected-access
# -> 1401   for step in data_handler.steps():
#    1402     with tf.profiler.experimental.Trace(
#    1403         'train',
#    1404         epoch_num=epoch,
#    1405         step_num=step,
#    1406         batch_size=batch_size,
#    1407         _r=1):
#    1408       callbacks.on_train_batch_begin(step)
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\keras\engine\data_adapter.py:1248, in DataHandler.steps(self)
#    1246 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1247   break
# -> 1248 original_spe = self._steps_per_execution.numpy().item()
#    1249 can_run_full_execution = (
#    1250     original_spe == 1 or
#    1251     self._inferred_steps is None or
#    1252     self._inferred_steps - self._current_step >=
#    1253     original_spe)
#    1255 if can_run_full_execution:
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\tensorflow\python\distribute\values.py:827, in DistributedVariable.numpy(self)
#     825 def numpy(self):
#     826   if context.executing_eagerly():
# --> 827     return self.read_value().numpy()
#     828   else:
#     829     raise NotImplementedError("DistributedVariable.numpy() is only available "
#     830                               "when eager execution is enabled.")
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\tensorflow\python\framework\ops.py:1159, in _EagerTensorBase.numpy(self)
#    1136 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1137
#    1138 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1156     NumPy dtype.
#    1157 """
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\darks\anaconda3\envs\TF290\lib\site-packages\tensorflow\python\framework\ops.py:1125, in _EagerTensorBase._numpy(self)
#    1123 def _numpy(self):
#    1124   try:
# -> 1125     return self._numpy_internal()
#    1126   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
save_model = model.save('DenseNet_50e_RAFDB_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    model = load_model('best_model.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  efficientnetb0 (Functional)  (None, 2, 2, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 4,411,306
# Trainable params: 4,369,283
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=300,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/300
# INFO:tensorflow:batch_all_reduce: 217 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 217 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 2.8627 - accuracy: 0.2278
# Epoch 1: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 74s 106ms/step - loss: 2.8627 - accuracy: 0.2278 - val_loss: 1.8933 - val_accuracy: 0.1777 - lr: 1.0000e-04
# Epoch 2/300
# 448/448 [==============================] - ETA: 0s - loss: 2.7003 - accuracy: 0.2944
# Epoch 2: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 41s 92ms/step - loss: 2.7003 - accuracy: 0.2944 - val_loss: 1.8993 - val_accuracy: 0.1491 - lr: 1.0000e-04
# Epoch 3/300
# 448/448 [==============================] - ETA: 0s - loss: 2.6057 - accuracy: 0.3372
# Epoch 3: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 93ms/step - loss: 2.6057 - accuracy: 0.3372 - val_loss: 16.2864 - val_accuracy: 0.1733 - lr: 1.0000e-04
# Epoch 4/300
# 448/448 [==============================] - ETA: 0s - loss: 2.5269 - accuracy: 0.3709
# Epoch 4: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 94ms/step - loss: 2.5269 - accuracy: 0.3709 - val_loss: 1.9412 - val_accuracy: 0.2009 - lr: 1.0000e-04
# Epoch 5/300
# 448/448 [==============================] - ETA: 0s - loss: 2.4376 - accuracy: 0.3962
# Epoch 5: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 94ms/step - loss: 2.4376 - accuracy: 0.3962 - val_loss: 1.9842 - val_accuracy: 0.1459 - lr: 1.0000e-04
# Epoch 6/300
# 448/448 [==============================] - ETA: 0s - loss: 2.3852 - accuracy: 0.4170
# Epoch 6: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 41s 92ms/step - loss: 2.3852 - accuracy: 0.4170 - val_loss: 1.9869 - val_accuracy: 0.1839 - lr: 1.0000e-04
# Epoch 7/300
# 448/448 [==============================] - ETA: 0s - loss: 2.3200 - accuracy: 0.4381
# Epoch 7: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 94ms/step - loss: 2.3200 - accuracy: 0.4381 - val_loss: 2.0734 - val_accuracy: 0.1396 - lr: 1.0000e-04
# Epoch 8/300
# 448/448 [==============================] - ETA: 0s - loss: 2.2646 - accuracy: 0.4522
# Epoch 8: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 94ms/step - loss: 2.2646 - accuracy: 0.4522 - val_loss: 2.0078 - val_accuracy: 0.1938 - lr: 1.0000e-04
# Epoch 9/300
# 448/448 [==============================] - ETA: 0s - loss: 2.2131 - accuracy: 0.4682
# Epoch 9: val_accuracy did not improve from 0.24707
# 448/448 [==============================] - 42s 93ms/step - loss: 2.2131 - accuracy: 0.4682 - val_loss: 1.8416 - val_accuracy: 0.2140 - lr: 1.0000e-04
# Epoch 10/300
# 448/448 [==============================] - ETA: 0s - loss: 2.1676 - accuracy: 0.4781
# Epoch 10: val_accuracy improved from 0.24707 to 0.39955, saving model to best_model.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 2.1676 - accuracy: 0.4781 - val_loss: 1.5299 - val_accuracy: 0.3996 - lr: 1.0000e-04
# Epoch 11/300
# 448/448 [==============================] - ETA: 0s - loss: 2.1318 - accuracy: 0.4914
# Epoch 11: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 42s 94ms/step - loss: 2.1318 - accuracy: 0.4914 - val_loss: 2.0415 - val_accuracy: 0.1819 - lr: 1.0000e-04
# Epoch 12/300
# 448/448 [==============================] - ETA: 0s - loss: 2.0820 - accuracy: 0.4996
# Epoch 12: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 41s 92ms/step - loss: 2.0820 - accuracy: 0.4996 - val_loss: 2.0281 - val_accuracy: 0.2161 - lr: 1.0000e-04
# Epoch 13/300
# 448/448 [==============================] - ETA: 0s - loss: 2.0551 - accuracy: 0.5060
# Epoch 13: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 41s 92ms/step - loss: 2.0551 - accuracy: 0.5060 - val_loss: 1.8356 - val_accuracy: 0.1911 - lr: 1.0000e-04
# Epoch 14/300
# 448/448 [==============================] - ETA: 0s - loss: 2.0193 - accuracy: 0.5182
# Epoch 14: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 41s 92ms/step - loss: 2.0193 - accuracy: 0.5182 - val_loss: 2.0776 - val_accuracy: 0.1394 - lr: 1.0000e-04
# Epoch 15/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9944 - accuracy: 0.5220
# Epoch 15: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 41s 91ms/step - loss: 1.9944 - accuracy: 0.5220 - val_loss: 2.8116 - val_accuracy: 0.1339 - lr: 1.0000e-04
# Epoch 16/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9591 - accuracy: 0.5321
# Epoch 16: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 41s 91ms/step - loss: 1.9591 - accuracy: 0.5321 - val_loss: 2.0676 - val_accuracy: 0.1939 - lr: 1.0000e-04
# Epoch 17/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9237 - accuracy: 0.5383
# Epoch 17: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 44s 98ms/step - loss: 1.9237 - accuracy: 0.5383 - val_loss: 1.9038 - val_accuracy: 0.1804 - lr: 1.0000e-04
# Epoch 18/300
# 448/448 [==============================] - ETA: 0s - loss: 1.9052 - accuracy: 0.5418
# Epoch 18: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 44s 98ms/step - loss: 1.9052 - accuracy: 0.5418 - val_loss: 1.7147 - val_accuracy: 0.3312 - lr: 1.0000e-04
# Epoch 19/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8850 - accuracy: 0.5510
# Epoch 19: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 43s 95ms/step - loss: 1.8850 - accuracy: 0.5510 - val_loss: 2.1046 - val_accuracy: 0.1673 - lr: 1.0000e-04
# Epoch 20/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8576 - accuracy: 0.5575
# Epoch 20: val_accuracy did not improve from 0.39955
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 448/448 [==============================] - 43s 95ms/step - loss: 1.8576 - accuracy: 0.5575 - val_loss: 2.2319 - val_accuracy: 0.1362 - lr: 1.0000e-04
# Epoch 21/300
# 448/448 [==============================] - ETA: 0s - loss: 1.8169 - accuracy: 0.5636
# Epoch 21: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 42s 94ms/step - loss: 1.8169 - accuracy: 0.5636 - val_loss: 2.0819 - val_accuracy: 0.1974 - lr: 5.0000e-05
# Epoch 22/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7986 - accuracy: 0.5703
# Epoch 22: val_accuracy did not improve from 0.39955
# 448/448 [==============================] - 43s 95ms/step - loss: 1.7986 - accuracy: 0.5703 - val_loss: 1.7969 - val_accuracy: 0.2833 - lr: 5.0000e-05
# Epoch 23/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7731 - accuracy: 0.5743
# Epoch 23: val_accuracy improved from 0.39955 to 0.41616, saving model to best_model.h5
# 448/448 [==============================] - 44s 97ms/step - loss: 1.7731 - accuracy: 0.5743 - val_loss: 1.5092 - val_accuracy: 0.4162 - lr: 5.0000e-05
# Epoch 24/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7655 - accuracy: 0.5795
# Epoch 24: val_accuracy did not improve from 0.41616
# 448/448 [==============================] - 44s 98ms/step - loss: 1.7655 - accuracy: 0.5795 - val_loss: 1.8470 - val_accuracy: 0.3324 - lr: 5.0000e-05
# Epoch 25/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7557 - accuracy: 0.5812
# Epoch 25: val_accuracy improved from 0.41616 to 0.46624, saving model to best_model.h5
# 448/448 [==============================] - 44s 98ms/step - loss: 1.7557 - accuracy: 0.5812 - val_loss: 1.3810 - val_accuracy: 0.4662 - lr: 5.0000e-05
# Epoch 26/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7387 - accuracy: 0.5834
# Epoch 26: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 43s 95ms/step - loss: 1.7387 - accuracy: 0.5834 - val_loss: 1.9714 - val_accuracy: 0.1872 - lr: 5.0000e-05
# Epoch 27/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7229 - accuracy: 0.5862
# Epoch 27: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 42s 93ms/step - loss: 1.7229 - accuracy: 0.5862 - val_loss: 1.7370 - val_accuracy: 0.3357 - lr: 5.0000e-05
# Epoch 28/300
# 448/448 [==============================] - ETA: 0s - loss: 1.7156 - accuracy: 0.5912
# Epoch 28: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 41s 92ms/step - loss: 1.7156 - accuracy: 0.5912 - val_loss: 1.5042 - val_accuracy: 0.4396 - lr: 5.0000e-05
# Epoch 29/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6976 - accuracy: 0.5926
# Epoch 29: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 42s 93ms/step - loss: 1.6976 - accuracy: 0.5926 - val_loss: 1.9817 - val_accuracy: 0.2181 - lr: 5.0000e-05
# Epoch 30/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6880 - accuracy: 0.5921
# Epoch 30: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 43s 95ms/step - loss: 1.6880 - accuracy: 0.5921 - val_loss: 1.7902 - val_accuracy: 0.3368 - lr: 5.0000e-05
# Epoch 31/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6707 - accuracy: 0.5969
# Epoch 31: val_accuracy did not improve from 0.46624
# 448/448 [==============================] - 44s 98ms/step - loss: 1.6707 - accuracy: 0.5969 - val_loss: 1.6038 - val_accuracy: 0.3952 - lr: 5.0000e-05
# Epoch 32/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6683 - accuracy: 0.6001
# Epoch 32: val_accuracy improved from 0.46624 to 0.47126, saving model to best_model.h5
# 448/448 [==============================] - 43s 97ms/step - loss: 1.6683 - accuracy: 0.6001 - val_loss: 1.3949 - val_accuracy: 0.4713 - lr: 5.0000e-05
# Epoch 33/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6525 - accuracy: 0.6023
# Epoch 33: val_accuracy did not improve from 0.47126
# 448/448 [==============================] - 44s 99ms/step - loss: 1.6525 - accuracy: 0.6023 - val_loss: 2.5042 - val_accuracy: 0.1599 - lr: 5.0000e-05
# Epoch 34/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6461 - accuracy: 0.6025
# Epoch 34: val_accuracy improved from 0.47126 to 0.49888, saving model to best_model.h5
# 448/448 [==============================] - 48s 106ms/step - loss: 1.6461 - accuracy: 0.6025 - val_loss: 1.3234 - val_accuracy: 0.4989 - lr: 5.0000e-05
# Epoch 35/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6367 - accuracy: 0.6058
# Epoch 35: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 46s 102ms/step - loss: 1.6367 - accuracy: 0.6058 - val_loss: 1.5433 - val_accuracy: 0.4149 - lr: 5.0000e-05
# Epoch 36/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.6128
# Epoch 36: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 43s 97ms/step - loss: 1.6095 - accuracy: 0.6128 - val_loss: 1.5180 - val_accuracy: 0.4224 - lr: 5.0000e-05
# Epoch 37/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6017 - accuracy: 0.6160
# Epoch 37: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 45s 101ms/step - loss: 1.6017 - accuracy: 0.6160 - val_loss: 2.1587 - val_accuracy: 0.1858 - lr: 5.0000e-05
# Epoch 38/300
# 448/448 [==============================] - ETA: 0s - loss: 1.6023 - accuracy: 0.6136
# Epoch 38: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 44s 98ms/step - loss: 1.6023 - accuracy: 0.6136 - val_loss: 1.5702 - val_accuracy: 0.4095 - lr: 5.0000e-05
# Epoch 39/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5789 - accuracy: 0.6202
# Epoch 39: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 42s 93ms/step - loss: 1.5789 - accuracy: 0.6202 - val_loss: 1.6416 - val_accuracy: 0.3923 - lr: 5.0000e-05
# Epoch 40/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5653 - accuracy: 0.6220
# Epoch 40: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 42s 94ms/step - loss: 1.5653 - accuracy: 0.6220 - val_loss: 1.9510 - val_accuracy: 0.2920 - lr: 5.0000e-05
# Epoch 41/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5661 - accuracy: 0.6251
# Epoch 41: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 44s 99ms/step - loss: 1.5661 - accuracy: 0.6251 - val_loss: 1.6420 - val_accuracy: 0.3951 - lr: 5.0000e-05
# Epoch 42/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5530 - accuracy: 0.6276
# Epoch 42: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 42s 94ms/step - loss: 1.5530 - accuracy: 0.6276 - val_loss: 2.1227 - val_accuracy: 0.2686 - lr: 5.0000e-05
# Epoch 43/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5482 - accuracy: 0.6273
# Epoch 43: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 43s 95ms/step - loss: 1.5482 - accuracy: 0.6273 - val_loss: 1.9188 - val_accuracy: 0.3103 - lr: 5.0000e-05
# Epoch 44/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5458 - accuracy: 0.6283
# Epoch 44: val_accuracy did not improve from 0.49888
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 448/448 [==============================] - 42s 94ms/step - loss: 1.5458 - accuracy: 0.6283 - val_loss: 1.6436 - val_accuracy: 0.3849 - lr: 5.0000e-05
# Epoch 45/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5096 - accuracy: 0.6394
# Epoch 45: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 92ms/step - loss: 1.5096 - accuracy: 0.6394 - val_loss: 2.0156 - val_accuracy: 0.3426 - lr: 2.5000e-05
# Epoch 46/300
# 448/448 [==============================] - ETA: 0s - loss: 1.5018 - accuracy: 0.6379
# Epoch 46: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 91ms/step - loss: 1.5018 - accuracy: 0.6379 - val_loss: 1.5242 - val_accuracy: 0.4595 - lr: 2.5000e-05
# Epoch 47/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4893 - accuracy: 0.6425
# Epoch 47: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 92ms/step - loss: 1.4893 - accuracy: 0.6425 - val_loss: 1.5395 - val_accuracy: 0.4682 - lr: 2.5000e-05
# Epoch 48/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4923 - accuracy: 0.6374
# Epoch 48: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 42s 94ms/step - loss: 1.4923 - accuracy: 0.6374 - val_loss: 1.9558 - val_accuracy: 0.3139 - lr: 2.5000e-05
# Epoch 49/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4809 - accuracy: 0.6433
# Epoch 49: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 43s 95ms/step - loss: 1.4809 - accuracy: 0.6433 - val_loss: 2.1267 - val_accuracy: 0.2303 - lr: 2.5000e-05
# Epoch 50/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4674 - accuracy: 0.6451
# Epoch 50: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 43s 96ms/step - loss: 1.4674 - accuracy: 0.6451 - val_loss: 1.8405 - val_accuracy: 0.3682 - lr: 2.5000e-05
# Epoch 51/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4619 - accuracy: 0.6467
# Epoch 51: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 92ms/step - loss: 1.4619 - accuracy: 0.6467 - val_loss: 2.0022 - val_accuracy: 0.3149 - lr: 2.5000e-05
# Epoch 52/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4615 - accuracy: 0.6463
# Epoch 52: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 92ms/step - loss: 1.4615 - accuracy: 0.6463 - val_loss: 1.6073 - val_accuracy: 0.4360 - lr: 2.5000e-05
# Epoch 53/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4423 - accuracy: 0.6543
# Epoch 53: val_accuracy did not improve from 0.49888
# 448/448 [==============================] - 41s 91ms/step - loss: 1.4423 - accuracy: 0.6543 - val_loss: 1.6174 - val_accuracy: 0.4558 - lr: 2.5000e-05
# Epoch 54/300
# 448/448 [==============================] - ETA: 0s - loss: 1.4498 - accuracy: 0.6487
# Epoch 54: val_accuracy did not improve from 0.49888
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 448/448 [==============================] - 43s 97ms/step - loss: 1.4498 - accuracy: 0.6487 - val_loss: 1.7722 - val_accuracy: 0.3809 - lr: 2.5000e-05
# Epoch 54: early stopping

# %%
save_model = model.save('DenseNet_100e_RAFDB_BetterWeights.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 5s 24ms/step
# Accuracy =  0.453125

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 48ms/step
# Accuracy =  0.53125
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.21875

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.3838

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 47ms/step
# Accuracy: 38.37890625
# Angry 957/7178 acc: 30.0
# Disgust 111/7178 acc: 24.3
# Fear 1024/7178 acc: 19.5
# Happy 1769/7178 acc: 29.9
# Neutral 1231/7178 acc: 41.9
# Sad 1246/7178 acc: 58.7
# Surprise 830/7178 acc: 55.5

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 38.37890625
# Angry 957/7178 acc: 30.0
# Disgust 111/7178 acc: 24.3
# Fear 1024/7178 acc: 19.5
# Happy 1769/7178 acc: 29.9
# Neutral 1231/7178 acc: 41.9
# Sad 1246/7178 acc: 58.7
# Surprise 830/7178 acc: 55.5

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.42      0.30      0.35       957
#      Disgust       0.15      0.24      0.19       111
#         Fear       0.33      0.20      0.25      1024
#        Happy       0.90      0.30      0.45      1769
#      Neutral       0.29      0.42      0.34      1231
#          Sad       0.30      0.59      0.39      1246
#     Surprise       0.52      0.56      0.54       830
#
#     accuracy                           0.38      7168
#    macro avg       0.42      0.37      0.36      7168
# weighted avg       0.49      0.38      0.39      7168

# %% [markdown]
# # Unseen batch

# %%
# model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 61ms/step
# Accuracy =  0.453125
# 2/2 [==============================] - 0s 39ms/step
# Accuracy =  0.125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.2900

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 29.00390625
# Angry 292/2100 acc: 29.8
# Disgust 292/2100 acc: 0.3
# Fear 291/2100 acc: 41.2
# Happy 289/2100 acc: 74.4
# Neutral 293/2100 acc: 22.9
# Sad 294/2100 acc: 19.0
# Surprise 297/2100 acc: 16.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 29.00390625
# Angry 292/2100 acc: 29.8
# Disgust 292/2100 acc: 0.3
# Fear 291/2100 acc: 41.2
# Happy 289/2100 acc: 74.4
# Neutral 293/2100 acc: 22.9
# Sad 294/2100 acc: 19.0
# Surprise 297/2100 acc: 16.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.41      0.30      0.35       292
#      Disgust       0.33      0.00      0.01       292
#         Fear       0.20      0.41      0.27       291
#        Happy       0.30      0.74      0.43       289
#      Neutral       0.24      0.23      0.23       293
#          Sad       0.45      0.19      0.27       294
#     Surprise       0.37      0.16      0.22       297
#
#     accuracy                           0.29      2048
#    macro avg       0.33      0.29      0.25      2048
# weighted avg       0.33      0.29      0.25      2048

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 127.5

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
