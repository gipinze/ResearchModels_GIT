# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/train/"
validation_data_dir = r"C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/FER2013/FER2013 - names/test/"

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3995</td>
#       <td>436</td>
#       <td>4097</td>
#       <td>7215</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>3171</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>958</td>
#       <td>111</td>
#       <td>1024</td>
#       <td>1774</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>831</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 28709
# 7178

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
class RepVGGBlock(layers.Layer):
      def __init__(self, out_channels, strides, kernel_size, name=None, **kwargs):
         super().__init__(name=name, **kwargs)
         self.out_channels = out_channels
         self.strides = strides
         self.kernel_size = kernel_size
         self.conv1 = Conv2D(out_channels, kernel_size, strides=strides, padding='same', use_bias=False)
         self.bn1 = BatchNormalization()
         self.relu = ReLU()
         self.conv2 = Conv2D(out_channels, kernel_size, padding='same', use_bias=False)
         self.bn2 = BatchNormalization()
         if strides == 1:
               self.identity_map = Activation('linear')
         else:
               self.identity_map = Conv2D(out_channels, kernel_size=1, strides=strides, padding='same', use_bias=False)
         
      def call(self, inputs):
         x = self.conv1(inputs)
         x = self.bn1(x)
         x = self.relu(x)
         x = self.conv2(x)
         x = self.bn2(x)
         identity_map = self.identity_map(inputs)
         return x + identity_map
      
      def get_config(self):
         config = super().get_config()
         config.update({
               'out_channels': self.out_channels,
               'strides': self.strides,
               'kernel_size': self.kernel_size,
         })
         return config

class GradientCheckpointing(layers.Layer):
      def __init__(self, checkpointing_depth, **kwargs):
         super().__init__(**kwargs)
         self.checkpointing_depth = checkpointing_depth

      def get_config(self):
         config = super().get_config()
         config.update({
               "checkpointing_depth": self.checkpointing_depth,
         })
         return config

      def call(self, inputs):
         if self.checkpointing_depth == 0:
               return inputs
         else:
               num_chunks = self.checkpointing_depth + 1
               chunk_size = inputs.shape[-1] // num_chunks
               remainder = inputs.shape[-1] % num_chunks
               if remainder != 0:
                  chunk_size += 1
               chunks = []
               for i in range(num_chunks):
                  start = i * chunk_size
                  end = start + chunk_size
                  if i == num_chunks - 1:
                     end = inputs.shape[-1]
                  chunk = inputs[..., start:end]
                  if i == 0:
                     chunk = tf.identity(chunk)
                  else:
                     chunk = tf.stop_gradient(chunk)
                  chunks.append(chunk)
         return tf.concat(chunks, axis=-1)

def create_repvgg_a0(checkpointing_depth=1):
      inputs = Input(shape=IMAGE_SHAPE)
      x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(inputs)
      x = BatchNormalization()(x)
      x = ReLU()(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=64, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)

      x = GlobalAveragePooling2D()(x)
      outputs = Dense(num_classes, activation='softmax')(x)  # number of classes in VGGFace2 dataset

      model = Model(inputs=inputs, outputs=outputs)

      return model

# %%
with strategy.scope():

   model = create_repvgg_a0()


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
# # Compute the class weights
# class_to_idx=validation_generator.class_indices
# idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
# print(idx_to_class)

# (unique, counts) = np.unique(train_generator.classes, return_counts=True)
# cw=1/counts
# cw/=cw.min()
# class_weights = {i:cwi for i,cwi in zip(unique,cw)}
# print(class_weights)

from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     



# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 448/448 [==============================] - ETA: 0s - loss: 3.1557 - accuracy: 0.2122
# Epoch 1: val_accuracy improved from -inf to 0.18276, saving model to best_model.h5
# 448/448 [==============================] - 60s 91ms/step - loss: 3.1557 - accuracy: 0.2122 - val_loss: 1.8697 - val_accuracy: 0.1828 - lr: 1.0000e-04
# Epoch 2/200
# 448/448 [==============================] - ETA: 0s - loss: 2.8541 - accuracy: 0.2589
# Epoch 2: val_accuracy improved from 0.18276 to 0.23465, saving model to best_model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 2.8541 - accuracy: 0.2589 - val_loss: 2.3980 - val_accuracy: 0.2347 - lr: 1.0000e-04
# Epoch 3/200
# 448/448 [==============================] - ETA: 0s - loss: 2.7683 - accuracy: 0.2874
# Epoch 3: val_accuracy improved from 0.23465 to 0.23535, saving model to best_model.h5
# 448/448 [==============================] - 37s 81ms/step - loss: 2.7683 - accuracy: 0.2874 - val_loss: 1.9821 - val_accuracy: 0.2354 - lr: 1.0000e-04
# Epoch 4/200
# 448/448 [==============================] - ETA: 0s - loss: 2.6645 - accuracy: 0.3293
# Epoch 4: val_accuracy improved from 0.23535 to 0.26590, saving model to best_model.h5
# 448/448 [==============================] - 37s 81ms/step - loss: 2.6645 - accuracy: 0.3293 - val_loss: 1.9547 - val_accuracy: 0.2659 - lr: 1.0000e-04
# Epoch 5/200
# 448/448 [==============================] - ETA: 0s - loss: 2.5565 - accuracy: 0.3669
# Epoch 5: val_accuracy improved from 0.26590 to 0.30008, saving model to best_model.h5
# 448/448 [==============================] - 36s 79ms/step - loss: 2.5565 - accuracy: 0.3669 - val_loss: 1.9705 - val_accuracy: 0.3001 - lr: 1.0000e-04
# Epoch 6/200
# 448/448 [==============================] - ETA: 0s - loss: 2.4719 - accuracy: 0.3951
# Epoch 6: val_accuracy improved from 0.30008 to 0.41044, saving model to best_model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 2.4719 - accuracy: 0.3951 - val_loss: 1.6821 - val_accuracy: 0.4104 - lr: 1.0000e-04
# Epoch 7/200
# 448/448 [==============================] - ETA: 0s - loss: 2.3790 - accuracy: 0.4228
# Epoch 7: val_accuracy improved from 0.41044 to 0.44043, saving model to best_model.h5
# 448/448 [==============================] - 38s 85ms/step - loss: 2.3790 - accuracy: 0.4228 - val_loss: 1.4794 - val_accuracy: 0.4404 - lr: 1.0000e-04
# Epoch 8/200
# 448/448 [==============================] - ETA: 0s - loss: 2.3136 - accuracy: 0.4395
# Epoch 8: val_accuracy did not improve from 0.44043
# 448/448 [==============================] - 37s 83ms/step - loss: 2.3136 - accuracy: 0.4395 - val_loss: 1.4410 - val_accuracy: 0.4364 - lr: 1.0000e-04
# Epoch 9/200
# 448/448 [==============================] - ETA: 0s - loss: 2.2589 - accuracy: 0.4539
# Epoch 9: val_accuracy did not improve from 0.44043
# 448/448 [==============================] - 36s 79ms/step - loss: 2.2589 - accuracy: 0.4539 - val_loss: 1.9208 - val_accuracy: 0.3097 - lr: 1.0000e-04
# Epoch 10/200
# 448/448 [==============================] - ETA: 0s - loss: 2.2196 - accuracy: 0.4674
# Epoch 10: val_accuracy did not improve from 0.44043
# 448/448 [==============================] - 35s 77ms/step - loss: 2.2196 - accuracy: 0.4674 - val_loss: 1.8957 - val_accuracy: 0.3496 - lr: 1.0000e-04
# Epoch 11/200
# 448/448 [==============================] - ETA: 0s - loss: 2.1670 - accuracy: 0.4794
# Epoch 11: val_accuracy did not improve from 0.44043
# 448/448 [==============================] - 35s 78ms/step - loss: 2.1670 - accuracy: 0.4794 - val_loss: 1.6689 - val_accuracy: 0.4001 - lr: 1.0000e-04
# Epoch 12/200
# 448/448 [==============================] - ETA: 0s - loss: 2.1299 - accuracy: 0.4918
# Epoch 12: val_accuracy improved from 0.44043 to 0.44741, saving model to best_model.h5
# 448/448 [==============================] - 36s 81ms/step - loss: 2.1299 - accuracy: 0.4918 - val_loss: 1.4446 - val_accuracy: 0.4474 - lr: 1.0000e-04
# Epoch 13/200
# 448/448 [==============================] - ETA: 0s - loss: 2.1111 - accuracy: 0.4943
# Epoch 13: val_accuracy improved from 0.44741 to 0.47656, saving model to best_model.h5
# 448/448 [==============================] - 36s 81ms/step - loss: 2.1111 - accuracy: 0.4943 - val_loss: 1.4209 - val_accuracy: 0.4766 - lr: 1.0000e-04
# Epoch 14/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0814 - accuracy: 0.5025
# Epoch 14: val_accuracy did not improve from 0.47656
# 448/448 [==============================] - 36s 80ms/step - loss: 2.0814 - accuracy: 0.5025 - val_loss: 1.5471 - val_accuracy: 0.4542 - lr: 1.0000e-04
# Epoch 15/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0530 - accuracy: 0.5132
# Epoch 15: val_accuracy improved from 0.47656 to 0.48996, saving model to best_model.h5
# 448/448 [==============================] - 36s 80ms/step - loss: 2.0530 - accuracy: 0.5132 - val_loss: 1.3838 - val_accuracy: 0.4900 - lr: 1.0000e-04
# Epoch 16/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0236 - accuracy: 0.5170
# Epoch 16: val_accuracy improved from 0.48996 to 0.50251, saving model to best_model.h5
# 448/448 [==============================] - 36s 81ms/step - loss: 2.0236 - accuracy: 0.5170 - val_loss: 1.3443 - val_accuracy: 0.5025 - lr: 1.0000e-04
# Epoch 17/200
# 448/448 [==============================] - ETA: 0s - loss: 2.0015 - accuracy: 0.5232
# Epoch 17: val_accuracy did not improve from 0.50251
# 448/448 [==============================] - 35s 78ms/step - loss: 2.0015 - accuracy: 0.5232 - val_loss: 1.6791 - val_accuracy: 0.3785 - lr: 1.0000e-04
# Epoch 18/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9767 - accuracy: 0.5299
# Epoch 18: val_accuracy did not improve from 0.50251
# 448/448 [==============================] - 35s 77ms/step - loss: 1.9767 - accuracy: 0.5299 - val_loss: 1.4895 - val_accuracy: 0.4781 - lr: 1.0000e-04
# Epoch 19/200
# 448/448 [==============================] - ETA: 0s - loss: 1.9559 - accuracy: 0.5348
# Epoch 19: val_accuracy improved from 0.50251 to 0.50516, saving model to best_model.h5
# 448/448 [==============================] - 35s 79ms/step - loss: 1.9559 - accuracy: 0.5348 - val_loss: 1.4242 - val_accuracy: 0.5052 - lr: 1.0000e-04
# Epoch 20/200
# 448/448 [==============================] - ETA: 0s - loss: 1.
- lr: 1.0000e-04
# Epoch 38/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6872 - accuracy: 0.6028
# Epoch 38: val_accuracy improved from 0.57045 to 0.57492, saving model to best_model.h5
# 448/448 [==============================] - 36s 81ms/step - loss: 1.6872 - accuracy: 0.6028 - val_loss: 1.1232 - val_accuracy: 0.5749 - lr: 1.0000e-04
# Epoch 39/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6804 - accuracy: 0.6042
# Epoch 39: val_accuracy did not improve from 0.57492
# 448/448 [==============================] - 35s 77ms/step - loss: 1.6804 - accuracy: 0.6042 - val_loss: 1.2386 - val_accuracy: 0.5485 - lr: 1.0000e-04
# Epoch 40/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6784 - accuracy: 0.6074
# Epoch 40: val_accuracy did not improve from 0.57492
# 448/448 [==============================] - 34s 75ms/step - loss: 1.6784 - accuracy: 0.6074 - val_loss: 1.3618 - val_accuracy: 0.5010 - lr: 1.0000e-04
# Epoch 41/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6448 - accuracy: 0.6118
# Epoch 41: val_accuracy did not improve from 0.57492
# 448/448 [==============================] - 34s 76ms/step - loss: 1.6448 - accuracy: 0.6118 - val_loss: 1.3196 - val_accuracy: 0.5197 - lr: 1.0000e-04
# Epoch 42/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6513 - accuracy: 0.6124
# Epoch 42: val_accuracy did not improve from 0.57492
# 448/448 [==============================] - 35s 77ms/step - loss: 1.6513 - accuracy: 0.6124 - val_loss: 1.2257 - val_accuracy: 0.5672 - lr: 1.0000e-04
# Epoch 43/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6351 - accuracy: 0.6154
# Epoch 43: val_accuracy improved from 0.57492 to 0.57659, saving model to best_model.h5
# 448/448 [==============================] - 35s 77ms/step - loss: 1.6351 - accuracy: 0.6154 - val_loss: 1.1700 - val_accuracy: 0.5766 - lr: 1.0000e-04
# Epoch 44/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6307 - accuracy: 0.6183
# Epoch 44: val_accuracy did not improve from 0.57659
# 448/448 [==============================] - 34s 77ms/step - loss: 1.6307 - accuracy: 0.6183 - val_loss: 1.1728 - val_accuracy: 0.5728 - lr: 1.0000e-04
# Epoch 45/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6231 - accuracy: 0.6161
# Epoch 45: val_accuracy did not improve from 0.57659
# 448/448 [==============================] - 34s 76ms/step - loss: 1.6231 - accuracy: 0.6161 - val_loss: 1.4660 - val_accuracy: 0.4897 - lr: 1.0000e-04
# Epoch 46/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6085 - accuracy: 0.6238
# Epoch 46: val_accuracy improved from 0.57659 to 0.58287, saving model to best_model.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 1.6085 - accuracy: 0.6238 - val_loss: 1.1728 - val_accuracy: 0.5829 - lr: 1.0000e-04
# Epoch 47/200
# 448/448 [==============================] - ETA: 0s - loss: 1.6078 - accuracy: 0.6216
# Epoch 47: val_accuracy did not improve from 0.58287
# 448/448 [==============================] - 34s 76ms/step - loss: 1.6078 - accuracy: 0.6216 - val_loss: 1.2701 - val_accuracy: 0.5416 - lr: 1.0000e-04
# Epoch 48/200
# 448/448 [==============================] - ETA: 0s - loss: 1.5952 - accuracy: 0.6265
# Epoch 48: val_accuracy did not improve from 0.58287
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 448/448 [==============================] - 33s 74ms/step - loss: 1.5952 - accuracy: 0.6265 - val_loss: 1.1275 - val_accuracy: 0.5777 - lr: 1.0000e-04
# Epoch 49/200
# 448/448 [==============================] - ETA: 0s - loss: 1.5203 - accuracy: 0.6422
# Epoch 49: val_accuracy improved from 0.58287 to 0.58915, saving model to best_model.h5
# 448/448 [==============================] - 35s 79ms/step - loss: 1.5203 - accuracy: 0.6422 - val_loss: 1.1487 - val_accuracy: 0.5891 - lr: 5.0000e-05
# Epoch 50/200
# 448/448 [==============================] - ETA: 0s - loss: 1.5032 - accuracy: 0.6500
# Epoch 50: val_accuracy improved from 0.58915 to 0.61398, saving model to best_model.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 1.5032 - accuracy: 0.6500 - val_loss: 1.0944 - val_accuracy: 0.6140 - lr: 5.0000e-05
# Epoch 51/200
# 448/448 [==============================] - ETA: 0s - loss: 1.4993 - accuracy: 0.6519
# Epoch 51: val_accuracy improved from 0.61398 to 0.62360, saving model to best_model.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 1.4993 - accuracy: 0.6519 - val_loss: 1.0525 - val_accuracy: 0.6236 - lr: 5.0000e-05
# Epoch 52/200
# 448/448 [==============================] - ETA: 0s - loss: 1.4852 - accuracy: 0.6545
# Epoch 52: val_accuracy improved from 0.62360 to 0.62835, saving model to best_model.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 1.4852 - accuracy: 0.6545 - val_loss: 1.0151 - val_accuracy: 0.6283 - lr: 5.0000e-05
# Epoch 53/200
# 448/448 [==============================] - ETA: 0s - loss: 1.4840 - accuracy: 0.6546
# Epoch 53: val_accuracy did not improve from 0.62835
# 448/448 [==============================] - 34s 75ms/step - loss: 1.4840 - accuracy: 0.6546 - val_loss: 1.0389 - val_accuracy: 0.6222 - lr: 5.0000e-05
# Epoch 54/200
# 448/448 [==============================] - ETA: 0s - loss: 1.4701 - accuracy: 0.6526
# Epoch 54: val_accuracy improved from 0.62835 to 0.63142, saving model to best_model.h5
# 448/448 [==============================] - 35s 77ms/step - loss: 1.
# Epoch 90/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2499 - accuracy: 0.7104
# Epoch 90: val_accuracy did not improve from 0.64648
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2499 - accuracy: 0.7104 - val_loss: 1.0145 - val_accuracy: 0.6420 - lr: 2.5000e-05
# Epoch 91/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2614 - accuracy: 0.7026
# Epoch 91: val_accuracy did not improve from 0.64648
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2614 - accuracy: 0.7026 - val_loss: 1.0056 - val_accuracy: 0.6461 - lr: 2.5000e-05
# Epoch 92/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2253 - accuracy: 0.7129
# Epoch 92: val_accuracy improved from 0.64648 to 0.65025, saving model to best_model.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2253 - accuracy: 0.7129 - val_loss: 0.9865 - val_accuracy: 0.6503 - lr: 1.2500e-05
# Epoch 93/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2363 - accuracy: 0.7106
# Epoch 93: val_accuracy did not improve from 0.65025
# 448/448 [==============================] - 33s 73ms/step - loss: 1.2363 - accuracy: 0.7106 - val_loss: 1.0108 - val_accuracy: 0.6429 - lr: 1.2500e-05
# Epoch 94/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2175 - accuracy: 0.7116
# Epoch 94: val_accuracy improved from 0.65025 to 0.65193, saving model to best_model.h5
# 448/448 [==============================] - 35s 77ms/step - loss: 1.2175 - accuracy: 0.7116 - val_loss: 0.9913 - val_accuracy: 0.6519 - lr: 1.2500e-05
# Epoch 95/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2199 - accuracy: 0.7134
# Epoch 95: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2199 - accuracy: 0.7134 - val_loss: 1.0108 - val_accuracy: 0.6395 - lr: 1.2500e-05
# Epoch 96/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2143 - accuracy: 0.7131
# Epoch 96: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 76ms/step - loss: 1.2143 - accuracy: 0.7131 - val_loss: 1.0171 - val_accuracy: 0.6417 - lr: 1.2500e-05
# Epoch 97/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2058 - accuracy: 0.7142
# Epoch 97: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2058 - accuracy: 0.7142 - val_loss: 0.9984 - val_accuracy: 0.6497 - lr: 1.2500e-05
# Epoch 98/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2171 - accuracy: 0.7140
# Epoch 98: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 75ms/step - loss: 1.2171 - accuracy: 0.7140 - val_loss: 1.0200 - val_accuracy: 0.6416 - lr: 1.2500e-05
# Epoch 99/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2064 - accuracy: 0.7187
# Epoch 99: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 73ms/step - loss: 1.2064 - accuracy: 0.7187 - val_loss: 0.9985 - val_accuracy: 0.6484 - lr: 1.2500e-05
# Epoch 100/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1999 - accuracy: 0.7173
# Epoch 100: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1999 - accuracy: 0.7173 - val_loss: 1.0420 - val_accuracy: 0.6366 - lr: 1.2500e-05
# Epoch 101/200
# 448/448 [==============================] - ETA: 0s - loss: 1.2005 - accuracy: 0.7177
# Epoch 101: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 75ms/step - loss: 1.2005 - accuracy: 0.7177 - val_loss: 1.0216 - val_accuracy: 0.6402 - lr: 1.2500e-05
# Epoch 102/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1979 - accuracy: 0.7169
# Epoch 102: val_accuracy did not improve from 0.65193
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1979 - accuracy: 0.7169 - val_loss: 1.0318 - val_accuracy: 0.6417 - lr: 1.2500e-05
# Epoch 103/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1884 - accuracy: 0.7225
# Epoch 103: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1884 - accuracy: 0.7225 - val_loss: 1.0028 - val_accuracy: 0.6451 - lr: 6.2500e-06
# Epoch 104/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.7182
# Epoch 104: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 75ms/step - loss: 1.1931 - accuracy: 0.7182 - val_loss: 1.0006 - val_accuracy: 0.6497 - lr: 6.2500e-06
# Epoch 105/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1791 - accuracy: 0.7232
# Epoch 105: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 75ms/step - loss: 1.1791 - accuracy: 0.7232 - val_loss: 1.0101 - val_accuracy: 0.6461 - lr: 6.2500e-06
# Epoch 106/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1833 - accuracy: 0.7199
# Epoch 106: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1833 - accuracy: 0.7199 - val_loss: 1.0077 - val_accuracy: 0.6482 - lr: 6.2500e-06
# Epoch 107/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.7245
# Epoch 107: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1760 - accuracy: 0.7245 - val_loss: 1.0133 - val_accuracy: 0.6458 - lr: 6.2500e-06
# Epoch 108/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1698 - accuracy: 0.7239
# Epoch 108: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1698 - accuracy: 0.7239 - val_loss: 1.0074 - val_accuracy: 0.6473 - lr: 6.2500e-06
# Epoch 109/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1812 - accuracy: 0.7199
# Epoch 109: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 74ms/step - loss: 1.1812 - accuracy: 0.7199 - val_loss: 1.0184 - val_accuracy: 0.6451 - lr: 6.2500e-06
# Epoch 110/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1727 - accuracy: 0.7218
# Epoch 110: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 33s 73ms/step - loss: 1.1727 - accuracy: 0.7218 - val_loss: 1.0092 - val_accuracy: 0.6500 - lr: 6.2500e-06
# Epoch 111/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1817 - accuracy: 0.7224
# Epoch 111: val_accuracy did not improve from 0.65193
# 448/448 [==============================] - 34s 75ms/step - loss: 1.1817 - accuracy: 0.7224 - val_loss: 1.0111 - val_accuracy: 0.6452 - lr: 6.2500e-06
# Epoch 112/200
# 448/448 [==============================] - ETA: 0s - loss: 1.1668 - accuracy: 0.7222
# Epoch 112: val_accuracy did not improve from 0.65193
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 448/448 [==============================] - 34s 76ms/step - loss: 1.1668 - accuracy: 0.7222 - val_loss: 1.0130 - val_accuracy: 0.6487 - lr: 6.2500e-06
# Epoch 112: early stopping

# %%
save_model = model.save('RepVGG_100e_RAFDB_BetterBalance_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 11ms/step
# Accuracy =  0.6875

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 43ms/step
# Accuracy =  0.796875
# 2/2 [==============================] - 0s 44ms/step
# Accuracy =  0.46875

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.6483

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# Accuracy: 64.82979910714286
# Angry 957/7178 acc: 63.8
# Disgust 111/7178 acc: 61.3
# Fear 1024/7178 acc: 42.1
# Happy 1772/7178 acc: 81.2
# Neutral 1229/7178 acc: 70.2
# Sad 1244/7178 acc: 46.7
# Surprise 831/7178 acc: 78.8

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 64.82979910714286
# Angry 957/7178 acc: 63.8
# Disgust 111/7178 acc: 61.3
# Fear 1024/7178 acc: 42.1
# Happy 1772/7178 acc: 81.2
# Neutral 1229/7178 acc: 70.2
# Sad 1244/7178 acc: 46.7
# Surprise 831/7178 acc: 78.8

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.54      0.64      0.59       957
#      Disgust       0.60      0.61      0.60       111
#         Fear       0.53      0.42      0.47      1024
#        Happy       0.89      0.81      0.85      1772
#      Neutral       0.55      0.70      0.62      1229
#          Sad       0.56      0.47      0.51      1244
#     Surprise       0.74      0.79      0.76       831
#
#     accuracy                           0.65      7168
#    macro avg       0.63      0.63      0.63      7168
# weighted avg       0.65      0.65      0.65      7168

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 449/449 [==============================] - 26s 58ms/step - loss: 0.7161 - accuracy: 0.7348
# 113/113 [==============================] - 3s 22ms/step - loss: 1.0139 - accuracy: 0.6481

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Worst batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.296875
# 2/2 [==============================] - 0s 42ms/step
# Accuracy =  0.078125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.1982

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# Accuracy: 19.82421875
# Angry 292/2100 acc: 48.6
# Disgust 290/2100 acc: 0.0
# Fear 291/2100 acc: 6.9
# Happy 294/2100 acc: 2.7
# Neutral 297/2100 acc: 13.1
# Sad 293/2100 acc: 64.5
# Surprise 291/2100 acc: 2.7

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 19.82421875
# Angry 292/2100 acc: 48.6
# Disgust 290/2100 acc: 0.0
# Fear 291/2100 acc: 6.9
# Happy 294/2100 acc: 2.7
# Neutral 297/2100 acc: 13.1
# Sad 293/2100 acc: 64.5
# Surprise 291/2100 acc: 2.7

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.40      0.49      0.44       292
#      Disgust       0.00      0.00      0.00       290
#         Fear       0.34      0.07      0.11       291
#        Happy       0.62      0.03      0.05       294
#      Neutral       0.21      0.13      0.16       297
#          Sad       0.13      0.65      0.22       293
#     Surprise       0.42      0.03      0.05       291
#
#     accuracy                           0.20      2048
#    macro avg       0.30      0.20      0.15      2048
# weighted avg       0.30      0.20      0.15      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
