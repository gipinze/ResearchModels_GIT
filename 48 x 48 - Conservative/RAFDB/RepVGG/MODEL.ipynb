# %%
import os
import tensorflow as tf
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"

# %%
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"],
                                           cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D, Dropout, Activation
from keras import regularizers
from keras.models import Model, load_model
from keras import layers
from keras import Input
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, HTML
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
import pandas as pd

from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

# %%
train_data_dir = r'W:/RAFDB/RAFDB/train/'
validation_data_dir = r'W:/RAFDB/RAFDB/val/'

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
CHANNELS = 3
num_classes = 7

IMAGE_SHAPE = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)

batch_size=32*strategy.num_replicas_in_sync

csv_logger = CSVLogger('log.csv', separator=',', append=True)
class_labels=['Angry', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
# Init the Image Data Generator
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Train Images
train_generator = train_data_gen.flow_from_directory(
        train_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
)

# Validation images (From Train Images)
validation_generator = valid_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical'
)
# Out:
# Found 10733 images belonging to 7 classes.
# Found 4606 images belonging to 7 classes.

# %%
img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(pd.concat([train_count, test_count], axis=0).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>606</td>
#       <td>613</td>
#       <td>248</td>
#       <td>4169</td>
#       <td>2242</td>
#       <td>1722</td>
#       <td>1133</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>261</td>
#       <td>264</td>
#       <td>107</td>
#       <td>1788</td>
#       <td>962</td>
#       <td>738</td>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_data_dir):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(validation_data_dir):
    num_test_imgs += len(files)

print(num_train_imgs)
print(num_test_imgs)
# Out:
# 10733
# 4606

# %%
plt.figure(figsize=(14, 22))
i = 1
for expression in os.listdir(train_data_dir):
    img_file = random.choice(os.listdir(train_data_dir + expression))
    img = load_img(os.path.join(train_data_dir, expression, img_file))
    plt.subplot(1, 8, i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
class RepVGGBlock(layers.Layer):
      def __init__(self, out_channels, strides, kernel_size, name=None, **kwargs):
         super().__init__(name=name, **kwargs)
         self.out_channels = out_channels
         self.strides = strides
         self.kernel_size = kernel_size
         self.conv1 = Conv2D(out_channels, kernel_size, strides=strides, padding='same', use_bias=False)
         self.bn1 = BatchNormalization()
         self.relu = ReLU()
         self.conv2 = Conv2D(out_channels, kernel_size, padding='same', use_bias=False)
         self.bn2 = BatchNormalization()
         if strides == 1:
               self.identity_map = Activation('linear')
         else:
               self.identity_map = Conv2D(out_channels, kernel_size=1, strides=strides, padding='same', use_bias=False)
         
      def call(self, inputs):
         x = self.conv1(inputs)
         x = self.bn1(x)
         x = self.relu(x)
         x = self.conv2(x)
         x = self.bn2(x)
         identity_map = self.identity_map(inputs)
         return x + identity_map
      
      def get_config(self):
         config = super().get_config()
         config.update({
               'out_channels': self.out_channels,
               'strides': self.strides,
               'kernel_size': self.kernel_size,
         })
         return config

class GradientCheckpointing(layers.Layer):
      def __init__(self, checkpointing_depth, **kwargs):
         super().__init__(**kwargs)
         self.checkpointing_depth = checkpointing_depth

      def get_config(self):
         config = super().get_config()
         config.update({
               "checkpointing_depth": self.checkpointing_depth,
         })
         return config

      def call(self, inputs):
         if self.checkpointing_depth == 0:
               return inputs
         else:
               num_chunks = self.checkpointing_depth + 1
               chunk_size = inputs.shape[-1] // num_chunks
               remainder = inputs.shape[-1] % num_chunks
               if remainder != 0:
                  chunk_size += 1
               chunks = []
               for i in range(num_chunks):
                  start = i * chunk_size
                  end = start + chunk_size
                  if i == num_chunks - 1:
                     end = inputs.shape[-1]
                  chunk = inputs[..., start:end]
                  if i == 0:
                     chunk = tf.identity(chunk)
                  else:
                     chunk = tf.stop_gradient(chunk)
                  chunks.append(chunk)
         return tf.concat(chunks, axis=-1)

def create_repvgg_a0(checkpointing_depth=1):
      inputs = Input(shape=IMAGE_SHAPE)
      x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(inputs)
      x = BatchNormalization()(x)
      x = ReLU()(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=64, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=128, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=256, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=2, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)
      x = GradientCheckpointing(checkpointing_depth)(x)
      x = RepVGGBlock(out_channels=512, strides=1, kernel_size=3)(x)

      x = GlobalAveragePooling2D()(x)
      outputs = Dense(num_classes, activation='softmax')(x)  # number of classes in VGGFace2 dataset

      model = Model(inputs=inputs, outputs=outputs)

      return model

# %%
with strategy.scope():

   model = create_repvgg_a0()


   model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

   model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 24, 24, 64)        1792
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  re_lu (ReLU)                (None, 24, 24, 64)        0
#
#  gradient_checkpointing (Gra  (None, 24, 24, 64)       0
#  dientCheckpointing)
#
#  rep_vgg_block (RepVGGBlock)  (None, 24, 24, 64)       74240
#
#  gradient_checkpointing_1 (G  (None, 24, 24, 64)       0
#  radientCheckpointing)
#
#  rep_vgg_block_1 (RepVGGBloc  (None, 12, 12, 128)      230400
#  k)
#
#  gradient_checkpointing_2 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_2 (RepVGGBloc  (None, 12, 12, 128)      295936
#  k)
#
#  gradient_checkpointing_3 (G  (None, 12, 12, 128)      0
#  radientCheckpointing)
#
#  rep_vgg_block_3 (RepVGGBloc  (None, 6, 6, 256)        919552
#  k)
#
#  gradient_checkpointing_4 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_4 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_5 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_5 (RepVGGBloc  (None, 6, 6, 256)        1181696
#  k)
#
#  gradient_checkpointing_6 (G  (None, 6, 6, 256)        0
#  radientCheckpointing)
#
#  rep_vgg_block_6 (RepVGGBloc  (None, 3, 3, 512)        3674112
#  k)
#
#  gradient_checkpointing_7 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_7 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_8 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_8 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_9 (G  (None, 3, 3, 512)        0
#  radientCheckpointing)
#
#  rep_vgg_block_9 (RepVGGBloc  (None, 3, 3, 512)        4722688
#  k)
#
#  gradient_checkpointing_10 (  (None, 3, 3, 512)        0
#  GradientCheckpointing)
#
#  rep_vgg_block_10 (RepVGGBlo  (None, 3, 3, 512)        4722688
#  ck)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 3591
#
# =================================================================
# Total params: 26,454,023
# Trainable params: 26,439,303
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
# # Compute the class weights
# class_to_idx=validation_generator.class_indices
# idx_to_class={class_to_idx[cls]:cls for cls in class_to_idx}
# print(idx_to_class)

# (unique, counts) = np.unique(train_generator.classes, return_counts=True)
# cw=1/counts
# cw/=cw.min()
# class_weights = {i:cwi for i,cwi in zip(unique,cw)}
# print(class_weights)

from collections import Counter

counter = Counter(train_generator.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : np.minimum(max_val/num_images,3) for class_id, num_images in counter.items()}     



# Callbacks

# Checkpoints
filepath="best_model.h5"
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    mode='max',
    save_freq='epoch')

#Early Stopping
Early = EarlyStopping(verbose=1, patience=20)

#Learning rate reduction
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 10, verbose = 1,factor = 0.50, min_lr = 1e-10)

# %%
# Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=200,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)
# Out:
# Epoch 1/200
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 75 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 167/167 [==============================] - ETA: 0s - loss: 4.0379 - accuracy: 0.2855
# Epoch 1: val_accuracy improved from -inf to 0.39085, saving model to best_model.h5
# 167/167 [==============================] - 35s 106ms/step - loss: 4.0379 - accuracy: 0.2855 - val_loss: 1.8696 - val_accuracy: 0.3908 - lr: 1.0000e-04
# Epoch 2/200
# 167/167 [==============================] - ETA: 0s - loss: 3.4926 - accuracy: 0.3398
# Epoch 2: val_accuracy improved from 0.39085 to 0.40163, saving model to best_model.h5
# 167/167 [==============================] - 16s 97ms/step - loss: 3.4926 - accuracy: 0.3398 - val_loss: 1.6835 - val_accuracy: 0.4016 - lr: 1.0000e-04
# Epoch 3/200
# 167/167 [==============================] - ETA: 0s - loss: 3.3783 - accuracy: 0.3572
# Epoch 3: val_accuracy did not improve from 0.40163
# 167/167 [==============================] - 15s 90ms/step - loss: 3.3783 - accuracy: 0.3572 - val_loss: 2.1611 - val_accuracy: 0.2064 - lr: 1.0000e-04
# Epoch 4/200
# 167/167 [==============================] - ETA: 0s - loss: 3.3133 - accuracy: 0.3751
# Epoch 4: val_accuracy did not improve from 0.40163
# 167/167 [==============================] - 16s 93ms/step - loss: 3.3133 - accuracy: 0.3751 - val_loss: 1.8483 - val_accuracy: 0.3028 - lr: 1.0000e-04
# Epoch 5/200
# 167/167 [==============================] - ETA: 0s - loss: 3.2506 - accuracy: 0.3931
# Epoch 5: val_accuracy improved from 0.40163 to 0.43134, saving model to best_model.h5
# 167/167 [==============================] - 17s 100ms/step - loss: 3.2506 - accuracy: 0.3931 - val_loss: 1.5536 - val_accuracy: 0.4313 - lr: 1.0000e-04
# Epoch 6/200
# 167/167 [==============================] - ETA: 0s - loss: 3.2021 - accuracy: 0.4013
# Epoch 6: val_accuracy did not improve from 0.43134
# 167/167 [==============================] - 16s 94ms/step - loss: 3.2021 - accuracy: 0.4013 - val_loss: 1.9186 - val_accuracy: 0.2835 - lr: 1.0000e-04
# Epoch 7/200
# 167/167 [==============================] - ETA: 0s - loss: 3.1538 - accuracy: 0.4156
# Epoch 7: val_accuracy did not improve from 0.43134
# 167/167 [==============================] - 16s 93ms/step - loss: 3.1538 - accuracy: 0.4156 - val_loss: 2.0998 - val_accuracy: 0.2967 - lr: 1.0000e-04
# Epoch 8/200
# 167/167 [==============================] - ETA: 0s - loss: 3.0624 - accuracy: 0.4341
# Epoch 8: val_accuracy did not improve from 0.43134
# 167/167 [==============================] - 16s 94ms/step - loss: 3.0624 - accuracy: 0.4341 - val_loss: 1.6730 - val_accuracy: 0.4036 - lr: 1.0000e-04
# Epoch 9/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9923 - accuracy: 0.4528
# Epoch 9: val_accuracy improved from 0.43134 to 0.43464, saving model to best_model.h5
# 167/167 [==============================] - 17s 102ms/step - loss: 2.9923 - accuracy: 0.4528 - val_loss: 1.5596 - val_accuracy: 0.4346 - lr: 1.0000e-04
# Epoch 10/200
# 167/167 [==============================] - ETA: 0s - loss: 2.9584 - accuracy: 0.4587
# Epoch 10: val_accuracy did not improve from 0.43464
# 167/167 [==============================] - 16s 94ms/step - loss: 2.9584 - accuracy: 0.4587 - val_loss: 1.6011 - val_accuracy: 0.4148 - lr: 1.0000e-04
# Epoch 11/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8893 - accuracy: 0.4729
# Epoch 11: val_accuracy improved from 0.43464 to 0.53037, saving model to best_model.h5
# 167/167 [==============================] - 16s 98ms/step - loss: 2.8893 - accuracy: 0.4729 - val_loss: 1.3067 - val_accuracy: 0.5304 - lr: 1.0000e-04
# Epoch 12/200
# 167/167 [==============================] - ETA: 0s - loss: 2.8224 - accuracy: 0.4950
# Epoch 12: val_accuracy did not improve from 0.53037
# 167/167 [==============================] - 16s 93ms/step - loss: 2.8224 - accuracy: 0.4950 - val_loss: 1.4956 - val_accuracy: 0.4355 - lr: 1.0000e-04
# Epoch 13/200
# 167/167 [==============================] - ETA: 0s - loss: 2.7574 - accuracy: 0.5054
# Epoch 13: val_accuracy improved from 0.53037 to 0.54643, saving model to best_model.h5
# 167/167 [==============================] - 16s 96ms/step - loss: 2.7574 - accuracy: 0.5054 - val_loss: 1.4020 - val_accuracy: 0.5464 - lr: 1.0000e-04
# Epoch 14/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6828 - accuracy: 0.5242
# Epoch 14: val_accuracy did not improve from 0.54643
# 167/167 [==============================] - 15s 92ms/step - loss: 2.6828 - accuracy: 0.5242 - val_loss: 1.3214 - val_accuracy: 0.4960 - lr: 1.0000e-04
# Epoch 15/200
# 167/167 [==============================] - ETA: 0s - loss: 2.6212 - accuracy: 0.5324
# Epoch 15: val_accuracy improved from 0.54643 to 0.55942, saving model to best_model.h5
# 167/167 [==============================] - 16s 94ms/step - loss: 2.6212 - accuracy: 0.5324 - val_loss: 1.2472 - val_accuracy: 0.5594 - lr: 1.0000e-04
# Epoch 16/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5607 - accuracy: 0.5458
# Epoch 16: val_accuracy did not improve from 0.55942
# 167/167 [==============================] - 16s 93ms/step - loss: 2.5607 - accuracy: 0.5458 - val_loss: 1.3452 - val_accuracy: 0.5156 - lr: 1.0000e-04
# Epoch 17/200
# 167/167 [==============================] - ETA: 0s - loss: 2.5039 - accuracy: 0.5568
# Epoch 17: val_accuracy did not improve from 0.55942
# 167/167 [==============================] - 15s 92ms/step - loss: 2.5039 - accuracy: 0.5568 - val_loss: 1.8714 - val_accuracy: 0.3633 - lr: 1.0000e-04
# Epoch 18/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4747 - accuracy: 0.5619
# Epoch 18: val_accuracy did not improve from 0.55942
# 167/167 [==============================] - 16s 93ms/step - loss: 2.4747 - accuracy: 0.5619 - val_loss: 1.3523 - val_accuracy: 0.5317 - lr: 1.0000e-04
# Epoch 19/200
# 167/167 [==============================] - ETA: 0s - loss: 2.4114 - accuracy: 0.5754
# Epoch 19: val_accuracy did not improve from 0.55942
# 167/167 [==============================] - 15s 91ms/step - loss: 2.4114 - accuracy: 0.5754 - val_loss: 1.4999 - val_accuracy: 0.4729 - lr: 1.0000e-04
# Epoch 20/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3576 - accuracy: 0.5867
# Epoch 20: val_accuracy improved from 0.55942 to 0.56338, saving model to best_model.h5
# 167/167 [==============================] - 16s 94ms/step - loss: 2.3576 - accuracy: 0.5867 - val_loss: 1.2288 - val_accuracy: 0.5634 - lr: 1.0000e-04
# Epoch 21/200
# 167/167 [==============================] - ETA: 0s - loss: 2.3180 - accuracy: 0.5913
# Epoch 21: val_accuracy improved from 0.56338 to 0.60497, saving model to best_model.h5
# 167/167 [==============================] - 16s 95ms/step - loss: 2.3180 - accuracy: 0.5913 - val_loss: 1.1138 - val_accuracy: 0.6050 - lr: 1.0000e-04
# Epoch 22/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2591 - accuracy: 0.6065
# Epoch 22: val_accuracy did not improve from 0.60497
# 167/167 [==============================] - 15s 91ms/step - loss: 2.2591 - accuracy: 0.6065 - val_loss: 1.1630 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 23/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2344 - accuracy: 0.6066
# Epoch 23: val_accuracy did not improve from 0.60497
# 167/167 [==============================] - 15s 91ms/step - loss: 2.2344 - accuracy: 0.6066 - val_loss: 1.1601 - val_accuracy: 0.5834 - lr: 1.0000e-04
# Epoch 24/200
# 167/167 [==============================] - ETA: 0s - loss: 2.2445 - accuracy: 0.6041
# Epoch 24: val_accuracy improved from 0.60497 to 0.62808, saving model to best_model.h5
# 167/167 [==============================] - 16s 93ms/step - loss: 2.2445 - accuracy: 0.6041 - val_loss: 1.0535 - val_accuracy: 0.6281 - lr: 1.0000e-04
# Epoch 25/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1566 - accuracy: 0.6271
# Epoch 25: val_accuracy did not improve from 0.62808
# 167/167 [==============================] - 15s 91ms/step - loss: 2.1566 - accuracy: 0.6271 - val_loss: 1.3819 - val_accuracy: 0.5361 - lr: 1.0000e-04
# Epoch 26/200
# 167/167 [==============================] - ETA: 0s - loss: 2.1434 - accuracy: 0.6264
# Epoch 26: val_accuracy did not improve from 0.62808
# 167/167 [==============================] - 15s 91ms/step - loss: 2.1434 - accuracy: 0.6264 - val_loss: 1.1569 - val_accuracy: 0.6017 - lr: 1.0000e-04
# Epoch 27/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0808 - accuracy: 0.6396
# Epoch 27: val_accuracy improved from 0.62808 to 0.63380, saving model to best_model.h5
# 167/167 [==============================] - 16s 94ms/step - loss: 2.0808 - accuracy: 0.6396 - val_loss: 1.0709 - val_accuracy: 0.6338 - lr: 1.0000e-04
# Epoch 28/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0904 - accuracy: 0.6360
# Epoch 28: val_accuracy did not improve from 0.63380
# 167/167 [==============================] - 15s 88ms/step - loss: 2.0904 - accuracy: 0.6360 - val_loss: 1.1820 - val_accuracy: 0.5874 - lr: 1.0000e-04
# Epoch 29/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0379 - accuracy: 0.6432
# Epoch 29: val_accuracy did not improve from 0.63380
# 167/167 [==============================] - 15s 89ms/step - loss: 2.0379 - accuracy: 0.6432 - val_loss: 1.0724 - val_accuracy: 0.6228 - lr: 1.0000e-04
# Epoch 30/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0188 - accuracy: 0.6466
# Epoch 30: val_accuracy did not improve from 0.63380
# 167/167 [==============================] - 15s 89ms/step - loss: 2.0188 - accuracy: 0.6466 - val_loss: 1.1605 - val_accuracy: 0.6074 - lr: 1.0000e-04
# Epoch 31/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0034 - accuracy: 0.6501
# Epoch 31: val_accuracy did not improve from 0.63380
# 167/167 [==============================] - 15s 88ms/step - loss: 2.0034 - accuracy: 0.6501 - val_loss: 1.4273 - val_accuracy: 0.5262 - lr: 1.0000e-04
# Epoch 32/200
# 167/167 [==============================] - ETA: 0s - loss: 2.0200 - accuracy: 0.6530
# Epoch 32: val_accuracy did not improve from 0.63380
# 167/167 [==============================] - 15s 89ms/step - loss: 2.0200 - accuracy: 0.6530 - val_loss: 1.1593 - val_accuracy: 0.5902 - lr: 1.0000e-04
# Epoch 33/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9451 - accuracy: 0.6614
# Epoch 33: val_accuracy improved from 0.63380 to 0.68420, saving model to best_model.h5
# 167/167 [==============================] - 15s 89ms/step - loss: 1.9451 - accuracy: 0.6614 - val_loss: 0.9163 - val_accuracy: 0.6842 - lr: 1.0000e-04
# Epoch 34/200
# 167/167 [==============================] - ETA: 0s - loss: 1.9569 - accuracy: 0.6572
# Epoch 34: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 15s 90ms/step - loss: 1.9569 - accuracy: 0.6572 - val_loss: 1.1363 - val_accuracy: 0.5979 - lr: 1.0000e-04
# Epoch 35/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8967 - accuracy: 0.6739
# Epoch 35: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 15s 88ms/step - loss: 1.8967 - accuracy: 0.6739 - val_loss: 0.9423 - val_accuracy: 0.6787 - lr: 1.0000e-04
# Epoch 36/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8788 - accuracy: 0.6717
# Epoch 36: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 15s 87ms/step - loss: 1.8788 - accuracy: 0.6717 - val_loss: 1.2305 - val_accuracy: 0.5876 - lr: 1.0000e-04
# Epoch 37/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8789 - accuracy: 0.6740
# Epoch 37: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 15s 88ms/step - loss: 1.8789 - accuracy: 0.6740 - val_loss: 1.2348 - val_accuracy: 0.5929 - lr: 1.0000e-04
# Epoch 38/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8397 - accuracy: 0.6777
# Epoch 38: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 14s 86ms/step - loss: 1.8397 - accuracy: 0.6777 - val_loss: 1.1877 - val_accuracy: 0.5832 - lr: 1.0000e-04
# Epoch 39/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8180 - accuracy: 0.6827
# Epoch 39: val_accuracy did not improve from 0.68420
# 167/167 [==============================] - 14s 86ms/step - loss: 1.8180 - accuracy: 0.6827 - val_loss: 1.2125 - val_accuracy: 0.6050 - lr: 1.0000e-04
# Epoch 40/200
# 167/167 [==============================] - ETA: 0s - loss: 1.8118 - accuracy: 0.6803
# Epoch 40: val_accuracy improved from 0.68420 to 0.69146, saving model to best_model.h5
# 167/167 [==============================] - 16s 93ms/step - loss: 1.8118 - accuracy: 0.6803 - val_loss: 0.9149 - val_accuracy: 0.6915 - lr: 1.0000e-04
# Epoch 41/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7807 - accuracy: 0.6909
# Epoch 41: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7807 - accuracy: 0.6909 - val_loss: 0.9740 - val_accuracy: 0.6774 - lr: 1.0000e-04
# Epoch 42/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7843 - accuracy: 0.6866
# Epoch 42: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7843 - accuracy: 0.6866 - val_loss: 1.4042 - val_accuracy: 0.5308 - lr: 1.0000e-04
# Epoch 43/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7492 - accuracy: 0.6971
# Epoch 43: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7492 - accuracy: 0.6971 - val_loss: 1.0313 - val_accuracy: 0.6371 - lr: 1.0000e-04
# Epoch 44/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7634 - accuracy: 0.6921
# Epoch 44: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 14s 86ms/step - loss: 1.7634 - accuracy: 0.6921 - val_loss: 0.9921 - val_accuracy: 0.6620 - lr: 1.0000e-04
# Epoch 45/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7204 - accuracy: 0.6974
# Epoch 45: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 87ms/step - loss: 1.7204 - accuracy: 0.6974 - val_loss: 1.3042 - val_accuracy: 0.5645 - lr: 1.0000e-04
# Epoch 46/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7240 - accuracy: 0.6967
# Epoch 46: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7240 - accuracy: 0.6967 - val_loss: 1.2228 - val_accuracy: 0.6048 - lr: 1.0000e-04
# Epoch 47/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7022 - accuracy: 0.7001
# Epoch 47: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7022 - accuracy: 0.7001 - val_loss: 0.9691 - val_accuracy: 0.6794 - lr: 1.0000e-04
# Epoch 48/200
# 167/167 [==============================] - ETA: 0s - loss: 1.7023 - accuracy: 0.6999
# Epoch 48: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 89ms/step - loss: 1.7023 - accuracy: 0.6999 - val_loss: 1.4501 - val_accuracy: 0.5301 - lr: 1.0000e-04
# Epoch 49/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6556 - accuracy: 0.7093
# Epoch 49: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 15s 91ms/step - loss: 1.6556 - accuracy: 0.7093 - val_loss: 0.9239 - val_accuracy: 0.6879 - lr: 1.0000e-04
# Epoch 50/200
# 167/167 [==============================] - ETA: 0s - loss: 1.6671 - accuracy: 0.7094
# Epoch 50: val_accuracy did not improve from 0.69146
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 167/167 [==============================] - 16s 98ms/step - loss: 1.6671 - accuracy: 0.7094 - val_loss: 1.0024 - val_accuracy: 0.6611 - lr: 1.0000e-04
# Epoch 51/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5403 - accuracy: 0.7336
# Epoch 51: val_accuracy did not improve from 0.69146
# 167/167 [==============================] - 19s 87ms/step - loss: 1.5403 - accuracy: 0.7336 - val_loss: 1.0307 - val_accuracy: 0.6428 - lr: 5.0000e-05
# Epoch 52/200
# 167/167 [==============================] - ETA: 0s - loss: 1.5004 - accuracy: 0.7398
# Epoch 52: val_accuracy improved from 0.69146 to 0.70335, saving model to best_model.h5
# 167/167 [==============================] - 15s 92ms/step - loss: 1.5004 - accuracy: 0.7398 - val_loss: 0.8519 - val_accuracy: 0.7033 - lr: 5.0000e-05
# Epoch 53/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4843 - accuracy: 0.7390
# Epoch 53: val_accuracy improved from 0.70335 to 0.71567, saving model to best_model.h5
# 167/167 [==============================] - 16s 93ms/step - loss: 1.4843 - accuracy: 0.7390 - val_loss: 0.8236 - val_accuracy: 0.7157 - lr: 5.0000e-05
# Epoch 54/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4783 - accuracy: 0.7436
# Epoch 54: val_accuracy did not improve from 0.71567
# 167/167 [==============================] - 15s 88ms/step - loss: 1.4783 - accuracy: 0.7436 - val_loss: 0.9422 - val_accuracy: 0.6912 - lr: 5.0000e-05
# Epoch 55/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4760 - accuracy: 0.7412
# Epoch 55: val_accuracy did not improve from 0.71567
# 167/167 [==============================] - 15s 87ms/step - loss: 1.4760 - accuracy: 0.7412 - val_loss: 0.9698 - val_accuracy: 0.6686 - lr: 5.0000e-05
# Epoch 56/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4544 - accuracy: 0.7421
# Epoch 56: val_accuracy improved from 0.71567 to 0.71875, saving model to best_model.h5
# 167/167 [==============================] - 15s 92ms/step - loss: 1.4544 - accuracy: 0.7421 - val_loss: 0.8229 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 57/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4426 - accuracy: 0.7420
# Epoch 57: val_accuracy did not improve from 0.71875
# 167/167 [==============================] - 15s 90ms/step - loss: 1.4426 - accuracy: 0.7420 - val_loss: 0.9494 - val_accuracy: 0.6794 - lr: 5.0000e-05
# Epoch 58/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4431 - accuracy: 0.7422
# Epoch 58: val_accuracy improved from 0.71875 to 0.73041, saving model to best_model.h5
# 167/167 [==============================] - 15s 92ms/step - loss: 1.4431 - accuracy: 0.7422 - val_loss: 0.8069 - val_accuracy: 0.7304 - lr: 5.0000e-05
# Epoch 59/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4172 - accuracy: 0.7533
# Epoch 59: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 89ms/step - loss: 1.4172 - accuracy: 0.7533 - val_loss: 0.9318 - val_accuracy: 0.6956 - lr: 5.0000e-05
# Epoch 60/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4009 - accuracy: 0.7490
# Epoch 60: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 88ms/step - loss: 1.4009 - accuracy: 0.7490 - val_loss: 0.9453 - val_accuracy: 0.6783 - lr: 5.0000e-05
# Epoch 61/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3916 - accuracy: 0.7573
# Epoch 61: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 87ms/step - loss: 1.3916 - accuracy: 0.7573 - val_loss: 0.8264 - val_accuracy: 0.7194 - lr: 5.0000e-05
# Epoch 62/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4044 - accuracy: 0.7513
# Epoch 62: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 90ms/step - loss: 1.4044 - accuracy: 0.7513 - val_loss: 0.9685 - val_accuracy: 0.6783 - lr: 5.0000e-05
# Epoch 63/200
# 167/167 [==============================] - ETA: 0s - loss: 1.4087 - accuracy: 0.7545
# Epoch 63: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 92ms/step - loss: 1.4087 - accuracy: 0.7545 - val_loss: 0.8260 - val_accuracy: 0.7170 - lr: 5.0000e-05
# Epoch 64/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3916 - accuracy: 0.7588
# Epoch 64: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 89ms/step - loss: 1.3916 - accuracy: 0.7588 - val_loss: 0.8893 - val_accuracy: 0.7099 - lr: 5.0000e-05
# Epoch 65/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3371 - accuracy: 0.7650
# Epoch 65: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 16s 93ms/step - loss: 1.3371 - accuracy: 0.7650 - val_loss: 0.8656 - val_accuracy: 0.7113 - lr: 5.0000e-05
# Epoch 66/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3413 - accuracy: 0.7641
# Epoch 66: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 16s 97ms/step - loss: 1.3413 - accuracy: 0.7641 - val_loss: 1.0098 - val_accuracy: 0.6730 - lr: 5.0000e-05
# Epoch 67/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3524 - accuracy: 0.7670
# Epoch 67: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 22s 135ms/step - loss: 1.3524 - accuracy: 0.7670 - val_loss: 0.8668 - val_accuracy: 0.7069 - lr: 5.0000e-05
# Epoch 68/200
# 167/167 [==============================] - ETA: 0s - loss: 1.3246 - accuracy: 0.7643
# Epoch 68: val_accuracy did not improve from 0.73041
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 167/167 [==============================] - 15s 88ms/step - loss: 1.3246 - accuracy: 0.7643 - val_loss: 0.9558 - val_accuracy: 0.6904 - lr: 5.0000e-05
# Epoch 69/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2636 - accuracy: 0.7815
# Epoch 69: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 88ms/step - loss: 1.2636 - accuracy: 0.7815 - val_loss: 0.7986 - val_accuracy: 0.7291 - lr: 2.5000e-05
# Epoch 70/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2492 - accuracy: 0.7795
# Epoch 70: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 14s 86ms/step - loss: 1.2492 - accuracy: 0.7795 - val_loss: 0.8613 - val_accuracy: 0.7126 - lr: 2.5000e-05
# Epoch 71/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2160 - accuracy: 0.7831
# Epoch 71: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 88ms/step - loss: 1.2160 - accuracy: 0.7831 - val_loss: 0.8512 - val_accuracy: 0.7234 - lr: 2.5000e-05
# Epoch 72/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1861 - accuracy: 0.7885
# Epoch 72: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 17s 101ms/step - loss: 1.1861 - accuracy: 0.7885 - val_loss: 0.9052 - val_accuracy: 0.7051 - lr: 2.5000e-05
# Epoch 73/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2412 - accuracy: 0.7849
# Epoch 73: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 87ms/step - loss: 1.2412 - accuracy: 0.7849 - val_loss: 0.9131 - val_accuracy: 0.7044 - lr: 2.5000e-05
# Epoch 74/200
# 167/167 [==============================] - ETA: 0s - loss: 1.2075 - accuracy: 0.7865
# Epoch 74: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 91ms/step - loss: 1.2075 - accuracy: 0.7865 - val_loss: 0.8816 - val_accuracy: 0.7150 - lr: 2.5000e-05
# Epoch 75/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1929 - accuracy: 0.7850
# Epoch 75: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 87ms/step - loss: 1.1929 - accuracy: 0.7850 - val_loss: 0.8625 - val_accuracy: 0.7203 - lr: 2.5000e-05
# Epoch 76/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1882 - accuracy: 0.7907
# Epoch 76: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 88ms/step - loss: 1.1882 - accuracy: 0.7907 - val_loss: 0.9037 - val_accuracy: 0.7025 - lr: 2.5000e-05
# Epoch 77/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1818 - accuracy: 0.7890
# Epoch 77: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 92ms/step - loss: 1.1818 - accuracy: 0.7890 - val_loss: 1.0031 - val_accuracy: 0.6655 - lr: 2.5000e-05
# Epoch 78/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1832 - accuracy: 0.7939
# Epoch 78: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 15s 91ms/step - loss: 1.1832 - accuracy: 0.7939 - val_loss: 0.9477 - val_accuracy: 0.7007 - lr: 2.5000e-05
# Epoch 79/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1906 - accuracy: 0.7877
# Epoch 79: val_accuracy did not improve from 0.73041
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 167/167 [==============================] - 15s 90ms/step - loss: 1.1906 - accuracy: 0.7877 - val_loss: 0.9447 - val_accuracy: 0.6893 - lr: 2.5000e-05
# Epoch 80/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1485 - accuracy: 0.7947
# Epoch 80: val_accuracy did not improve from 0.73041
# 167/167 [==============================] - 20s 121ms/step - loss: 1.1485 - accuracy: 0.7947 - val_loss: 0.8425 - val_accuracy: 0.7236 - lr: 1.2500e-05
# Epoch 81/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1387 - accuracy: 0.7995
# Epoch 81: val_accuracy improved from 0.73041 to 0.73526, saving model to best_model.h5
# 167/167 [==============================] - 18s 109ms/step - loss: 1.1387 - accuracy: 0.7995 - val_loss: 0.8158 - val_accuracy: 0.7353 - lr: 1.2500e-05
# Epoch 82/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1062 - accuracy: 0.8035
# Epoch 82: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 15s 91ms/step - loss: 1.1062 - accuracy: 0.8035 - val_loss: 0.8095 - val_accuracy: 0.7337 - lr: 1.2500e-05
# Epoch 83/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1089 - accuracy: 0.7995
# Epoch 83: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 14s 86ms/step - loss: 1.1089 - accuracy: 0.7995 - val_loss: 0.8513 - val_accuracy: 0.7287 - lr: 1.2500e-05
# Epoch 84/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1367 - accuracy: 0.7996
# Epoch 84: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 14s 86ms/step - loss: 1.1367 - accuracy: 0.7996 - val_loss: 0.8292 - val_accuracy: 0.7256 - lr: 1.2500e-05
# Epoch 85/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1041 - accuracy: 0.8001
# Epoch 85: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 14s 86ms/step - loss: 1.1041 - accuracy: 0.8001 - val_loss: 0.8533 - val_accuracy: 0.7265 - lr: 1.2500e-05
# Epoch 86/200
# 167/167 [==============================] - ETA: 0s - loss: 1.0785 - accuracy: 0.8045
# Epoch 86: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 15s 90ms/step - loss: 1.0785 - accuracy: 0.8045 - val_loss: 0.8878 - val_accuracy: 0.7176 - lr: 1.2500e-05
# Epoch 87/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1060 - accuracy: 0.8004
# Epoch 87: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 15s 89ms/step - loss: 1.1060 - accuracy: 0.8004 - val_loss: 0.8408 - val_accuracy: 0.7251 - lr: 1.2500e-05
# Epoch 88/200
# 167/167 [==============================] - ETA: 0s - loss: 1.0977 - accuracy: 0.8057
# Epoch 88: val_accuracy did not improve from 0.73526
# 167/167 [==============================] - 15s 87ms/step - loss: 1.0977 - accuracy: 0.8057 - val_loss: 0.9022 - val_accuracy: 0.7075 - lr: 1.2500e-05
# Epoch 89/200
# 167/167 [==============================] - ETA: 0s - loss: 1.1134 - accuracy: 0.8033
# Epoch 89: val_accuracy did not improve from 0.73526
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 167/167 [==============================] - 15s 87ms/step - loss: 1.1134 - accuracy: 0.8033 - val_loss: 0.8743 - val_accuracy: 0.7143 - lr: 1.2500e-05
# Epoch 89: early stopping

# %%
save_model = model.save('RepVGG_100e_RAFDB_BetterBalance_.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = load_model("best_model_076.h5")

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 2/2 [==============================] - 2s 16ms/step
# Accuracy =  0.65625

# %% [markdown]
# # Model Evaluation

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# 2/2 [==============================] - 0s 40ms/step
# Accuracy =  0.859375
# 2/2 [==============================] - 0s 61ms/step
# Accuracy =  0.578125

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.7174

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 38ms/step
# Accuracy: 71.74295774647888
# Angry 254/4606 acc: 72.0
# Disgust 256/4606 acc: 35.9
# Fear 107/4606 acc: 43.0
# Happy 1764/4606 acc: 75.7
# Neutral 952/4606 acc: 73.2
# Sad 731/4606 acc: 73.6
# Surprise 480/4606 acc: 76.9

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 71.74295774647888
# Angry 254/4606 acc: 72.0
# Disgust 256/4606 acc: 35.9
# Fear 107/4606 acc: 43.0
# Happy 1764/4606 acc: 75.7
# Neutral 952/4606 acc: 73.2
# Sad 731/4606 acc: 73.6
# Surprise 480/4606 acc: 76.9

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.53      0.72      0.61       254
#      Disgust       0.46      0.36      0.40       256
#         Fear       0.36      0.43      0.39       107
#        Happy       0.96      0.76      0.85      1764
#      Neutral       0.67      0.73      0.70       952
#          Sad       0.61      0.74      0.67       731
#     Surprise       0.66      0.77      0.71       480
#
#     accuracy                           0.72      4544
#    macro avg       0.61      0.64      0.62      4544
# weighted avg       0.74      0.72      0.72      4544

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_generator)
test_evaluation = model.evaluate(validation_generator)
# Out:
# 168/168 [==============================] - 10s 59ms/step - loss: 1.3444 - accuracy: 0.5136
# 72/72 [==============================] - 2s 24ms/step - loss: 0.7043 - accuracy: 0.7586

# %% [markdown]
# # Unseen batch

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 2100 images belonging to 7 classes.

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# Best batch saved
# Worst batch saved
# 2/2 [==============================] - 0s 78ms/step
# Accuracy =  0.546875
# 2/2 [==============================] - 0s 36ms/step
# Accuracy =  0.3125

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))
# Out:
# Average accuracy: 0.4551

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# Accuracy: 45.5078125
# Angry 293/2100 acc: 63.1
# Disgust 294/2100 acc: 25.5
# Fear 294/2100 acc: 20.1
# Happy 292/2100 acc: 47.3
# Neutral 290/2100 acc: 64.1
# Sad 293/2100 acc: 30.7
# Surprise 292/2100 acc: 68.2

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")
# Out:
# Accuracy: 45.5078125
# Angry 293/2100 acc: 63.1
# Disgust 294/2100 acc: 25.5
# Fear 294/2100 acc: 20.1
# Happy 292/2100 acc: 47.3
# Neutral 290/2100 acc: 64.1
# Sad 293/2100 acc: 30.7
# Surprise 292/2100 acc: 68.2

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.48      0.63      0.54       293
#      Disgust       0.56      0.26      0.35       294
#         Fear       0.40      0.20      0.27       294
#        Happy       0.71      0.47      0.57       292
#      Neutral       0.47      0.64      0.54       290
#          Sad       0.30      0.31      0.30       293
#     Surprise       0.41      0.68      0.51       292
#
#     accuracy                           0.46      2048
#    macro avg       0.47      0.46      0.44      2048
# weighted avg       0.47      0.46      0.44      2048

# %% [markdown]
# # Test with Images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces4.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predicted emotion class: happy, probability: 0.9999638795852661
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: fear, probability: 0.705699622631073
# 1/1 [==============================] - 0s 109ms/step
# Predicted emotion class: disgust, probability: 0.5174249410629272
# 1/1 [==============================] - 0s 106ms/step
# Predicted emotion class: fear, probability: 0.979381799697876
# 1/1 [==============================] - 0s 96ms/step
# Predicted emotion class: sad, probability: 0.9469862580299377
# 1/1 [==============================] - 0s 103ms/step
# Predicted emotion class: disgust, probability: 0.6935069561004639

# %% [markdown]
# # Fine Tunning

# %%
with strategy.scope():

    # model = load_model('training_test_2GPU3.h5')
    
    # # Load the VGG19 model
    # base_model = VGG16(
    #     weights='imagenet', 
    #     include_top=False, 
    #     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    # Freeze the layers
    for layer in base_model.layers:
        layer.trainable = True
        
    # # # Unfreeze the last 5 layers
    # n = 5
    # for layer in base_model.layers[-n:]:
    #     layer.trainable = True

    # Create the new model on top
    # inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    # x = base_model(inputs)
    # x = Flatten()(x)
    # x = Dense(256, activation='relu')(x)
    # x = Dropout(0.2)(x)
    # x = Dense(128, activation='relu')(x) 
    # predictions = Dense(7, activation='softmax')(x)

    # # Compile the model
    # model = Model(inputs=inputs, outputs=predictions)


    model.compile(optimizer=Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999), loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

# %%
    # Train the model
history = model.fit(
                train_generator,
                steps_per_epoch = num_train_imgs//batch_size,
                epochs=50,
                validation_data=validation_generator,
                validation_steps = num_test_imgs//batch_size,
                class_weight=class_weights,
                callbacks=[checkpoint, Early, lrd, csv_logger],
                verbose=1)

# %%
save_model = model.save('VGG16_VGGFACE_100e_TF_FT_FER.h5')

# %% [markdown]
# # Fine Tunning model evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import random

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = validation_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = validation_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(validation_generator.n // batch_size):
    test_img, test_lbl = validation_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = validation_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{validation_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Unseen batch

# %%
model = load_model("VGG16_VGGFACE_100e_TF_FT_FER.h5")

# %%
test_data_dir = r'C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7'

# %%
# Validation images (From Train Images)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(directory = test_data_dir,
                                                    target_size=(48, 48),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# %%
img, label = test_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
import pickle

# Save the best and worst batches
best_val_acc = 0
worst_val_acc = 1
for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    val_acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_batch = (test_img, test_lbl)
        with open('best_batch.pickle', 'wb') as f:
            pickle.dump(best_batch, f)
            print("Best batch saved")
    if val_acc < worst_val_acc:
        worst_val_acc = val_acc
        worst_batch = (test_img, test_lbl)
        with open('worst_batch.pickle', 'wb') as f:
            pickle.dump(worst_batch, f)
            print("Worst batch saved")

# Load the best batch
with open('best_batch.pickle', 'rb') as f:
    best_batch = pickle.load(f)
test_img, test_lbl = best_batch

# Generate predictions for the best batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the best batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# Load the worst batch
with open('worst_batch.pickle', 'rb') as f:
    worst_batch = pickle.load(f)
test_img, test_lbl = worst_batch

# Generate predictions for the worst batch
predictions=model.predict(test_img)
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# Compute accuracy and confusion matrix for the worst batch
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
# Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()

# %%
total_acc = 0
num_batches = test_generator.n // batch_size

for i in range(num_batches):
    test_img, test_lbl = test_generator.__getitem__(i)
    acc = model.evaluate(test_img, test_lbl, verbose=0)[1]
    total_acc += acc

avg_acc = total_acc / num_batches
print("Average accuracy: {:.4f}".format(avg_acc))

# %%
from sklearn.metrics import accuracy_score, classification_report

# Get the true labels and predictions for all the validation data
y_true = []
y_pred = []

for i in range(test_generator.n // batch_size):
    test_img, test_lbl = test_generator.__getitem__(i)
    pred_lbl = model.predict(test_img)
    y_true.extend(np.argmax(test_lbl, axis=1))
    y_pred.extend(np.argmax(pred_lbl, axis=1))

# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %% [markdown]
# # Accuracy global and per class

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y_true, y_pred) * 100
print(f"Accuracy: {accuracy}")

# Calculate the accuracy for each class
class_names = test_generator.class_indices.keys()
class_accuracy = {}

for i, class_name in enumerate(class_names):
    class_idx = i
    class_mask = [True if label == class_idx else False for label in y_true]
    class_true = np.array(y_true)[class_mask]
    class_pred = np.array(y_pred)[class_mask]
    class_acc = accuracy_score(class_true, class_pred) * 100
    class_accuracy[class_name] = class_acc
    print(f"{class_name} {len(class_true)}/{test_generator.n} acc: {class_acc:.1f}")

# %%
# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

# Print the classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, annot=True, fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Test it with real images

# %%
import cv2
import numpy as np
from keras.models import load_model

# # Load the pre-trained model
# model = load_model('Sequential_50e.h5')

# Define the emotion classes
emotion_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load the image and convert it to RGB format
image = cv2.imread("C:/Users/darks/Downloads/faces3.jpg")
# image = cv2.imread("C:/Users/darks/Desktop/Emotion AI/Emotion Recognition/DATASETS/Batch_Ready 7/Angry/anger-69.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.3, 5)

# Loop through each detected face
for (x, y, w, h) in faces:
    # Extract the face ROI
    face_image = rgb_image[y:y+h, x:x+w, :]

    # Resize the face ROI to 48x48 pixels
    resized_image = cv2.resize(face_image, (48, 48))

    # Convert the resized image to a numpy array
    normalized_image = resized_image.astype('float32') / 255.0

    # Make a prediction on the normalized image using the loaded model
    predictions = model.predict(np.expand_dims(normalized_image, axis=0))

    # Get the index of the highest predicted class
    predicted_class_index = np.argmax(predictions)

    # Print the predicted emotion class and its corresponding probability
    predicted_class = emotion_classes[predicted_class_index]
    predicted_probability = predictions[0][predicted_class_index]
    print(f"Predicted emotion class: {predicted_class}, probability: {predicted_probability}")

    # Draw a rectangle around the detected face
    cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 1)

    # Display the predicted emotion class and its corresponding probability on the image
    text = f"{predicted_class} ({predicted_probability:.2f})"
    cv2.putText(rgb_image, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)


# Convert the image from BGR to RGB format
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Resize the image to 450x450 pixels
rgb_image = cv2.resize(rgb_image, (1800, 1200))

# Display the image with the detected faces and their predictions
cv2.imshow("Image", rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
